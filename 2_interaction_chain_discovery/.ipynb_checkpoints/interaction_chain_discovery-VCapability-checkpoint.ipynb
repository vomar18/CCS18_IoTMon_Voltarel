# %% [markdown]
# ##  interaction chain discovery algorithm - capability version
#
# this algorithm is based on the table 3, that associated the capabilities to channels

# %%
import json   # for read the JSON file
import numpy as np

# %%
file = open("../1_application_analysis/1_Intra_app_Analysis/trigger-action.JSON","r") # read all the capability extrapolated from the apps
trigger_action = json.load(file)
print("tot app analysed:",len(trigger_action.keys()))
# Out:
# tot app analysed: 86

# %%
# you need the AP_tr,ac all trigger-action behaviour tuples in applications (cap 4.3.2 - p835)
list_trigger_action = []
for app in trigger_action.keys():         # for every app analysed
    for trigger in trigger_action[app].keys():      # for every trigger channel of that app
            for action in trigger_action[app][trigger]: # for every action 
                check = any(element == [trigger, action] for element in list_trigger_action)
                if not check: # if not duplicate
                    list_trigger_action.append([trigger, action]) # save capability (the channel) and action
list_trigger_action.sort()
list_trigger_action
# Out:
# [['accelerationSensor', ['colorControl', 'colorControl.each']],
#  ['accelerationSensor', ['colorControl', 'colorControl.setColor']],
#  ['accelerationSensor', ['imageCapture', 'imageCapture.take']],
#  ['accelerationSensor', ['momentary', 'momentary.push']],
#  ['accelerationSensor', ['number', 'number.times']],
#  ['accelerationSensor', ['sendAction', 'sendNotificationToContacts']],
#  ['accelerationSensor', ['sendAction', 'sendPush']],
#  ['accelerationSensor', ['sendAction', 'sendSms']],
#  ['accelerationSensor', ['switch', 'switch.on']],
#  ['alarm', ['alarm', 'alarm.off']],
#  ['app', ['alarm', 'alarm.off']],
#  ['app', ['colorControl', 'colorControl.each']],
#  ['app', ['colorControl', 'colorControl.setColor']],
#  ['app', ['doorControl', 'doorControl.each']],
#  ['app', ['lock', 'lock.each']],
#  ['app', ['switch', 'switch.each']],
#  ['app', ['switch', 'switch.off']],
#  ['app', ['switch', 'switch.on']],
#  ['app', ['thermostat', 'thermostat.each']],
#  ['app', ['thermostat', 'thermostat.poll']],
#  ['app', ['thermostat', 'thermostat.setCoolingSetpoint']],
#  ['app', ['thermostat', 'thermostat.setHeatingSetpoint']],
#  ['beacon', ['lock', 'lock.lock']],
#  ['beacon', ['lock', 'lock.unlock']],
#  ['beacon', ['switch', 'switch.off']],
#  ['beacon', ['switch', 'switch.on']],
#  ['button', ['colorControl', 'colorControl.each']],
#  ['button', ['colorControl', 'colorControl.off']],
#  ['button', ['colorControl', 'colorControl.on']],
#  ['button', ['colorControl', 'colorControl.setColor']],
#  ['button', ['colorControl', 'colorControl.setLevel']],
#  ['button', ['locationMode', 'locationMode.setLocationMode']],
#  ['button', ['sendAction', 'sendNotificationToContacts']],
#  ['button', ['sendAction', 'sendPush']],
#  ['button', ['sendAction', 'sendSms']],
#  ['carbonMonoxideDetector', ['sendAction', 'sendNotificationToContacts']],
#  ['carbonMonoxideDetector', ['thermostat', 'thermostat.setThermostatMode']],
#  ['contactSensor', ['alarm', 'alarm.both']],
#  ['contactSensor', ['alarm', 'alarm.strobe']],
#  ['contactSensor', ['colorControl', 'colorControl.each']],
#  ['contactSensor', ['colorControl', 'colorControl.off']],
#  ['contactSensor', ['colorControl', 'colorControl.setColor']],
#  ['contactSensor', ['colorControl', 'colorControl.setHue']],
#  ['contactSensor', ['imageCapture', 'imageCapture.take']],
#  ['contactSensor', ['locationMode', 'locationMode.setLocationMode']],
#  ['contactSensor', ['momentary', 'momentary.push']],
#  ['contactSensor', ['number', 'number.times']],
#  ['contactSensor', ['sendAction', 'sendNotificationToContacts']],
#  ['contactSensor', ['sendAction', 'sendPush']],
#  ['contactSensor', ['sendAction', 'sendSms']],
#  ['contactSensor', ['switch', 'switch.currentValue']],
#  ['contactSensor', ['switch', 'switch.off']],
#  ['contactSensor', ['switch', 'switch.on']],
#  ['contactSensor', ['thermostat', 'thermostat.currentValue']],
#  ['contactSensor', ['thermostat', 'thermostat.off']],
#  ['contactSensor', ['thermostat', 'thermostat.setThermostatMode']],
#  ['device.jawboneUser', ['colorControl', 'colorControl.each']],
#  ['device.jawboneUser', ['colorControl', 'colorControl.setColor']],
#  ['device.jawboneUser', ['musicPlayer', 'musicPlayer.on']],
#  ['device.jawboneUser', ['musicPlayer', 'musicPlayer.playTrack']],
#  ['device.jawboneUser', ['musicPlayer', 'musicPlayer.playTrackAndResume']],
#  ['device.jawboneUser', ['musicPlayer', 'musicPlayer.playTrackAtVolume']],
#  ['device.jawboneUser', ['sendAction', 'sendNotificationToContacts']],
#  ['device.jawboneUser', ['switch', 'switch.each']],
#  ['illuminanceMeasurement', ['switch', 'switch.off']],
#  ['illuminanceMeasurement', ['switch', 'switch.on']],
#  ['location', ['lock', 'lock.each']],
#  ['location', ['switch', 'switch.each']],
#  ['location', ['switch', 'switch.off']],
#  ['location', ['switch', 'switch.on']],
#  ['location', ['thermostat', 'thermostat.each']],
#  ['location', ['thermostat', 'thermostat.poll']],
#  ['location', ['thermostat', 'thermostat.setCoolingSetpoint']],
#  ['location', ['thermostat', 'thermostat.setHeatingSetpoint']],
#  ['motionSensor', ['alarm', 'alarm.both']],
#  ['motionSensor', ['alarm', 'alarm.strobe']],
#  ['motionSensor', ['colorControl', 'colorControl.each']],
#  ['motionSensor', ['colorControl', 'colorControl.setColor']],
#  ['motionSensor', ['imageCapture', 'imageCapture.take']],
#  ['motionSensor', ['locationMode', 'locationMode.setLocationMode']],
#  ['motionSensor', ['number', 'number.times']],
#  ['motionSensor', ['sendAction', 'sendNotificationToContacts']],
#  ['motionSensor', ['sendAction', 'sendPush']],
#  ['motionSensor', ['sendAction', 'sendSms']],
#  ['motionSensor', ['switch', 'switch.off']],
#  ['motionSensor', ['switch', 'switch.on']],
#  ['powerMeter', ['sendAction', 'sendNotificationToContacts']],
#  ['powerMeter', ['sendAction', 'sendPush']],
#  ['powerMeter', ['sendAction', 'sendSms']],
#  ['powerMeter', ['switch', 'switch.off']],
#  ['presenceSensor', ['colorControl', 'colorControl.each']],
#  ['presenceSensor', ['colorControl', 'colorControl.setColor']],
#  ['presenceSensor', ['imageCapture', 'imageCapture.take']],
#  ['presenceSensor', ['locationMode', 'locationMode.setLocationMode']],
#  ['presenceSensor', ['lock', 'lock.lock']],
#  ['presenceSensor', ['lock', 'lock.unlock']],
#  ['presenceSensor', ['momentary', 'momentary.push']],
#  ['presenceSensor', ['number', 'number.times']],
#  ['presenceSensor', ['sendAction', 'sendNotificationToContacts']],
#  ['presenceSensor', ['sendAction', 'sendPush']],
#  ['presenceSensor', ['sendAction', 'sendSms']],
#  ['presenceSensor', ['switch', 'switch.off']],
#  ['presenceSensor', ['switch', 'switch.on']],
#  ['relativeHumidityMeasurement', ['sendAction', 'sendPush']],
#  ['relativeHumidityMeasurement', ['sendAction', 'sendSms']],
#  ['relativeHumidityMeasurement', ['switch', 'switch.off']],
#  ['relativeHumidityMeasurement', ['switch', 'switch.on']],
#  ['smokeDetector', ['colorControl', 'colorControl.each']],
#  ['smokeDetector', ['colorControl', 'colorControl.setColor']],
#  ['smokeDetector', ['sendAction', 'sendNotificationToContacts']],
#  ['smokeDetector', ['thermostat', 'thermostat.setThermostatMode']],
#  ['switch', ['colorControl', 'colorControl.each']],
#  ['switch', ['colorControl', 'colorControl.setColor']],
#  ['switch', ['imageCapture', 'imageCapture.take']],
#  ['switch', ['locationMode', 'locationMode.setLocationMode']],
#  ['switch', ['number', 'number.times']],
#  ['switch', ['sendAction', 'sendNotificationToContacts']],
#  ['switch', ['sendAction', 'sendPush']],
#  ['switch', ['sendAction', 'sendSms']],
#  ['switch', ['switch', 'switch.off']],
#  ['switch', ['switch', 'switch.on']],
#  ['switch', ['switchLevel', 'switchLevel.setLevel']],
#  ['temperatureMeasurement', ['sendAction', 'sendNotificationToContacts']],
#  ['temperatureMeasurement', ['sendAction', 'sendPush']],
#  ['temperatureMeasurement', ['sendAction', 'sendSms']],
#  ['temperatureMeasurement', ['switch', 'switch.off']],
#  ['temperatureMeasurement', ['switch', 'switch.on']],
#  ['temperatureMeasurement', ['thermostat', 'thermostat.poll']],
#  ['temperatureMeasurement', ['thermostat', 'thermostat.setCoolingSetpoint']],
#  ['temperatureMeasurement', ['thermostat', 'thermostat.setHeatingSetpoint']],
#  ['thermostat', ['switch', 'switch.off']],
#  ['thermostat', ['switch', 'switch.on']],
#  ['thermostat', ['thermostat', 'thermostat.poll']],
#  ['thermostat', ['thermostat', 'thermostat.setCoolingSetpoint']],
#  ['thermostat', ['thermostat', 'thermostat.setHeatingSetpoint']],
#  ['threeAxis', ['sendAction', 'sendNotificationToContacts']],
#  ['threeAxis', ['sendAction', 'sendPush']],
#  ['threeAxis', ['sendAction', 'sendSms']],
#  ['time', ['device.PetFeederShield', 'device.PetFeederShield.feed']],
#  ['time', ['locationMode', 'locationMode.setLocationMode']],
#  ['time', ['lock', 'lock.lock']],
#  ['time', ['sendAction', 'sendNotificationToContacts']],
#  ['time', ['sendAction', 'sendPush']],
#  ['time', ['sendAction', 'sendSms']],
#  ['time', ['switch', 'switch.off']],
#  ['time', ['switch', 'switch.on']],
#  ['touchSensor', ['doorControl', 'doorControl.each']],
#  ['touchSensor', ['lock', 'lock.each']],
#  ['touchSensor', ['switch', 'switch.each']],
#  ['waterSensor', ['colorControl', 'colorControl.each']],
#  ['waterSensor', ['colorControl', 'colorControl.setColor']],
#  ['waterSensor', ['sendAction', 'sendNotificationToContacts']],
#  ['waterSensor', ['sendAction', 'sendPush']],
#  ['waterSensor', ['sendAction', 'sendSms']],
#  ['waterSensor', ['switch', 'switch.off']],
#  ['waterSensor', ['switch', 'switch.on']],
#  ['waterSensor', ['valve', 'valve.close']]]

# %%
# function that map the capability to string
def cap2string(capability):
    switcher = {
        'accelerationSensor': "acceleration",
        'alarm': "alarm",
        'app': "app",
        'beacon': "beacon",
        'button': "button",
        'carbonMonoxideDetector': "carbon_monoxide",
        'colorControl': "color",
        'contactSensor': "contact",
        'doorControl': "door control",
        'illuminanceMeasurement':"illumination",
        'imageCapture': "image capture",
        'location':"location",
        'momentary': "momentary",
        'motionSensor':"motion ",
        'musicPlayer': "music player",
        'powerMeter':"power",
        'presenceSensor': "presence",
        'relativeHumidityMeasurement': "relative humidity ",
        'smokeDetector': "smoke",
        'switch': "switch",
        'switchLevel': "switch level",
        'temperatureMeasurement':"temperature",
        'thermostat': "thermostat",
        'threeAxis':"three axis",
        'touchSensor':"touch",
        'valve':"valve",
        'waterSensor':"water sensor",
        'device.PetFeederShield':"pet feeder shield",
        'device.jawboneUser':"jawbone user",
        'number': "number",
        
        'lock':"lock",
        'locationMode':"locationMode",
        'sendAction':"send action",
        'time':"time"
    }
    return switcher.get(capability, f"capabliti not found: {capability}")

# %%
file = open("../1_application_analysis/2_physical_channel_identification/1_relay_on_capability/set_of_capability_related_channels.JSON","r")
capability_channel = json.load(file)
capability_channel
# Out:
# {'temperature': ['thermostat'],
#  'humidity': ['relative humidity ', 'temperature'],
#  'illumination': ['beacon',
#   'color',
#   'illumination',
#   'image capture',
#   'momentary',
#   'power',
#   'switch',
#   'switch level'],
#  'motion': ['acceleration', 'motion ', 'send action'],
#  'location': ['location', 'music player', 'presence'],
#  'smoke': ['alarm', 'carbon_monoxide', 'smoke'],
#  'leakage': ['app', 'jawbone user', 'valve', 'water sensor'],
#  'time': ['number', 'three axis', 'time'],
#  'locationMode': ['locationMode'],
#  'lock': ['button',
#   'contact',
#   'pet feeder shield',
#   'door control',
#   'lock',
#   'touch']}

# %%
# algorithm 1: algorithm for interaction chain discovery - ALL CHANNELS
INTAC = []
for i in list_trigger_action: # for every pair of trigger-action
    for j in list_trigger_action:
        for channel in capability_channel.keys(): # this implies --> k.ch == m.ch
            #print("physical channel:",physical_channel)
            for k in capability_channel[channel]:     # for every possible pair of capabilities
                for m in capability_channel[channel]: # correlated to the same physical channel
                    action_cap = cap2string(i[1][0]) # action capability of first trigger-action
                    trigger_cap = cap2string(j[0])   # trigger capability of second trigger-action
                    if ((action_cap == k) and (trigger_cap == m)):
                        first_app = [i[0], i[1][0]]  # use only trigger-action
                        second_app = [j[0], j[1][0]] # use only trigger-action
                        if not [first_app, channel, second_app] in INTAC: # not duplicates 
                            print(f"action {action_cap} nel canale {channel} triggera {trigger_cap}")
                            INTAC.append([first_app, channel, second_app])
                            
                            
# this part was correlated to the system channels ...
#         for system_channel in system_capabilities: # now check the system channels
#             if (action_cap == system_channel) and (trigger_cap == system_channel): 
#                         if not [i, system_channel, j] in INTAC: # not duplicates 
#                             print(f"action {action_cap} nel canale {physical_channel} triggera {trigger_cap}")
#                             INTAC.append([i, physical_channel, j])
# Out:
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera illumination
# action color nel canale illumination triggera power
# action color nel canale illumination triggera power
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action image capture nel canale illumination triggera beacon
# action image capture nel canale illumination triggera beacon
# action image capture nel canale illumination triggera illumination
# action image capture nel canale illumination triggera power
# action image capture nel canale illumination triggera power
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action momentary nel canale illumination triggera beacon
# action momentary nel canale illumination triggera beacon
# action momentary nel canale illumination triggera illumination
# action momentary nel canale illumination triggera power
# action momentary nel canale illumination triggera power
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action number nel canale time triggera three axis
# action number nel canale time triggera time
# action number nel canale time triggera time
# action number nel canale time triggera time
# action number nel canale time triggera time
# action number nel canale time triggera time
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action alarm nel canale smoke triggera alarm
# action alarm nel canale smoke triggera carbon_monoxide
# action alarm nel canale smoke triggera carbon_monoxide
# action alarm nel canale smoke triggera smoke
# action alarm nel canale smoke triggera smoke
# action alarm nel canale smoke triggera smoke
# action alarm nel canale smoke triggera alarm
# action alarm nel canale smoke triggera carbon_monoxide
# action alarm nel canale smoke triggera carbon_monoxide
# action alarm nel canale smoke triggera smoke
# action alarm nel canale smoke triggera smoke
# action alarm nel canale smoke triggera smoke
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera illumination
# action color nel canale illumination triggera power
# action color nel canale illumination triggera power
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action door control nel canale lock triggera button
# action door control nel canale lock triggera button
# action door control nel canale lock triggera button
# action door control nel canale lock triggera contact
# action door control nel canale lock triggera contact
# action door control nel canale lock triggera contact
# action door control nel canale lock triggera contact
# action door control nel canale lock triggera contact
# action door control nel canale lock triggera contact
# action door control nel canale lock triggera contact
# action door control nel canale lock triggera contact
# action door control nel canale lock triggera contact
# action door control nel canale lock triggera touch
# action door control nel canale lock triggera touch
# action door control nel canale lock triggera touch
# action lock nel canale lock triggera button
# action lock nel canale lock triggera button
# action lock nel canale lock triggera button
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera touch
# action lock nel canale lock triggera touch
# action lock nel canale lock triggera touch
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action thermostat nel canale temperature triggera thermostat
# action thermostat nel canale temperature triggera thermostat
# action lock nel canale lock triggera button
# action lock nel canale lock triggera button
# action lock nel canale lock triggera button
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera touch
# action lock nel canale lock triggera touch
# action lock nel canale lock triggera touch
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera illumination
# action color nel canale illumination triggera power
# action color nel canale illumination triggera power
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action thermostat nel canale temperature triggera thermostat
# action thermostat nel canale temperature triggera thermostat
# action alarm nel canale smoke triggera alarm
# action alarm nel canale smoke triggera carbon_monoxide
# action alarm nel canale smoke triggera carbon_monoxide
# action alarm nel canale smoke triggera smoke
# action alarm nel canale smoke triggera smoke
# action alarm nel canale smoke triggera smoke
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera illumination
# action color nel canale illumination triggera power
# action color nel canale illumination triggera power
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action image capture nel canale illumination triggera beacon
# action image capture nel canale illumination triggera beacon
# action image capture nel canale illumination triggera illumination
# action image capture nel canale illumination triggera power
# action image capture nel canale illumination triggera power
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action momentary nel canale illumination triggera beacon
# action momentary nel canale illumination triggera beacon
# action momentary nel canale illumination triggera illumination
# action momentary nel canale illumination triggera power
# action momentary nel canale illumination triggera power
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action number nel canale time triggera three axis
# action number nel canale time triggera time
# action number nel canale time triggera time
# action number nel canale time triggera time
# action number nel canale time triggera time
# action number nel canale time triggera time
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action thermostat nel canale temperature triggera thermostat
# action thermostat nel canale temperature triggera thermostat
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera illumination
# action color nel canale illumination triggera power
# action color nel canale illumination triggera power
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action music player nel canale location triggera location
# action music player nel canale location triggera location
# action music player nel canale location triggera location
# action music player nel canale location triggera presence
# action music player nel canale location triggera presence
# action music player nel canale location triggera presence
# action music player nel canale location triggera presence
# action music player nel canale location triggera presence
# action music player nel canale location triggera presence
# action music player nel canale location triggera presence
# action music player nel canale location triggera presence
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action lock nel canale lock triggera button
# action lock nel canale lock triggera button
# action lock nel canale lock triggera button
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera touch
# action lock nel canale lock triggera touch
# action lock nel canale lock triggera touch
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action thermostat nel canale temperature triggera thermostat
# action thermostat nel canale temperature triggera thermostat
# action alarm nel canale smoke triggera alarm
# action alarm nel canale smoke triggera carbon_monoxide
# action alarm nel canale smoke triggera carbon_monoxide
# action alarm nel canale smoke triggera smoke
# action alarm nel canale smoke triggera smoke
# action alarm nel canale smoke triggera smoke
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera illumination
# action color nel canale illumination triggera power
# action color nel canale illumination triggera power
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action image capture nel canale illumination triggera beacon
# action image capture nel canale illumination triggera beacon
# action image capture nel canale illumination triggera illumination
# action image capture nel canale illumination triggera power
# action image capture nel canale illumination triggera power
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action number nel canale time triggera three axis
# action number nel canale time triggera time
# action number nel canale time triggera time
# action number nel canale time triggera time
# action number nel canale time triggera time
# action number nel canale time triggera time
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera illumination
# action color nel canale illumination triggera power
# action color nel canale illumination triggera power
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action image capture nel canale illumination triggera beacon
# action image capture nel canale illumination triggera beacon
# action image capture nel canale illumination triggera illumination
# action image capture nel canale illumination triggera power
# action image capture nel canale illumination triggera power
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action lock nel canale lock triggera button
# action lock nel canale lock triggera button
# action lock nel canale lock triggera button
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera touch
# action lock nel canale lock triggera touch
# action lock nel canale lock triggera touch
# action momentary nel canale illumination triggera beacon
# action momentary nel canale illumination triggera beacon
# action momentary nel canale illumination triggera illumination
# action momentary nel canale illumination triggera power
# action momentary nel canale illumination triggera power
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action number nel canale time triggera three axis
# action number nel canale time triggera time
# action number nel canale time triggera time
# action number nel canale time triggera time
# action number nel canale time triggera time
# action number nel canale time triggera time
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera illumination
# action color nel canale illumination triggera power
# action color nel canale illumination triggera power
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action thermostat nel canale temperature triggera thermostat
# action thermostat nel canale temperature triggera thermostat
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera illumination
# action color nel canale illumination triggera power
# action color nel canale illumination triggera power
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action image capture nel canale illumination triggera beacon
# action image capture nel canale illumination triggera beacon
# action image capture nel canale illumination triggera illumination
# action image capture nel canale illumination triggera power
# action image capture nel canale illumination triggera power
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action number nel canale time triggera three axis
# action number nel canale time triggera time
# action number nel canale time triggera time
# action number nel canale time triggera time
# action number nel canale time triggera time
# action number nel canale time triggera time
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch level nel canale illumination triggera beacon
# action switch level nel canale illumination triggera beacon
# action switch level nel canale illumination triggera illumination
# action switch level nel canale illumination triggera power
# action switch level nel canale illumination triggera power
# action switch level nel canale illumination triggera switch
# action switch level nel canale illumination triggera switch
# action switch level nel canale illumination triggera switch
# action switch level nel canale illumination triggera switch
# action switch level nel canale illumination triggera switch
# action switch level nel canale illumination triggera switch
# action switch level nel canale illumination triggera switch
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action thermostat nel canale temperature triggera thermostat
# action thermostat nel canale temperature triggera thermostat
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action thermostat nel canale temperature triggera thermostat
# action thermostat nel canale temperature triggera thermostat
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action pet feeder shield nel canale lock triggera button
# action pet feeder shield nel canale lock triggera button
# action pet feeder shield nel canale lock triggera button
# action pet feeder shield nel canale lock triggera contact
# action pet feeder shield nel canale lock triggera contact
# action pet feeder shield nel canale lock triggera contact
# action pet feeder shield nel canale lock triggera contact
# action pet feeder shield nel canale lock triggera contact
# action pet feeder shield nel canale lock triggera contact
# action pet feeder shield nel canale lock triggera contact
# action pet feeder shield nel canale lock triggera contact
# action pet feeder shield nel canale lock triggera contact
# action pet feeder shield nel canale lock triggera touch
# action pet feeder shield nel canale lock triggera touch
# action pet feeder shield nel canale lock triggera touch
# action lock nel canale lock triggera button
# action lock nel canale lock triggera button
# action lock nel canale lock triggera button
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera touch
# action lock nel canale lock triggera touch
# action lock nel canale lock triggera touch
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action door control nel canale lock triggera button
# action door control nel canale lock triggera button
# action door control nel canale lock triggera button
# action door control nel canale lock triggera contact
# action door control nel canale lock triggera contact
# action door control nel canale lock triggera contact
# action door control nel canale lock triggera contact
# action door control nel canale lock triggera contact
# action door control nel canale lock triggera contact
# action door control nel canale lock triggera contact
# action door control nel canale lock triggera contact
# action door control nel canale lock triggera contact
# action door control nel canale lock triggera touch
# action door control nel canale lock triggera touch
# action door control nel canale lock triggera touch
# action lock nel canale lock triggera button
# action lock nel canale lock triggera button
# action lock nel canale lock triggera button
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera contact
# action lock nel canale lock triggera touch
# action lock nel canale lock triggera touch
# action lock nel canale lock triggera touch
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera illumination
# action color nel canale illumination triggera power
# action color nel canale illumination triggera power
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action valve nel canale leakage triggera app
# action valve nel canale leakage triggera app
# action valve nel canale leakage triggera app
# action valve nel canale leakage triggera app
# action valve nel canale leakage triggera app
# action valve nel canale leakage triggera app
# action valve nel canale leakage triggera jawbone user
# action valve nel canale leakage triggera jawbone user
# action valve nel canale leakage triggera jawbone user
# action valve nel canale leakage triggera jawbone user
# action valve nel canale leakage triggera water sensor
# action valve nel canale leakage triggera water sensor
# action valve nel canale leakage triggera water sensor
# action valve nel canale leakage triggera water sensor

# %%
print(len(INTAC)) # for the paper just 570 (cap 5.2 - p839) prima avevo 2500 .....
# Out:
# 855

# %%
# take second element for sort
def takeSecond(elem):
    return elem[1]

INTAC.sort(key=takeSecond)
INTAC
# Out:
# [[['accelerationSensor', 'colorControl'], 'illumination', ['beacon', 'lock']],
#  [['accelerationSensor', 'colorControl'],
#   'illumination',
#   ['beacon', 'switch']],
#  [['accelerationSensor', 'colorControl'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['accelerationSensor', 'colorControl'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['accelerationSensor', 'colorControl'],
#   'illumination',
#   ['powerMeter', 'switch']],
#  [['accelerationSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['accelerationSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['accelerationSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['accelerationSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'number']],
#  [['accelerationSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'sendAction']],
#  [['accelerationSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'switch']],
#  [['accelerationSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'switchLevel']],
#  [['accelerationSensor', 'imageCapture'], 'illumination', ['beacon', 'lock']],
#  [['accelerationSensor', 'imageCapture'],
#   'illumination',
#   ['beacon', 'switch']],
#  [['accelerationSensor', 'imageCapture'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['accelerationSensor', 'imageCapture'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['accelerationSensor', 'imageCapture'],
#   'illumination',
#   ['powerMeter', 'switch']],
#  [['accelerationSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['accelerationSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['accelerationSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['accelerationSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'number']],
#  [['accelerationSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'sendAction']],
#  [['accelerationSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'switch']],
#  [['accelerationSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'switchLevel']],
#  [['accelerationSensor', 'momentary'], 'illumination', ['beacon', 'lock']],
#  [['accelerationSensor', 'momentary'], 'illumination', ['beacon', 'switch']],
#  [['accelerationSensor', 'momentary'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['accelerationSensor', 'momentary'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['accelerationSensor', 'momentary'],
#   'illumination',
#   ['powerMeter', 'switch']],
#  [['accelerationSensor', 'momentary'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['accelerationSensor', 'momentary'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['accelerationSensor', 'momentary'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['accelerationSensor', 'momentary'], 'illumination', ['switch', 'number']],
#  [['accelerationSensor', 'momentary'],
#   'illumination',
#   ['switch', 'sendAction']],
#  [['accelerationSensor', 'momentary'], 'illumination', ['switch', 'switch']],
#  [['accelerationSensor', 'momentary'],
#   'illumination',
#   ['switch', 'switchLevel']],
#  [['accelerationSensor', 'switch'], 'illumination', ['beacon', 'lock']],
#  [['accelerationSensor', 'switch'], 'illumination', ['beacon', 'switch']],
#  [['accelerationSensor', 'switch'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['accelerationSensor', 'switch'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['accelerationSensor', 'switch'], 'illumination', ['powerMeter', 'switch']],
#  [['accelerationSensor', 'switch'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['accelerationSensor', 'switch'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['accelerationSensor', 'switch'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['accelerationSensor', 'switch'], 'illumination', ['switch', 'number']],
#  [['accelerationSensor', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['accelerationSensor', 'switch'], 'illumination', ['switch', 'switch']],
#  [['accelerationSensor', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['app', 'colorControl'], 'illumination', ['beacon', 'lock']],
#  [['app', 'colorControl'], 'illumination', ['beacon', 'switch']],
#  [['app', 'colorControl'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['app', 'colorControl'], 'illumination', ['powerMeter', 'sendAction']],
#  [['app', 'colorControl'], 'illumination', ['powerMeter', 'switch']],
#  [['app', 'colorControl'], 'illumination', ['switch', 'colorControl']],
#  [['app', 'colorControl'], 'illumination', ['switch', 'imageCapture']],
#  [['app', 'colorControl'], 'illumination', ['switch', 'locationMode']],
#  [['app', 'colorControl'], 'illumination', ['switch', 'number']],
#  [['app', 'colorControl'], 'illumination', ['switch', 'sendAction']],
#  [['app', 'colorControl'], 'illumination', ['switch', 'switch']],
#  [['app', 'colorControl'], 'illumination', ['switch', 'switchLevel']],
#  [['app', 'switch'], 'illumination', ['beacon', 'lock']],
#  [['app', 'switch'], 'illumination', ['beacon', 'switch']],
#  [['app', 'switch'], 'illumination', ['illuminanceMeasurement', 'switch']],
#  [['app', 'switch'], 'illumination', ['powerMeter', 'sendAction']],
#  [['app', 'switch'], 'illumination', ['powerMeter', 'switch']],
#  [['app', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['app', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['app', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['app', 'switch'], 'illumination', ['switch', 'number']],
#  [['app', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['app', 'switch'], 'illumination', ['switch', 'switch']],
#  [['app', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['beacon', 'switch'], 'illumination', ['beacon', 'lock']],
#  [['beacon', 'switch'], 'illumination', ['beacon', 'switch']],
#  [['beacon', 'switch'], 'illumination', ['illuminanceMeasurement', 'switch']],
#  [['beacon', 'switch'], 'illumination', ['powerMeter', 'sendAction']],
#  [['beacon', 'switch'], 'illumination', ['powerMeter', 'switch']],
#  [['beacon', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['beacon', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['beacon', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['beacon', 'switch'], 'illumination', ['switch', 'number']],
#  [['beacon', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['beacon', 'switch'], 'illumination', ['switch', 'switch']],
#  [['beacon', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['button', 'colorControl'], 'illumination', ['beacon', 'lock']],
#  [['button', 'colorControl'], 'illumination', ['beacon', 'switch']],
#  [['button', 'colorControl'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['button', 'colorControl'], 'illumination', ['powerMeter', 'sendAction']],
#  [['button', 'colorControl'], 'illumination', ['powerMeter', 'switch']],
#  [['button', 'colorControl'], 'illumination', ['switch', 'colorControl']],
#  [['button', 'colorControl'], 'illumination', ['switch', 'imageCapture']],
#  [['button', 'colorControl'], 'illumination', ['switch', 'locationMode']],
#  [['button', 'colorControl'], 'illumination', ['switch', 'number']],
#  [['button', 'colorControl'], 'illumination', ['switch', 'sendAction']],
#  [['button', 'colorControl'], 'illumination', ['switch', 'switch']],
#  [['button', 'colorControl'], 'illumination', ['switch', 'switchLevel']],
#  [['contactSensor', 'colorControl'], 'illumination', ['beacon', 'lock']],
#  [['contactSensor', 'colorControl'], 'illumination', ['beacon', 'switch']],
#  [['contactSensor', 'colorControl'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['contactSensor', 'colorControl'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['contactSensor', 'colorControl'], 'illumination', ['powerMeter', 'switch']],
#  [['contactSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['contactSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['contactSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['contactSensor', 'colorControl'], 'illumination', ['switch', 'number']],
#  [['contactSensor', 'colorControl'], 'illumination', ['switch', 'sendAction']],
#  [['contactSensor', 'colorControl'], 'illumination', ['switch', 'switch']],
#  [['contactSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'switchLevel']],
#  [['contactSensor', 'imageCapture'], 'illumination', ['beacon', 'lock']],
#  [['contactSensor', 'imageCapture'], 'illumination', ['beacon', 'switch']],
#  [['contactSensor', 'imageCapture'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['contactSensor', 'imageCapture'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['contactSensor', 'imageCapture'], 'illumination', ['powerMeter', 'switch']],
#  [['contactSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['contactSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['contactSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['contactSensor', 'imageCapture'], 'illumination', ['switch', 'number']],
#  [['contactSensor', 'imageCapture'], 'illumination', ['switch', 'sendAction']],
#  [['contactSensor', 'imageCapture'], 'illumination', ['switch', 'switch']],
#  [['contactSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'switchLevel']],
#  [['contactSensor', 'momentary'], 'illumination', ['beacon', 'lock']],
#  [['contactSensor', 'momentary'], 'illumination', ['beacon', 'switch']],
#  [['contactSensor', 'momentary'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['contactSensor', 'momentary'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['contactSensor', 'momentary'], 'illumination', ['powerMeter', 'switch']],
#  [['contactSensor', 'momentary'], 'illumination', ['switch', 'colorControl']],
#  [['contactSensor', 'momentary'], 'illumination', ['switch', 'imageCapture']],
#  [['contactSensor', 'momentary'], 'illumination', ['switch', 'locationMode']],
#  [['contactSensor', 'momentary'], 'illumination', ['switch', 'number']],
#  [['contactSensor', 'momentary'], 'illumination', ['switch', 'sendAction']],
#  [['contactSensor', 'momentary'], 'illumination', ['switch', 'switch']],
#  [['contactSensor', 'momentary'], 'illumination', ['switch', 'switchLevel']],
#  [['contactSensor', 'switch'], 'illumination', ['beacon', 'lock']],
#  [['contactSensor', 'switch'], 'illumination', ['beacon', 'switch']],
#  [['contactSensor', 'switch'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['contactSensor', 'switch'], 'illumination', ['powerMeter', 'sendAction']],
#  [['contactSensor', 'switch'], 'illumination', ['powerMeter', 'switch']],
#  [['contactSensor', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['contactSensor', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['contactSensor', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['contactSensor', 'switch'], 'illumination', ['switch', 'number']],
#  [['contactSensor', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['contactSensor', 'switch'], 'illumination', ['switch', 'switch']],
#  [['contactSensor', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['device.jawboneUser', 'colorControl'], 'illumination', ['beacon', 'lock']],
#  [['device.jawboneUser', 'colorControl'],
#   'illumination',
#   ['beacon', 'switch']],
#  [['device.jawboneUser', 'colorControl'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['device.jawboneUser', 'colorControl'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['device.jawboneUser', 'colorControl'],
#   'illumination',
#   ['powerMeter', 'switch']],
#  [['device.jawboneUser', 'colorControl'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['device.jawboneUser', 'colorControl'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['device.jawboneUser', 'colorControl'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['device.jawboneUser', 'colorControl'],
#   'illumination',
#   ['switch', 'number']],
#  [['device.jawboneUser', 'colorControl'],
#   'illumination',
#   ['switch', 'sendAction']],
#  [['device.jawboneUser', 'colorControl'],
#   'illumination',
#   ['switch', 'switch']],
#  [['device.jawboneUser', 'colorControl'],
#   'illumination',
#   ['switch', 'switchLevel']],
#  [['device.jawboneUser', 'switch'], 'illumination', ['beacon', 'lock']],
#  [['device.jawboneUser', 'switch'], 'illumination', ['beacon', 'switch']],
#  [['device.jawboneUser', 'switch'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['device.jawboneUser', 'switch'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['device.jawboneUser', 'switch'], 'illumination', ['powerMeter', 'switch']],
#  [['device.jawboneUser', 'switch'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['device.jawboneUser', 'switch'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['device.jawboneUser', 'switch'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['device.jawboneUser', 'switch'], 'illumination', ['switch', 'number']],
#  [['device.jawboneUser', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['device.jawboneUser', 'switch'], 'illumination', ['switch', 'switch']],
#  [['device.jawboneUser', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['illuminanceMeasurement', 'switch'], 'illumination', ['beacon', 'lock']],
#  [['illuminanceMeasurement', 'switch'], 'illumination', ['beacon', 'switch']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['powerMeter', 'switch']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['illuminanceMeasurement', 'switch'], 'illumination', ['switch', 'number']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'sendAction']],
#  [['illuminanceMeasurement', 'switch'], 'illumination', ['switch', 'switch']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'switchLevel']],
#  [['location', 'switch'], 'illumination', ['beacon', 'lock']],
#  [['location', 'switch'], 'illumination', ['beacon', 'switch']],
#  [['location', 'switch'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['location', 'switch'], 'illumination', ['powerMeter', 'sendAction']],
#  [['location', 'switch'], 'illumination', ['powerMeter', 'switch']],
#  [['location', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['location', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['location', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['location', 'switch'], 'illumination', ['switch', 'number']],
#  [['location', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['location', 'switch'], 'illumination', ['switch', 'switch']],
#  [['location', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['motionSensor', 'colorControl'], 'illumination', ['beacon', 'lock']],
#  [['motionSensor', 'colorControl'], 'illumination', ['beacon', 'switch']],
#  [['motionSensor', 'colorControl'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['motionSensor', 'colorControl'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['motionSensor', 'colorControl'], 'illumination', ['powerMeter', 'switch']],
#  [['motionSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['motionSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['motionSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['motionSensor', 'colorControl'], 'illumination', ['switch', 'number']],
#  [['motionSensor', 'colorControl'], 'illumination', ['switch', 'sendAction']],
#  [['motionSensor', 'colorControl'], 'illumination', ['switch', 'switch']],
#  [['motionSensor', 'colorControl'], 'illumination', ['switch', 'switchLevel']],
#  [['motionSensor', 'imageCapture'], 'illumination', ['beacon', 'lock']],
#  [['motionSensor', 'imageCapture'], 'illumination', ['beacon', 'switch']],
#  [['motionSensor', 'imageCapture'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['motionSensor', 'imageCapture'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['motionSensor', 'imageCapture'], 'illumination', ['powerMeter', 'switch']],
#  [['motionSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['motionSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['motionSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['motionSensor', 'imageCapture'], 'illumination', ['switch', 'number']],
#  [['motionSensor', 'imageCapture'], 'illumination', ['switch', 'sendAction']],
#  [['motionSensor', 'imageCapture'], 'illumination', ['switch', 'switch']],
#  [['motionSensor', 'imageCapture'], 'illumination', ['switch', 'switchLevel']],
#  [['motionSensor', 'switch'], 'illumination', ['beacon', 'lock']],
#  [['motionSensor', 'switch'], 'illumination', ['beacon', 'switch']],
#  [['motionSensor', 'switch'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['motionSensor', 'switch'], 'illumination', ['powerMeter', 'sendAction']],
#  [['motionSensor', 'switch'], 'illumination', ['powerMeter', 'switch']],
#  [['motionSensor', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['motionSensor', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['motionSensor', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['motionSensor', 'switch'], 'illumination', ['switch', 'number']],
#  [['motionSensor', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['motionSensor', 'switch'], 'illumination', ['switch', 'switch']],
#  [['motionSensor', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['powerMeter', 'switch'], 'illumination', ['beacon', 'lock']],
#  [['powerMeter', 'switch'], 'illumination', ['beacon', 'switch']],
#  [['powerMeter', 'switch'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['powerMeter', 'switch'], 'illumination', ['powerMeter', 'sendAction']],
#  [['powerMeter', 'switch'], 'illumination', ['powerMeter', 'switch']],
#  [['powerMeter', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['powerMeter', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['powerMeter', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['powerMeter', 'switch'], 'illumination', ['switch', 'number']],
#  [['powerMeter', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['powerMeter', 'switch'], 'illumination', ['switch', 'switch']],
#  [['powerMeter', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['presenceSensor', 'colorControl'], 'illumination', ['beacon', 'lock']],
#  [['presenceSensor', 'colorControl'], 'illumination', ['beacon', 'switch']],
#  [['presenceSensor', 'colorControl'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['presenceSensor', 'colorControl'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['presenceSensor', 'colorControl'],
#   'illumination',
#   ['powerMeter', 'switch']],
#  [['presenceSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['presenceSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['presenceSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['presenceSensor', 'colorControl'], 'illumination', ['switch', 'number']],
#  [['presenceSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'sendAction']],
#  [['presenceSensor', 'colorControl'], 'illumination', ['switch', 'switch']],
#  [['presenceSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'switchLevel']],
#  [['presenceSensor', 'imageCapture'], 'illumination', ['beacon', 'lock']],
#  [['presenceSensor', 'imageCapture'], 'illumination', ['beacon', 'switch']],
#  [['presenceSensor', 'imageCapture'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['presenceSensor', 'imageCapture'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['presenceSensor', 'imageCapture'],
#   'illumination',
#   ['powerMeter', 'switch']],
#  [['presenceSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['presenceSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['presenceSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['presenceSensor', 'imageCapture'], 'illumination', ['switch', 'number']],
#  [['presenceSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'sendAction']],
#  [['presenceSensor', 'imageCapture'], 'illumination', ['switch', 'switch']],
#  [['presenceSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'switchLevel']],
#  [['presenceSensor', 'momentary'], 'illumination', ['beacon', 'lock']],
#  [['presenceSensor', 'momentary'], 'illumination', ['beacon', 'switch']],
#  [['presenceSensor', 'momentary'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['presenceSensor', 'momentary'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['presenceSensor', 'momentary'], 'illumination', ['powerMeter', 'switch']],
#  [['presenceSensor', 'momentary'], 'illumination', ['switch', 'colorControl']],
#  [['presenceSensor', 'momentary'], 'illumination', ['switch', 'imageCapture']],
#  [['presenceSensor', 'momentary'], 'illumination', ['switch', 'locationMode']],
#  [['presenceSensor', 'momentary'], 'illumination', ['switch', 'number']],
#  [['presenceSensor', 'momentary'], 'illumination', ['switch', 'sendAction']],
#  [['presenceSensor', 'momentary'], 'illumination', ['switch', 'switch']],
#  [['presenceSensor', 'momentary'], 'illumination', ['switch', 'switchLevel']],
#  [['presenceSensor', 'switch'], 'illumination', ['beacon', 'lock']],
#  [['presenceSensor', 'switch'], 'illumination', ['beacon', 'switch']],
#  [['presenceSensor', 'switch'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['presenceSensor', 'switch'], 'illumination', ['powerMeter', 'sendAction']],
#  [['presenceSensor', 'switch'], 'illumination', ['powerMeter', 'switch']],
#  [['presenceSensor', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['presenceSensor', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['presenceSensor', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['presenceSensor', 'switch'], 'illumination', ['switch', 'number']],
#  [['presenceSensor', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['presenceSensor', 'switch'], 'illumination', ['switch', 'switch']],
#  [['presenceSensor', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['beacon', 'lock']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['beacon', 'switch']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['powerMeter', 'switch']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'number']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'sendAction']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'switch']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'switchLevel']],
#  [['smokeDetector', 'colorControl'], 'illumination', ['beacon', 'lock']],
#  [['smokeDetector', 'colorControl'], 'illumination', ['beacon', 'switch']],
#  [['smokeDetector', 'colorControl'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['smokeDetector', 'colorControl'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['smokeDetector', 'colorControl'], 'illumination', ['powerMeter', 'switch']],
#  [['smokeDetector', 'colorControl'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['smokeDetector', 'colorControl'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['smokeDetector', 'colorControl'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['smokeDetector', 'colorControl'], 'illumination', ['switch', 'number']],
#  [['smokeDetector', 'colorControl'], 'illumination', ['switch', 'sendAction']],
#  [['smokeDetector', 'colorControl'], 'illumination', ['switch', 'switch']],
#  [['smokeDetector', 'colorControl'],
#   'illumination',
#   ['switch', 'switchLevel']],
#  [['switch', 'colorControl'], 'illumination', ['beacon', 'lock']],
#  [['switch', 'colorControl'], 'illumination', ['beacon', 'switch']],
#  [['switch', 'colorControl'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['switch', 'colorControl'], 'illumination', ['powerMeter', 'sendAction']],
#  [['switch', 'colorControl'], 'illumination', ['powerMeter', 'switch']],
#  [['switch', 'colorControl'], 'illumination', ['switch', 'colorControl']],
#  [['switch', 'colorControl'], 'illumination', ['switch', 'imageCapture']],
#  [['switch', 'colorControl'], 'illumination', ['switch', 'locationMode']],
#  [['switch', 'colorControl'], 'illumination', ['switch', 'number']],
#  [['switch', 'colorControl'], 'illumination', ['switch', 'sendAction']],
#  [['switch', 'colorControl'], 'illumination', ['switch', 'switch']],
#  [['switch', 'colorControl'], 'illumination', ['switch', 'switchLevel']],
#  [['switch', 'imageCapture'], 'illumination', ['beacon', 'lock']],
#  [['switch', 'imageCapture'], 'illumination', ['beacon', 'switch']],
#  [['switch', 'imageCapture'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['switch', 'imageCapture'], 'illumination', ['powerMeter', 'sendAction']],
#  [['switch', 'imageCapture'], 'illumination', ['powerMeter', 'switch']],
#  [['switch', 'imageCapture'], 'illumination', ['switch', 'colorControl']],
#  [['switch', 'imageCapture'], 'illumination', ['switch', 'imageCapture']],
#  [['switch', 'imageCapture'], 'illumination', ['switch', 'locationMode']],
#  [['switch', 'imageCapture'], 'illumination', ['switch', 'number']],
#  [['switch', 'imageCapture'], 'illumination', ['switch', 'sendAction']],
#  [['switch', 'imageCapture'], 'illumination', ['switch', 'switch']],
#  [['switch', 'imageCapture'], 'illumination', ['switch', 'switchLevel']],
#  [['switch', 'switch'], 'illumination', ['beacon', 'lock']],
#  [['switch', 'switch'], 'illumination', ['beacon', 'switch']],
#  [['switch', 'switch'], 'illumination', ['illuminanceMeasurement', 'switch']],
#  [['switch', 'switch'], 'illumination', ['powerMeter', 'sendAction']],
#  [['switch', 'switch'], 'illumination', ['powerMeter', 'switch']],
#  [['switch', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['switch', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['switch', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['switch', 'switch'], 'illumination', ['switch', 'number']],
#  [['switch', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['switch', 'switch'], 'illumination', ['switch', 'switch']],
#  [['switch', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['switch', 'switchLevel'], 'illumination', ['beacon', 'lock']],
#  [['switch', 'switchLevel'], 'illumination', ['beacon', 'switch']],
#  [['switch', 'switchLevel'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['switch', 'switchLevel'], 'illumination', ['powerMeter', 'sendAction']],
#  [['switch', 'switchLevel'], 'illumination', ['powerMeter', 'switch']],
#  [['switch', 'switchLevel'], 'illumination', ['switch', 'colorControl']],
#  [['switch', 'switchLevel'], 'illumination', ['switch', 'imageCapture']],
#  [['switch', 'switchLevel'], 'illumination', ['switch', 'locationMode']],
#  [['switch', 'switchLevel'], 'illumination', ['switch', 'number']],
#  [['switch', 'switchLevel'], 'illumination', ['switch', 'sendAction']],
#  [['switch', 'switchLevel'], 'illumination', ['switch', 'switch']],
#  [['switch', 'switchLevel'], 'illumination', ['switch', 'switchLevel']],
#  [['temperatureMeasurement', 'switch'], 'illumination', ['beacon', 'lock']],
#  [['temperatureMeasurement', 'switch'], 'illumination', ['beacon', 'switch']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['powerMeter', 'switch']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['temperatureMeasurement', 'switch'], 'illumination', ['switch', 'number']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'sendAction']],
#  [['temperatureMeasurement', 'switch'], 'illumination', ['switch', 'switch']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'switchLevel']],
#  [['thermostat', 'switch'], 'illumination', ['beacon', 'lock']],
#  [['thermostat', 'switch'], 'illumination', ['beacon', 'switch']],
#  [['thermostat', 'switch'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['thermostat', 'switch'], 'illumination', ['powerMeter', 'sendAction']],
#  [['thermostat', 'switch'], 'illumination', ['powerMeter', 'switch']],
#  [['thermostat', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['thermostat', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['thermostat', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['thermostat', 'switch'], 'illumination', ['switch', 'number']],
#  [['thermostat', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['thermostat', 'switch'], 'illumination', ['switch', 'switch']],
#  [['thermostat', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['time', 'switch'], 'illumination', ['beacon', 'lock']],
#  [['time', 'switch'], 'illumination', ['beacon', 'switch']],
#  [['time', 'switch'], 'illumination', ['illuminanceMeasurement', 'switch']],
#  [['time', 'switch'], 'illumination', ['powerMeter', 'sendAction']],
#  [['time', 'switch'], 'illumination', ['powerMeter', 'switch']],
#  [['time', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['time', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['time', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['time', 'switch'], 'illumination', ['switch', 'number']],
#  [['time', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['time', 'switch'], 'illumination', ['switch', 'switch']],
#  [['time', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['touchSensor', 'switch'], 'illumination', ['beacon', 'lock']],
#  [['touchSensor', 'switch'], 'illumination', ['beacon', 'switch']],
#  [['touchSensor', 'switch'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['touchSensor', 'switch'], 'illumination', ['powerMeter', 'sendAction']],
#  [['touchSensor', 'switch'], 'illumination', ['powerMeter', 'switch']],
#  [['touchSensor', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['touchSensor', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['touchSensor', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['touchSensor', 'switch'], 'illumination', ['switch', 'number']],
#  [['touchSensor', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['touchSensor', 'switch'], 'illumination', ['switch', 'switch']],
#  [['touchSensor', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['waterSensor', 'colorControl'], 'illumination', ['beacon', 'lock']],
#  [['waterSensor', 'colorControl'], 'illumination', ['beacon', 'switch']],
#  [['waterSensor', 'colorControl'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['waterSensor', 'colorControl'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['waterSensor', 'colorControl'], 'illumination', ['powerMeter', 'switch']],
#  [['waterSensor', 'colorControl'], 'illumination', ['switch', 'colorControl']],
#  [['waterSensor', 'colorControl'], 'illumination', ['switch', 'imageCapture']],
#  [['waterSensor', 'colorControl'], 'illumination', ['switch', 'locationMode']],
#  [['waterSensor', 'colorControl'], 'illumination', ['switch', 'number']],
#  [['waterSensor', 'colorControl'], 'illumination', ['switch', 'sendAction']],
#  [['waterSensor', 'colorControl'], 'illumination', ['switch', 'switch']],
#  [['waterSensor', 'colorControl'], 'illumination', ['switch', 'switchLevel']],
#  [['waterSensor', 'switch'], 'illumination', ['beacon', 'lock']],
#  [['waterSensor', 'switch'], 'illumination', ['beacon', 'switch']],
#  [['waterSensor', 'switch'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['waterSensor', 'switch'], 'illumination', ['powerMeter', 'sendAction']],
#  [['waterSensor', 'switch'], 'illumination', ['powerMeter', 'switch']],
#  [['waterSensor', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['waterSensor', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['waterSensor', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['waterSensor', 'switch'], 'illumination', ['switch', 'number']],
#  [['waterSensor', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['waterSensor', 'switch'], 'illumination', ['switch', 'switch']],
#  [['waterSensor', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['waterSensor', 'valve'], 'leakage', ['app', 'alarm']],
#  [['waterSensor', 'valve'], 'leakage', ['app', 'colorControl']],
#  [['waterSensor', 'valve'], 'leakage', ['app', 'doorControl']],
#  [['waterSensor', 'valve'], 'leakage', ['app', 'lock']],
#  [['waterSensor', 'valve'], 'leakage', ['app', 'switch']],
#  [['waterSensor', 'valve'], 'leakage', ['app', 'thermostat']],
#  [['waterSensor', 'valve'], 'leakage', ['device.jawboneUser', 'colorControl']],
#  [['waterSensor', 'valve'], 'leakage', ['device.jawboneUser', 'musicPlayer']],
#  [['waterSensor', 'valve'], 'leakage', ['device.jawboneUser', 'sendAction']],
#  [['waterSensor', 'valve'], 'leakage', ['device.jawboneUser', 'switch']],
#  [['waterSensor', 'valve'], 'leakage', ['waterSensor', 'colorControl']],
#  [['waterSensor', 'valve'], 'leakage', ['waterSensor', 'sendAction']],
#  [['waterSensor', 'valve'], 'leakage', ['waterSensor', 'switch']],
#  [['waterSensor', 'valve'], 'leakage', ['waterSensor', 'valve']],
#  [['device.jawboneUser', 'musicPlayer'], 'location', ['location', 'lock']],
#  [['device.jawboneUser', 'musicPlayer'], 'location', ['location', 'switch']],
#  [['device.jawboneUser', 'musicPlayer'],
#   'location',
#   ['location', 'thermostat']],
#  [['device.jawboneUser', 'musicPlayer'],
#   'location',
#   ['presenceSensor', 'colorControl']],
#  [['device.jawboneUser', 'musicPlayer'],
#   'location',
#   ['presenceSensor', 'imageCapture']],
#  [['device.jawboneUser', 'musicPlayer'],
#   'location',
#   ['presenceSensor', 'locationMode']],
#  [['device.jawboneUser', 'musicPlayer'],
#   'location',
#   ['presenceSensor', 'lock']],
#  [['device.jawboneUser', 'musicPlayer'],
#   'location',
#   ['presenceSensor', 'momentary']],
#  [['device.jawboneUser', 'musicPlayer'],
#   'location',
#   ['presenceSensor', 'number']],
#  [['device.jawboneUser', 'musicPlayer'],
#   'location',
#   ['presenceSensor', 'sendAction']],
#  [['device.jawboneUser', 'musicPlayer'],
#   'location',
#   ['presenceSensor', 'switch']],
#  [['app', 'doorControl'], 'lock', ['button', 'colorControl']],
#  [['app', 'doorControl'], 'lock', ['button', 'locationMode']],
#  [['app', 'doorControl'], 'lock', ['button', 'sendAction']],
#  [['app', 'doorControl'], 'lock', ['contactSensor', 'alarm']],
#  [['app', 'doorControl'], 'lock', ['contactSensor', 'colorControl']],
#  [['app', 'doorControl'], 'lock', ['contactSensor', 'imageCapture']],
#  [['app', 'doorControl'], 'lock', ['contactSensor', 'locationMode']],
#  [['app', 'doorControl'], 'lock', ['contactSensor', 'momentary']],
#  [['app', 'doorControl'], 'lock', ['contactSensor', 'number']],
#  [['app', 'doorControl'], 'lock', ['contactSensor', 'sendAction']],
#  [['app', 'doorControl'], 'lock', ['contactSensor', 'switch']],
#  [['app', 'doorControl'], 'lock', ['contactSensor', 'thermostat']],
#  [['app', 'doorControl'], 'lock', ['touchSensor', 'doorControl']],
#  [['app', 'doorControl'], 'lock', ['touchSensor', 'lock']],
#  [['app', 'doorControl'], 'lock', ['touchSensor', 'switch']],
#  [['app', 'lock'], 'lock', ['button', 'colorControl']],
#  [['app', 'lock'], 'lock', ['button', 'locationMode']],
#  [['app', 'lock'], 'lock', ['button', 'sendAction']],
#  [['app', 'lock'], 'lock', ['contactSensor', 'alarm']],
#  [['app', 'lock'], 'lock', ['contactSensor', 'colorControl']],
#  [['app', 'lock'], 'lock', ['contactSensor', 'imageCapture']],
#  [['app', 'lock'], 'lock', ['contactSensor', 'locationMode']],
#  [['app', 'lock'], 'lock', ['contactSensor', 'momentary']],
#  [['app', 'lock'], 'lock', ['contactSensor', 'number']],
#  [['app', 'lock'], 'lock', ['contactSensor', 'sendAction']],
#  [['app', 'lock'], 'lock', ['contactSensor', 'switch']],
#  [['app', 'lock'], 'lock', ['contactSensor', 'thermostat']],
#  [['app', 'lock'], 'lock', ['touchSensor', 'doorControl']],
#  [['app', 'lock'], 'lock', ['touchSensor', 'lock']],
#  [['app', 'lock'], 'lock', ['touchSensor', 'switch']],
#  [['beacon', 'lock'], 'lock', ['button', 'colorControl']],
#  [['beacon', 'lock'], 'lock', ['button', 'locationMode']],
#  [['beacon', 'lock'], 'lock', ['button', 'sendAction']],
#  [['beacon', 'lock'], 'lock', ['contactSensor', 'alarm']],
#  [['beacon', 'lock'], 'lock', ['contactSensor', 'colorControl']],
#  [['beacon', 'lock'], 'lock', ['contactSensor', 'imageCapture']],
#  [['beacon', 'lock'], 'lock', ['contactSensor', 'locationMode']],
#  [['beacon', 'lock'], 'lock', ['contactSensor', 'momentary']],
#  [['beacon', 'lock'], 'lock', ['contactSensor', 'number']],
#  [['beacon', 'lock'], 'lock', ['contactSensor', 'sendAction']],
#  [['beacon', 'lock'], 'lock', ['contactSensor', 'switch']],
#  [['beacon', 'lock'], 'lock', ['contactSensor', 'thermostat']],
#  [['beacon', 'lock'], 'lock', ['touchSensor', 'doorControl']],
#  [['beacon', 'lock'], 'lock', ['touchSensor', 'lock']],
#  [['beacon', 'lock'], 'lock', ['touchSensor', 'switch']],
#  [['location', 'lock'], 'lock', ['button', 'colorControl']],
#  [['location', 'lock'], 'lock', ['button', 'locationMode']],
#  [['location', 'lock'], 'lock', ['button', 'sendAction']],
#  [['location', 'lock'], 'lock', ['contactSensor', 'alarm']],
#  [['location', 'lock'], 'lock', ['contactSensor', 'colorControl']],
#  [['location', 'lock'], 'lock', ['contactSensor', 'imageCapture']],
#  [['location', 'lock'], 'lock', ['contactSensor', 'locationMode']],
#  [['location', 'lock'], 'lock', ['contactSensor', 'momentary']],
#  [['location', 'lock'], 'lock', ['contactSensor', 'number']],
#  [['location', 'lock'], 'lock', ['contactSensor', 'sendAction']],
#  [['location', 'lock'], 'lock', ['contactSensor', 'switch']],
#  [['location', 'lock'], 'lock', ['contactSensor', 'thermostat']],
#  [['location', 'lock'], 'lock', ['touchSensor', 'doorControl']],
#  [['location', 'lock'], 'lock', ['touchSensor', 'lock']],
#  [['location', 'lock'], 'lock', ['touchSensor', 'switch']],
#  [['presenceSensor', 'lock'], 'lock', ['button', 'colorControl']],
#  [['presenceSensor', 'lock'], 'lock', ['button', 'locationMode']],
#  [['presenceSensor', 'lock'], 'lock', ['button', 'sendAction']],
#  [['presenceSensor', 'lock'], 'lock', ['contactSensor', 'alarm']],
#  [['presenceSensor', 'lock'], 'lock', ['contactSensor', 'colorControl']],
#  [['presenceSensor', 'lock'], 'lock', ['contactSensor', 'imageCapture']],
#  [['presenceSensor', 'lock'], 'lock', ['contactSensor', 'locationMode']],
#  [['presenceSensor', 'lock'], 'lock', ['contactSensor', 'momentary']],
#  [['presenceSensor', 'lock'], 'lock', ['contactSensor', 'number']],
#  [['presenceSensor', 'lock'], 'lock', ['contactSensor', 'sendAction']],
#  [['presenceSensor', 'lock'], 'lock', ['contactSensor', 'switch']],
#  [['presenceSensor', 'lock'], 'lock', ['contactSensor', 'thermostat']],
#  [['presenceSensor', 'lock'], 'lock', ['touchSensor', 'doorControl']],
#  [['presenceSensor', 'lock'], 'lock', ['touchSensor', 'lock']],
#  [['presenceSensor', 'lock'], 'lock', ['touchSensor', 'switch']],
#  [['time', 'device.PetFeederShield'], 'lock', ['button', 'colorControl']],
#  [['time', 'device.PetFeederShield'], 'lock', ['button', 'locationMode']],
#  [['time', 'device.PetFeederShield'], 'lock', ['button', 'sendAction']],
#  [['time', 'device.PetFeederShield'], 'lock', ['contactSensor', 'alarm']],
#  [['time', 'device.PetFeederShield'],
#   'lock',
#   ['contactSensor', 'colorControl']],
#  [['time', 'device.PetFeederShield'],
#   'lock',
#   ['contactSensor', 'imageCapture']],
#  [['time', 'device.PetFeederShield'],
#   'lock',
#   ['contactSensor', 'locationMode']],
#  [['time', 'device.PetFeederShield'], 'lock', ['contactSensor', 'momentary']],
#  [['time', 'device.PetFeederShield'], 'lock', ['contactSensor', 'number']],
#  [['time', 'device.PetFeederShield'], 'lock', ['contactSensor', 'sendAction']],
#  [['time', 'device.PetFeederShield'], 'lock', ['contactSensor', 'switch']],
#  [['time', 'device.PetFeederShield'], 'lock', ['contactSensor', 'thermostat']],
#  [['time', 'device.PetFeederShield'], 'lock', ['touchSensor', 'doorControl']],
#  [['time', 'device.PetFeederShield'], 'lock', ['touchSensor', 'lock']],
#  [['time', 'device.PetFeederShield'], 'lock', ['touchSensor', 'switch']],
#  [['time', 'lock'], 'lock', ['button', 'colorControl']],
#  [['time', 'lock'], 'lock', ['button', 'locationMode']],
#  [['time', 'lock'], 'lock', ['button', 'sendAction']],
#  [['time', 'lock'], 'lock', ['contactSensor', 'alarm']],
#  [['time', 'lock'], 'lock', ['contactSensor', 'colorControl']],
#  [['time', 'lock'], 'lock', ['contactSensor', 'imageCapture']],
#  [['time', 'lock'], 'lock', ['contactSensor', 'locationMode']],
#  [['time', 'lock'], 'lock', ['contactSensor', 'momentary']],
#  [['time', 'lock'], 'lock', ['contactSensor', 'number']],
#  [['time', 'lock'], 'lock', ['contactSensor', 'sendAction']],
#  [['time', 'lock'], 'lock', ['contactSensor', 'switch']],
#  [['time', 'lock'], 'lock', ['contactSensor', 'thermostat']],
#  [['time', 'lock'], 'lock', ['touchSensor', 'doorControl']],
#  [['time', 'lock'], 'lock', ['touchSensor', 'lock']],
#  [['time', 'lock'], 'lock', ['touchSensor', 'switch']],
#  [['touchSensor', 'doorControl'], 'lock', ['button', 'colorControl']],
#  [['touchSensor', 'doorControl'], 'lock', ['button', 'locationMode']],
#  [['touchSensor', 'doorControl'], 'lock', ['button', 'sendAction']],
#  [['touchSensor', 'doorControl'], 'lock', ['contactSensor', 'alarm']],
#  [['touchSensor', 'doorControl'], 'lock', ['contactSensor', 'colorControl']],
#  [['touchSensor', 'doorControl'], 'lock', ['contactSensor', 'imageCapture']],
#  [['touchSensor', 'doorControl'], 'lock', ['contactSensor', 'locationMode']],
#  [['touchSensor', 'doorControl'], 'lock', ['contactSensor', 'momentary']],
#  [['touchSensor', 'doorControl'], 'lock', ['contactSensor', 'number']],
#  [['touchSensor', 'doorControl'], 'lock', ['contactSensor', 'sendAction']],
#  [['touchSensor', 'doorControl'], 'lock', ['contactSensor', 'switch']],
#  [['touchSensor', 'doorControl'], 'lock', ['contactSensor', 'thermostat']],
#  [['touchSensor', 'doorControl'], 'lock', ['touchSensor', 'doorControl']],
#  [['touchSensor', 'doorControl'], 'lock', ['touchSensor', 'lock']],
#  [['touchSensor', 'doorControl'], 'lock', ['touchSensor', 'switch']],
#  [['touchSensor', 'lock'], 'lock', ['button', 'colorControl']],
#  [['touchSensor', 'lock'], 'lock', ['button', 'locationMode']],
#  [['touchSensor', 'lock'], 'lock', ['button', 'sendAction']],
#  [['touchSensor', 'lock'], 'lock', ['contactSensor', 'alarm']],
#  [['touchSensor', 'lock'], 'lock', ['contactSensor', 'colorControl']],
#  [['touchSensor', 'lock'], 'lock', ['contactSensor', 'imageCapture']],
#  [['touchSensor', 'lock'], 'lock', ['contactSensor', 'locationMode']],
#  [['touchSensor', 'lock'], 'lock', ['contactSensor', 'momentary']],
#  [['touchSensor', 'lock'], 'lock', ['contactSensor', 'number']],
#  [['touchSensor', 'lock'], 'lock', ['contactSensor', 'sendAction']],
#  [['touchSensor', 'lock'], 'lock', ['contactSensor', 'switch']],
#  [['touchSensor', 'lock'], 'lock', ['contactSensor', 'thermostat']],
#  [['touchSensor', 'lock'], 'lock', ['touchSensor', 'doorControl']],
#  [['touchSensor', 'lock'], 'lock', ['touchSensor', 'lock']],
#  [['touchSensor', 'lock'], 'lock', ['touchSensor', 'switch']],
#  [['accelerationSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'colorControl']],
#  [['accelerationSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'imageCapture']],
#  [['accelerationSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'momentary']],
#  [['accelerationSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'number']],
#  [['accelerationSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'sendAction']],
#  [['accelerationSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'switch']],
#  [['accelerationSensor', 'sendAction'], 'motion', ['motionSensor', 'alarm']],
#  [['accelerationSensor', 'sendAction'],
#   'motion',
#   ['motionSensor', 'colorControl']],
#  [['accelerationSensor', 'sendAction'],
#   'motion',
#   ['motionSensor', 'imageCapture']],
#  [['accelerationSensor', 'sendAction'],
#   'motion',
#   ['motionSensor', 'locationMode']],
#  [['accelerationSensor', 'sendAction'], 'motion', ['motionSensor', 'number']],
#  [['accelerationSensor', 'sendAction'],
#   'motion',
#   ['motionSensor', 'sendAction']],
#  [['accelerationSensor', 'sendAction'], 'motion', ['motionSensor', 'switch']],
#  [['button', 'sendAction'], 'motion', ['accelerationSensor', 'colorControl']],
#  [['button', 'sendAction'], 'motion', ['accelerationSensor', 'imageCapture']],
#  [['button', 'sendAction'], 'motion', ['accelerationSensor', 'momentary']],
#  [['button', 'sendAction'], 'motion', ['accelerationSensor', 'number']],
#  [['button', 'sendAction'], 'motion', ['accelerationSensor', 'sendAction']],
#  [['button', 'sendAction'], 'motion', ['accelerationSensor', 'switch']],
#  [['button', 'sendAction'], 'motion', ['motionSensor', 'alarm']],
#  [['button', 'sendAction'], 'motion', ['motionSensor', 'colorControl']],
#  [['button', 'sendAction'], 'motion', ['motionSensor', 'imageCapture']],
#  [['button', 'sendAction'], 'motion', ['motionSensor', 'locationMode']],
#  [['button', 'sendAction'], 'motion', ['motionSensor', 'number']],
#  [['button', 'sendAction'], 'motion', ['motionSensor', 'sendAction']],
#  [['button', 'sendAction'], 'motion', ['motionSensor', 'switch']],
#  [['carbonMonoxideDetector', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'colorControl']],
#  [['carbonMonoxideDetector', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'imageCapture']],
#  [['carbonMonoxideDetector', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'momentary']],
#  [['carbonMonoxideDetector', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'number']],
#  [['carbonMonoxideDetector', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'sendAction']],
#  [['carbonMonoxideDetector', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'switch']],
#  [['carbonMonoxideDetector', 'sendAction'],
#   'motion',
#   ['motionSensor', 'alarm']],
#  [['carbonMonoxideDetector', 'sendAction'],
#   'motion',
#   ['motionSensor', 'colorControl']],
#  [['carbonMonoxideDetector', 'sendAction'],
#   'motion',
#   ['motionSensor', 'imageCapture']],
#  [['carbonMonoxideDetector', 'sendAction'],
#   'motion',
#   ['motionSensor', 'locationMode']],
#  [['carbonMonoxideDetector', 'sendAction'],
#   'motion',
#   ['motionSensor', 'number']],
#  [['carbonMonoxideDetector', 'sendAction'],
#   'motion',
#   ['motionSensor', 'sendAction']],
#  [['carbonMonoxideDetector', 'sendAction'],
#   'motion',
#   ['motionSensor', 'switch']],
#  [['contactSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'colorControl']],
#  [['contactSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'imageCapture']],
# ...
#   'motion',
#   ['accelerationSensor', 'switch']],
#  [['device.jawboneUser', 'sendAction'], 'motion', ['motionSensor', 'alarm']],
#  [['device.jawboneUser', 'sendAction'],
#   'motion',
#   ['motionSensor', 'colorControl']],
#  [['device.jawboneUser', 'sendAction'],
#   'motion',
#   ['motionSensor', 'imageCapture']],
#  [['device.jawboneUser', 'sendAction'],
#   'motion',
#   ['motionSensor', 'locationMode']],
#  [['device.jawboneUser', 'sendAction'], 'motion', ['motionSensor', 'number']],
#  [['device.jawboneUser', 'sendAction'],
#   'motion',
#   ['motionSensor', 'sendAction']],
#  [['device.jawboneUser', 'sendAction'], 'motion', ['motionSensor', 'switch']],
#  [['motionSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'colorControl']],
#  [['motionSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'imageCapture']],
#  [['motionSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'momentary']],
#  [['motionSensor', 'sendAction'], 'motion', ['accelerationSensor', 'number']],
#  [['motionSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'sendAction']],
#  [['motionSensor', 'sendAction'], 'motion', ['accelerationSensor', 'switch']],
#  [['motionSensor', 'sendAction'], 'motion', ['motionSensor', 'alarm']],
#  [['motionSensor', 'sendAction'], 'motion', ['motionSensor', 'colorControl']],
#  [['motionSensor', 'sendAction'], 'motion', ['motionSensor', 'imageCapture']],
#  [['motionSensor', 'sendAction'], 'motion', ['motionSensor', 'locationMode']],
#  [['motionSensor', 'sendAction'], 'motion', ['motionSensor', 'number']],
#  [['motionSensor', 'sendAction'], 'motion', ['motionSensor', 'sendAction']],
#  [['motionSensor', 'sendAction'], 'motion', ['motionSensor', 'switch']],
#  [['powerMeter', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'colorControl']],
#  [['powerMeter', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'imageCapture']],
#  [['powerMeter', 'sendAction'], 'motion', ['accelerationSensor', 'momentary']],
#  [['powerMeter', 'sendAction'], 'motion', ['accelerationSensor', 'number']],
#  [['powerMeter', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'sendAction']],
#  [['powerMeter', 'sendAction'], 'motion', ['accelerationSensor', 'switch']],
#  [['powerMeter', 'sendAction'], 'motion', ['motionSensor', 'alarm']],
#  [['powerMeter', 'sendAction'], 'motion', ['motionSensor', 'colorControl']],
#  [['powerMeter', 'sendAction'], 'motion', ['motionSensor', 'imageCapture']],
#  [['powerMeter', 'sendAction'], 'motion', ['motionSensor', 'locationMode']],
#  [['powerMeter', 'sendAction'], 'motion', ['motionSensor', 'number']],
#  [['powerMeter', 'sendAction'], 'motion', ['motionSensor', 'sendAction']],
#  [['powerMeter', 'sendAction'], 'motion', ['motionSensor', 'switch']],
#  [['presenceSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'colorControl']],
#  [['presenceSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'imageCapture']],
#  [['presenceSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'momentary']],
#  [['presenceSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'number']],
#  [['presenceSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'sendAction']],
#  [['presenceSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'switch']],
#  [['presenceSensor', 'sendAction'], 'motion', ['motionSensor', 'alarm']],
#  [['presenceSensor', 'sendAction'],
#   'motion',
#   ['motionSensor', 'colorControl']],
#  [['presenceSensor', 'sendAction'],
#   'motion',
#   ['motionSensor', 'imageCapture']],
#  [['presenceSensor', 'sendAction'],
#   'motion',
#   ['motionSensor', 'locationMode']],
#  [['presenceSensor', 'sendAction'], 'motion', ['motionSensor', 'number']],
#  [['presenceSensor', 'sendAction'], 'motion', ['motionSensor', 'sendAction']],
#  [['presenceSensor', 'sendAction'], 'motion', ['motionSensor', 'switch']],
#  [['relativeHumidityMeasurement', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'colorControl']],
#  [['relativeHumidityMeasurement', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'imageCapture']],
#  [['relativeHumidityMeasurement', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'momentary']],
#  [['relativeHumidityMeasurement', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'number']],
#  [['relativeHumidityMeasurement', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'sendAction']],
#  [['relativeHumidityMeasurement', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'switch']],
#  [['relativeHumidityMeasurement', 'sendAction'],
#   'motion',
#   ['motionSensor', 'alarm']],
#  [['relativeHumidityMeasurement', 'sendAction'],
#   'motion',
#   ['motionSensor', 'colorControl']],
#  [['relativeHumidityMeasurement', 'sendAction'],
#   'motion',
#   ['motionSensor', 'imageCapture']],
#  [['relativeHumidityMeasurement', 'sendAction'],
#   'motion',
#   ['motionSensor', 'locationMode']],
#  [['relativeHumidityMeasurement', 'sendAction'],
#   'motion',
#   ['motionSensor', 'number']],
#  [['relativeHumidityMeasurement', 'sendAction'],
#   'motion',
#   ['motionSensor', 'sendAction']],
#  [['relativeHumidityMeasurement', 'sendAction'],
#   'motion',
#   ['motionSensor', 'switch']],
#  [['smokeDetector', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'colorControl']],
#  [['smokeDetector', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'imageCapture']],
#  [['smokeDetector', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'momentary']],
#  [['smokeDetector', 'sendAction'], 'motion', ['accelerationSensor', 'number']],
#  [['smokeDetector', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'sendAction']],
#  [['smokeDetector', 'sendAction'], 'motion', ['accelerationSensor', 'switch']],
#  [['smokeDetector', 'sendAction'], 'motion', ['motionSensor', 'alarm']],
#  [['smokeDetector', 'sendAction'], 'motion', ['motionSensor', 'colorControl']],
#  [['smokeDetector', 'sendAction'], 'motion', ['motionSensor', 'imageCapture']],
#  [['smokeDetector', 'sendAction'], 'motion', ['motionSensor', 'locationMode']],
#  [['smokeDetector', 'sendAction'], 'motion', ['motionSensor', 'number']],
#  [['smokeDetector', 'sendAction'], 'motion', ['motionSensor', 'sendAction']],
#  [['smokeDetector', 'sendAction'], 'motion', ['motionSensor', 'switch']],
#  [['switch', 'sendAction'], 'motion', ['accelerationSensor', 'colorControl']],
#  [['switch', 'sendAction'], 'motion', ['accelerationSensor', 'imageCapture']],
#  [['switch', 'sendAction'], 'motion', ['accelerationSensor', 'momentary']],
#  [['switch', 'sendAction'], 'motion', ['accelerationSensor', 'number']],
#  [['switch', 'sendAction'], 'motion', ['accelerationSensor', 'sendAction']],
#  [['switch', 'sendAction'], 'motion', ['accelerationSensor', 'switch']],
#  [['switch', 'sendAction'], 'motion', ['motionSensor', 'alarm']],
#  [['switch', 'sendAction'], 'motion', ['motionSensor', 'colorControl']],
#  [['switch', 'sendAction'], 'motion', ['motionSensor', 'imageCapture']],
#  [['switch', 'sendAction'], 'motion', ['motionSensor', 'locationMode']],
#  [['switch', 'sendAction'], 'motion', ['motionSensor', 'number']],
#  [['switch', 'sendAction'], 'motion', ['motionSensor', 'sendAction']],
#  [['switch', 'sendAction'], 'motion', ['motionSensor', 'switch']],
#  [['temperatureMeasurement', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'colorControl']],
#  [['temperatureMeasurement', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'imageCapture']],
#  [['temperatureMeasurement', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'momentary']],
#  [['temperatureMeasurement', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'number']],
#  [['temperatureMeasurement', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'sendAction']],
#  [['temperatureMeasurement', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'switch']],
#  [['temperatureMeasurement', 'sendAction'],
#   'motion',
#   ['motionSensor', 'alarm']],
#  [['temperatureMeasurement', 'sendAction'],
#   'motion',
#   ['motionSensor', 'colorControl']],
#  [['temperatureMeasurement', 'sendAction'],
#   'motion',
#   ['motionSensor', 'imageCapture']],
#  [['temperatureMeasurement', 'sendAction'],
#   'motion',
#   ['motionSensor', 'locationMode']],
#  [['temperatureMeasurement', 'sendAction'],
#   'motion',
#   ['motionSensor', 'number']],
#  [['temperatureMeasurement', 'sendAction'],
#   'motion',
#   ['motionSensor', 'sendAction']],
#  [['temperatureMeasurement', 'sendAction'],
#   'motion',
#   ['motionSensor', 'switch']],
#  [['threeAxis', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'colorControl']],
#  [['threeAxis', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'imageCapture']],
#  [['threeAxis', 'sendAction'], 'motion', ['accelerationSensor', 'momentary']],
#  [['threeAxis', 'sendAction'], 'motion', ['accelerationSensor', 'number']],
#  [['threeAxis', 'sendAction'], 'motion', ['accelerationSensor', 'sendAction']],
#  [['threeAxis', 'sendAction'], 'motion', ['accelerationSensor', 'switch']],
#  [['threeAxis', 'sendAction'], 'motion', ['motionSensor', 'alarm']],
#  [['threeAxis', 'sendAction'], 'motion', ['motionSensor', 'colorControl']],
#  [['threeAxis', 'sendAction'], 'motion', ['motionSensor', 'imageCapture']],
#  [['threeAxis', 'sendAction'], 'motion', ['motionSensor', 'locationMode']],
#  [['threeAxis', 'sendAction'], 'motion', ['motionSensor', 'number']],
#  [['threeAxis', 'sendAction'], 'motion', ['motionSensor', 'sendAction']],
#  [['threeAxis', 'sendAction'], 'motion', ['motionSensor', 'switch']],
#  [['time', 'sendAction'], 'motion', ['accelerationSensor', 'colorControl']],
#  [['time', 'sendAction'], 'motion', ['accelerationSensor', 'imageCapture']],
#  [['time', 'sendAction'], 'motion', ['accelerationSensor', 'momentary']],
#  [['time', 'sendAction'], 'motion', ['accelerationSensor', 'number']],
#  [['time', 'sendAction'], 'motion', ['accelerationSensor', 'sendAction']],
#  [['time', 'sendAction'], 'motion', ['accelerationSensor', 'switch']],
#  [['time', 'sendAction'], 'motion', ['motionSensor', 'alarm']],
#  [['time', 'sendAction'], 'motion', ['motionSensor', 'colorControl']],
#  [['time', 'sendAction'], 'motion', ['motionSensor', 'imageCapture']],
#  [['time', 'sendAction'], 'motion', ['motionSensor', 'locationMode']],
#  [['time', 'sendAction'], 'motion', ['motionSensor', 'number']],
#  [['time', 'sendAction'], 'motion', ['motionSensor', 'sendAction']],
#  [['time', 'sendAction'], 'motion', ['motionSensor', 'switch']],
#  [['waterSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'colorControl']],
#  [['waterSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'imageCapture']],
#  [['waterSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'momentary']],
#  [['waterSensor', 'sendAction'], 'motion', ['accelerationSensor', 'number']],
#  [['waterSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'sendAction']],
#  [['waterSensor', 'sendAction'], 'motion', ['accelerationSensor', 'switch']],
#  [['waterSensor', 'sendAction'], 'motion', ['motionSensor', 'alarm']],
#  [['waterSensor', 'sendAction'], 'motion', ['motionSensor', 'colorControl']],
#  [['waterSensor', 'sendAction'], 'motion', ['motionSensor', 'imageCapture']],
#  [['waterSensor', 'sendAction'], 'motion', ['motionSensor', 'locationMode']],
#  [['waterSensor', 'sendAction'], 'motion', ['motionSensor', 'number']],
#  [['waterSensor', 'sendAction'], 'motion', ['motionSensor', 'sendAction']],
#  [['waterSensor', 'sendAction'], 'motion', ['motionSensor', 'switch']],
#  [['alarm', 'alarm'], 'smoke', ['alarm', 'alarm']],
#  [['alarm', 'alarm'], 'smoke', ['carbonMonoxideDetector', 'sendAction']],
#  [['alarm', 'alarm'], 'smoke', ['carbonMonoxideDetector', 'thermostat']],
#  [['alarm', 'alarm'], 'smoke', ['smokeDetector', 'colorControl']],
#  [['alarm', 'alarm'], 'smoke', ['smokeDetector', 'sendAction']],
#  [['alarm', 'alarm'], 'smoke', ['smokeDetector', 'thermostat']],
#  [['app', 'alarm'], 'smoke', ['alarm', 'alarm']],
#  [['app', 'alarm'], 'smoke', ['carbonMonoxideDetector', 'sendAction']],
#  [['app', 'alarm'], 'smoke', ['carbonMonoxideDetector', 'thermostat']],
#  [['app', 'alarm'], 'smoke', ['smokeDetector', 'colorControl']],
#  [['app', 'alarm'], 'smoke', ['smokeDetector', 'sendAction']],
#  [['app', 'alarm'], 'smoke', ['smokeDetector', 'thermostat']],
#  [['contactSensor', 'alarm'], 'smoke', ['alarm', 'alarm']],
#  [['contactSensor', 'alarm'],
#   'smoke',
#   ['carbonMonoxideDetector', 'sendAction']],
#  [['contactSensor', 'alarm'],
#   'smoke',
#   ['carbonMonoxideDetector', 'thermostat']],
#  [['contactSensor', 'alarm'], 'smoke', ['smokeDetector', 'colorControl']],
#  [['contactSensor', 'alarm'], 'smoke', ['smokeDetector', 'sendAction']],
#  [['contactSensor', 'alarm'], 'smoke', ['smokeDetector', 'thermostat']],
#  [['motionSensor', 'alarm'], 'smoke', ['alarm', 'alarm']],
#  [['motionSensor', 'alarm'],
#   'smoke',
#   ['carbonMonoxideDetector', 'sendAction']],
#  [['motionSensor', 'alarm'],
#   'smoke',
#   ['carbonMonoxideDetector', 'thermostat']],
#  [['motionSensor', 'alarm'], 'smoke', ['smokeDetector', 'colorControl']],
#  [['motionSensor', 'alarm'], 'smoke', ['smokeDetector', 'sendAction']],
#  [['motionSensor', 'alarm'], 'smoke', ['smokeDetector', 'thermostat']],
#  [['app', 'thermostat'], 'temperature', ['thermostat', 'switch']],
#  [['app', 'thermostat'], 'temperature', ['thermostat', 'thermostat']],
#  [['carbonMonoxideDetector', 'thermostat'],
#   'temperature',
#   ['thermostat', 'switch']],
#  [['carbonMonoxideDetector', 'thermostat'],
#   'temperature',
#   ['thermostat', 'thermostat']],
#  [['contactSensor', 'thermostat'], 'temperature', ['thermostat', 'switch']],
#  [['contactSensor', 'thermostat'],
#   'temperature',
#   ['thermostat', 'thermostat']],
#  [['location', 'thermostat'], 'temperature', ['thermostat', 'switch']],
#  [['location', 'thermostat'], 'temperature', ['thermostat', 'thermostat']],
#  [['smokeDetector', 'thermostat'], 'temperature', ['thermostat', 'switch']],
#  [['smokeDetector', 'thermostat'],
#   'temperature',
#   ['thermostat', 'thermostat']],
#  [['temperatureMeasurement', 'thermostat'],
#   'temperature',
#   ['thermostat', 'switch']],
#  [['temperatureMeasurement', 'thermostat'],
#   'temperature',
#   ['thermostat', 'thermostat']],
#  [['thermostat', 'thermostat'], 'temperature', ['thermostat', 'switch']],
#  [['thermostat', 'thermostat'], 'temperature', ['thermostat', 'thermostat']],
#  [['accelerationSensor', 'number'], 'time', ['threeAxis', 'sendAction']],
#  [['accelerationSensor', 'number'],
#   'time',
#   ['time', 'device.PetFeederShield']],
#  [['accelerationSensor', 'number'], 'time', ['time', 'locationMode']],
#  [['accelerationSensor', 'number'], 'time', ['time', 'lock']],
#  [['accelerationSensor', 'number'], 'time', ['time', 'sendAction']],
#  [['accelerationSensor', 'number'], 'time', ['time', 'switch']],
#  [['contactSensor', 'number'], 'time', ['threeAxis', 'sendAction']],
#  [['contactSensor', 'number'], 'time', ['time', 'device.PetFeederShield']],
#  [['contactSensor', 'number'], 'time', ['time', 'locationMode']],
#  [['contactSensor', 'number'], 'time', ['time', 'lock']],
#  [['contactSensor', 'number'], 'time', ['time', 'sendAction']],
#  [['contactSensor', 'number'], 'time', ['time', 'switch']],
#  [['motionSensor', 'number'], 'time', ['threeAxis', 'sendAction']],
#  [['motionSensor', 'number'], 'time', ['time', 'device.PetFeederShield']],
#  [['motionSensor', 'number'], 'time', ['time', 'locationMode']],
#  [['motionSensor', 'number'], 'time', ['time', 'lock']],
#  [['motionSensor', 'number'], 'time', ['time', 'sendAction']],
#  [['motionSensor', 'number'], 'time', ['time', 'switch']],
#  [['presenceSensor', 'number'], 'time', ['threeAxis', 'sendAction']],
#  [['presenceSensor', 'number'], 'time', ['time', 'device.PetFeederShield']],
#  [['presenceSensor', 'number'], 'time', ['time', 'locationMode']],
#  [['presenceSensor', 'number'], 'time', ['time', 'lock']],
#  [['presenceSensor', 'number'], 'time', ['time', 'sendAction']],
#  [['presenceSensor', 'number'], 'time', ['time', 'switch']],
#  [['switch', 'number'], 'time', ['threeAxis', 'sendAction']],
#  [['switch', 'number'], 'time', ['time', 'device.PetFeederShield']],
#  [['switch', 'number'], 'time', ['time', 'locationMode']],
#  [['switch', 'number'], 'time', ['time', 'lock']],
#  [['switch', 'number'], 'time', ['time', 'sendAction']],
#  [['switch', 'number'], 'time', ['time', 'switch']]]

# %%
for triple in INTAC:
    first_app = triple[0]
    channel = triple[1]
    second_app = triple[2]
    print(f"tri_1:{first_app[0]}, act_1:{first_app[1]}\t-- {channel} -- tri_2:{second_app[0]}, act:{second_app[1]}")
# Out:
# tri_1:accelerationSensor, act_1:colorControl	-- illumination -- tri_2:beacon, act:lock
# tri_1:accelerationSensor, act_1:colorControl	-- illumination -- tri_2:beacon, act:switch
# tri_1:accelerationSensor, act_1:colorControl	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:accelerationSensor, act_1:colorControl	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:accelerationSensor, act_1:colorControl	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:accelerationSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:colorControl
# tri_1:accelerationSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:accelerationSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:locationMode
# tri_1:accelerationSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:number
# tri_1:accelerationSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:sendAction
# tri_1:accelerationSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:switch
# tri_1:accelerationSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:accelerationSensor, act_1:imageCapture	-- illumination -- tri_2:beacon, act:lock
# tri_1:accelerationSensor, act_1:imageCapture	-- illumination -- tri_2:beacon, act:switch
# tri_1:accelerationSensor, act_1:imageCapture	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:accelerationSensor, act_1:imageCapture	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:accelerationSensor, act_1:imageCapture	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:accelerationSensor, act_1:imageCapture	-- illumination -- tri_2:switch, act:colorControl
# tri_1:accelerationSensor, act_1:imageCapture	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:accelerationSensor, act_1:imageCapture	-- illumination -- tri_2:switch, act:locationMode
# tri_1:accelerationSensor, act_1:imageCapture	-- illumination -- tri_2:switch, act:number
# tri_1:accelerationSensor, act_1:imageCapture	-- illumination -- tri_2:switch, act:sendAction
# tri_1:accelerationSensor, act_1:imageCapture	-- illumination -- tri_2:switch, act:switch
# tri_1:accelerationSensor, act_1:imageCapture	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:accelerationSensor, act_1:momentary	-- illumination -- tri_2:beacon, act:lock
# tri_1:accelerationSensor, act_1:momentary	-- illumination -- tri_2:beacon, act:switch
# tri_1:accelerationSensor, act_1:momentary	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:accelerationSensor, act_1:momentary	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:accelerationSensor, act_1:momentary	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:accelerationSensor, act_1:momentary	-- illumination -- tri_2:switch, act:colorControl
# tri_1:accelerationSensor, act_1:momentary	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:accelerationSensor, act_1:momentary	-- illumination -- tri_2:switch, act:locationMode
# tri_1:accelerationSensor, act_1:momentary	-- illumination -- tri_2:switch, act:number
# tri_1:accelerationSensor, act_1:momentary	-- illumination -- tri_2:switch, act:sendAction
# tri_1:accelerationSensor, act_1:momentary	-- illumination -- tri_2:switch, act:switch
# tri_1:accelerationSensor, act_1:momentary	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:accelerationSensor, act_1:switch	-- illumination -- tri_2:beacon, act:lock
# tri_1:accelerationSensor, act_1:switch	-- illumination -- tri_2:beacon, act:switch
# tri_1:accelerationSensor, act_1:switch	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:accelerationSensor, act_1:switch	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:accelerationSensor, act_1:switch	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:accelerationSensor, act_1:switch	-- illumination -- tri_2:switch, act:colorControl
# tri_1:accelerationSensor, act_1:switch	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:accelerationSensor, act_1:switch	-- illumination -- tri_2:switch, act:locationMode
# tri_1:accelerationSensor, act_1:switch	-- illumination -- tri_2:switch, act:number
# tri_1:accelerationSensor, act_1:switch	-- illumination -- tri_2:switch, act:sendAction
# tri_1:accelerationSensor, act_1:switch	-- illumination -- tri_2:switch, act:switch
# tri_1:accelerationSensor, act_1:switch	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:app, act_1:colorControl	-- illumination -- tri_2:beacon, act:lock
# tri_1:app, act_1:colorControl	-- illumination -- tri_2:beacon, act:switch
# tri_1:app, act_1:colorControl	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:app, act_1:colorControl	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:app, act_1:colorControl	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:app, act_1:colorControl	-- illumination -- tri_2:switch, act:colorControl
# tri_1:app, act_1:colorControl	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:app, act_1:colorControl	-- illumination -- tri_2:switch, act:locationMode
# tri_1:app, act_1:colorControl	-- illumination -- tri_2:switch, act:number
# tri_1:app, act_1:colorControl	-- illumination -- tri_2:switch, act:sendAction
# tri_1:app, act_1:colorControl	-- illumination -- tri_2:switch, act:switch
# tri_1:app, act_1:colorControl	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:app, act_1:switch	-- illumination -- tri_2:beacon, act:lock
# tri_1:app, act_1:switch	-- illumination -- tri_2:beacon, act:switch
# tri_1:app, act_1:switch	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:app, act_1:switch	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:app, act_1:switch	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:app, act_1:switch	-- illumination -- tri_2:switch, act:colorControl
# tri_1:app, act_1:switch	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:app, act_1:switch	-- illumination -- tri_2:switch, act:locationMode
# tri_1:app, act_1:switch	-- illumination -- tri_2:switch, act:number
# tri_1:app, act_1:switch	-- illumination -- tri_2:switch, act:sendAction
# tri_1:app, act_1:switch	-- illumination -- tri_2:switch, act:switch
# tri_1:app, act_1:switch	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:beacon, act_1:switch	-- illumination -- tri_2:beacon, act:lock
# tri_1:beacon, act_1:switch	-- illumination -- tri_2:beacon, act:switch
# tri_1:beacon, act_1:switch	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:beacon, act_1:switch	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:beacon, act_1:switch	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:beacon, act_1:switch	-- illumination -- tri_2:switch, act:colorControl
# tri_1:beacon, act_1:switch	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:beacon, act_1:switch	-- illumination -- tri_2:switch, act:locationMode
# tri_1:beacon, act_1:switch	-- illumination -- tri_2:switch, act:number
# tri_1:beacon, act_1:switch	-- illumination -- tri_2:switch, act:sendAction
# tri_1:beacon, act_1:switch	-- illumination -- tri_2:switch, act:switch
# tri_1:beacon, act_1:switch	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:button, act_1:colorControl	-- illumination -- tri_2:beacon, act:lock
# tri_1:button, act_1:colorControl	-- illumination -- tri_2:beacon, act:switch
# tri_1:button, act_1:colorControl	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:button, act_1:colorControl	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:button, act_1:colorControl	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:button, act_1:colorControl	-- illumination -- tri_2:switch, act:colorControl
# tri_1:button, act_1:colorControl	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:button, act_1:colorControl	-- illumination -- tri_2:switch, act:locationMode
# tri_1:button, act_1:colorControl	-- illumination -- tri_2:switch, act:number
# tri_1:button, act_1:colorControl	-- illumination -- tri_2:switch, act:sendAction
# tri_1:button, act_1:colorControl	-- illumination -- tri_2:switch, act:switch
# tri_1:button, act_1:colorControl	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:contactSensor, act_1:colorControl	-- illumination -- tri_2:beacon, act:lock
# tri_1:contactSensor, act_1:colorControl	-- illumination -- tri_2:beacon, act:switch
# tri_1:contactSensor, act_1:colorControl	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:contactSensor, act_1:colorControl	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:contactSensor, act_1:colorControl	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:contactSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:colorControl
# tri_1:contactSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:contactSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:locationMode
# tri_1:contactSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:number
# tri_1:contactSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:sendAction
# tri_1:contactSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:switch
# tri_1:contactSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:contactSensor, act_1:imageCapture	-- illumination -- tri_2:beacon, act:lock
# tri_1:contactSensor, act_1:imageCapture	-- illumination -- tri_2:beacon, act:switch
# tri_1:contactSensor, act_1:imageCapture	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:contactSensor, act_1:imageCapture	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:contactSensor, act_1:imageCapture	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:contactSensor, act_1:imageCapture	-- illumination -- tri_2:switch, act:colorControl
# tri_1:contactSensor, act_1:imageCapture	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:contactSensor, act_1:imageCapture	-- illumination -- tri_2:switch, act:locationMode
# tri_1:contactSensor, act_1:imageCapture	-- illumination -- tri_2:switch, act:number
# tri_1:contactSensor, act_1:imageCapture	-- illumination -- tri_2:switch, act:sendAction
# tri_1:contactSensor, act_1:imageCapture	-- illumination -- tri_2:switch, act:switch
# tri_1:contactSensor, act_1:imageCapture	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:contactSensor, act_1:momentary	-- illumination -- tri_2:beacon, act:lock
# tri_1:contactSensor, act_1:momentary	-- illumination -- tri_2:beacon, act:switch
# tri_1:contactSensor, act_1:momentary	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:contactSensor, act_1:momentary	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:contactSensor, act_1:momentary	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:contactSensor, act_1:momentary	-- illumination -- tri_2:switch, act:colorControl
# tri_1:contactSensor, act_1:momentary	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:contactSensor, act_1:momentary	-- illumination -- tri_2:switch, act:locationMode
# tri_1:contactSensor, act_1:momentary	-- illumination -- tri_2:switch, act:number
# tri_1:contactSensor, act_1:momentary	-- illumination -- tri_2:switch, act:sendAction
# tri_1:contactSensor, act_1:momentary	-- illumination -- tri_2:switch, act:switch
# tri_1:contactSensor, act_1:momentary	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:contactSensor, act_1:switch	-- illumination -- tri_2:beacon, act:lock
# tri_1:contactSensor, act_1:switch	-- illumination -- tri_2:beacon, act:switch
# tri_1:contactSensor, act_1:switch	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:contactSensor, act_1:switch	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:contactSensor, act_1:switch	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:contactSensor, act_1:switch	-- illumination -- tri_2:switch, act:colorControl
# tri_1:contactSensor, act_1:switch	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:contactSensor, act_1:switch	-- illumination -- tri_2:switch, act:locationMode
# tri_1:contactSensor, act_1:switch	-- illumination -- tri_2:switch, act:number
# tri_1:contactSensor, act_1:switch	-- illumination -- tri_2:switch, act:sendAction
# tri_1:contactSensor, act_1:switch	-- illumination -- tri_2:switch, act:switch
# tri_1:contactSensor, act_1:switch	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:device.jawboneUser, act_1:colorControl	-- illumination -- tri_2:beacon, act:lock
# tri_1:device.jawboneUser, act_1:colorControl	-- illumination -- tri_2:beacon, act:switch
# tri_1:device.jawboneUser, act_1:colorControl	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:device.jawboneUser, act_1:colorControl	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:device.jawboneUser, act_1:colorControl	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:device.jawboneUser, act_1:colorControl	-- illumination -- tri_2:switch, act:colorControl
# tri_1:device.jawboneUser, act_1:colorControl	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:device.jawboneUser, act_1:colorControl	-- illumination -- tri_2:switch, act:locationMode
# tri_1:device.jawboneUser, act_1:colorControl	-- illumination -- tri_2:switch, act:number
# tri_1:device.jawboneUser, act_1:colorControl	-- illumination -- tri_2:switch, act:sendAction
# tri_1:device.jawboneUser, act_1:colorControl	-- illumination -- tri_2:switch, act:switch
# tri_1:device.jawboneUser, act_1:colorControl	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:device.jawboneUser, act_1:switch	-- illumination -- tri_2:beacon, act:lock
# tri_1:device.jawboneUser, act_1:switch	-- illumination -- tri_2:beacon, act:switch
# tri_1:device.jawboneUser, act_1:switch	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:device.jawboneUser, act_1:switch	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:device.jawboneUser, act_1:switch	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:device.jawboneUser, act_1:switch	-- illumination -- tri_2:switch, act:colorControl
# tri_1:device.jawboneUser, act_1:switch	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:device.jawboneUser, act_1:switch	-- illumination -- tri_2:switch, act:locationMode
# tri_1:device.jawboneUser, act_1:switch	-- illumination -- tri_2:switch, act:number
# tri_1:device.jawboneUser, act_1:switch	-- illumination -- tri_2:switch, act:sendAction
# tri_1:device.jawboneUser, act_1:switch	-- illumination -- tri_2:switch, act:switch
# tri_1:device.jawboneUser, act_1:switch	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:illuminanceMeasurement, act_1:switch	-- illumination -- tri_2:beacon, act:lock
# tri_1:illuminanceMeasurement, act_1:switch	-- illumination -- tri_2:beacon, act:switch
# tri_1:illuminanceMeasurement, act_1:switch	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:illuminanceMeasurement, act_1:switch	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:illuminanceMeasurement, act_1:switch	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:illuminanceMeasurement, act_1:switch	-- illumination -- tri_2:switch, act:colorControl
# tri_1:illuminanceMeasurement, act_1:switch	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:illuminanceMeasurement, act_1:switch	-- illumination -- tri_2:switch, act:locationMode
# tri_1:illuminanceMeasurement, act_1:switch	-- illumination -- tri_2:switch, act:number
# tri_1:illuminanceMeasurement, act_1:switch	-- illumination -- tri_2:switch, act:sendAction
# tri_1:illuminanceMeasurement, act_1:switch	-- illumination -- tri_2:switch, act:switch
# tri_1:illuminanceMeasurement, act_1:switch	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:location, act_1:switch	-- illumination -- tri_2:beacon, act:lock
# tri_1:location, act_1:switch	-- illumination -- tri_2:beacon, act:switch
# tri_1:location, act_1:switch	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:location, act_1:switch	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:location, act_1:switch	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:location, act_1:switch	-- illumination -- tri_2:switch, act:colorControl
# tri_1:location, act_1:switch	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:location, act_1:switch	-- illumination -- tri_2:switch, act:locationMode
# tri_1:location, act_1:switch	-- illumination -- tri_2:switch, act:number
# tri_1:location, act_1:switch	-- illumination -- tri_2:switch, act:sendAction
# tri_1:location, act_1:switch	-- illumination -- tri_2:switch, act:switch
# tri_1:location, act_1:switch	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:motionSensor, act_1:colorControl	-- illumination -- tri_2:beacon, act:lock
# tri_1:motionSensor, act_1:colorControl	-- illumination -- tri_2:beacon, act:switch
# tri_1:motionSensor, act_1:colorControl	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:motionSensor, act_1:colorControl	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:motionSensor, act_1:colorControl	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:motionSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:colorControl
# tri_1:motionSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:motionSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:locationMode
# tri_1:motionSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:number
# tri_1:motionSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:sendAction
# tri_1:motionSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:switch
# tri_1:motionSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:motionSensor, act_1:imageCapture	-- illumination -- tri_2:beacon, act:lock
# tri_1:motionSensor, act_1:imageCapture	-- illumination -- tri_2:beacon, act:switch
# tri_1:motionSensor, act_1:imageCapture	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:motionSensor, act_1:imageCapture	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:motionSensor, act_1:imageCapture	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:motionSensor, act_1:imageCapture	-- illumination -- tri_2:switch, act:colorControl
# tri_1:motionSensor, act_1:imageCapture	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:motionSensor, act_1:imageCapture	-- illumination -- tri_2:switch, act:locationMode
# tri_1:motionSensor, act_1:imageCapture	-- illumination -- tri_2:switch, act:number
# tri_1:motionSensor, act_1:imageCapture	-- illumination -- tri_2:switch, act:sendAction
# tri_1:motionSensor, act_1:imageCapture	-- illumination -- tri_2:switch, act:switch
# tri_1:motionSensor, act_1:imageCapture	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:motionSensor, act_1:switch	-- illumination -- tri_2:beacon, act:lock
# tri_1:motionSensor, act_1:switch	-- illumination -- tri_2:beacon, act:switch
# tri_1:motionSensor, act_1:switch	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:motionSensor, act_1:switch	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:motionSensor, act_1:switch	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:motionSensor, act_1:switch	-- illumination -- tri_2:switch, act:colorControl
# tri_1:motionSensor, act_1:switch	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:motionSensor, act_1:switch	-- illumination -- tri_2:switch, act:locationMode
# tri_1:motionSensor, act_1:switch	-- illumination -- tri_2:switch, act:number
# tri_1:motionSensor, act_1:switch	-- illumination -- tri_2:switch, act:sendAction
# tri_1:motionSensor, act_1:switch	-- illumination -- tri_2:switch, act:switch
# tri_1:motionSensor, act_1:switch	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:powerMeter, act_1:switch	-- illumination -- tri_2:beacon, act:lock
# tri_1:powerMeter, act_1:switch	-- illumination -- tri_2:beacon, act:switch
# tri_1:powerMeter, act_1:switch	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:powerMeter, act_1:switch	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:powerMeter, act_1:switch	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:powerMeter, act_1:switch	-- illumination -- tri_2:switch, act:colorControl
# tri_1:powerMeter, act_1:switch	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:powerMeter, act_1:switch	-- illumination -- tri_2:switch, act:locationMode
# tri_1:powerMeter, act_1:switch	-- illumination -- tri_2:switch, act:number
# tri_1:powerMeter, act_1:switch	-- illumination -- tri_2:switch, act:sendAction
# tri_1:powerMeter, act_1:switch	-- illumination -- tri_2:switch, act:switch
# tri_1:powerMeter, act_1:switch	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:presenceSensor, act_1:colorControl	-- illumination -- tri_2:beacon, act:lock
# tri_1:presenceSensor, act_1:colorControl	-- illumination -- tri_2:beacon, act:switch
# tri_1:presenceSensor, act_1:colorControl	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:presenceSensor, act_1:colorControl	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:presenceSensor, act_1:colorControl	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:presenceSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:colorControl
# tri_1:presenceSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:presenceSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:locationMode
# tri_1:presenceSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:number
# tri_1:presenceSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:sendAction
# tri_1:presenceSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:switch
# tri_1:presenceSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:presenceSensor, act_1:imageCapture	-- illumination -- tri_2:beacon, act:lock
# tri_1:presenceSensor, act_1:imageCapture	-- illumination -- tri_2:beacon, act:switch
# tri_1:presenceSensor, act_1:imageCapture	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:presenceSensor, act_1:imageCapture	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:presenceSensor, act_1:imageCapture	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:presenceSensor, act_1:imageCapture	-- illumination -- tri_2:switch, act:colorControl
# tri_1:presenceSensor, act_1:imageCapture	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:presenceSensor, act_1:imageCapture	-- illumination -- tri_2:switch, act:locationMode
# tri_1:presenceSensor, act_1:imageCapture	-- illumination -- tri_2:switch, act:number
# tri_1:presenceSensor, act_1:imageCapture	-- illumination -- tri_2:switch, act:sendAction
# tri_1:presenceSensor, act_1:imageCapture	-- illumination -- tri_2:switch, act:switch
# tri_1:presenceSensor, act_1:imageCapture	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:presenceSensor, act_1:momentary	-- illumination -- tri_2:beacon, act:lock
# tri_1:presenceSensor, act_1:momentary	-- illumination -- tri_2:beacon, act:switch
# tri_1:presenceSensor, act_1:momentary	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:presenceSensor, act_1:momentary	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:presenceSensor, act_1:momentary	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:presenceSensor, act_1:momentary	-- illumination -- tri_2:switch, act:colorControl
# tri_1:presenceSensor, act_1:momentary	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:presenceSensor, act_1:momentary	-- illumination -- tri_2:switch, act:locationMode
# tri_1:presenceSensor, act_1:momentary	-- illumination -- tri_2:switch, act:number
# tri_1:presenceSensor, act_1:momentary	-- illumination -- tri_2:switch, act:sendAction
# tri_1:presenceSensor, act_1:momentary	-- illumination -- tri_2:switch, act:switch
# tri_1:presenceSensor, act_1:momentary	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:presenceSensor, act_1:switch	-- illumination -- tri_2:beacon, act:lock
# tri_1:presenceSensor, act_1:switch	-- illumination -- tri_2:beacon, act:switch
# tri_1:presenceSensor, act_1:switch	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:presenceSensor, act_1:switch	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:presenceSensor, act_1:switch	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:presenceSensor, act_1:switch	-- illumination -- tri_2:switch, act:colorControl
# tri_1:presenceSensor, act_1:switch	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:presenceSensor, act_1:switch	-- illumination -- tri_2:switch, act:locationMode
# tri_1:presenceSensor, act_1:switch	-- illumination -- tri_2:switch, act:number
# tri_1:presenceSensor, act_1:switch	-- illumination -- tri_2:switch, act:sendAction
# tri_1:presenceSensor, act_1:switch	-- illumination -- tri_2:switch, act:switch
# tri_1:presenceSensor, act_1:switch	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:relativeHumidityMeasurement, act_1:switch	-- illumination -- tri_2:beacon, act:lock
# tri_1:relativeHumidityMeasurement, act_1:switch	-- illumination -- tri_2:beacon, act:switch
# tri_1:relativeHumidityMeasurement, act_1:switch	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:relativeHumidityMeasurement, act_1:switch	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:relativeHumidityMeasurement, act_1:switch	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:relativeHumidityMeasurement, act_1:switch	-- illumination -- tri_2:switch, act:colorControl
# tri_1:relativeHumidityMeasurement, act_1:switch	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:relativeHumidityMeasurement, act_1:switch	-- illumination -- tri_2:switch, act:locationMode
# tri_1:relativeHumidityMeasurement, act_1:switch	-- illumination -- tri_2:switch, act:number
# tri_1:relativeHumidityMeasurement, act_1:switch	-- illumination -- tri_2:switch, act:sendAction
# tri_1:relativeHumidityMeasurement, act_1:switch	-- illumination -- tri_2:switch, act:switch
# tri_1:relativeHumidityMeasurement, act_1:switch	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:smokeDetector, act_1:colorControl	-- illumination -- tri_2:beacon, act:lock
# tri_1:smokeDetector, act_1:colorControl	-- illumination -- tri_2:beacon, act:switch
# tri_1:smokeDetector, act_1:colorControl	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:smokeDetector, act_1:colorControl	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:smokeDetector, act_1:colorControl	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:smokeDetector, act_1:colorControl	-- illumination -- tri_2:switch, act:colorControl
# tri_1:smokeDetector, act_1:colorControl	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:smokeDetector, act_1:colorControl	-- illumination -- tri_2:switch, act:locationMode
# tri_1:smokeDetector, act_1:colorControl	-- illumination -- tri_2:switch, act:number
# tri_1:smokeDetector, act_1:colorControl	-- illumination -- tri_2:switch, act:sendAction
# tri_1:smokeDetector, act_1:colorControl	-- illumination -- tri_2:switch, act:switch
# tri_1:smokeDetector, act_1:colorControl	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:switch, act_1:colorControl	-- illumination -- tri_2:beacon, act:lock
# tri_1:switch, act_1:colorControl	-- illumination -- tri_2:beacon, act:switch
# tri_1:switch, act_1:colorControl	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:switch, act_1:colorControl	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:switch, act_1:colorControl	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:switch, act_1:colorControl	-- illumination -- tri_2:switch, act:colorControl
# tri_1:switch, act_1:colorControl	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:switch, act_1:colorControl	-- illumination -- tri_2:switch, act:locationMode
# tri_1:switch, act_1:colorControl	-- illumination -- tri_2:switch, act:number
# tri_1:switch, act_1:colorControl	-- illumination -- tri_2:switch, act:sendAction
# tri_1:switch, act_1:colorControl	-- illumination -- tri_2:switch, act:switch
# tri_1:switch, act_1:colorControl	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:switch, act_1:imageCapture	-- illumination -- tri_2:beacon, act:lock
# tri_1:switch, act_1:imageCapture	-- illumination -- tri_2:beacon, act:switch
# tri_1:switch, act_1:imageCapture	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:switch, act_1:imageCapture	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:switch, act_1:imageCapture	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:switch, act_1:imageCapture	-- illumination -- tri_2:switch, act:colorControl
# tri_1:switch, act_1:imageCapture	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:switch, act_1:imageCapture	-- illumination -- tri_2:switch, act:locationMode
# tri_1:switch, act_1:imageCapture	-- illumination -- tri_2:switch, act:number
# tri_1:switch, act_1:imageCapture	-- illumination -- tri_2:switch, act:sendAction
# tri_1:switch, act_1:imageCapture	-- illumination -- tri_2:switch, act:switch
# tri_1:switch, act_1:imageCapture	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:switch, act_1:switch	-- illumination -- tri_2:beacon, act:lock
# tri_1:switch, act_1:switch	-- illumination -- tri_2:beacon, act:switch
# tri_1:switch, act_1:switch	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:switch, act_1:switch	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:switch, act_1:switch	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:switch, act_1:switch	-- illumination -- tri_2:switch, act:colorControl
# tri_1:switch, act_1:switch	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:switch, act_1:switch	-- illumination -- tri_2:switch, act:locationMode
# tri_1:switch, act_1:switch	-- illumination -- tri_2:switch, act:number
# tri_1:switch, act_1:switch	-- illumination -- tri_2:switch, act:sendAction
# tri_1:switch, act_1:switch	-- illumination -- tri_2:switch, act:switch
# tri_1:switch, act_1:switch	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:switch, act_1:switchLevel	-- illumination -- tri_2:beacon, act:lock
# tri_1:switch, act_1:switchLevel	-- illumination -- tri_2:beacon, act:switch
# tri_1:switch, act_1:switchLevel	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:switch, act_1:switchLevel	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:switch, act_1:switchLevel	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:switch, act_1:switchLevel	-- illumination -- tri_2:switch, act:colorControl
# tri_1:switch, act_1:switchLevel	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:switch, act_1:switchLevel	-- illumination -- tri_2:switch, act:locationMode
# tri_1:switch, act_1:switchLevel	-- illumination -- tri_2:switch, act:number
# tri_1:switch, act_1:switchLevel	-- illumination -- tri_2:switch, act:sendAction
# tri_1:switch, act_1:switchLevel	-- illumination -- tri_2:switch, act:switch
# tri_1:switch, act_1:switchLevel	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:temperatureMeasurement, act_1:switch	-- illumination -- tri_2:beacon, act:lock
# tri_1:temperatureMeasurement, act_1:switch	-- illumination -- tri_2:beacon, act:switch
# tri_1:temperatureMeasurement, act_1:switch	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:temperatureMeasurement, act_1:switch	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:temperatureMeasurement, act_1:switch	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:temperatureMeasurement, act_1:switch	-- illumination -- tri_2:switch, act:colorControl
# tri_1:temperatureMeasurement, act_1:switch	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:temperatureMeasurement, act_1:switch	-- illumination -- tri_2:switch, act:locationMode
# tri_1:temperatureMeasurement, act_1:switch	-- illumination -- tri_2:switch, act:number
# tri_1:temperatureMeasurement, act_1:switch	-- illumination -- tri_2:switch, act:sendAction
# tri_1:temperatureMeasurement, act_1:switch	-- illumination -- tri_2:switch, act:switch
# tri_1:temperatureMeasurement, act_1:switch	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:thermostat, act_1:switch	-- illumination -- tri_2:beacon, act:lock
# tri_1:thermostat, act_1:switch	-- illumination -- tri_2:beacon, act:switch
# tri_1:thermostat, act_1:switch	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:thermostat, act_1:switch	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:thermostat, act_1:switch	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:thermostat, act_1:switch	-- illumination -- tri_2:switch, act:colorControl
# tri_1:thermostat, act_1:switch	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:thermostat, act_1:switch	-- illumination -- tri_2:switch, act:locationMode
# tri_1:thermostat, act_1:switch	-- illumination -- tri_2:switch, act:number
# tri_1:thermostat, act_1:switch	-- illumination -- tri_2:switch, act:sendAction
# tri_1:thermostat, act_1:switch	-- illumination -- tri_2:switch, act:switch
# tri_1:thermostat, act_1:switch	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:time, act_1:switch	-- illumination -- tri_2:beacon, act:lock
# tri_1:time, act_1:switch	-- illumination -- tri_2:beacon, act:switch
# tri_1:time, act_1:switch	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:time, act_1:switch	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:time, act_1:switch	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:time, act_1:switch	-- illumination -- tri_2:switch, act:colorControl
# tri_1:time, act_1:switch	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:time, act_1:switch	-- illumination -- tri_2:switch, act:locationMode
# tri_1:time, act_1:switch	-- illumination -- tri_2:switch, act:number
# tri_1:time, act_1:switch	-- illumination -- tri_2:switch, act:sendAction
# tri_1:time, act_1:switch	-- illumination -- tri_2:switch, act:switch
# tri_1:time, act_1:switch	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:touchSensor, act_1:switch	-- illumination -- tri_2:beacon, act:lock
# tri_1:touchSensor, act_1:switch	-- illumination -- tri_2:beacon, act:switch
# tri_1:touchSensor, act_1:switch	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:touchSensor, act_1:switch	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:touchSensor, act_1:switch	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:touchSensor, act_1:switch	-- illumination -- tri_2:switch, act:colorControl
# tri_1:touchSensor, act_1:switch	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:touchSensor, act_1:switch	-- illumination -- tri_2:switch, act:locationMode
# tri_1:touchSensor, act_1:switch	-- illumination -- tri_2:switch, act:number
# tri_1:touchSensor, act_1:switch	-- illumination -- tri_2:switch, act:sendAction
# tri_1:touchSensor, act_1:switch	-- illumination -- tri_2:switch, act:switch
# tri_1:touchSensor, act_1:switch	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:waterSensor, act_1:colorControl	-- illumination -- tri_2:beacon, act:lock
# tri_1:waterSensor, act_1:colorControl	-- illumination -- tri_2:beacon, act:switch
# tri_1:waterSensor, act_1:colorControl	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:waterSensor, act_1:colorControl	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:waterSensor, act_1:colorControl	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:waterSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:colorControl
# tri_1:waterSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:waterSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:locationMode
# tri_1:waterSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:number
# tri_1:waterSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:sendAction
# tri_1:waterSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:switch
# tri_1:waterSensor, act_1:colorControl	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:waterSensor, act_1:switch	-- illumination -- tri_2:beacon, act:lock
# tri_1:waterSensor, act_1:switch	-- illumination -- tri_2:beacon, act:switch
# tri_1:waterSensor, act_1:switch	-- illumination -- tri_2:illuminanceMeasurement, act:switch
# tri_1:waterSensor, act_1:switch	-- illumination -- tri_2:powerMeter, act:sendAction
# tri_1:waterSensor, act_1:switch	-- illumination -- tri_2:powerMeter, act:switch
# tri_1:waterSensor, act_1:switch	-- illumination -- tri_2:switch, act:colorControl
# tri_1:waterSensor, act_1:switch	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:waterSensor, act_1:switch	-- illumination -- tri_2:switch, act:locationMode
# tri_1:waterSensor, act_1:switch	-- illumination -- tri_2:switch, act:number
# tri_1:waterSensor, act_1:switch	-- illumination -- tri_2:switch, act:sendAction
# tri_1:waterSensor, act_1:switch	-- illumination -- tri_2:switch, act:switch
# tri_1:waterSensor, act_1:switch	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:waterSensor, act_1:valve	-- leakage -- tri_2:app, act:alarm
# tri_1:waterSensor, act_1:valve	-- leakage -- tri_2:app, act:colorControl
# tri_1:waterSensor, act_1:valve	-- leakage -- tri_2:app, act:doorControl
# tri_1:waterSensor, act_1:valve	-- leakage -- tri_2:app, act:lock
# tri_1:waterSensor, act_1:valve	-- leakage -- tri_2:app, act:switch
# tri_1:waterSensor, act_1:valve	-- leakage -- tri_2:app, act:thermostat
# tri_1:waterSensor, act_1:valve	-- leakage -- tri_2:device.jawboneUser, act:colorControl
# tri_1:waterSensor, act_1:valve	-- leakage -- tri_2:device.jawboneUser, act:musicPlayer
# tri_1:waterSensor, act_1:valve	-- leakage -- tri_2:device.jawboneUser, act:sendAction
# tri_1:waterSensor, act_1:valve	-- leakage -- tri_2:device.jawboneUser, act:switch
# tri_1:waterSensor, act_1:valve	-- leakage -- tri_2:waterSensor, act:colorControl
# tri_1:waterSensor, act_1:valve	-- leakage -- tri_2:waterSensor, act:sendAction
# tri_1:waterSensor, act_1:valve	-- leakage -- tri_2:waterSensor, act:switch
# tri_1:waterSensor, act_1:valve	-- leakage -- tri_2:waterSensor, act:valve
# tri_1:device.jawboneUser, act_1:musicPlayer	-- location -- tri_2:location, act:lock
# tri_1:device.jawboneUser, act_1:musicPlayer	-- location -- tri_2:location, act:switch
# tri_1:device.jawboneUser, act_1:musicPlayer	-- location -- tri_2:location, act:thermostat
# tri_1:device.jawboneUser, act_1:musicPlayer	-- location -- tri_2:presenceSensor, act:colorControl
# tri_1:device.jawboneUser, act_1:musicPlayer	-- location -- tri_2:presenceSensor, act:imageCapture
# tri_1:device.jawboneUser, act_1:musicPlayer	-- location -- tri_2:presenceSensor, act:locationMode
# tri_1:device.jawboneUser, act_1:musicPlayer	-- location -- tri_2:presenceSensor, act:lock
# tri_1:device.jawboneUser, act_1:musicPlayer	-- location -- tri_2:presenceSensor, act:momentary
# tri_1:device.jawboneUser, act_1:musicPlayer	-- location -- tri_2:presenceSensor, act:number
# tri_1:device.jawboneUser, act_1:musicPlayer	-- location -- tri_2:presenceSensor, act:sendAction
# tri_1:device.jawboneUser, act_1:musicPlayer	-- location -- tri_2:presenceSensor, act:switch
# tri_1:app, act_1:doorControl	-- lock -- tri_2:button, act:colorControl
# tri_1:app, act_1:doorControl	-- lock -- tri_2:button, act:locationMode
# tri_1:app, act_1:doorControl	-- lock -- tri_2:button, act:sendAction
# tri_1:app, act_1:doorControl	-- lock -- tri_2:contactSensor, act:alarm
# tri_1:app, act_1:doorControl	-- lock -- tri_2:contactSensor, act:colorControl
# tri_1:app, act_1:doorControl	-- lock -- tri_2:contactSensor, act:imageCapture
# tri_1:app, act_1:doorControl	-- lock -- tri_2:contactSensor, act:locationMode
# tri_1:app, act_1:doorControl	-- lock -- tri_2:contactSensor, act:momentary
# tri_1:app, act_1:doorControl	-- lock -- tri_2:contactSensor, act:number
# tri_1:app, act_1:doorControl	-- lock -- tri_2:contactSensor, act:sendAction
# tri_1:app, act_1:doorControl	-- lock -- tri_2:contactSensor, act:switch
# tri_1:app, act_1:doorControl	-- lock -- tri_2:contactSensor, act:thermostat
# tri_1:app, act_1:doorControl	-- lock -- tri_2:touchSensor, act:doorControl
# tri_1:app, act_1:doorControl	-- lock -- tri_2:touchSensor, act:lock
# tri_1:app, act_1:doorControl	-- lock -- tri_2:touchSensor, act:switch
# tri_1:app, act_1:lock	-- lock -- tri_2:button, act:colorControl
# tri_1:app, act_1:lock	-- lock -- tri_2:button, act:locationMode
# tri_1:app, act_1:lock	-- lock -- tri_2:button, act:sendAction
# tri_1:app, act_1:lock	-- lock -- tri_2:contactSensor, act:alarm
# tri_1:app, act_1:lock	-- lock -- tri_2:contactSensor, act:colorControl
# tri_1:app, act_1:lock	-- lock -- tri_2:contactSensor, act:imageCapture
# tri_1:app, act_1:lock	-- lock -- tri_2:contactSensor, act:locationMode
# tri_1:app, act_1:lock	-- lock -- tri_2:contactSensor, act:momentary
# tri_1:app, act_1:lock	-- lock -- tri_2:contactSensor, act:number
# tri_1:app, act_1:lock	-- lock -- tri_2:contactSensor, act:sendAction
# tri_1:app, act_1:lock	-- lock -- tri_2:contactSensor, act:switch
# tri_1:app, act_1:lock	-- lock -- tri_2:contactSensor, act:thermostat
# tri_1:app, act_1:lock	-- lock -- tri_2:touchSensor, act:doorControl
# tri_1:app, act_1:lock	-- lock -- tri_2:touchSensor, act:lock
# tri_1:app, act_1:lock	-- lock -- tri_2:touchSensor, act:switch
# tri_1:beacon, act_1:lock	-- lock -- tri_2:button, act:colorControl
# tri_1:beacon, act_1:lock	-- lock -- tri_2:button, act:locationMode
# tri_1:beacon, act_1:lock	-- lock -- tri_2:button, act:sendAction
# tri_1:beacon, act_1:lock	-- lock -- tri_2:contactSensor, act:alarm
# tri_1:beacon, act_1:lock	-- lock -- tri_2:contactSensor, act:colorControl
# tri_1:beacon, act_1:lock	-- lock -- tri_2:contactSensor, act:imageCapture
# tri_1:beacon, act_1:lock	-- lock -- tri_2:contactSensor, act:locationMode
# tri_1:beacon, act_1:lock	-- lock -- tri_2:contactSensor, act:momentary
# tri_1:beacon, act_1:lock	-- lock -- tri_2:contactSensor, act:number
# tri_1:beacon, act_1:lock	-- lock -- tri_2:contactSensor, act:sendAction
# tri_1:beacon, act_1:lock	-- lock -- tri_2:contactSensor, act:switch
# tri_1:beacon, act_1:lock	-- lock -- tri_2:contactSensor, act:thermostat
# tri_1:beacon, act_1:lock	-- lock -- tri_2:touchSensor, act:doorControl
# tri_1:beacon, act_1:lock	-- lock -- tri_2:touchSensor, act:lock
# tri_1:beacon, act_1:lock	-- lock -- tri_2:touchSensor, act:switch
# tri_1:location, act_1:lock	-- lock -- tri_2:button, act:colorControl
# tri_1:location, act_1:lock	-- lock -- tri_2:button, act:locationMode
# tri_1:location, act_1:lock	-- lock -- tri_2:button, act:sendAction
# tri_1:location, act_1:lock	-- lock -- tri_2:contactSensor, act:alarm
# tri_1:location, act_1:lock	-- lock -- tri_2:contactSensor, act:colorControl
# tri_1:location, act_1:lock	-- lock -- tri_2:contactSensor, act:imageCapture
# tri_1:location, act_1:lock	-- lock -- tri_2:contactSensor, act:locationMode
# tri_1:location, act_1:lock	-- lock -- tri_2:contactSensor, act:momentary
# tri_1:location, act_1:lock	-- lock -- tri_2:contactSensor, act:number
# tri_1:location, act_1:lock	-- lock -- tri_2:contactSensor, act:sendAction
# tri_1:location, act_1:lock	-- lock -- tri_2:contactSensor, act:switch
# tri_1:location, act_1:lock	-- lock -- tri_2:contactSensor, act:thermostat
# tri_1:location, act_1:lock	-- lock -- tri_2:touchSensor, act:doorControl
# tri_1:location, act_1:lock	-- lock -- tri_2:touchSensor, act:lock
# tri_1:location, act_1:lock	-- lock -- tri_2:touchSensor, act:switch
# tri_1:presenceSensor, act_1:lock	-- lock -- tri_2:button, act:colorControl
# tri_1:presenceSensor, act_1:lock	-- lock -- tri_2:button, act:locationMode
# tri_1:presenceSensor, act_1:lock	-- lock -- tri_2:button, act:sendAction
# tri_1:presenceSensor, act_1:lock	-- lock -- tri_2:contactSensor, act:alarm
# tri_1:presenceSensor, act_1:lock	-- lock -- tri_2:contactSensor, act:colorControl
# tri_1:presenceSensor, act_1:lock	-- lock -- tri_2:contactSensor, act:imageCapture
# tri_1:presenceSensor, act_1:lock	-- lock -- tri_2:contactSensor, act:locationMode
# tri_1:presenceSensor, act_1:lock	-- lock -- tri_2:contactSensor, act:momentary
# tri_1:presenceSensor, act_1:lock	-- lock -- tri_2:contactSensor, act:number
# tri_1:presenceSensor, act_1:lock	-- lock -- tri_2:contactSensor, act:sendAction
# tri_1:presenceSensor, act_1:lock	-- lock -- tri_2:contactSensor, act:switch
# tri_1:presenceSensor, act_1:lock	-- lock -- tri_2:contactSensor, act:thermostat
# tri_1:presenceSensor, act_1:lock	-- lock -- tri_2:touchSensor, act:doorControl
# tri_1:presenceSensor, act_1:lock	-- lock -- tri_2:touchSensor, act:lock
# tri_1:presenceSensor, act_1:lock	-- lock -- tri_2:touchSensor, act:switch
# tri_1:time, act_1:device.PetFeederShield	-- lock -- tri_2:button, act:colorControl
# tri_1:time, act_1:device.PetFeederShield	-- lock -- tri_2:button, act:locationMode
# tri_1:time, act_1:device.PetFeederShield	-- lock -- tri_2:button, act:sendAction
# tri_1:time, act_1:device.PetFeederShield	-- lock -- tri_2:contactSensor, act:alarm
# tri_1:time, act_1:device.PetFeederShield	-- lock -- tri_2:contactSensor, act:colorControl
# tri_1:time, act_1:device.PetFeederShield	-- lock -- tri_2:contactSensor, act:imageCapture
# tri_1:time, act_1:device.PetFeederShield	-- lock -- tri_2:contactSensor, act:locationMode
# tri_1:time, act_1:device.PetFeederShield	-- lock -- tri_2:contactSensor, act:momentary
# tri_1:time, act_1:device.PetFeederShield	-- lock -- tri_2:contactSensor, act:number
# tri_1:time, act_1:device.PetFeederShield	-- lock -- tri_2:contactSensor, act:sendAction
# tri_1:time, act_1:device.PetFeederShield	-- lock -- tri_2:contactSensor, act:switch
# tri_1:time, act_1:device.PetFeederShield	-- lock -- tri_2:contactSensor, act:thermostat
# tri_1:time, act_1:device.PetFeederShield	-- lock -- tri_2:touchSensor, act:doorControl
# tri_1:time, act_1:device.PetFeederShield	-- lock -- tri_2:touchSensor, act:lock
# tri_1:time, act_1:device.PetFeederShield	-- lock -- tri_2:touchSensor, act:switch
# tri_1:time, act_1:lock	-- lock -- tri_2:button, act:colorControl
# tri_1:time, act_1:lock	-- lock -- tri_2:button, act:locationMode
# tri_1:time, act_1:lock	-- lock -- tri_2:button, act:sendAction
# tri_1:time, act_1:lock	-- lock -- tri_2:contactSensor, act:alarm
# tri_1:time, act_1:lock	-- lock -- tri_2:contactSensor, act:colorControl
# tri_1:time, act_1:lock	-- lock -- tri_2:contactSensor, act:imageCapture
# tri_1:time, act_1:lock	-- lock -- tri_2:contactSensor, act:locationMode
# tri_1:time, act_1:lock	-- lock -- tri_2:contactSensor, act:momentary
# tri_1:time, act_1:lock	-- lock -- tri_2:contactSensor, act:number
# tri_1:time, act_1:lock	-- lock -- tri_2:contactSensor, act:sendAction
# tri_1:time, act_1:lock	-- lock -- tri_2:contactSensor, act:switch
# tri_1:time, act_1:lock	-- lock -- tri_2:contactSensor, act:thermostat
# tri_1:time, act_1:lock	-- lock -- tri_2:touchSensor, act:doorControl
# tri_1:time, act_1:lock	-- lock -- tri_2:touchSensor, act:lock
# tri_1:time, act_1:lock	-- lock -- tri_2:touchSensor, act:switch
# tri_1:touchSensor, act_1:doorControl	-- lock -- tri_2:button, act:colorControl
# tri_1:touchSensor, act_1:doorControl	-- lock -- tri_2:button, act:locationMode
# tri_1:touchSensor, act_1:doorControl	-- lock -- tri_2:button, act:sendAction
# tri_1:touchSensor, act_1:doorControl	-- lock -- tri_2:contactSensor, act:alarm
# tri_1:touchSensor, act_1:doorControl	-- lock -- tri_2:contactSensor, act:colorControl
# tri_1:touchSensor, act_1:doorControl	-- lock -- tri_2:contactSensor, act:imageCapture
# tri_1:touchSensor, act_1:doorControl	-- lock -- tri_2:contactSensor, act:locationMode
# tri_1:touchSensor, act_1:doorControl	-- lock -- tri_2:contactSensor, act:momentary
# tri_1:touchSensor, act_1:doorControl	-- lock -- tri_2:contactSensor, act:number
# tri_1:touchSensor, act_1:doorControl	-- lock -- tri_2:contactSensor, act:sendAction
# tri_1:touchSensor, act_1:doorControl	-- lock -- tri_2:contactSensor, act:switch
# tri_1:touchSensor, act_1:doorControl	-- lock -- tri_2:contactSensor, act:thermostat
# tri_1:touchSensor, act_1:doorControl	-- lock -- tri_2:touchSensor, act:doorControl
# tri_1:touchSensor, act_1:doorControl	-- lock -- tri_2:touchSensor, act:lock
# tri_1:touchSensor, act_1:doorControl	-- lock -- tri_2:touchSensor, act:switch
# tri_1:touchSensor, act_1:lock	-- lock -- tri_2:button, act:colorControl
# tri_1:touchSensor, act_1:lock	-- lock -- tri_2:button, act:locationMode
# tri_1:touchSensor, act_1:lock	-- lock -- tri_2:button, act:sendAction
# tri_1:touchSensor, act_1:lock	-- lock -- tri_2:contactSensor, act:alarm
# tri_1:touchSensor, act_1:lock	-- lock -- tri_2:contactSensor, act:colorControl
# tri_1:touchSensor, act_1:lock	-- lock -- tri_2:contactSensor, act:imageCapture
# ...
# tri_1:motionSensor, act_1:sendAction	-- motion -- tri_2:motionSensor, act:imageCapture
# tri_1:motionSensor, act_1:sendAction	-- motion -- tri_2:motionSensor, act:locationMode
# tri_1:motionSensor, act_1:sendAction	-- motion -- tri_2:motionSensor, act:number
# tri_1:motionSensor, act_1:sendAction	-- motion -- tri_2:motionSensor, act:sendAction
# tri_1:motionSensor, act_1:sendAction	-- motion -- tri_2:motionSensor, act:switch
# tri_1:powerMeter, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:colorControl
# tri_1:powerMeter, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:imageCapture
# tri_1:powerMeter, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:momentary
# tri_1:powerMeter, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:number
# tri_1:powerMeter, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:sendAction
# tri_1:powerMeter, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:switch
# tri_1:powerMeter, act_1:sendAction	-- motion -- tri_2:motionSensor, act:alarm
# tri_1:powerMeter, act_1:sendAction	-- motion -- tri_2:motionSensor, act:colorControl
# tri_1:powerMeter, act_1:sendAction	-- motion -- tri_2:motionSensor, act:imageCapture
# tri_1:powerMeter, act_1:sendAction	-- motion -- tri_2:motionSensor, act:locationMode
# tri_1:powerMeter, act_1:sendAction	-- motion -- tri_2:motionSensor, act:number
# tri_1:powerMeter, act_1:sendAction	-- motion -- tri_2:motionSensor, act:sendAction
# tri_1:powerMeter, act_1:sendAction	-- motion -- tri_2:motionSensor, act:switch
# tri_1:presenceSensor, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:colorControl
# tri_1:presenceSensor, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:imageCapture
# tri_1:presenceSensor, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:momentary
# tri_1:presenceSensor, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:number
# tri_1:presenceSensor, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:sendAction
# tri_1:presenceSensor, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:switch
# tri_1:presenceSensor, act_1:sendAction	-- motion -- tri_2:motionSensor, act:alarm
# tri_1:presenceSensor, act_1:sendAction	-- motion -- tri_2:motionSensor, act:colorControl
# tri_1:presenceSensor, act_1:sendAction	-- motion -- tri_2:motionSensor, act:imageCapture
# tri_1:presenceSensor, act_1:sendAction	-- motion -- tri_2:motionSensor, act:locationMode
# tri_1:presenceSensor, act_1:sendAction	-- motion -- tri_2:motionSensor, act:number
# tri_1:presenceSensor, act_1:sendAction	-- motion -- tri_2:motionSensor, act:sendAction
# tri_1:presenceSensor, act_1:sendAction	-- motion -- tri_2:motionSensor, act:switch
# tri_1:relativeHumidityMeasurement, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:colorControl
# tri_1:relativeHumidityMeasurement, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:imageCapture
# tri_1:relativeHumidityMeasurement, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:momentary
# tri_1:relativeHumidityMeasurement, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:number
# tri_1:relativeHumidityMeasurement, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:sendAction
# tri_1:relativeHumidityMeasurement, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:switch
# tri_1:relativeHumidityMeasurement, act_1:sendAction	-- motion -- tri_2:motionSensor, act:alarm
# tri_1:relativeHumidityMeasurement, act_1:sendAction	-- motion -- tri_2:motionSensor, act:colorControl
# tri_1:relativeHumidityMeasurement, act_1:sendAction	-- motion -- tri_2:motionSensor, act:imageCapture
# tri_1:relativeHumidityMeasurement, act_1:sendAction	-- motion -- tri_2:motionSensor, act:locationMode
# tri_1:relativeHumidityMeasurement, act_1:sendAction	-- motion -- tri_2:motionSensor, act:number
# tri_1:relativeHumidityMeasurement, act_1:sendAction	-- motion -- tri_2:motionSensor, act:sendAction
# tri_1:relativeHumidityMeasurement, act_1:sendAction	-- motion -- tri_2:motionSensor, act:switch
# tri_1:smokeDetector, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:colorControl
# tri_1:smokeDetector, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:imageCapture
# tri_1:smokeDetector, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:momentary
# tri_1:smokeDetector, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:number
# tri_1:smokeDetector, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:sendAction
# tri_1:smokeDetector, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:switch
# tri_1:smokeDetector, act_1:sendAction	-- motion -- tri_2:motionSensor, act:alarm
# tri_1:smokeDetector, act_1:sendAction	-- motion -- tri_2:motionSensor, act:colorControl
# tri_1:smokeDetector, act_1:sendAction	-- motion -- tri_2:motionSensor, act:imageCapture
# tri_1:smokeDetector, act_1:sendAction	-- motion -- tri_2:motionSensor, act:locationMode
# tri_1:smokeDetector, act_1:sendAction	-- motion -- tri_2:motionSensor, act:number
# tri_1:smokeDetector, act_1:sendAction	-- motion -- tri_2:motionSensor, act:sendAction
# tri_1:smokeDetector, act_1:sendAction	-- motion -- tri_2:motionSensor, act:switch
# tri_1:switch, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:colorControl
# tri_1:switch, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:imageCapture
# tri_1:switch, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:momentary
# tri_1:switch, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:number
# tri_1:switch, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:sendAction
# tri_1:switch, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:switch
# tri_1:switch, act_1:sendAction	-- motion -- tri_2:motionSensor, act:alarm
# tri_1:switch, act_1:sendAction	-- motion -- tri_2:motionSensor, act:colorControl
# tri_1:switch, act_1:sendAction	-- motion -- tri_2:motionSensor, act:imageCapture
# tri_1:switch, act_1:sendAction	-- motion -- tri_2:motionSensor, act:locationMode
# tri_1:switch, act_1:sendAction	-- motion -- tri_2:motionSensor, act:number
# tri_1:switch, act_1:sendAction	-- motion -- tri_2:motionSensor, act:sendAction
# tri_1:switch, act_1:sendAction	-- motion -- tri_2:motionSensor, act:switch
# tri_1:temperatureMeasurement, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:colorControl
# tri_1:temperatureMeasurement, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:imageCapture
# tri_1:temperatureMeasurement, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:momentary
# tri_1:temperatureMeasurement, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:number
# tri_1:temperatureMeasurement, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:sendAction
# tri_1:temperatureMeasurement, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:switch
# tri_1:temperatureMeasurement, act_1:sendAction	-- motion -- tri_2:motionSensor, act:alarm
# tri_1:temperatureMeasurement, act_1:sendAction	-- motion -- tri_2:motionSensor, act:colorControl
# tri_1:temperatureMeasurement, act_1:sendAction	-- motion -- tri_2:motionSensor, act:imageCapture
# tri_1:temperatureMeasurement, act_1:sendAction	-- motion -- tri_2:motionSensor, act:locationMode
# tri_1:temperatureMeasurement, act_1:sendAction	-- motion -- tri_2:motionSensor, act:number
# tri_1:temperatureMeasurement, act_1:sendAction	-- motion -- tri_2:motionSensor, act:sendAction
# tri_1:temperatureMeasurement, act_1:sendAction	-- motion -- tri_2:motionSensor, act:switch
# tri_1:threeAxis, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:colorControl
# tri_1:threeAxis, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:imageCapture
# tri_1:threeAxis, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:momentary
# tri_1:threeAxis, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:number
# tri_1:threeAxis, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:sendAction
# tri_1:threeAxis, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:switch
# tri_1:threeAxis, act_1:sendAction	-- motion -- tri_2:motionSensor, act:alarm
# tri_1:threeAxis, act_1:sendAction	-- motion -- tri_2:motionSensor, act:colorControl
# tri_1:threeAxis, act_1:sendAction	-- motion -- tri_2:motionSensor, act:imageCapture
# tri_1:threeAxis, act_1:sendAction	-- motion -- tri_2:motionSensor, act:locationMode
# tri_1:threeAxis, act_1:sendAction	-- motion -- tri_2:motionSensor, act:number
# tri_1:threeAxis, act_1:sendAction	-- motion -- tri_2:motionSensor, act:sendAction
# tri_1:threeAxis, act_1:sendAction	-- motion -- tri_2:motionSensor, act:switch
# tri_1:time, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:colorControl
# tri_1:time, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:imageCapture
# tri_1:time, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:momentary
# tri_1:time, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:number
# tri_1:time, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:sendAction
# tri_1:time, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:switch
# tri_1:time, act_1:sendAction	-- motion -- tri_2:motionSensor, act:alarm
# tri_1:time, act_1:sendAction	-- motion -- tri_2:motionSensor, act:colorControl
# tri_1:time, act_1:sendAction	-- motion -- tri_2:motionSensor, act:imageCapture
# tri_1:time, act_1:sendAction	-- motion -- tri_2:motionSensor, act:locationMode
# tri_1:time, act_1:sendAction	-- motion -- tri_2:motionSensor, act:number
# tri_1:time, act_1:sendAction	-- motion -- tri_2:motionSensor, act:sendAction
# tri_1:time, act_1:sendAction	-- motion -- tri_2:motionSensor, act:switch
# tri_1:waterSensor, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:colorControl
# tri_1:waterSensor, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:imageCapture
# tri_1:waterSensor, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:momentary
# tri_1:waterSensor, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:number
# tri_1:waterSensor, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:sendAction
# tri_1:waterSensor, act_1:sendAction	-- motion -- tri_2:accelerationSensor, act:switch
# tri_1:waterSensor, act_1:sendAction	-- motion -- tri_2:motionSensor, act:alarm
# tri_1:waterSensor, act_1:sendAction	-- motion -- tri_2:motionSensor, act:colorControl
# tri_1:waterSensor, act_1:sendAction	-- motion -- tri_2:motionSensor, act:imageCapture
# tri_1:waterSensor, act_1:sendAction	-- motion -- tri_2:motionSensor, act:locationMode
# tri_1:waterSensor, act_1:sendAction	-- motion -- tri_2:motionSensor, act:number
# tri_1:waterSensor, act_1:sendAction	-- motion -- tri_2:motionSensor, act:sendAction
# tri_1:waterSensor, act_1:sendAction	-- motion -- tri_2:motionSensor, act:switch
# tri_1:alarm, act_1:alarm	-- smoke -- tri_2:alarm, act:alarm
# tri_1:alarm, act_1:alarm	-- smoke -- tri_2:carbonMonoxideDetector, act:sendAction
# tri_1:alarm, act_1:alarm	-- smoke -- tri_2:carbonMonoxideDetector, act:thermostat
# tri_1:alarm, act_1:alarm	-- smoke -- tri_2:smokeDetector, act:colorControl
# tri_1:alarm, act_1:alarm	-- smoke -- tri_2:smokeDetector, act:sendAction
# tri_1:alarm, act_1:alarm	-- smoke -- tri_2:smokeDetector, act:thermostat
# tri_1:app, act_1:alarm	-- smoke -- tri_2:alarm, act:alarm
# tri_1:app, act_1:alarm	-- smoke -- tri_2:carbonMonoxideDetector, act:sendAction
# tri_1:app, act_1:alarm	-- smoke -- tri_2:carbonMonoxideDetector, act:thermostat
# tri_1:app, act_1:alarm	-- smoke -- tri_2:smokeDetector, act:colorControl
# tri_1:app, act_1:alarm	-- smoke -- tri_2:smokeDetector, act:sendAction
# tri_1:app, act_1:alarm	-- smoke -- tri_2:smokeDetector, act:thermostat
# tri_1:contactSensor, act_1:alarm	-- smoke -- tri_2:alarm, act:alarm
# tri_1:contactSensor, act_1:alarm	-- smoke -- tri_2:carbonMonoxideDetector, act:sendAction
# tri_1:contactSensor, act_1:alarm	-- smoke -- tri_2:carbonMonoxideDetector, act:thermostat
# tri_1:contactSensor, act_1:alarm	-- smoke -- tri_2:smokeDetector, act:colorControl
# tri_1:contactSensor, act_1:alarm	-- smoke -- tri_2:smokeDetector, act:sendAction
# tri_1:contactSensor, act_1:alarm	-- smoke -- tri_2:smokeDetector, act:thermostat
# tri_1:motionSensor, act_1:alarm	-- smoke -- tri_2:alarm, act:alarm
# tri_1:motionSensor, act_1:alarm	-- smoke -- tri_2:carbonMonoxideDetector, act:sendAction
# tri_1:motionSensor, act_1:alarm	-- smoke -- tri_2:carbonMonoxideDetector, act:thermostat
# tri_1:motionSensor, act_1:alarm	-- smoke -- tri_2:smokeDetector, act:colorControl
# tri_1:motionSensor, act_1:alarm	-- smoke -- tri_2:smokeDetector, act:sendAction
# tri_1:motionSensor, act_1:alarm	-- smoke -- tri_2:smokeDetector, act:thermostat
# tri_1:app, act_1:thermostat	-- temperature -- tri_2:thermostat, act:switch
# tri_1:app, act_1:thermostat	-- temperature -- tri_2:thermostat, act:thermostat
# tri_1:carbonMonoxideDetector, act_1:thermostat	-- temperature -- tri_2:thermostat, act:switch
# tri_1:carbonMonoxideDetector, act_1:thermostat	-- temperature -- tri_2:thermostat, act:thermostat
# tri_1:contactSensor, act_1:thermostat	-- temperature -- tri_2:thermostat, act:switch
# tri_1:contactSensor, act_1:thermostat	-- temperature -- tri_2:thermostat, act:thermostat
# tri_1:location, act_1:thermostat	-- temperature -- tri_2:thermostat, act:switch
# tri_1:location, act_1:thermostat	-- temperature -- tri_2:thermostat, act:thermostat
# tri_1:smokeDetector, act_1:thermostat	-- temperature -- tri_2:thermostat, act:switch
# tri_1:smokeDetector, act_1:thermostat	-- temperature -- tri_2:thermostat, act:thermostat
# tri_1:temperatureMeasurement, act_1:thermostat	-- temperature -- tri_2:thermostat, act:switch
# tri_1:temperatureMeasurement, act_1:thermostat	-- temperature -- tri_2:thermostat, act:thermostat
# tri_1:thermostat, act_1:thermostat	-- temperature -- tri_2:thermostat, act:switch
# tri_1:thermostat, act_1:thermostat	-- temperature -- tri_2:thermostat, act:thermostat
# tri_1:accelerationSensor, act_1:number	-- time -- tri_2:threeAxis, act:sendAction
# tri_1:accelerationSensor, act_1:number	-- time -- tri_2:time, act:device.PetFeederShield
# tri_1:accelerationSensor, act_1:number	-- time -- tri_2:time, act:locationMode
# tri_1:accelerationSensor, act_1:number	-- time -- tri_2:time, act:lock
# tri_1:accelerationSensor, act_1:number	-- time -- tri_2:time, act:sendAction
# tri_1:accelerationSensor, act_1:number	-- time -- tri_2:time, act:switch
# tri_1:contactSensor, act_1:number	-- time -- tri_2:threeAxis, act:sendAction
# tri_1:contactSensor, act_1:number	-- time -- tri_2:time, act:device.PetFeederShield
# tri_1:contactSensor, act_1:number	-- time -- tri_2:time, act:locationMode
# tri_1:contactSensor, act_1:number	-- time -- tri_2:time, act:lock
# tri_1:contactSensor, act_1:number	-- time -- tri_2:time, act:sendAction
# tri_1:contactSensor, act_1:number	-- time -- tri_2:time, act:switch
# tri_1:motionSensor, act_1:number	-- time -- tri_2:threeAxis, act:sendAction
# tri_1:motionSensor, act_1:number	-- time -- tri_2:time, act:device.PetFeederShield
# tri_1:motionSensor, act_1:number	-- time -- tri_2:time, act:locationMode
# tri_1:motionSensor, act_1:number	-- time -- tri_2:time, act:lock
# tri_1:motionSensor, act_1:number	-- time -- tri_2:time, act:sendAction
# tri_1:motionSensor, act_1:number	-- time -- tri_2:time, act:switch
# tri_1:presenceSensor, act_1:number	-- time -- tri_2:threeAxis, act:sendAction
# tri_1:presenceSensor, act_1:number	-- time -- tri_2:time, act:device.PetFeederShield
# tri_1:presenceSensor, act_1:number	-- time -- tri_2:time, act:locationMode
# tri_1:presenceSensor, act_1:number	-- time -- tri_2:time, act:lock
# tri_1:presenceSensor, act_1:number	-- time -- tri_2:time, act:sendAction
# tri_1:presenceSensor, act_1:number	-- time -- tri_2:time, act:switch
# tri_1:switch, act_1:number	-- time -- tri_2:threeAxis, act:sendAction
# tri_1:switch, act_1:number	-- time -- tri_2:time, act:device.PetFeederShield
# tri_1:switch, act_1:number	-- time -- tri_2:time, act:locationMode
# tri_1:switch, act_1:number	-- time -- tri_2:time, act:lock
# tri_1:switch, act_1:number	-- time -- tri_2:time, act:sendAction
# tri_1:switch, act_1:number	-- time -- tri_2:time, act:switch

# %%
# algorithm 1: algorithm for interaction chain discovery - ONLY PHYSICAL CHANNELS
phy_ch = { "temperature", "humidity", "illumination", "motion", "location", "smoke", "leakage" }
phy_INTAC = []

for i in list_trigger_action: # for every pair of trigger-action
    for j in list_trigger_action:
        for channel in capability_channel.keys(): # this implies --> k.ch == m.ch
            if channel in phy_ch: # elaborates only physical channels
                #print("physical channel:",physical_channel)
                for k in capability_channel[channel]:     # for every possible pair of capabilities
                    for m in capability_channel[channel]: # correlated to the same physical channel
                        action_cap = cap2string(i[1][0]) # action capability of first trigger-action
                        trigger_cap = cap2string(j[0])   # trigger capability of second trigger-action
                        if ((action_cap == k) and (trigger_cap == m)):
                            first_app = [i[0], i[1][0]]  # use only trigger-action
                            second_app = [j[0], j[1][0]] # use only trigger-action
                            if not [first_app, channel, second_app] in phy_INTAC: # not duplicates 
                                print(f"action {action_cap} nel canale {channel} triggera {trigger_cap}")
                                phy_INTAC.append([first_app, channel, second_app])
# Out:
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera illumination
# action color nel canale illumination triggera power
# action color nel canale illumination triggera power
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action image capture nel canale illumination triggera beacon
# action image capture nel canale illumination triggera beacon
# action image capture nel canale illumination triggera illumination
# action image capture nel canale illumination triggera power
# action image capture nel canale illumination triggera power
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action momentary nel canale illumination triggera beacon
# action momentary nel canale illumination triggera beacon
# action momentary nel canale illumination triggera illumination
# action momentary nel canale illumination triggera power
# action momentary nel canale illumination triggera power
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action alarm nel canale smoke triggera alarm
# action alarm nel canale smoke triggera carbon_monoxide
# action alarm nel canale smoke triggera carbon_monoxide
# action alarm nel canale smoke triggera smoke
# action alarm nel canale smoke triggera smoke
# action alarm nel canale smoke triggera smoke
# action alarm nel canale smoke triggera alarm
# action alarm nel canale smoke triggera carbon_monoxide
# action alarm nel canale smoke triggera carbon_monoxide
# action alarm nel canale smoke triggera smoke
# action alarm nel canale smoke triggera smoke
# action alarm nel canale smoke triggera smoke
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera illumination
# action color nel canale illumination triggera power
# action color nel canale illumination triggera power
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action thermostat nel canale temperature triggera thermostat
# action thermostat nel canale temperature triggera thermostat
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera illumination
# action color nel canale illumination triggera power
# action color nel canale illumination triggera power
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action thermostat nel canale temperature triggera thermostat
# action thermostat nel canale temperature triggera thermostat
# action alarm nel canale smoke triggera alarm
# action alarm nel canale smoke triggera carbon_monoxide
# action alarm nel canale smoke triggera carbon_monoxide
# action alarm nel canale smoke triggera smoke
# action alarm nel canale smoke triggera smoke
# action alarm nel canale smoke triggera smoke
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera illumination
# action color nel canale illumination triggera power
# action color nel canale illumination triggera power
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action image capture nel canale illumination triggera beacon
# action image capture nel canale illumination triggera beacon
# action image capture nel canale illumination triggera illumination
# action image capture nel canale illumination triggera power
# action image capture nel canale illumination triggera power
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action momentary nel canale illumination triggera beacon
# action momentary nel canale illumination triggera beacon
# action momentary nel canale illumination triggera illumination
# action momentary nel canale illumination triggera power
# action momentary nel canale illumination triggera power
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action thermostat nel canale temperature triggera thermostat
# action thermostat nel canale temperature triggera thermostat
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera illumination
# action color nel canale illumination triggera power
# action color nel canale illumination triggera power
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action music player nel canale location triggera location
# action music player nel canale location triggera location
# action music player nel canale location triggera location
# action music player nel canale location triggera presence
# action music player nel canale location triggera presence
# action music player nel canale location triggera presence
# action music player nel canale location triggera presence
# action music player nel canale location triggera presence
# action music player nel canale location triggera presence
# action music player nel canale location triggera presence
# action music player nel canale location triggera presence
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action thermostat nel canale temperature triggera thermostat
# action thermostat nel canale temperature triggera thermostat
# action alarm nel canale smoke triggera alarm
# action alarm nel canale smoke triggera carbon_monoxide
# action alarm nel canale smoke triggera carbon_monoxide
# action alarm nel canale smoke triggera smoke
# action alarm nel canale smoke triggera smoke
# action alarm nel canale smoke triggera smoke
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera illumination
# action color nel canale illumination triggera power
# action color nel canale illumination triggera power
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action image capture nel canale illumination triggera beacon
# action image capture nel canale illumination triggera beacon
# action image capture nel canale illumination triggera illumination
# action image capture nel canale illumination triggera power
# action image capture nel canale illumination triggera power
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera illumination
# action color nel canale illumination triggera power
# action color nel canale illumination triggera power
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action image capture nel canale illumination triggera beacon
# action image capture nel canale illumination triggera beacon
# action image capture nel canale illumination triggera illumination
# action image capture nel canale illumination triggera power
# action image capture nel canale illumination triggera power
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action momentary nel canale illumination triggera beacon
# action momentary nel canale illumination triggera beacon
# action momentary nel canale illumination triggera illumination
# action momentary nel canale illumination triggera power
# action momentary nel canale illumination triggera power
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action momentary nel canale illumination triggera switch
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera illumination
# action color nel canale illumination triggera power
# action color nel canale illumination triggera power
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action thermostat nel canale temperature triggera thermostat
# action thermostat nel canale temperature triggera thermostat
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera illumination
# action color nel canale illumination triggera power
# action color nel canale illumination triggera power
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action image capture nel canale illumination triggera beacon
# action image capture nel canale illumination triggera beacon
# action image capture nel canale illumination triggera illumination
# action image capture nel canale illumination triggera power
# action image capture nel canale illumination triggera power
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action image capture nel canale illumination triggera switch
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch level nel canale illumination triggera beacon
# action switch level nel canale illumination triggera beacon
# action switch level nel canale illumination triggera illumination
# action switch level nel canale illumination triggera power
# action switch level nel canale illumination triggera power
# action switch level nel canale illumination triggera switch
# action switch level nel canale illumination triggera switch
# action switch level nel canale illumination triggera switch
# action switch level nel canale illumination triggera switch
# action switch level nel canale illumination triggera switch
# action switch level nel canale illumination triggera switch
# action switch level nel canale illumination triggera switch
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action thermostat nel canale temperature triggera thermostat
# action thermostat nel canale temperature triggera thermostat
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action thermostat nel canale temperature triggera thermostat
# action thermostat nel canale temperature triggera thermostat
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera beacon
# action color nel canale illumination triggera illumination
# action color nel canale illumination triggera power
# action color nel canale illumination triggera power
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action color nel canale illumination triggera switch
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera acceleration
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action send action nel canale motion triggera motion
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera beacon
# action switch nel canale illumination triggera illumination
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera power
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale illumination triggera switch
# action valve nel canale leakage triggera app
# action valve nel canale leakage triggera app
# action valve nel canale leakage triggera app
# action valve nel canale leakage triggera app
# action valve nel canale leakage triggera app
# action valve nel canale leakage triggera app
# action valve nel canale leakage triggera jawbone user
# action valve nel canale leakage triggera jawbone user
# action valve nel canale leakage triggera jawbone user
# action valve nel canale leakage triggera jawbone user
# action valve nel canale leakage triggera water sensor
# action valve nel canale leakage triggera water sensor
# action valve nel canale leakage triggera water sensor
# action valve nel canale leakage triggera water sensor

# %%
print(len(phy_INTAC))
# Out:
# 690

# %%
phy_INTAC
# Out:
# [[['accelerationSensor', 'colorControl'], 'illumination', ['beacon', 'lock']],
#  [['accelerationSensor', 'colorControl'],
#   'illumination',
#   ['beacon', 'switch']],
#  [['accelerationSensor', 'colorControl'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['accelerationSensor', 'colorControl'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['accelerationSensor', 'colorControl'],
#   'illumination',
#   ['powerMeter', 'switch']],
#  [['accelerationSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['accelerationSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['accelerationSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['accelerationSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'number']],
#  [['accelerationSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'sendAction']],
#  [['accelerationSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'switch']],
#  [['accelerationSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'switchLevel']],
#  [['accelerationSensor', 'imageCapture'], 'illumination', ['beacon', 'lock']],
#  [['accelerationSensor', 'imageCapture'],
#   'illumination',
#   ['beacon', 'switch']],
#  [['accelerationSensor', 'imageCapture'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['accelerationSensor', 'imageCapture'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['accelerationSensor', 'imageCapture'],
#   'illumination',
#   ['powerMeter', 'switch']],
#  [['accelerationSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['accelerationSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['accelerationSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['accelerationSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'number']],
#  [['accelerationSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'sendAction']],
#  [['accelerationSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'switch']],
#  [['accelerationSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'switchLevel']],
#  [['accelerationSensor', 'momentary'], 'illumination', ['beacon', 'lock']],
#  [['accelerationSensor', 'momentary'], 'illumination', ['beacon', 'switch']],
#  [['accelerationSensor', 'momentary'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['accelerationSensor', 'momentary'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['accelerationSensor', 'momentary'],
#   'illumination',
#   ['powerMeter', 'switch']],
#  [['accelerationSensor', 'momentary'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['accelerationSensor', 'momentary'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['accelerationSensor', 'momentary'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['accelerationSensor', 'momentary'], 'illumination', ['switch', 'number']],
#  [['accelerationSensor', 'momentary'],
#   'illumination',
#   ['switch', 'sendAction']],
#  [['accelerationSensor', 'momentary'], 'illumination', ['switch', 'switch']],
#  [['accelerationSensor', 'momentary'],
#   'illumination',
#   ['switch', 'switchLevel']],
#  [['accelerationSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'colorControl']],
#  [['accelerationSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'imageCapture']],
#  [['accelerationSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'momentary']],
#  [['accelerationSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'number']],
#  [['accelerationSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'sendAction']],
#  [['accelerationSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'switch']],
#  [['accelerationSensor', 'sendAction'], 'motion', ['motionSensor', 'alarm']],
#  [['accelerationSensor', 'sendAction'],
#   'motion',
#   ['motionSensor', 'colorControl']],
#  [['accelerationSensor', 'sendAction'],
#   'motion',
#   ['motionSensor', 'imageCapture']],
#  [['accelerationSensor', 'sendAction'],
#   'motion',
#   ['motionSensor', 'locationMode']],
#  [['accelerationSensor', 'sendAction'], 'motion', ['motionSensor', 'number']],
#  [['accelerationSensor', 'sendAction'],
#   'motion',
#   ['motionSensor', 'sendAction']],
#  [['accelerationSensor', 'sendAction'], 'motion', ['motionSensor', 'switch']],
#  [['accelerationSensor', 'switch'], 'illumination', ['beacon', 'lock']],
#  [['accelerationSensor', 'switch'], 'illumination', ['beacon', 'switch']],
#  [['accelerationSensor', 'switch'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['accelerationSensor', 'switch'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['accelerationSensor', 'switch'], 'illumination', ['powerMeter', 'switch']],
#  [['accelerationSensor', 'switch'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['accelerationSensor', 'switch'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['accelerationSensor', 'switch'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['accelerationSensor', 'switch'], 'illumination', ['switch', 'number']],
#  [['accelerationSensor', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['accelerationSensor', 'switch'], 'illumination', ['switch', 'switch']],
#  [['accelerationSensor', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['alarm', 'alarm'], 'smoke', ['alarm', 'alarm']],
#  [['alarm', 'alarm'], 'smoke', ['carbonMonoxideDetector', 'sendAction']],
#  [['alarm', 'alarm'], 'smoke', ['carbonMonoxideDetector', 'thermostat']],
#  [['alarm', 'alarm'], 'smoke', ['smokeDetector', 'colorControl']],
#  [['alarm', 'alarm'], 'smoke', ['smokeDetector', 'sendAction']],
#  [['alarm', 'alarm'], 'smoke', ['smokeDetector', 'thermostat']],
#  [['app', 'alarm'], 'smoke', ['alarm', 'alarm']],
#  [['app', 'alarm'], 'smoke', ['carbonMonoxideDetector', 'sendAction']],
#  [['app', 'alarm'], 'smoke', ['carbonMonoxideDetector', 'thermostat']],
#  [['app', 'alarm'], 'smoke', ['smokeDetector', 'colorControl']],
#  [['app', 'alarm'], 'smoke', ['smokeDetector', 'sendAction']],
#  [['app', 'alarm'], 'smoke', ['smokeDetector', 'thermostat']],
#  [['app', 'colorControl'], 'illumination', ['beacon', 'lock']],
#  [['app', 'colorControl'], 'illumination', ['beacon', 'switch']],
#  [['app', 'colorControl'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['app', 'colorControl'], 'illumination', ['powerMeter', 'sendAction']],
#  [['app', 'colorControl'], 'illumination', ['powerMeter', 'switch']],
#  [['app', 'colorControl'], 'illumination', ['switch', 'colorControl']],
#  [['app', 'colorControl'], 'illumination', ['switch', 'imageCapture']],
#  [['app', 'colorControl'], 'illumination', ['switch', 'locationMode']],
#  [['app', 'colorControl'], 'illumination', ['switch', 'number']],
#  [['app', 'colorControl'], 'illumination', ['switch', 'sendAction']],
#  [['app', 'colorControl'], 'illumination', ['switch', 'switch']],
#  [['app', 'colorControl'], 'illumination', ['switch', 'switchLevel']],
#  [['app', 'switch'], 'illumination', ['beacon', 'lock']],
#  [['app', 'switch'], 'illumination', ['beacon', 'switch']],
#  [['app', 'switch'], 'illumination', ['illuminanceMeasurement', 'switch']],
#  [['app', 'switch'], 'illumination', ['powerMeter', 'sendAction']],
#  [['app', 'switch'], 'illumination', ['powerMeter', 'switch']],
#  [['app', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['app', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['app', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['app', 'switch'], 'illumination', ['switch', 'number']],
#  [['app', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['app', 'switch'], 'illumination', ['switch', 'switch']],
#  [['app', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['app', 'thermostat'], 'temperature', ['thermostat', 'switch']],
#  [['app', 'thermostat'], 'temperature', ['thermostat', 'thermostat']],
#  [['beacon', 'switch'], 'illumination', ['beacon', 'lock']],
#  [['beacon', 'switch'], 'illumination', ['beacon', 'switch']],
#  [['beacon', 'switch'], 'illumination', ['illuminanceMeasurement', 'switch']],
#  [['beacon', 'switch'], 'illumination', ['powerMeter', 'sendAction']],
#  [['beacon', 'switch'], 'illumination', ['powerMeter', 'switch']],
#  [['beacon', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['beacon', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['beacon', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['beacon', 'switch'], 'illumination', ['switch', 'number']],
#  [['beacon', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['beacon', 'switch'], 'illumination', ['switch', 'switch']],
#  [['beacon', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['button', 'colorControl'], 'illumination', ['beacon', 'lock']],
#  [['button', 'colorControl'], 'illumination', ['beacon', 'switch']],
#  [['button', 'colorControl'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['button', 'colorControl'], 'illumination', ['powerMeter', 'sendAction']],
#  [['button', 'colorControl'], 'illumination', ['powerMeter', 'switch']],
#  [['button', 'colorControl'], 'illumination', ['switch', 'colorControl']],
#  [['button', 'colorControl'], 'illumination', ['switch', 'imageCapture']],
#  [['button', 'colorControl'], 'illumination', ['switch', 'locationMode']],
#  [['button', 'colorControl'], 'illumination', ['switch', 'number']],
#  [['button', 'colorControl'], 'illumination', ['switch', 'sendAction']],
#  [['button', 'colorControl'], 'illumination', ['switch', 'switch']],
#  [['button', 'colorControl'], 'illumination', ['switch', 'switchLevel']],
#  [['button', 'sendAction'], 'motion', ['accelerationSensor', 'colorControl']],
#  [['button', 'sendAction'], 'motion', ['accelerationSensor', 'imageCapture']],
#  [['button', 'sendAction'], 'motion', ['accelerationSensor', 'momentary']],
#  [['button', 'sendAction'], 'motion', ['accelerationSensor', 'number']],
#  [['button', 'sendAction'], 'motion', ['accelerationSensor', 'sendAction']],
#  [['button', 'sendAction'], 'motion', ['accelerationSensor', 'switch']],
#  [['button', 'sendAction'], 'motion', ['motionSensor', 'alarm']],
#  [['button', 'sendAction'], 'motion', ['motionSensor', 'colorControl']],
#  [['button', 'sendAction'], 'motion', ['motionSensor', 'imageCapture']],
#  [['button', 'sendAction'], 'motion', ['motionSensor', 'locationMode']],
#  [['button', 'sendAction'], 'motion', ['motionSensor', 'number']],
#  [['button', 'sendAction'], 'motion', ['motionSensor', 'sendAction']],
#  [['button', 'sendAction'], 'motion', ['motionSensor', 'switch']],
#  [['carbonMonoxideDetector', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'colorControl']],
#  [['carbonMonoxideDetector', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'imageCapture']],
#  [['carbonMonoxideDetector', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'momentary']],
#  [['carbonMonoxideDetector', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'number']],
#  [['carbonMonoxideDetector', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'sendAction']],
#  [['carbonMonoxideDetector', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'switch']],
#  [['carbonMonoxideDetector', 'sendAction'],
#   'motion',
#   ['motionSensor', 'alarm']],
#  [['carbonMonoxideDetector', 'sendAction'],
#   'motion',
#   ['motionSensor', 'colorControl']],
#  [['carbonMonoxideDetector', 'sendAction'],
#   'motion',
#   ['motionSensor', 'imageCapture']],
#  [['carbonMonoxideDetector', 'sendAction'],
#   'motion',
#   ['motionSensor', 'locationMode']],
#  [['carbonMonoxideDetector', 'sendAction'],
#   'motion',
#   ['motionSensor', 'number']],
#  [['carbonMonoxideDetector', 'sendAction'],
#   'motion',
#   ['motionSensor', 'sendAction']],
#  [['carbonMonoxideDetector', 'sendAction'],
#   'motion',
#   ['motionSensor', 'switch']],
#  [['carbonMonoxideDetector', 'thermostat'],
#   'temperature',
#   ['thermostat', 'switch']],
#  [['carbonMonoxideDetector', 'thermostat'],
#   'temperature',
#   ['thermostat', 'thermostat']],
#  [['contactSensor', 'alarm'], 'smoke', ['alarm', 'alarm']],
#  [['contactSensor', 'alarm'],
#   'smoke',
#   ['carbonMonoxideDetector', 'sendAction']],
#  [['contactSensor', 'alarm'],
#   'smoke',
#   ['carbonMonoxideDetector', 'thermostat']],
#  [['contactSensor', 'alarm'], 'smoke', ['smokeDetector', 'colorControl']],
#  [['contactSensor', 'alarm'], 'smoke', ['smokeDetector', 'sendAction']],
#  [['contactSensor', 'alarm'], 'smoke', ['smokeDetector', 'thermostat']],
#  [['contactSensor', 'colorControl'], 'illumination', ['beacon', 'lock']],
#  [['contactSensor', 'colorControl'], 'illumination', ['beacon', 'switch']],
#  [['contactSensor', 'colorControl'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['contactSensor', 'colorControl'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['contactSensor', 'colorControl'], 'illumination', ['powerMeter', 'switch']],
#  [['contactSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['contactSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['contactSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['contactSensor', 'colorControl'], 'illumination', ['switch', 'number']],
#  [['contactSensor', 'colorControl'], 'illumination', ['switch', 'sendAction']],
#  [['contactSensor', 'colorControl'], 'illumination', ['switch', 'switch']],
#  [['contactSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'switchLevel']],
#  [['contactSensor', 'imageCapture'], 'illumination', ['beacon', 'lock']],
#  [['contactSensor', 'imageCapture'], 'illumination', ['beacon', 'switch']],
#  [['contactSensor', 'imageCapture'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['contactSensor', 'imageCapture'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['contactSensor', 'imageCapture'], 'illumination', ['powerMeter', 'switch']],
#  [['contactSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['contactSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['contactSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['contactSensor', 'imageCapture'], 'illumination', ['switch', 'number']],
#  [['contactSensor', 'imageCapture'], 'illumination', ['switch', 'sendAction']],
#  [['contactSensor', 'imageCapture'], 'illumination', ['switch', 'switch']],
#  [['contactSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'switchLevel']],
#  [['contactSensor', 'momentary'], 'illumination', ['beacon', 'lock']],
#  [['contactSensor', 'momentary'], 'illumination', ['beacon', 'switch']],
#  [['contactSensor', 'momentary'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['contactSensor', 'momentary'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['contactSensor', 'momentary'], 'illumination', ['powerMeter', 'switch']],
#  [['contactSensor', 'momentary'], 'illumination', ['switch', 'colorControl']],
#  [['contactSensor', 'momentary'], 'illumination', ['switch', 'imageCapture']],
#  [['contactSensor', 'momentary'], 'illumination', ['switch', 'locationMode']],
#  [['contactSensor', 'momentary'], 'illumination', ['switch', 'number']],
#  [['contactSensor', 'momentary'], 'illumination', ['switch', 'sendAction']],
#  [['contactSensor', 'momentary'], 'illumination', ['switch', 'switch']],
#  [['contactSensor', 'momentary'], 'illumination', ['switch', 'switchLevel']],
#  [['contactSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'colorControl']],
#  [['contactSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'imageCapture']],
#  [['contactSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'momentary']],
#  [['contactSensor', 'sendAction'], 'motion', ['accelerationSensor', 'number']],
#  [['contactSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'sendAction']],
#  [['contactSensor', 'sendAction'], 'motion', ['accelerationSensor', 'switch']],
#  [['contactSensor', 'sendAction'], 'motion', ['motionSensor', 'alarm']],
#  [['contactSensor', 'sendAction'], 'motion', ['motionSensor', 'colorControl']],
#  [['contactSensor', 'sendAction'], 'motion', ['motionSensor', 'imageCapture']],
#  [['contactSensor', 'sendAction'], 'motion', ['motionSensor', 'locationMode']],
#  [['contactSensor', 'sendAction'], 'motion', ['motionSensor', 'number']],
#  [['contactSensor', 'sendAction'], 'motion', ['motionSensor', 'sendAction']],
#  [['contactSensor', 'sendAction'], 'motion', ['motionSensor', 'switch']],
#  [['contactSensor', 'switch'], 'illumination', ['beacon', 'lock']],
#  [['contactSensor', 'switch'], 'illumination', ['beacon', 'switch']],
#  [['contactSensor', 'switch'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['contactSensor', 'switch'], 'illumination', ['powerMeter', 'sendAction']],
#  [['contactSensor', 'switch'], 'illumination', ['powerMeter', 'switch']],
#  [['contactSensor', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['contactSensor', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['contactSensor', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['contactSensor', 'switch'], 'illumination', ['switch', 'number']],
#  [['contactSensor', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['contactSensor', 'switch'], 'illumination', ['switch', 'switch']],
#  [['contactSensor', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['contactSensor', 'thermostat'], 'temperature', ['thermostat', 'switch']],
#  [['contactSensor', 'thermostat'],
#   'temperature',
#   ['thermostat', 'thermostat']],
#  [['device.jawboneUser', 'colorControl'], 'illumination', ['beacon', 'lock']],
#  [['device.jawboneUser', 'colorControl'],
#   'illumination',
#   ['beacon', 'switch']],
#  [['device.jawboneUser', 'colorControl'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['device.jawboneUser', 'colorControl'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['device.jawboneUser', 'colorControl'],
#   'illumination',
#   ['powerMeter', 'switch']],
#  [['device.jawboneUser', 'colorControl'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['device.jawboneUser', 'colorControl'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['device.jawboneUser', 'colorControl'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['device.jawboneUser', 'colorControl'],
#   'illumination',
#   ['switch', 'number']],
#  [['device.jawboneUser', 'colorControl'],
#   'illumination',
#   ['switch', 'sendAction']],
#  [['device.jawboneUser', 'colorControl'],
#   'illumination',
#   ['switch', 'switch']],
#  [['device.jawboneUser', 'colorControl'],
#   'illumination',
#   ['switch', 'switchLevel']],
#  [['device.jawboneUser', 'musicPlayer'], 'location', ['location', 'lock']],
#  [['device.jawboneUser', 'musicPlayer'], 'location', ['location', 'switch']],
#  [['device.jawboneUser', 'musicPlayer'],
#   'location',
#   ['location', 'thermostat']],
#  [['device.jawboneUser', 'musicPlayer'],
#   'location',
#   ['presenceSensor', 'colorControl']],
#  [['device.jawboneUser', 'musicPlayer'],
#   'location',
#   ['presenceSensor', 'imageCapture']],
#  [['device.jawboneUser', 'musicPlayer'],
#   'location',
#   ['presenceSensor', 'locationMode']],
#  [['device.jawboneUser', 'musicPlayer'],
#   'location',
#   ['presenceSensor', 'lock']],
#  [['device.jawboneUser', 'musicPlayer'],
#   'location',
#   ['presenceSensor', 'momentary']],
#  [['device.jawboneUser', 'musicPlayer'],
#   'location',
#   ['presenceSensor', 'number']],
#  [['device.jawboneUser', 'musicPlayer'],
#   'location',
#   ['presenceSensor', 'sendAction']],
#  [['device.jawboneUser', 'musicPlayer'],
#   'location',
#   ['presenceSensor', 'switch']],
#  [['device.jawboneUser', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'colorControl']],
#  [['device.jawboneUser', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'imageCapture']],
#  [['device.jawboneUser', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'momentary']],
#  [['device.jawboneUser', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'number']],
#  [['device.jawboneUser', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'sendAction']],
#  [['device.jawboneUser', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'switch']],
#  [['device.jawboneUser', 'sendAction'], 'motion', ['motionSensor', 'alarm']],
#  [['device.jawboneUser', 'sendAction'],
#   'motion',
#   ['motionSensor', 'colorControl']],
#  [['device.jawboneUser', 'sendAction'],
#   'motion',
#   ['motionSensor', 'imageCapture']],
#  [['device.jawboneUser', 'sendAction'],
#   'motion',
#   ['motionSensor', 'locationMode']],
#  [['device.jawboneUser', 'sendAction'], 'motion', ['motionSensor', 'number']],
#  [['device.jawboneUser', 'sendAction'],
#   'motion',
#   ['motionSensor', 'sendAction']],
#  [['device.jawboneUser', 'sendAction'], 'motion', ['motionSensor', 'switch']],
#  [['device.jawboneUser', 'switch'], 'illumination', ['beacon', 'lock']],
#  [['device.jawboneUser', 'switch'], 'illumination', ['beacon', 'switch']],
#  [['device.jawboneUser', 'switch'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['device.jawboneUser', 'switch'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['device.jawboneUser', 'switch'], 'illumination', ['powerMeter', 'switch']],
#  [['device.jawboneUser', 'switch'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['device.jawboneUser', 'switch'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['device.jawboneUser', 'switch'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['device.jawboneUser', 'switch'], 'illumination', ['switch', 'number']],
#  [['device.jawboneUser', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['device.jawboneUser', 'switch'], 'illumination', ['switch', 'switch']],
#  [['device.jawboneUser', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['illuminanceMeasurement', 'switch'], 'illumination', ['beacon', 'lock']],
#  [['illuminanceMeasurement', 'switch'], 'illumination', ['beacon', 'switch']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['powerMeter', 'switch']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['illuminanceMeasurement', 'switch'], 'illumination', ['switch', 'number']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'sendAction']],
#  [['illuminanceMeasurement', 'switch'], 'illumination', ['switch', 'switch']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'switchLevel']],
#  [['location', 'switch'], 'illumination', ['beacon', 'lock']],
#  [['location', 'switch'], 'illumination', ['beacon', 'switch']],
#  [['location', 'switch'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['location', 'switch'], 'illumination', ['powerMeter', 'sendAction']],
#  [['location', 'switch'], 'illumination', ['powerMeter', 'switch']],
#  [['location', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['location', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['location', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['location', 'switch'], 'illumination', ['switch', 'number']],
#  [['location', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['location', 'switch'], 'illumination', ['switch', 'switch']],
#  [['location', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['location', 'thermostat'], 'temperature', ['thermostat', 'switch']],
#  [['location', 'thermostat'], 'temperature', ['thermostat', 'thermostat']],
#  [['motionSensor', 'alarm'], 'smoke', ['alarm', 'alarm']],
#  [['motionSensor', 'alarm'],
#   'smoke',
#   ['carbonMonoxideDetector', 'sendAction']],
#  [['motionSensor', 'alarm'],
#   'smoke',
#   ['carbonMonoxideDetector', 'thermostat']],
#  [['motionSensor', 'alarm'], 'smoke', ['smokeDetector', 'colorControl']],
#  [['motionSensor', 'alarm'], 'smoke', ['smokeDetector', 'sendAction']],
#  [['motionSensor', 'alarm'], 'smoke', ['smokeDetector', 'thermostat']],
#  [['motionSensor', 'colorControl'], 'illumination', ['beacon', 'lock']],
#  [['motionSensor', 'colorControl'], 'illumination', ['beacon', 'switch']],
#  [['motionSensor', 'colorControl'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['motionSensor', 'colorControl'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['motionSensor', 'colorControl'], 'illumination', ['powerMeter', 'switch']],
#  [['motionSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['motionSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['motionSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['motionSensor', 'colorControl'], 'illumination', ['switch', 'number']],
#  [['motionSensor', 'colorControl'], 'illumination', ['switch', 'sendAction']],
#  [['motionSensor', 'colorControl'], 'illumination', ['switch', 'switch']],
#  [['motionSensor', 'colorControl'], 'illumination', ['switch', 'switchLevel']],
#  [['motionSensor', 'imageCapture'], 'illumination', ['beacon', 'lock']],
#  [['motionSensor', 'imageCapture'], 'illumination', ['beacon', 'switch']],
#  [['motionSensor', 'imageCapture'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['motionSensor', 'imageCapture'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['motionSensor', 'imageCapture'], 'illumination', ['powerMeter', 'switch']],
#  [['motionSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['motionSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['motionSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['motionSensor', 'imageCapture'], 'illumination', ['switch', 'number']],
#  [['motionSensor', 'imageCapture'], 'illumination', ['switch', 'sendAction']],
#  [['motionSensor', 'imageCapture'], 'illumination', ['switch', 'switch']],
#  [['motionSensor', 'imageCapture'], 'illumination', ['switch', 'switchLevel']],
#  [['motionSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'colorControl']],
#  [['motionSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'imageCapture']],
#  [['motionSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'momentary']],
#  [['motionSensor', 'sendAction'], 'motion', ['accelerationSensor', 'number']],
#  [['motionSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'sendAction']],
#  [['motionSensor', 'sendAction'], 'motion', ['accelerationSensor', 'switch']],
#  [['motionSensor', 'sendAction'], 'motion', ['motionSensor', 'alarm']],
#  [['motionSensor', 'sendAction'], 'motion', ['motionSensor', 'colorControl']],
#  [['motionSensor', 'sendAction'], 'motion', ['motionSensor', 'imageCapture']],
#  [['motionSensor', 'sendAction'], 'motion', ['motionSensor', 'locationMode']],
#  [['motionSensor', 'sendAction'], 'motion', ['motionSensor', 'number']],
#  [['motionSensor', 'sendAction'], 'motion', ['motionSensor', 'sendAction']],
#  [['motionSensor', 'sendAction'], 'motion', ['motionSensor', 'switch']],
#  [['motionSensor', 'switch'], 'illumination', ['beacon', 'lock']],
#  [['motionSensor', 'switch'], 'illumination', ['beacon', 'switch']],
#  [['motionSensor', 'switch'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['motionSensor', 'switch'], 'illumination', ['powerMeter', 'sendAction']],
#  [['motionSensor', 'switch'], 'illumination', ['powerMeter', 'switch']],
#  [['motionSensor', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['motionSensor', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['motionSensor', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['motionSensor', 'switch'], 'illumination', ['switch', 'number']],
#  [['motionSensor', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['motionSensor', 'switch'], 'illumination', ['switch', 'switch']],
#  [['motionSensor', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['powerMeter', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'colorControl']],
#  [['powerMeter', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'imageCapture']],
#  [['powerMeter', 'sendAction'], 'motion', ['accelerationSensor', 'momentary']],
#  [['powerMeter', 'sendAction'], 'motion', ['accelerationSensor', 'number']],
#  [['powerMeter', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'sendAction']],
#  [['powerMeter', 'sendAction'], 'motion', ['accelerationSensor', 'switch']],
#  [['powerMeter', 'sendAction'], 'motion', ['motionSensor', 'alarm']],
#  [['powerMeter', 'sendAction'], 'motion', ['motionSensor', 'colorControl']],
#  [['powerMeter', 'sendAction'], 'motion', ['motionSensor', 'imageCapture']],
#  [['powerMeter', 'sendAction'], 'motion', ['motionSensor', 'locationMode']],
#  [['powerMeter', 'sendAction'], 'motion', ['motionSensor', 'number']],
#  [['powerMeter', 'sendAction'], 'motion', ['motionSensor', 'sendAction']],
#  [['powerMeter', 'sendAction'], 'motion', ['motionSensor', 'switch']],
#  [['powerMeter', 'switch'], 'illumination', ['beacon', 'lock']],
#  [['powerMeter', 'switch'], 'illumination', ['beacon', 'switch']],
#  [['powerMeter', 'switch'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['powerMeter', 'switch'], 'illumination', ['powerMeter', 'sendAction']],
#  [['powerMeter', 'switch'], 'illumination', ['powerMeter', 'switch']],
#  [['powerMeter', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['powerMeter', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['powerMeter', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['powerMeter', 'switch'], 'illumination', ['switch', 'number']],
#  [['powerMeter', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['powerMeter', 'switch'], 'illumination', ['switch', 'switch']],
#  [['powerMeter', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['presenceSensor', 'colorControl'], 'illumination', ['beacon', 'lock']],
#  [['presenceSensor', 'colorControl'], 'illumination', ['beacon', 'switch']],
#  [['presenceSensor', 'colorControl'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['presenceSensor', 'colorControl'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['presenceSensor', 'colorControl'],
#   'illumination',
#   ['powerMeter', 'switch']],
#  [['presenceSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['presenceSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['presenceSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['presenceSensor', 'colorControl'], 'illumination', ['switch', 'number']],
#  [['presenceSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'sendAction']],
#  [['presenceSensor', 'colorControl'], 'illumination', ['switch', 'switch']],
#  [['presenceSensor', 'colorControl'],
#   'illumination',
#   ['switch', 'switchLevel']],
#  [['presenceSensor', 'imageCapture'], 'illumination', ['beacon', 'lock']],
#  [['presenceSensor', 'imageCapture'], 'illumination', ['beacon', 'switch']],
#  [['presenceSensor', 'imageCapture'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['presenceSensor', 'imageCapture'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['presenceSensor', 'imageCapture'],
#   'illumination',
#   ['powerMeter', 'switch']],
#  [['presenceSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['presenceSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['presenceSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['presenceSensor', 'imageCapture'], 'illumination', ['switch', 'number']],
#  [['presenceSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'sendAction']],
#  [['presenceSensor', 'imageCapture'], 'illumination', ['switch', 'switch']],
#  [['presenceSensor', 'imageCapture'],
#   'illumination',
#   ['switch', 'switchLevel']],
#  [['presenceSensor', 'momentary'], 'illumination', ['beacon', 'lock']],
#  [['presenceSensor', 'momentary'], 'illumination', ['beacon', 'switch']],
#  [['presenceSensor', 'momentary'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['presenceSensor', 'momentary'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['presenceSensor', 'momentary'], 'illumination', ['powerMeter', 'switch']],
#  [['presenceSensor', 'momentary'], 'illumination', ['switch', 'colorControl']],
#  [['presenceSensor', 'momentary'], 'illumination', ['switch', 'imageCapture']],
#  [['presenceSensor', 'momentary'], 'illumination', ['switch', 'locationMode']],
#  [['presenceSensor', 'momentary'], 'illumination', ['switch', 'number']],
#  [['presenceSensor', 'momentary'], 'illumination', ['switch', 'sendAction']],
#  [['presenceSensor', 'momentary'], 'illumination', ['switch', 'switch']],
#  [['presenceSensor', 'momentary'], 'illumination', ['switch', 'switchLevel']],
#  [['presenceSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'colorControl']],
#  [['presenceSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'imageCapture']],
#  [['presenceSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'momentary']],
#  [['presenceSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'number']],
#  [['presenceSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'sendAction']],
#  [['presenceSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'switch']],
#  [['presenceSensor', 'sendAction'], 'motion', ['motionSensor', 'alarm']],
#  [['presenceSensor', 'sendAction'],
#   'motion',
#   ['motionSensor', 'colorControl']],
#  [['presenceSensor', 'sendAction'],
#   'motion',
#   ['motionSensor', 'imageCapture']],
#  [['presenceSensor', 'sendAction'],
#   'motion',
#   ['motionSensor', 'locationMode']],
#  [['presenceSensor', 'sendAction'], 'motion', ['motionSensor', 'number']],
#  [['presenceSensor', 'sendAction'], 'motion', ['motionSensor', 'sendAction']],
#  [['presenceSensor', 'sendAction'], 'motion', ['motionSensor', 'switch']],
#  [['presenceSensor', 'switch'], 'illumination', ['beacon', 'lock']],
#  [['presenceSensor', 'switch'], 'illumination', ['beacon', 'switch']],
#  [['presenceSensor', 'switch'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['presenceSensor', 'switch'], 'illumination', ['powerMeter', 'sendAction']],
#  [['presenceSensor', 'switch'], 'illumination', ['powerMeter', 'switch']],
#  [['presenceSensor', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['presenceSensor', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['presenceSensor', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['presenceSensor', 'switch'], 'illumination', ['switch', 'number']],
#  [['presenceSensor', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['presenceSensor', 'switch'], 'illumination', ['switch', 'switch']],
#  [['presenceSensor', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['relativeHumidityMeasurement', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'colorControl']],
#  [['relativeHumidityMeasurement', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'imageCapture']],
#  [['relativeHumidityMeasurement', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'momentary']],
#  [['relativeHumidityMeasurement', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'number']],
#  [['relativeHumidityMeasurement', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'sendAction']],
#  [['relativeHumidityMeasurement', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'switch']],
#  [['relativeHumidityMeasurement', 'sendAction'],
#   'motion',
#   ['motionSensor', 'alarm']],
#  [['relativeHumidityMeasurement', 'sendAction'],
#   'motion',
#   ['motionSensor', 'colorControl']],
#  [['relativeHumidityMeasurement', 'sendAction'],
#   'motion',
#   ['motionSensor', 'imageCapture']],
#  [['relativeHumidityMeasurement', 'sendAction'],
#   'motion',
#   ['motionSensor', 'locationMode']],
#  [['relativeHumidityMeasurement', 'sendAction'],
#   'motion',
#   ['motionSensor', 'number']],
#  [['relativeHumidityMeasurement', 'sendAction'],
#   'motion',
#   ['motionSensor', 'sendAction']],
#  [['relativeHumidityMeasurement', 'sendAction'],
#   'motion',
#   ['motionSensor', 'switch']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['beacon', 'lock']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['beacon', 'switch']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['powerMeter', 'switch']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'number']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'sendAction']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'switch']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'switchLevel']],
#  [['smokeDetector', 'colorControl'], 'illumination', ['beacon', 'lock']],
#  [['smokeDetector', 'colorControl'], 'illumination', ['beacon', 'switch']],
#  [['smokeDetector', 'colorControl'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['smokeDetector', 'colorControl'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['smokeDetector', 'colorControl'], 'illumination', ['powerMeter', 'switch']],
#  [['smokeDetector', 'colorControl'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['smokeDetector', 'colorControl'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['smokeDetector', 'colorControl'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['smokeDetector', 'colorControl'], 'illumination', ['switch', 'number']],
#  [['smokeDetector', 'colorControl'], 'illumination', ['switch', 'sendAction']],
#  [['smokeDetector', 'colorControl'], 'illumination', ['switch', 'switch']],
#  [['smokeDetector', 'colorControl'],
#   'illumination',
#   ['switch', 'switchLevel']],
#  [['smokeDetector', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'colorControl']],
#  [['smokeDetector', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'imageCapture']],
#  [['smokeDetector', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'momentary']],
#  [['smokeDetector', 'sendAction'], 'motion', ['accelerationSensor', 'number']],
#  [['smokeDetector', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'sendAction']],
#  [['smokeDetector', 'sendAction'], 'motion', ['accelerationSensor', 'switch']],
#  [['smokeDetector', 'sendAction'], 'motion', ['motionSensor', 'alarm']],
#  [['smokeDetector', 'sendAction'], 'motion', ['motionSensor', 'colorControl']],
#  [['smokeDetector', 'sendAction'], 'motion', ['motionSensor', 'imageCapture']],
#  [['smokeDetector', 'sendAction'], 'motion', ['motionSensor', 'locationMode']],
#  [['smokeDetector', 'sendAction'], 'motion', ['motionSensor', 'number']],
#  [['smokeDetector', 'sendAction'], 'motion', ['motionSensor', 'sendAction']],
#  [['smokeDetector', 'sendAction'], 'motion', ['motionSensor', 'switch']],
#  [['smokeDetector', 'thermostat'], 'temperature', ['thermostat', 'switch']],
#  [['smokeDetector', 'thermostat'],
#   'temperature',
#   ['thermostat', 'thermostat']],
#  [['switch', 'colorControl'], 'illumination', ['beacon', 'lock']],
#  [['switch', 'colorControl'], 'illumination', ['beacon', 'switch']],
#  [['switch', 'colorControl'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['switch', 'colorControl'], 'illumination', ['powerMeter', 'sendAction']],
#  [['switch', 'colorControl'], 'illumination', ['powerMeter', 'switch']],
#  [['switch', 'colorControl'], 'illumination', ['switch', 'colorControl']],
#  [['switch', 'colorControl'], 'illumination', ['switch', 'imageCapture']],
#  [['switch', 'colorControl'], 'illumination', ['switch', 'locationMode']],
#  [['switch', 'colorControl'], 'illumination', ['switch', 'number']],
#  [['switch', 'colorControl'], 'illumination', ['switch', 'sendAction']],
#  [['switch', 'colorControl'], 'illumination', ['switch', 'switch']],
#  [['switch', 'colorControl'], 'illumination', ['switch', 'switchLevel']],
#  [['switch', 'imageCapture'], 'illumination', ['beacon', 'lock']],
#  [['switch', 'imageCapture'], 'illumination', ['beacon', 'switch']],
#  [['switch', 'imageCapture'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['switch', 'imageCapture'], 'illumination', ['powerMeter', 'sendAction']],
#  [['switch', 'imageCapture'], 'illumination', ['powerMeter', 'switch']],
#  [['switch', 'imageCapture'], 'illumination', ['switch', 'colorControl']],
#  [['switch', 'imageCapture'], 'illumination', ['switch', 'imageCapture']],
#  [['switch', 'imageCapture'], 'illumination', ['switch', 'locationMode']],
#  [['switch', 'imageCapture'], 'illumination', ['switch', 'number']],
#  [['switch', 'imageCapture'], 'illumination', ['switch', 'sendAction']],
#  [['switch', 'imageCapture'], 'illumination', ['switch', 'switch']],
#  [['switch', 'imageCapture'], 'illumination', ['switch', 'switchLevel']],
#  [['switch', 'sendAction'], 'motion', ['accelerationSensor', 'colorControl']],
#  [['switch', 'sendAction'], 'motion', ['accelerationSensor', 'imageCapture']],
#  [['switch', 'sendAction'], 'motion', ['accelerationSensor', 'momentary']],
#  [['switch', 'sendAction'], 'motion', ['accelerationSensor', 'number']],
#  [['switch', 'sendAction'], 'motion', ['accelerationSensor', 'sendAction']],
#  [['switch', 'sendAction'], 'motion', ['accelerationSensor', 'switch']],
#  [['switch', 'sendAction'], 'motion', ['motionSensor', 'alarm']],
#  [['switch', 'sendAction'], 'motion', ['motionSensor', 'colorControl']],
#  [['switch', 'sendAction'], 'motion', ['motionSensor', 'imageCapture']],
#  [['switch', 'sendAction'], 'motion', ['motionSensor', 'locationMode']],
#  [['switch', 'sendAction'], 'motion', ['motionSensor', 'number']],
#  [['switch', 'sendAction'], 'motion', ['motionSensor', 'sendAction']],
#  [['switch', 'sendAction'], 'motion', ['motionSensor', 'switch']],
#  [['switch', 'switch'], 'illumination', ['beacon', 'lock']],
#  [['switch', 'switch'], 'illumination', ['beacon', 'switch']],
#  [['switch', 'switch'], 'illumination', ['illuminanceMeasurement', 'switch']],
#  [['switch', 'switch'], 'illumination', ['powerMeter', 'sendAction']],
#  [['switch', 'switch'], 'illumination', ['powerMeter', 'switch']],
#  [['switch', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['switch', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['switch', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['switch', 'switch'], 'illumination', ['switch', 'number']],
#  [['switch', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['switch', 'switch'], 'illumination', ['switch', 'switch']],
#  [['switch', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['switch', 'switchLevel'], 'illumination', ['beacon', 'lock']],
#  [['switch', 'switchLevel'], 'illumination', ['beacon', 'switch']],
#  [['switch', 'switchLevel'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['switch', 'switchLevel'], 'illumination', ['powerMeter', 'sendAction']],
#  [['switch', 'switchLevel'], 'illumination', ['powerMeter', 'switch']],
#  [['switch', 'switchLevel'], 'illumination', ['switch', 'colorControl']],
#  [['switch', 'switchLevel'], 'illumination', ['switch', 'imageCapture']],
#  [['switch', 'switchLevel'], 'illumination', ['switch', 'locationMode']],
#  [['switch', 'switchLevel'], 'illumination', ['switch', 'number']],
#  [['switch', 'switchLevel'], 'illumination', ['switch', 'sendAction']],
#  [['switch', 'switchLevel'], 'illumination', ['switch', 'switch']],
#  [['switch', 'switchLevel'], 'illumination', ['switch', 'switchLevel']],
#  [['temperatureMeasurement', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'colorControl']],
#  [['temperatureMeasurement', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'imageCapture']],
#  [['temperatureMeasurement', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'momentary']],
#  [['temperatureMeasurement', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'number']],
#  [['temperatureMeasurement', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'sendAction']],
#  [['temperatureMeasurement', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'switch']],
#  [['temperatureMeasurement', 'sendAction'],
#   'motion',
#   ['motionSensor', 'alarm']],
#  [['temperatureMeasurement', 'sendAction'],
#   'motion',
#   ['motionSensor', 'colorControl']],
#  [['temperatureMeasurement', 'sendAction'],
#   'motion',
#   ['motionSensor', 'imageCapture']],
#  [['temperatureMeasurement', 'sendAction'],
#   'motion',
#   ['motionSensor', 'locationMode']],
#  [['temperatureMeasurement', 'sendAction'],
#   'motion',
#   ['motionSensor', 'number']],
#  [['temperatureMeasurement', 'sendAction'],
#   'motion',
#   ['motionSensor', 'sendAction']],
#  [['temperatureMeasurement', 'sendAction'],
#   'motion',
#   ['motionSensor', 'switch']],
#  [['temperatureMeasurement', 'switch'], 'illumination', ['beacon', 'lock']],
#  [['temperatureMeasurement', 'switch'], 'illumination', ['beacon', 'switch']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['powerMeter', 'switch']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['temperatureMeasurement', 'switch'], 'illumination', ['switch', 'number']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'sendAction']],
#  [['temperatureMeasurement', 'switch'], 'illumination', ['switch', 'switch']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'switchLevel']],
#  [['temperatureMeasurement', 'thermostat'],
#   'temperature',
#   ['thermostat', 'switch']],
#  [['temperatureMeasurement', 'thermostat'],
#   'temperature',
#   ['thermostat', 'thermostat']],
#  [['thermostat', 'switch'], 'illumination', ['beacon', 'lock']],
#  [['thermostat', 'switch'], 'illumination', ['beacon', 'switch']],
#  [['thermostat', 'switch'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['thermostat', 'switch'], 'illumination', ['powerMeter', 'sendAction']],
#  [['thermostat', 'switch'], 'illumination', ['powerMeter', 'switch']],
#  [['thermostat', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['thermostat', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['thermostat', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['thermostat', 'switch'], 'illumination', ['switch', 'number']],
#  [['thermostat', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['thermostat', 'switch'], 'illumination', ['switch', 'switch']],
#  [['thermostat', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['thermostat', 'thermostat'], 'temperature', ['thermostat', 'switch']],
#  [['thermostat', 'thermostat'], 'temperature', ['thermostat', 'thermostat']],
#  [['threeAxis', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'colorControl']],
#  [['threeAxis', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'imageCapture']],
#  [['threeAxis', 'sendAction'], 'motion', ['accelerationSensor', 'momentary']],
#  [['threeAxis', 'sendAction'], 'motion', ['accelerationSensor', 'number']],
#  [['threeAxis', 'sendAction'], 'motion', ['accelerationSensor', 'sendAction']],
#  [['threeAxis', 'sendAction'], 'motion', ['accelerationSensor', 'switch']],
#  [['threeAxis', 'sendAction'], 'motion', ['motionSensor', 'alarm']],
#  [['threeAxis', 'sendAction'], 'motion', ['motionSensor', 'colorControl']],
#  [['threeAxis', 'sendAction'], 'motion', ['motionSensor', 'imageCapture']],
#  [['threeAxis', 'sendAction'], 'motion', ['motionSensor', 'locationMode']],
#  [['threeAxis', 'sendAction'], 'motion', ['motionSensor', 'number']],
#  [['threeAxis', 'sendAction'], 'motion', ['motionSensor', 'sendAction']],
#  [['threeAxis', 'sendAction'], 'motion', ['motionSensor', 'switch']],
#  [['time', 'sendAction'], 'motion', ['accelerationSensor', 'colorControl']],
#  [['time', 'sendAction'], 'motion', ['accelerationSensor', 'imageCapture']],
#  [['time', 'sendAction'], 'motion', ['accelerationSensor', 'momentary']],
#  [['time', 'sendAction'], 'motion', ['accelerationSensor', 'number']],
#  [['time', 'sendAction'], 'motion', ['accelerationSensor', 'sendAction']],
#  [['time', 'sendAction'], 'motion', ['accelerationSensor', 'switch']],
#  [['time', 'sendAction'], 'motion', ['motionSensor', 'alarm']],
#  [['time', 'sendAction'], 'motion', ['motionSensor', 'colorControl']],
#  [['time', 'sendAction'], 'motion', ['motionSensor', 'imageCapture']],
#  [['time', 'sendAction'], 'motion', ['motionSensor', 'locationMode']],
#  [['time', 'sendAction'], 'motion', ['motionSensor', 'number']],
#  [['time', 'sendAction'], 'motion', ['motionSensor', 'sendAction']],
#  [['time', 'sendAction'], 'motion', ['motionSensor', 'switch']],
#  [['time', 'switch'], 'illumination', ['beacon', 'lock']],
#  [['time', 'switch'], 'illumination', ['beacon', 'switch']],
#  [['time', 'switch'], 'illumination', ['illuminanceMeasurement', 'switch']],
#  [['time', 'switch'], 'illumination', ['powerMeter', 'sendAction']],
#  [['time', 'switch'], 'illumination', ['powerMeter', 'switch']],
#  [['time', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['time', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['time', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['time', 'switch'], 'illumination', ['switch', 'number']],
#  [['time', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['time', 'switch'], 'illumination', ['switch', 'switch']],
#  [['time', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['touchSensor', 'switch'], 'illumination', ['beacon', 'lock']],
#  [['touchSensor', 'switch'], 'illumination', ['beacon', 'switch']],
#  [['touchSensor', 'switch'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['touchSensor', 'switch'], 'illumination', ['powerMeter', 'sendAction']],
#  [['touchSensor', 'switch'], 'illumination', ['powerMeter', 'switch']],
#  [['touchSensor', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['touchSensor', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['touchSensor', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['touchSensor', 'switch'], 'illumination', ['switch', 'number']],
#  [['touchSensor', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['touchSensor', 'switch'], 'illumination', ['switch', 'switch']],
#  [['touchSensor', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['waterSensor', 'colorControl'], 'illumination', ['beacon', 'lock']],
#  [['waterSensor', 'colorControl'], 'illumination', ['beacon', 'switch']],
#  [['waterSensor', 'colorControl'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['waterSensor', 'colorControl'],
#   'illumination',
#   ['powerMeter', 'sendAction']],
#  [['waterSensor', 'colorControl'], 'illumination', ['powerMeter', 'switch']],
#  [['waterSensor', 'colorControl'], 'illumination', ['switch', 'colorControl']],
#  [['waterSensor', 'colorControl'], 'illumination', ['switch', 'imageCapture']],
#  [['waterSensor', 'colorControl'], 'illumination', ['switch', 'locationMode']],
#  [['waterSensor', 'colorControl'], 'illumination', ['switch', 'number']],
#  [['waterSensor', 'colorControl'], 'illumination', ['switch', 'sendAction']],
#  [['waterSensor', 'colorControl'], 'illumination', ['switch', 'switch']],
#  [['waterSensor', 'colorControl'], 'illumination', ['switch', 'switchLevel']],
#  [['waterSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'colorControl']],
#  [['waterSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'imageCapture']],
#  [['waterSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'momentary']],
#  [['waterSensor', 'sendAction'], 'motion', ['accelerationSensor', 'number']],
#  [['waterSensor', 'sendAction'],
#   'motion',
#   ['accelerationSensor', 'sendAction']],
#  [['waterSensor', 'sendAction'], 'motion', ['accelerationSensor', 'switch']],
#  [['waterSensor', 'sendAction'], 'motion', ['motionSensor', 'alarm']],
#  [['waterSensor', 'sendAction'], 'motion', ['motionSensor', 'colorControl']],
#  [['waterSensor', 'sendAction'], 'motion', ['motionSensor', 'imageCapture']],
#  [['waterSensor', 'sendAction'], 'motion', ['motionSensor', 'locationMode']],
#  [['waterSensor', 'sendAction'], 'motion', ['motionSensor', 'number']],
#  [['waterSensor', 'sendAction'], 'motion', ['motionSensor', 'sendAction']],
#  [['waterSensor', 'sendAction'], 'motion', ['motionSensor', 'switch']],
#  [['waterSensor', 'switch'], 'illumination', ['beacon', 'lock']],
#  [['waterSensor', 'switch'], 'illumination', ['beacon', 'switch']],
#  [['waterSensor', 'switch'],
#   'illumination',
#   ['illuminanceMeasurement', 'switch']],
#  [['waterSensor', 'switch'], 'illumination', ['powerMeter', 'sendAction']],
#  [['waterSensor', 'switch'], 'illumination', ['powerMeter', 'switch']],
#  [['waterSensor', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['waterSensor', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['waterSensor', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['waterSensor', 'switch'], 'illumination', ['switch', 'number']],
#  [['waterSensor', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['waterSensor', 'switch'], 'illumination', ['switch', 'switch']],
#  [['waterSensor', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['waterSensor', 'valve'], 'leakage', ['app', 'alarm']],
#  [['waterSensor', 'valve'], 'leakage', ['app', 'colorControl']],
#  [['waterSensor', 'valve'], 'leakage', ['app', 'doorControl']],
#  [['waterSensor', 'valve'], 'leakage', ['app', 'lock']],
#  [['waterSensor', 'valve'], 'leakage', ['app', 'switch']],
#  [['waterSensor', 'valve'], 'leakage', ['app', 'thermostat']],
#  [['waterSensor', 'valve'], 'leakage', ['device.jawboneUser', 'colorControl']],
#  [['waterSensor', 'valve'], 'leakage', ['device.jawboneUser', 'musicPlayer']],
#  [['waterSensor', 'valve'], 'leakage', ['device.jawboneUser', 'sendAction']],
#  [['waterSensor', 'valve'], 'leakage', ['device.jawboneUser', 'switch']],
#  [['waterSensor', 'valve'], 'leakage', ['waterSensor', 'colorControl']],
#  [['waterSensor', 'valve'], 'leakage', ['waterSensor', 'sendAction']],
#  [['waterSensor', 'valve'], 'leakage', ['waterSensor', 'switch']],
#  [['waterSensor', 'valve'], 'leakage', ['waterSensor', 'valve']]]
