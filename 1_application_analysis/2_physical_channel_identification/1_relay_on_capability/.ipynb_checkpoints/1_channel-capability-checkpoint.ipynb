# %% [markdown]
# ## creation of the correlation between trigger capablity and physical channels - tab. 3
#
# **This approach is based on the fact that every smartapp's trigger capability is correlated with a unique trigger channel**
#
# possible problems:
#
# 1. always the trigger capability describe a physical channel? (for capability "number"?)
#
# evolution:
#
# 1. save every pair of trigger-action and every smart app description
# 2. save the cluster of every channel
# 3. extrapolate from smartapp all the trigger and action capabilities
# 4. find the correlation between capability and channels

# %%
from gensim.models import Word2Vec, KeyedVectors 
import json   # for read the JSON file
import stanza # Official Stanford NLP Python Library for Many Human Languages
import re     # to all lowercase words
import numpy as np

# %%
file = open("../../1_Intra_app_Analysis/trigger-action.JSON","r") # read all the capability extrapolated from the apps
trigger_action = json.load(file)
print("tot app analysed:",len(trigger_action.keys()))
# Out:
# tot app analysed: 86

# %%
file = open("../../1_Intra_app_Analysis/app-description.JSON","r") # need the desription of the analysed apps
app_description = json.load(file)

# %%
# as wrote in the paper "In the end, we check each cluster’s representative keyword and remove
# non-physical-channel related keywords." (cap 4.2 - p 835) so modify and use cluster_channels_FINAL
file = open("../cluster_channels_FINAL.JSON","r") 
dict_channels = json.load(file)
dict_channels
# Out:
# {'temperature': ['air_conditioner',
#   'ambient',
#   'heater',
#   'temp',
#   'thermostat',
#   'ventilation',
#   'temperature'],
#  'humidity': ['moisture', 'ventilation', 'humidity'],
#  'illumination': ['brightness',
#   'bulbs',
#   'cameras',
#   'candle',
#   'colors',
#   'light',
#   'lighting',
#   'switch',
#   'switches',
#   'lights'],
#  'motion': ['action', 'motion'],
#  'location': ['area', 'hub', 'place', 'location'],
#  'smoke': ['fire',
#   'heater',
#   'leaks',
#   'temperature',
#   'ventilation',
#   'carbon_monoxide'],
#  'leakage': ['leaks',
#   'lever',
#   'sensor',
#   'sensors',
#   'switches',
#   'valve',
#   'water',
#   'weather',
#   'sms'],
#  'sound': ['sirens', 'song', 'sound']}

# %%
stanza.download('en')       # This downloads the English models for the neural pipeline
nlp = stanza.Pipeline('en') # This sets up a default neural pipeline in English
model = KeyedVectors.load_word2vec_format('../../../../GoogleNews-vectors-negative300.bin', binary=True, limit=100000) # load word2vec pre-trained
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.3.0.json:   0%|   …
# 2021-10-13 08:27:22 INFO: Downloading default packages for language: en (English)...
# 2021-10-13 08:27:23 INFO: File exists: /home/volta/stanza_resources/en/default.zip.
# 2021-10-13 08:27:29 INFO: Finished downloading models and saved to /home/volta/stanza_resources.
# 2021-10-13 08:27:29 INFO: Loading these models for language: en (English):
# ============================
# | Processor    | Package   |
# ----------------------------
# | tokenize     | combined  |
# | pos          | combined  |
# | lemma        | combined  |
# | depparse     | combined  |
# | sentiment    | sstplus   |
# | constituency | wsj       |
# | ner          | ontonotes |
# ============================
#
# 2021-10-13 08:27:29 INFO: Use device: cpu
# 2021-10-13 08:27:29 INFO: Loading: tokenize
# 2021-10-13 08:27:29 INFO: Loading: pos
# 2021-10-13 08:27:29 INFO: Loading: lemma
# 2021-10-13 08:27:29 INFO: Loading: depparse
# 2021-10-13 08:27:29 INFO: Loading: sentiment
# 2021-10-13 08:27:30 INFO: Loading: constituency
# 2021-10-13 08:27:30 INFO: Loading: ner
# 2021-10-13 08:27:31 INFO: Done loading processors!

# %%
# analyse every capability

list_all_capabilities = []

for app in trigger_action.keys():         # for every SmartThings app analysed
    for trigger_cap in trigger_action[app].keys():          # for every trigger channel of that app
            for action in trigger_action[app][trigger_cap]: # for every action 
                action_cap = action[0]
                
                if (not action_cap in list_all_capabilities): # avoid duplicates
                    list_all_capabilities.append(action_cap)

                if (not trigger_cap in list_all_capabilities): # avoid duplicates
                    list_all_capabilities.append(trigger_cap)

                    
print("all capabilities found:", len(list_all_capabilities))
list_all_capabilities.sort()
list_all_capabilities
# Out:
# all capabilities found: 34
# ['accelerationSensor',
#  'alarm',
#  'app',
#  'beacon',
#  'button',
#  'carbonMonoxideDetector',
#  'colorControl',
#  'contactSensor',
#  'device.PetFeederShield',
#  'device.jawboneUser',
#  'doorControl',
#  'illuminanceMeasurement',
#  'imageCapture',
#  'location',
#  'locationMode',
#  'lock',
#  'momentary',
#  'motionSensor',
#  'musicPlayer',
#  'number',
#  'powerMeter',
#  'presenceSensor',
#  'relativeHumidityMeasurement',
#  'sendAction',
#  'smokeDetector',
#  'switch',
#  'switchLevel',
#  'temperatureMeasurement',
#  'thermostat',
#  'threeAxis',
#  'time',
#  'touchSensor',
#  'valve',
#  'waterSensor']

# %%
# function that separate the physical capabilities from the system capabilities
# all physical capabilities are associated with a string that can be processed by word2vec
def cap2string(capability):
    switcher = {
        # physical capabilities 
        'accelerationSensor': "acceleration",
        'beacon': "beacon",
        'carbonMonoxideDetector': "carbon_monoxide",
        'contactSensor': "contact",
        'illuminanceMeasurement':"illumination",
        'location':"location",
        'motionSensor':"motion ",
        'musicPlayer': "music player",
        'number': "flash lights",
        'presenceSensor': "presence",
        'relativeHumidityMeasurement': "relative humidity ",
        'smokeDetector': "smoke",
        'switch': "switch",      
        'switchLevel': "switch level",
        'temperatureMeasurement':"temperature",
        'thermostat': "thermostat",
        'threeAxis':"three axis space",
        'valve':"valve",
        'waterSensor':"water sensor",
        
        # system capabilities
#         'alarm': "alarm",
#         'app': "app",
#         'button': "button", # of jawbone headphones
#         'colorControl': "colorControl", # of jawbone headphones or dadicated devices
#         'device.PetFeederShield':"pet feeder shield", # specific device 
#         'device.jawboneUser':"jawbone user", # specific device
#         'doorControl': "door control",
#         'imageCapture': "image capture",
#         'lock':"lock",
#         'locationMode':"locationMode",
#         'momentary': "momentary", # lock or unlock some doors
#         'powerMeter':"powerMeter",
#         'sendAction':"send action",
#         'time':"time",
#         'touchSensor':"touch"
    }
    return switcher.get(capability, f"capabliti not found: {capability}")

list_system_cap = ['alarm','app','button','colorControl','device.PetFeederShield', 
        'device.jawboneUser','doorControl','imageCapture','lock','locationMode',
        'momentary','powerMeter','sendAction','time','touchSensor']

# %%
# convert all physical capabilities to an 
physical_capabilities = []
for cap in list_all_capabilities:
    if not cap in list_system_cap:
        physical_capabilities.append(cap2string(cap))
    
physical_capabilities
# Out:
# ['acceleration',
#  'beacon',
#  'carbon_monoxide',
#  'contact',
#  'illumination',
#  'location',
#  'motion ',
#  'music player',
#  'flash lights',
#  'presence',
#  'relative humidity ',
#  'smoke',
#  'switch',
#  'switch level',
#  'temperature',
#  'thermostat',
#  'three axis space',
#  'valve',
#  'water sensor']

# %%
# now correlate every trigger/action capability to its own physical channel
words_pattern = '[a-zA-Z_]+'
cap_to_channel = {"temperature":[], "humidity":[], "illumination":[], "motion":[], "location":[], 
                           "smoke":[], "leakage":[], "sound":[]}

for cap in physical_capabilities: # analyse every physical capability (a capability could have more words inside)
    keywords = [] # keywords found inside app capability
    keywords = re.findall(words_pattern, cap, flags=re.IGNORECASE) # extrapolate the words from the capability
    print(keywords)
    
    clean_keywords = [] # find what words can be really processed by word2vec
    for i in range(len(keywords)):                   # for every keyword exstracted
        try:
            model[keywords[i]]                       # check Word2Vec
            clean_keywords.append(keywords[i])       # if can apply word2vec save it
        except KeyError as err:
            print("handling Error: ", err)           # some words can not be processed by Word2Vec

    print(cap,"-", clean_keywords)        

    similarity_list = {} # list made by 
    if len(clean_keywords) == 0: # case there aren't any NN keyword inside that app description (strange)
        print(f"!!error!!")

    else:
            if len(clean_keywords) == 1: # case there are only 1 keyword inside capability
                for key in dict_channels.keys(): # check for every physical channel
                    similarity_temp = 0
                    for channel_NN in dict_channels[key]: # for every keyword inside the channel cluster
                        similarity_temp += model.similarity(clean_keywords[0],channel_NN)
                    # divide by the number of cluster keywords --> result: the mean of similarity
                    similarity_list[key] = (similarity_temp/len(dict_channels[key]))*100

            else: # case there are more than 1 keyword inside tcapability
                for key in dict_channels.keys(): # check for every physical channel
                    similarity_partial = 0
                    for keyword in clean_keywords: # for every keyword NN extracted from description
                        similarity_temp = 0
                        for channel_NN in dict_channels[key]:  # for every keyword inside the channel cluster
                            #print(keyword,channel_NN,"\t", model.similarity(keyword,channel_NN))
                            similarity_temp += model.similarity(keyword,channel_NN)
                         # divide by the number of cluster keywords --> result: the mean of similarity (given by only 1 NN)
                        similarity_temp = similarity_temp/len(dict_channels[key])
                        similarity_partial += similarity_temp
                    #print("this keyword for ",key,"has got a level", similarity_partial/len(clean_keywords))
                    similarity_list[key] = (similarity_partial/len(clean_keywords))*100

            print(similarity_list)
            # now find the highest physical channel association 
            channel_association = ""
            max_value = 0
            for channel in similarity_list.keys():
                if (similarity_list[channel] > max_value) and (channel != "locationMode"):
                    max_value = similarity_list[channel]
                    channel_association = channel

            print("most similar:", channel_association, max_value, "\n")
            cap_to_channel[channel_association].append(cap)

cap_to_channel
# Out:
# ['acceleration']
# acceleration - ['acceleration']
# {'temperature': 12.674963900021144, 'humidity': 11.768864840269089, 'illumination': 10.116687174886465, 'motion': 20.86850181221962, 'location': 3.6133638117462397, 'smoke': 11.38808336108923, 'leakage': 16.760574653744698, 'sound': 5.993366117278734}
# most similar: motion 20.86850181221962
#
# ['beacon']
# beacon - ['beacon']
# {'temperature': 7.566695514002017, 'humidity': 4.8923226073384285, 'illumination': 21.361069008708, 'motion': 1.4528759755194187, 'location': 18.30311417579651, 'smoke': 8.678069462378819, 'leakage': 12.829999832643402, 'sound': 17.57648686567942}
# most similar: illumination 21.361069008708
#
# ['carbon_monoxide']
# carbon_monoxide - ['carbon_monoxide']
# {'temperature': 35.156890749931335, 'humidity': 40.984738866488144, 'illumination': 13.85080773383379, 'motion': 2.0187011919915676, 'location': 4.6054113656282425, 'smoke': 49.541254838307694, 'leakage': 16.78143818345335, 'sound': 13.188401361306509}
# most similar: smoke 49.541254838307694
#
# ['contact']
# contact - ['contact']
# {'temperature': 7.9407413090978345, 'humidity': 8.569677919149399, 'illumination': 5.83661500364542, 'motion': 9.540395252406597, 'location': 9.781560953706503, 'smoke': 10.73130803803603, 'leakage': 8.628093409869406, 'sound': -1.531779890259107}
# most similar: smoke 10.73130803803603
#
# ['illumination']
# illumination - ['illumination']
# {'temperature': 24.979223098073685, 'humidity': 28.88282835483551, 'illumination': 39.90122899413109, 'motion': 10.32048910856247, 'location': 7.204498117789626, 'smoke': 21.7821958164374, 'leakage': 18.5931416021453, 'sound': 16.0105953613917}
# most similar: illumination 39.90122899413109
#
# ['location']
# location - ['location']
# {'temperature': 12.737432441541127, 'humidity': 12.627561390399933, 'illumination': 8.685851488262415, 'motion': 7.5747050344944, 'location': 53.93345132470131, 'smoke': 12.964177255829176, 'leakage': 12.960026951299774, 'sound': 12.251023451487224}
# most similar: location 53.93345132470131
#
# ['motion']
# motion  - ['motion']
# {'temperature': 8.371041076523918, 'humidity': 8.280167480309803, 'illumination': 13.264494128525255, 'motion': 65.65423607826233, 'location': 1.4803694910369813, 'smoke': 7.14192520827055, 'leakage': 12.210041222472984, 'sound': 12.226426601409912}
# most similar: motion 65.65423607826233
#
# ['music', 'player']
# music player - ['music', 'player']
# {'temperature': 6.365541382027525, 'humidity': 4.267819412052631, 'illumination': 8.734886883758008, 'motion': 8.520890399813652, 'location': 9.018041333183646, 'smoke': 3.288586561878522, 'leakage': 4.985329648479819, 'sound': 23.082165295879044}
# most similar: sound 23.082165295879044
#
# ['flash', 'lights']
# flash lights - ['flash', 'lights']
# {'temperature': 20.629227587154933, 'humidity': 13.995734850565592, 'illumination': 39.82864774763584, 'motion': 12.633445393294096, 'location': 5.1363152684643865, 'smoke': 17.46587439750632, 'leakage': 16.463150239239138, 'sound': 21.536164234081905}
# most similar: illumination 39.82864774763584
#
# ['presence']
# presence - ['presence']
# {'temperature': 2.288369688072375, 'humidity': 10.473002990086872, 'illumination': 6.937975115142763, 'motion': 8.988640457391739, 'location': 19.022601656615734, 'smoke': 5.07089525150756, 'leakage': 1.5509756385452218, 'sound': 5.317465960979462}
# most similar: location 19.022601656615734
#
# ['relative', 'humidity']
# relative humidity  - ['relative', 'humidity']
# {'temperature': 21.45596230402589, 'humidity': 35.80022115881245, 'illumination': 10.465825498104095, 'motion': 1.578325405716896, 'location': 10.366901569068432, 'smoke': 19.472422978530325, 'leakage': 11.62821093781127, 'sound': 8.927719791730244}
# most similar: humidity 35.80022115881245
#
# ['smoke']
# smoke - ['smoke']
# {'temperature': 20.190171045916422, 'humidity': 29.27914758523305, 'illumination': 15.347130708396433, 'motion': 6.924749910831451, 'location': 7.389276032336056, 'smoke': 32.32429921627045, 'leakage': 11.280772793624136, 'sound': 17.65662326167027}
# most similar: smoke 32.32429921627045
#
# ['switch']
# switch - ['switch']
# {'temperature': 14.021990395018033, 'humidity': 4.544826907416185, 'illumination': 30.916146636009216, 'motion': 16.613133251667023, 'location': 6.171485991217196, 'smoke': 10.718875688811142, 'leakage': 18.163967670665848, 'sound': 9.540629138549168}
# most similar: illumination 30.916146636009216
#
# ['switch', 'level']
# switch level - ['switch', 'level']
# {'temperature': 12.206728304071085, 'humidity': 7.862135116010904, 'illumination': 19.023043382912874, 'motion': 14.761918317526579, 'location': 9.596193872857839, 'smoke': 9.875399122635523, 'leakage': 12.436509132385254, 'sound': 7.391651161015034}
# most similar: illumination 19.023043382912874
#
# ['temperature']
# temperature - ['temperature']
# {'temperature': 50.22032729216984, 'humidity': 50.294081370035805, 'illumination': 20.10056622326374, 'motion': 8.942161500453949, 'location': 12.009406089782715, 'smoke': 40.59849282105763, 'leakage': 23.985208198428154, 'sound': 9.200154741605122}
# most similar: humidity 50.294081370035805
#
# ['thermostat']
# thermostat - ['thermostat']
# {'temperature': 52.030298752444125, 'humidity': 31.998351713021595, 'illumination': 26.75310134887695, 'motion': 5.126686207950115, 'location': 1.2600660789757967, 'smoke': 34.752103189627334, 'leakage': 23.917242429322666, 'sound': 13.441562155882517}
# most similar: temperature 52.030298752444125
#
# ['three', 'axis', 'space']
# three axis space - ['three', 'axis', 'space']
# {'temperature': 8.85551395338206, 'humidity': 5.99351764863564, 'illumination': 8.531366375585398, 'motion': 8.841838501393795, 'location': 13.276977790519595, 'smoke': 7.456584429989259, 'leakage': 8.131557806498476, 'sound': 2.545183731449975}
# most similar: location 13.276977790519595
#
# ['valve']
# valve - ['valve']
# {'temperature': 30.05428654806955, 'humidity': 27.788070340951283, 'illumination': 12.574790101498365, 'motion': 4.644566401839256, 'location': 6.687101675197482, 'smoke': 31.226905932029087, 'leakage': 34.547654777351354, 'sound': 8.925264080365498}
# most similar: leakage 34.547654777351354
#
# ['water', 'sensor']
# water sensor - ['water', 'sensor']
# {'temperature': 27.608069990362438, 'humidity': 30.756478508313496, 'illumination': 18.961314698681235, 'motion': 11.835237871855497, 'location': 12.632810114882886, 'smoke': 25.586320087313652, 'leakage': 32.40157696935866, 'sound': 12.457021574179333}
# most similar: leakage 32.40157696935866
# {'temperature': ['thermostat'],
#  'humidity': ['relative humidity ', 'temperature'],
#  'illumination': ['beacon',
#   'illumination',
#   'flash lights',
#   'switch',
#   'switch level'],
#  'motion': ['acceleration', 'motion '],
#  'location': ['location', 'presence', 'three axis space'],
#  'smoke': ['carbon_monoxide', 'contact', 'smoke'],
#  'leakage': ['valve', 'water sensor'],
#  'sound': ['music player']}

# %%
# final creation of table 3, p.839
cap_to_channel
# Out:
# {'temperature': ['thermostat'],
#  'humidity': ['relative humidity ', 'temperature'],
#  'illumination': ['beacon',
#   'illumination',
#   'flash lights',
#   'switch',
#   'switch level'],
#  'motion': ['acceleration', 'motion '],
#  'location': ['location', 'presence', 'three axis space'],
#  'smoke': ['carbon_monoxide', 'contact', 'smoke'],
#  'leakage': ['valve', 'water sensor'],
#  'sound': ['music player']}

# %%
# now classify the switch capability based on app description
# the cap switch is correlated to different appliances like fan, bulb or air_conditioner
# so there are three types of switch: switch_humidity, switch_illumination and switch_temperature
similarity_list = {}
POS_accepted = ["NN", "NNS"]  # part of speech tags accepted 
trigger_action_translated = []

for app in trigger_action.keys(): # for every app where I can extrapolate info
    for trigger_cap in trigger_action[app].keys(): # for every app trigger capability
        for actions in trigger_action[app][trigger_cap]: # for every action correlated to that trigger capability
            # check if the action capability is a switch
            pair = [] # pair of trigger-action capability
            action_cap = actions[0]
            if action_cap == "switch":
                if not trigger_cap in list_system_cap:
                    string_trigger_capability = cap2string(trigger_cap)
                    pair.append(string_trigger_capability)
                else:
                    pair.append(trigger_cap)
                
                # scegli che action switch applicargli
                print("found:",app, " use ", action_cap )
                description = nlp(app_description[app])
                keywords = []
                clean_keywords = []
                for sent in description.sentences: 
                    for word in sent.words:           # check each word of the description
                        if word.xpos in POS_accepted: # check is it is a NN or NNS
                            keywords_found = word.text.lower()
                            if not keywords_found in keywords:  # if not already saved that keyword 
                                keywords.append(keywords_found) # save it
    
                for i in range(len(keywords)): # for every keywords saved from the description 
                    try:
                        word = str(keywords[i])
                        if len(word) > 1: # if it is not a single letter or symbol
                            model[word]   # try to apply Word2Vec
                            clean_keywords.append(word)
                        else:
                            print("word not processed: ",word)
                    except KeyError as err:
                        print("handling Error: ", err) # some words can not be processed by Word2Vec

                print(clean_keywords)
                
                if len(clean_keywords) == 0: # case there aren't any NN keyword inside that app description (strange)
                    print(f"!!error!!")

                else:
                    if len(clean_keywords) == 1: # case there are only 1 keyword inside app description
                        for phy_ch in ['temperature', 'humidity', 'illumination']:
                            similarity_temp = 0
                            for channel_NN in dict_channels[phy_ch]: # for every keyword inside the channel cluster
                                similarity_temp += model.similarity(clean_keywords[0],channel_NN)
                            # divide by the number of cluster keywords --> result: the mean of similarity
                            similarity_list[phy_ch] = (similarity_temp/len(dict_channels[key]))*100

                    else: # case there are more than 1 keyword inside tcapability
                        for phy_ch in ['temperature', 'humidity', 'illumination']:
                            similarity_partial = 0
                            for keyword in clean_keywords: # for every keyword NN extracted from description
                                similarity_temp = 0
                                for channel_NN in dict_channels[phy_ch]:  # for every keyword inside the channel cluster
                                    #print(keyword,channel_NN,"\t", model.similarity(keyword,channel_NN))
                                    similarity_temp += model.similarity(keyword,channel_NN)
                                 # divide by the number of cluster keywords --> result: the mean of similarity (given by only 1 NN)
                                similarity_temp = similarity_temp/len(dict_channels[phy_ch])
                                similarity_partial += similarity_temp
                            #print("this keyword for ",key,"has got a level", similarity_partial/len(clean_keywords))
                            similarity_list[phy_ch] = (similarity_partial/len(clean_keywords))*100

                    #print(similarity_list)
                    # now find the highest physical channel association 
                    channel_association = ""
                    max_value = 0
                    for channel in similarity_list.keys():
                        if (similarity_list[channel] > max_value):
                            max_value = similarity_list[channel]
                            channel_association = channel

                    print("most similar:", channel_association, max_value)
                    
                    if channel_association == "temperature":
                        pair.append("switch air_conditioner") # switch AC
                    
                    elif channel_association == "humidity":
                        pair.append("switch vent") # switch vent
                    else:
                        pair.append("switch bulb") # switch bulb
                
                
            else:
                if not trigger_cap in list_system_cap:
                    string_trigger_capability = cap2string(trigger_cap)
                    pair.append(string_trigger_capability)
                else:
                    pair.append(trigger_cap)
                if not action_cap in list_system_cap:
                    string_action_capability = cap2string(action_cap)
                    pair.append(string_action_capability)
                else:
                    pair.append(action_cap)
                
            # in the end save the pair 
            print(app,"\t", pair, "\n")
            trigger_action_translated.append(pair)
                
trigger_action_translated
# Out:
# found: beacon-control  use  switch
# ['home', 'phrase', 'lights', 'door', 'region']
# most similar: illumination 14.02022996544838
# beacon-control 	 ['beacon', 'switch bulb']
#
# found: beacon-control  use  switch
# ['home', 'phrase', 'lights', 'door', 'region']
# most similar: illumination 14.02022996544838
# beacon-control 	 ['beacon', 'switch bulb']
#
# beacon-control 	 ['beacon', 'lock']
#
# found: beacon-control  use  switch
# ['home', 'phrase', 'lights', 'door', 'region']
# most similar: illumination 14.02022996544838
# beacon-control 	 ['beacon', 'switch bulb']
#
# found: beacon-control  use  switch
# ['home', 'phrase', 'lights', 'door', 'region']
# most similar: illumination 14.02022996544838
# beacon-control 	 ['beacon', 'switch bulb']
#
# beacon-control 	 ['beacon', 'lock']
#
# found: big-turn-off  use  switch
# ['lights']
# most similar: illumination 166.4512187242508
# big-turn-off 	 ['location', 'switch bulb']
#
# found: big-turn-off  use  switch
# ['lights']
# most similar: illumination 166.4512187242508
# big-turn-off 	 ['app', 'switch bulb']
#
# found: big-turn-on  use  switch
# ['lights']
# most similar: illumination 166.4512187242508
# big-turn-on 	 ['location', 'switch bulb']
#
# found: big-turn-on  use  switch
# ['lights']
# most similar: illumination 166.4512187242508
# big-turn-on 	 ['app', 'switch bulb']
#
# bon-voyage 	 ['presence', 'sendAction']
#
# bon-voyage 	 ['presence', 'sendAction']
#
# bon-voyage 	 ['presence', 'sendAction']
#
# bon-voyage 	 ['presence', 'locationMode']
#
# found: brighten-dark-places  use  switch
# ['lights', 'sensor', 'space']
# most similar: illumination 27.520575815190874
# brighten-dark-places 	 ['contact', 'switch bulb']
#
# found: brighten-my-path  use  switch
# ['lights', 'motion']
# most similar: illumination 31.599929872900244
# brighten-my-path 	 ['motion ', 'switch bulb']
#
# button-controller 	 ['button', 'locationMode']
#
# button-controller 	 ['button', 'sendAction']
#
# button-controller 	 ['button', 'sendAction']
#
# found: camera-power-scheduler  use  switch
# ['power', 'time']
# most similar: illumination 13.03652527742088
# camera-power-scheduler 	 ['time', 'switch bulb']
#
# found: cameras-on-when-im-away  use  switch
# ['cameras']
# most similar: illumination 100.46099548538525
# cameras-on-when-im-away 	 ['presence', 'switch bulb']
#
# found: cameras-on-when-im-away  use  switch
# ['cameras']
# most similar: illumination 100.46099548538525
# cameras-on-when-im-away 	 ['presence', 'switch bulb']
#
# carpool-notifier 	 ['presence', 'sendAction']
#
# carpool-notifier 	 ['presence', 'sendAction']
#
# close-the-valve 	 ['water sensor', 'valve']
#
# close-the-valve 	 ['water sensor', 'sendAction']
#
# close-the-valve 	 ['water sensor', 'sendAction']
#
# found: curling-iron  use  switch
# ['outlet', 'user', 'period', 'time']
# most similar: temperature 8.58725114459438
# curling-iron 	 ['motion ', 'switch air_conditioner']
#
# found: curling-iron  use  switch
# ['outlet', 'user', 'period', 'time']
# most similar: temperature 8.58725114459438
# curling-iron 	 ['presence', 'switch air_conditioner']
#
# found: darken-behind-me  use  switch
# ['lights', 'period', 'motion']
# most similar: illumination 22.47053456182281
# darken-behind-me 	 ['motion ', 'switch bulb']
#
# found: double-tap  use  switch
# ['number', 'switches', 'switch', 'row']
# most similar: illumination 19.75175629602745
# double-tap 	 ['switch', 'switch bulb']
#
# found: double-tap  use  switch
# ['number', 'switches', 'switch', 'row']
# most similar: illumination 19.75175629602745
# double-tap 	 ['switch', 'switch bulb']
#
# found: dry-the-wetspot  use  switch
# ['moisture', 'sensor', 'input']
# most similar: humidity 36.49645803703201
# dry-the-wetspot 	 ['water sensor', 'switch vent']
#
# found: dry-the-wetspot  use  switch
# ['moisture', 'sensor', 'input']
# most similar: humidity 36.49645803703201
# dry-the-wetspot 	 ['water sensor', 'switch vent']
#
# elder-care-daily-routine 	 ['time', 'sendAction']
#
# elder-care-daily-routine 	 ['time', 'sendAction']
#
# elder-care-daily-routine 	 ['time', 'sendAction']
#
# elder-care-slip-fall 	 ['motion ', 'sendAction']
#
# elder-care-slip-fall 	 ['motion ', 'sendAction']
#
# elder-care-slip-fall 	 ['motion ', 'sendAction']
#
# energy-alerts 	 ['powerMeter', 'sendAction']
#
# energy-alerts 	 ['powerMeter', 'sendAction']
#
# energy-alerts 	 ['powerMeter', 'sendAction']
#
# found: energy-saver  use  switch
# ['things', 'energy']
# most similar: illumination 16.87104575335979
# energy-saver 	 ['powerMeter', 'switch bulb']
#
# feed-my-pet 	 ['time', 'device.PetFeederShield']
#
# flood-alert 	 ['water sensor', 'sendAction']
#
# flood-alert 	 ['water sensor', 'sendAction']
#
# flood-alert 	 ['water sensor', 'sendAction']
#
# forgiving-security 	 ['contact', 'sendAction']
#
# forgiving-security 	 ['contact', 'sendAction']
#
# found: forgiving-security  use  switch
# ['something', 'grace', 'period', 'presence', 'sensors', 'seconds']
# most similar: illumination 11.295431224474063
# forgiving-security 	 ['contact', 'switch bulb']
#
# forgiving-security 	 ['contact', 'alarm']
#
# forgiving-security 	 ['motion ', 'sendAction']
#
# forgiving-security 	 ['motion ', 'sendAction']
#
# found: forgiving-security  use  switch
# ['something', 'grace', 'period', 'presence', 'sensors', 'seconds']
# most similar: illumination 11.295431224474063
# forgiving-security 	 ['motion ', 'switch bulb']
#
# forgiving-security 	 ['motion ', 'alarm']
#
# garage-door-monitor 	 ['three axis space', 'sendAction']
#
# garage-door-monitor 	 ['three axis space', 'sendAction']
#
# garage-door-monitor 	 ['three axis space', 'sendAction']
#
# found: garage-door-opener  use  switch
# ['garage', 'door', 'switch']
# most similar: temperature 18.47428793885878
# garage-door-opener 	 ['app', 'switch air_conditioner']
#
# found: garage-door-opener  use  switch
# ['garage', 'door', 'switch']
# most similar: temperature 18.47428793885878
# garage-door-opener 	 ['switch', 'switch air_conditioner']
#
# good-night 	 ['motion ', 'sendAction']
#
# good-night 	 ['motion ', 'sendAction']
#
# good-night 	 ['motion ', 'sendAction']
#
# good-night 	 ['motion ', 'locationMode']
#
# good-night 	 ['switch', 'sendAction']
#
# good-night 	 ['switch', 'sendAction']
#
# good-night 	 ['switch', 'sendAction']
#
# good-night 	 ['switch', 'locationMode']
#
# greetings-earthling 	 ['presence', 'sendAction']
#
# greetings-earthling 	 ['presence', 'sendAction']
#
# greetings-earthling 	 ['presence', 'sendAction']
#
# greetings-earthling 	 ['presence', 'locationMode']
#
# habit-helper 	 ['time', 'sendAction']
#
# habit-helper 	 ['time', 'sendAction']
#
# has-barkley-been-fed 	 ['time', 'sendAction']
#
# has-barkley-been-fed 	 ['time', 'sendAction']
#
# humidity-alert 	 ['relative humidity ', 'sendAction']
#
# humidity-alert 	 ['relative humidity ', 'sendAction']
#
# found: humidity-alert  use  switch
# ['humidity', 'threshold', 'switch']
# most similar: humidity 25.647443843384583
# humidity-alert 	 ['relative humidity ', 'switch vent']
#
# found: humidity-alert  use  switch
# ['humidity', 'threshold', 'switch']
# most similar: humidity 25.647443843384583
# humidity-alert 	 ['relative humidity ', 'switch vent']
#
# it-moved 	 ['acceleration', 'sendAction']
#
# it-moved 	 ['acceleration', 'sendAction']
#
# its-too-cold 	 ['temperature', 'sendAction']
#
# its-too-cold 	 ['temperature', 'sendAction']
#
# its-too-cold 	 ['temperature', 'sendAction']
#
# found: its-too-cold  use  switch
# ['temperature', 'setting', 'text', 'heater', 'appliance']
# most similar: temperature 28.093202723456283
# its-too-cold 	 ['temperature', 'switch air_conditioner']
#
# its-too-hot 	 ['temperature', 'sendAction']
#
# its-too-hot 	 ['temperature', 'sendAction']
#
# its-too-hot 	 ['temperature', 'sendAction']
#
# found: its-too-hot  use  switch
# handling Error:  "Key '/c' not present"
# ['temperature', 'setting', 'notification', 'unit', 'fan']
# most similar: temperature 17.742892296186515
# its-too-hot 	 ['temperature', 'switch air_conditioner']
#
# keep-me-cozy 	 ['location', 'thermostat']
#
# keep-me-cozy 	 ['location', 'thermostat']
#
# keep-me-cozy 	 ['location', 'thermostat']
#
# keep-me-cozy 	 ['app', 'thermostat']
#
# keep-me-cozy 	 ['app', 'thermostat']
#
# keep-me-cozy 	 ['app', 'thermostat']
#
# keep-me-cozy-ii 	 ['location', 'thermostat']
#
# keep-me-cozy-ii 	 ['location', 'thermostat']
#
# keep-me-cozy-ii 	 ['location', 'thermostat']
#
# keep-me-cozy-ii 	 ['temperature', 'thermostat']
#
# keep-me-cozy-ii 	 ['temperature', 'thermostat']
#
# keep-me-cozy-ii 	 ['temperature', 'thermostat']
#
# keep-me-cozy-ii 	 ['thermostat', 'thermostat']
#
# keep-me-cozy-ii 	 ['thermostat', 'thermostat']
#
# keep-me-cozy-ii 	 ['thermostat', 'thermostat']
#
# laundry-monitor 	 ['acceleration', 'sendAction']
#
# laundry-monitor 	 ['acceleration', 'sendAction']
#
# laundry-monitor 	 ['acceleration', 'sendAction']
#
# found: laundry-monitor  use  switch
# ['message', 'light', 'laundry']
# most similar: illumination 19.292593002319336
# laundry-monitor 	 ['acceleration', 'switch bulb']
#
# left-it-open 	 ['contact', 'sendAction']
#
# left-it-open 	 ['contact', 'sendAction']
#
# left-it-open 	 ['contact', 'sendAction']
#
# found: let-there-be-dark  use  switch
# ['lights', 'contact', 'sensor']
# most similar: illumination 26.81697643051545
# let-there-be-dark 	 ['contact', 'switch bulb']
#
# found: let-there-be-dark  use  switch
# ['lights', 'contact', 'sensor']
# most similar: illumination 26.81697643051545
# let-there-be-dark 	 ['contact', 'switch bulb']
#
# found: let-there-be-dark  use  switch
# ['lights', 'contact', 'sensor']
# most similar: illumination 26.81697643051545
# let-there-be-dark 	 ['contact', 'switch bulb']
#
# found: let-there-be-light  use  switch
# ['lights', 'multi']
# most similar: illumination 29.560739398002628
# let-there-be-light 	 ['contact', 'switch bulb']
#
# found: let-there-be-light  use  switch
# ['lights', 'multi']
# most similar: illumination 29.560739398002628
# let-there-be-light 	 ['contact', 'switch bulb']
#
# found: light-follows-me  use  switch
# ['lights', 'motion', 'period', 'time']
# most similar: illumination 19.12360533606261
# light-follows-me 	 ['motion ', 'switch bulb']
#
# found: light-follows-me  use  switch
# ['lights', 'motion', 'period', 'time']
# most similar: illumination 19.12360533606261
# light-follows-me 	 ['motion ', 'switch bulb']
#
# found: lights-off-when-closed  use  switch
# ['lights', 'sensor']
# most similar: illumination 37.30715714395046
# lights-off-when-closed 	 ['contact', 'switch bulb']
#
# found: light-up-the-night  use  switch
# ['lights']
# most similar: illumination 166.4512187242508
# light-up-the-night 	 ['illumination', 'switch bulb']
#
# found: light-up-the-night  use  switch
# ['lights']
# most similar: illumination 166.4512187242508
# light-up-the-night 	 ['illumination', 'switch bulb']
#
# lock-it-at-a-specific-time 	 ['time', 'sendAction']
#
# lock-it-at-a-specific-time 	 ['time', 'sendAction']
#
# lock-it-at-a-specific-time 	 ['time', 'lock']
#
# lock-it-when-i-leave 	 ['presence', 'sendAction']
#
# lock-it-when-i-leave 	 ['presence', 'sendAction']
#
# lock-it-when-i-leave 	 ['presence', 'lock']
#
# lock-it-when-i-leave 	 ['presence', 'lock']
#
# mail-arrived 	 ['acceleration', 'sendAction']
#
# mail-arrived 	 ['acceleration', 'sendAction']
#
# mail-arrived 	 ['acceleration', 'sendAction']
#
# found: make-it-so  use  switch
# handling Error:  "Key 'setpoints' not present"
# handling Error:  "Key 'setpoint' not present"
# ['states', 'set', 'switches', 'thermostat', 'mode', 'change', 'app', 'devices', 'state']
# most similar: illumination 15.043026984979713
# make-it-so 	 ['location', 'switch bulb']
#
# make-it-so 	 ['location', 'thermostat']
#
# make-it-so 	 ['location', 'lock']
#
# found: make-it-so  use  switch
# handling Error:  "Key 'setpoints' not present"
# handling Error:  "Key 'setpoint' not present"
# ['states', 'set', 'switches', 'thermostat', 'mode', 'change', 'app', 'devices', 'state']
# most similar: illumination 15.043026984979713
# make-it-so 	 ['app', 'switch bulb']
#
# make-it-so 	 ['app', 'thermostat']
#
# make-it-so 	 ['app', 'lock']
#
# medicine-management-contact-sensor 	 ['contact', 'colorControl']
#
# medicine-management-contact-sensor 	 ['contact', 'colorControl']
#
# medicine-management-contact-sensor 	 ['time', 'sendAction']
#
# mini-hue-controller 	 ['button', 'colorControl']
#
# mini-hue-controller 	 ['button', 'colorControl']
#
# mini-hue-controller 	 ['button', 'colorControl']
#
# mini-hue-controller 	 ['button', 'colorControl']
#
# found: nfc-tag-toggle  use  switch
# handling Error:  "Key 'toggling' not present"
# ['switch', 'lock', 'garage', 'door', 'tag', 'touch', 'event']
# most similar: illumination 13.567415137908286
# nfc-tag-toggle 	 ['touchSensor', 'switch bulb']
#
# nfc-tag-toggle 	 ['touchSensor', 'lock']
#
# nfc-tag-toggle 	 ['touchSensor', 'doorControl']
#
# found: nfc-tag-toggle  use  switch
# handling Error:  "Key 'toggling' not present"
# ['switch', 'lock', 'garage', 'door', 'tag', 'touch', 'event']
# most similar: illumination 13.567415137908286
# nfc-tag-toggle 	 ['app', 'switch bulb']
#
# nfc-tag-toggle 	 ['app', 'lock']
#
# nfc-tag-toggle 	 ['app', 'doorControl']
#
# notify-me-when 	 ['button', 'sendAction']
#
# notify-me-when 	 ['contact', 'sendAction']
#
# notify-me-when 	 ['acceleration', 'sendAction']
#
# notify-me-when 	 ['motion ', 'sendAction']
#
# notify-me-when 	 ['switch', 'sendAction']
#
# notify-me-when 	 ['presence', 'sendAction']
#
# notify-me-when 	 ['smoke', 'sendAction']
#
# notify-me-when 	 ['water sensor', 'sendAction']
#
# notify-me-when-it-opens 	 ['contact', 'sendAction']
#
# notify-me-with-hue 	 ['app', 'colorControl']
#
# notify-me-with-hue 	 ['app', 'colorControl']
#
# notify-me-with-hue 	 ['contact', 'colorControl']
#
# notify-me-with-hue 	 ['contact', 'colorControl']
#
# notify-me-with-hue 	 ['acceleration', 'colorControl']
#
# notify-me-with-hue 	 ['acceleration', 'colorControl']
#
# notify-me-with-hue 	 ['motion ', 'colorControl']
#
# notify-me-with-hue 	 ['motion ', 'colorControl']
#
# notify-me-with-hue 	 ['switch', 'colorControl']
#
# notify-me-with-hue 	 ['switch', 'colorControl']
#
# notify-me-with-hue 	 ['presence', 'colorControl']
#
# notify-me-with-hue 	 ['presence', 'colorControl']
#
# notify-me-with-hue 	 ['smoke', 'colorControl']
#
# notify-me-with-hue 	 ['smoke', 'colorControl']
#
# notify-me-with-hue 	 ['water sensor', 'colorControl']
#
# notify-me-with-hue 	 ['water sensor', 'colorControl']
#
# notify-me-with-hue 	 ['button', 'colorControl']
#
# notify-me-with-hue 	 ['button', 'colorControl']
#
# found: once-a-day  use  switch
# ['switches', 'time']
# most similar: illumination 22.65642698854208
# once-a-day 	 ['time', 'switch bulb']
#
# photo-burst-when 	 ['contact', 'imageCapture']
#
# photo-burst-when 	 ['contact', 'sendAction']
#
# photo-burst-when 	 ['contact', 'sendAction']
#
# photo-burst-when 	 ['contact', 'sendAction']
#
# photo-burst-when 	 ['acceleration', 'imageCapture']
#
# photo-burst-when 	 ['acceleration', 'sendAction']
#
# photo-burst-when 	 ['acceleration', 'sendAction']
#
# photo-burst-when 	 ['acceleration', 'sendAction']
#
# photo-burst-when 	 ['motion ', 'imageCapture']
#
# photo-burst-when 	 ['motion ', 'sendAction']
#
# photo-burst-when 	 ['motion ', 'sendAction']
#
# photo-burst-when 	 ['motion ', 'sendAction']
#
# photo-burst-when 	 ['switch', 'imageCapture']
#
# photo-burst-when 	 ['switch', 'sendAction']
#
# photo-burst-when 	 ['switch', 'sendAction']
#
# photo-burst-when 	 ['switch', 'sendAction']
#
# photo-burst-when 	 ['presence', 'imageCapture']
#
# photo-burst-when 	 ['presence', 'sendAction']
#
# photo-burst-when 	 ['presence', 'sendAction']
#
# photo-burst-when 	 ['presence', 'sendAction']
#
# found: power-allowance  use  switch
# ['energy', 'time', 'appliance', 'curling', 'iron', 'tv', 'use', 'switch', 'number', 'minutes']
# most similar: illumination 12.509635316673668
# power-allowance 	 ['switch', 'switch bulb']
#
# presence-change-push 	 ['presence', 'sendAction']
#
# presence-change-text 	 ['presence', 'sendAction']
#
# presence-change-text 	 ['presence', 'sendAction']
#
# ready-for-rain 	 ['contact', 'sendAction']
#
# ready-for-rain 	 ['contact', 'sendAction']
#
# ridiculously-automated-garage-door 	 ['presence', 'momentary']
#
# ridiculously-automated-garage-door 	 ['presence', 'sendAction']
#
# ridiculously-automated-garage-door 	 ['acceleration', 'momentary']
#
# ridiculously-automated-garage-door 	 ['contact', 'momentary']
#
# rise-and-shine 	 ['motion ', 'sendAction']
#
# rise-and-shine 	 ['motion ', 'sendAction']
#
# rise-and-shine 	 ['motion ', 'sendAction']
#
# rise-and-shine 	 ['motion ', 'locationMode']
#
# found: rise-and-shine  use  switch
# ['changes', 'someone', 'time', 'morning']
# most similar: illumination 8.769153638277203
# rise-and-shine 	 ['motion ', 'switch bulb']
#
# scheduled-mode-change 	 ['time', 'locationMode']
#
# scheduled-mode-change 	 ['time', 'sendAction']
#
# scheduled-mode-change 	 ['time', 'sendAction']
#
# scheduled-mode-change 	 ['time', 'sendAction']
#
# smart-care-daily-routine 	 ['time', 'sendAction']
#
# smart-care-daily-routine 	 ['time', 'sendAction']
#
# smart-care-daily-routine 	 ['time', 'sendAction']
#
# smart-care-detect-motion 	 ['motion ', 'sendAction']
#
# smart-care-detect-motion 	 ['motion ', 'sendAction']
#
# smart-care-detect-motion 	 ['motion ', 'sendAction']
#
# smart-humidifier 	 ['relative humidity ', 'sendAction']
#
# smart-humidifier 	 ['relative humidity ', 'sendAction']
#
# found: smart-humidifier  use  switch
# handling Error:  "Key 'humidifier' not present"
# ['humidity', 'sensor']
# most similar: humidity 47.88095752398173
# smart-humidifier 	 ['relative humidity ', 'switch vent']
#
# found: smart-humidifier  use  switch
# handling Error:  "Key 'humidifier' not present"
# ['humidity', 'sensor']
# most similar: humidity 47.88095752398173
# smart-humidifier 	 ['relative humidity ', 'switch vent']
#
# found: smart-nightlight  use  switch
# ['lights', 'motion', 'light', 'time']
# most similar: illumination 28.07584679685533
# smart-nightlight 	 ['motion ', 'switch bulb']
#
# found: smart-nightlight  use  switch
# ['lights', 'motion', 'light', 'time']
# most similar: illumination 28.07584679685533
# smart-nightlight 	 ['motion ', 'switch bulb']
#
# smart-security 	 ['motion ', 'sendAction']
#
# smart-security 	 ['motion ', 'locationMode']
#
# smart-security 	 ['motion ', 'alarm']
#
# smart-security 	 ['motion ', 'sendAction']
#
# smart-security 	 ['motion ', 'sendAction']
#
# smart-security 	 ['motion ', 'alarm']
#
# smart-security 	 ['contact', 'sendAction']
#
# smart-security 	 ['contact', 'locationMode']
#
# smart-security 	 ['contact', 'alarm']
#
# smart-security 	 ['contact', 'sendAction']
#
# smart-security 	 ['contact', 'sendAction']
#
# smart-security 	 ['contact', 'alarm']
#
# smart-security 	 ['alarm', 'alarm']
#
# smart-security 	 ['app', 'alarm']
#
# step-notifier 	 ['device.jawboneUser', 'sendAction']
#
# step-notifier 	 ['device.jawboneUser', 'music player']
#
# step-notifier 	 ['device.jawboneUser', 'music player']
#
# step-notifier 	 ['device.jawboneUser', 'music player']
#
# step-notifier 	 ['device.jawboneUser', 'music player']
#
# step-notifier 	 ['device.jawboneUser', 'colorControl']
#
# step-notifier 	 ['device.jawboneUser', 'colorControl']
#
# found: step-notifier  use  switch
# ['step', 'tracker', 'device', 'goals', 'actions']
# most similar: illumination 8.376131212338803
# step-notifier 	 ['device.jawboneUser', 'switch bulb']
#
# text-me-when-it-opens 	 ['contact', 'sendAction']
#
# text-me-when-it-opens 	 ['contact', 'sendAction']
#
# text-me-when-theres-motion-and-im-not-here 	 ['motion ', 'sendAction']
#
# text-me-when-theres-motion-and-im-not-here 	 ['motion ', 'sendAction']
#
# the-big-switch 	 ['switch', 'switch level']
#
# the-flasher 	 ['contact', 'flash lights']
#
# the-flasher 	 ['acceleration', 'flash lights']
#
# the-flasher 	 ['motion ', 'flash lights']
#
# the-flasher 	 ['switch', 'flash lights']
#
# the-flasher 	 ['presence', 'flash lights']
#
# the-gun-case-moved 	 ['acceleration', 'sendAction']
#
# the-gun-case-moved 	 ['acceleration', 'sendAction']
#
# thermostat-auto-off 	 ['contact', 'thermostat']
#
# thermostat-auto-off 	 ['contact', 'thermostat']
#
# thermostat-auto-off 	 ['contact', 'thermostat']
#
# thermostats 	 ['smoke', 'thermostat']
#
# thermostats 	 ['smoke', 'sendAction']
#
# thermostats 	 ['carbon_monoxide', 'thermostat']
#
# thermostats 	 ['carbon_monoxide', 'sendAction']
#
# found: turn-it-on-for-5-minutes  use  switch
# ['switch', 'minutes']
# most similar: illumination 18.805013727396727
# turn-it-on-for-5-minutes 	 ['contact', 'switch bulb']
#
# found: turn-it-on-for-5-minutes  use  switch
# ['switch', 'minutes']
# most similar: illumination 18.805013727396727
# turn-it-on-for-5-minutes 	 ['contact', 'switch bulb']
#
# found: turn-it-on-when-im-here  use  switch
# ['something']
# most similar: illumination 42.41059298316638
# turn-it-on-when-im-here 	 ['presence', 'switch bulb']
#
# found: turn-it-on-when-im-here  use  switch
# ['something']
# most similar: illumination 42.41059298316638
# turn-it-on-when-im-here 	 ['presence', 'switch bulb']
#
# found: turn-it-on-when-it-opens  use  switch
# ['something', 'sensor']
# most similar: temperature 20.63199526497296
# turn-it-on-when-it-opens 	 ['contact', 'switch air_conditioner']
#
# found: turn-on-only-if-i-arrive-after-sunset  use  switch
# ['something', 'sunset', 'anytime']
# most similar: illumination 12.133047788714368
# turn-on-only-if-i-arrive-after-sunset 	 ['presence', 'switch bulb']
#
# found: turn-on-only-if-i-arrive-after-sunset  use  switch
# ['something', 'sunset', 'anytime']
# most similar: illumination 12.133047788714368
# turn-on-only-if-i-arrive-after-sunset 	 ['presence', 'switch bulb']
#
# found: undead-early-warning  use  switch
# ['warning']
# most similar: illumination 31.39902390539646
# undead-early-warning 	 ['contact', 'switch bulb']
#
# unlock-it-when-i-arrive 	 ['presence', 'sendAction']
#
# unlock-it-when-i-arrive 	 ['presence', 'lock']
#
# found: virtual-thermostat  use  switch
# ['space', 'heater', 'window', 'air_conditioner', 'conjunction', 'temperature', 'sensor', 'multi']
# most similar: temperature 27.986222987861503
# virtual-thermostat 	 ['temperature', 'switch air_conditioner']
#
# found: virtual-thermostat  use  switch
# ['space', 'heater', 'window', 'air_conditioner', 'conjunction', 'temperature', 'sensor', 'multi']
# most similar: temperature 27.986222987861503
# virtual-thermostat 	 ['temperature', 'switch air_conditioner']
#
# found: virtual-thermostat  use  switch
# ['space', 'heater', 'window', 'air_conditioner', 'conjunction', 'temperature', 'sensor', 'multi']
# most similar: temperature 27.986222987861503
# virtual-thermostat 	 ['motion ', 'switch air_conditioner']
#
# found: virtual-thermostat  use  switch
# ['space', 'heater', 'window', 'air_conditioner', 'conjunction', 'temperature', 'sensor', 'multi']
# most similar: temperature 27.986222987861503
# virtual-thermostat 	 ['motion ', 'switch air_conditioner']
#
# when-its-going-to-rain 	 ['time', 'sendAction']
#
# when-its-going-to-rain 	 ['time', 'sendAction']
#
# found: whole-house-fan  use  switch
# word not processed:  x
# ['house', 'fan', 'switch', 'temp', 'thermostat']
# most similar: temperature 26.372170011912075
# whole-house-fan 	 ['temperature', 'switch air_conditioner']
#
# found: whole-house-fan  use  switch
# word not processed:  x
# ['house', 'fan', 'switch', 'temp', 'thermostat']
# most similar: temperature 26.372170011912075
# whole-house-fan 	 ['temperature', 'switch air_conditioner']
#
# found: whole-house-fan  use  switch
# word not processed:  x
# ['house', 'fan', 'switch', 'temp', 'thermostat']
# most similar: temperature 26.372170011912075
# whole-house-fan 	 ['thermostat', 'switch air_conditioner']
#
# found: whole-house-fan  use  switch
# word not processed:  x
# ['house', 'fan', 'switch', 'temp', 'thermostat']
# most similar: temperature 26.372170011912075
# whole-house-fan 	 ['thermostat', 'switch air_conditioner']
#
# found: whole-house-fan  use  switch
# word not processed:  x
# ['house', 'fan', 'switch', 'temp', 'thermostat']
# most similar: temperature 26.372170011912075
# whole-house-fan 	 ['contact', 'switch air_conditioner']
#
# found: whole-house-fan  use  switch
# word not processed:  x
# ['house', 'fan', 'switch', 'temp', 'thermostat']
# most similar: temperature 26.372170011912075
# whole-house-fan 	 ['contact', 'switch air_conditioner']
# [['beacon', 'switch bulb'],
#  ['beacon', 'switch bulb'],
#  ['beacon', 'lock'],
#  ['beacon', 'switch bulb'],
#  ['beacon', 'switch bulb'],
#  ['beacon', 'lock'],
#  ['location', 'switch bulb'],
#  ['app', 'switch bulb'],
#  ['location', 'switch bulb'],
#  ['app', 'switch bulb'],
#  ['presence', 'sendAction'],
#  ['presence', 'sendAction'],
#  ['presence', 'sendAction'],
#  ['presence', 'locationMode'],
#  ['contact', 'switch bulb'],
#  ['motion ', 'switch bulb'],
#  ['button', 'locationMode'],
#  ['button', 'sendAction'],
#  ['button', 'sendAction'],
#  ['time', 'switch bulb'],
#  ['presence', 'switch bulb'],
#  ['presence', 'switch bulb'],
#  ['presence', 'sendAction'],
#  ['presence', 'sendAction'],
#  ['water sensor', 'valve'],
#  ['water sensor', 'sendAction'],
#  ['water sensor', 'sendAction'],
#  ['motion ', 'switch air_conditioner'],
#  ['presence', 'switch air_conditioner'],
#  ['motion ', 'switch bulb'],
#  ['switch', 'switch bulb'],
#  ['switch', 'switch bulb'],
#  ['water sensor', 'switch vent'],
#  ['water sensor', 'switch vent'],
#  ['time', 'sendAction'],
#  ['time', 'sendAction'],
#  ['time', 'sendAction'],
#  ['motion ', 'sendAction'],
#  ['motion ', 'sendAction'],
#  ['motion ', 'sendAction'],
#  ['powerMeter', 'sendAction'],
#  ['powerMeter', 'sendAction'],
#  ['powerMeter', 'sendAction'],
#  ['powerMeter', 'switch bulb'],
#  ['time', 'device.PetFeederShield'],
#  ['water sensor', 'sendAction'],
#  ['water sensor', 'sendAction'],
#  ['water sensor', 'sendAction'],
#  ['contact', 'sendAction'],
#  ['contact', 'sendAction'],
#  ['contact', 'switch bulb'],
#  ['contact', 'alarm'],
#  ['motion ', 'sendAction'],
#  ['motion ', 'sendAction'],
#  ['motion ', 'switch bulb'],
#  ['motion ', 'alarm'],
#  ['three axis space', 'sendAction'],
#  ['three axis space', 'sendAction'],
#  ['three axis space', 'sendAction'],
#  ['app', 'switch air_conditioner'],
#  ['switch', 'switch air_conditioner'],
#  ['motion ', 'sendAction'],
#  ['motion ', 'sendAction'],
#  ['motion ', 'sendAction'],
#  ['motion ', 'locationMode'],
#  ['switch', 'sendAction'],
#  ['switch', 'sendAction'],
#  ['switch', 'sendAction'],
#  ['switch', 'locationMode'],
#  ['presence', 'sendAction'],
#  ['presence', 'sendAction'],
#  ['presence', 'sendAction'],
#  ['presence', 'locationMode'],
#  ['time', 'sendAction'],
#  ['time', 'sendAction'],
#  ['time', 'sendAction'],
#  ['time', 'sendAction'],
#  ['relative humidity ', 'sendAction'],
#  ['relative humidity ', 'sendAction'],
#  ['relative humidity ', 'switch vent'],
#  ['relative humidity ', 'switch vent'],
#  ['acceleration', 'sendAction'],
#  ['acceleration', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'switch air_conditioner'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'switch air_conditioner'],
#  ['location', 'thermostat'],
#  ['location', 'thermostat'],
#  ['location', 'thermostat'],
#  ['app', 'thermostat'],
#  ['app', 'thermostat'],
#  ['app', 'thermostat'],
#  ['location', 'thermostat'],
#  ['location', 'thermostat'],
#  ['location', 'thermostat'],
#  ['temperature', 'thermostat'],
#  ['temperature', 'thermostat'],
#  ['temperature', 'thermostat'],
#  ['thermostat', 'thermostat'],
#  ['thermostat', 'thermostat'],
#  ['thermostat', 'thermostat'],
#  ['acceleration', 'sendAction'],
#  ['acceleration', 'sendAction'],
#  ['acceleration', 'sendAction'],
#  ['acceleration', 'switch bulb'],
#  ['contact', 'sendAction'],
#  ['contact', 'sendAction'],
#  ['contact', 'sendAction'],
#  ['contact', 'switch bulb'],
#  ['contact', 'switch bulb'],
#  ['contact', 'switch bulb'],
#  ['contact', 'switch bulb'],
#  ['contact', 'switch bulb'],
#  ['motion ', 'switch bulb'],
#  ['motion ', 'switch bulb'],
#  ['contact', 'switch bulb'],
#  ['illumination', 'switch bulb'],
#  ['illumination', 'switch bulb'],
#  ['time', 'sendAction'],
#  ['time', 'sendAction'],
#  ['time', 'lock'],
#  ['presence', 'sendAction'],
#  ['presence', 'sendAction'],
#  ['presence', 'lock'],
#  ['presence', 'lock'],
#  ['acceleration', 'sendAction'],
#  ['acceleration', 'sendAction'],
#  ['acceleration', 'sendAction'],
#  ['location', 'switch bulb'],
#  ['location', 'thermostat'],
#  ['location', 'lock'],
#  ['app', 'switch bulb'],
#  ['app', 'thermostat'],
#  ['app', 'lock'],
#  ['contact', 'colorControl'],
#  ['contact', 'colorControl'],
#  ['time', 'sendAction'],
#  ['button', 'colorControl'],
#  ['button', 'colorControl'],
#  ['button', 'colorControl'],
#  ['button', 'colorControl'],
#  ['touchSensor', 'switch bulb'],
#  ['touchSensor', 'lock'],
#  ['touchSensor', 'doorControl'],
#  ['app', 'switch bulb'],
#  ['app', 'lock'],
#  ['app', 'doorControl'],
#  ['button', 'sendAction'],
#  ['contact', 'sendAction'],
#  ['acceleration', 'sendAction'],
#  ['motion ', 'sendAction'],
#  ['switch', 'sendAction'],
#  ['presence', 'sendAction'],
#  ['smoke', 'sendAction'],
#  ['water sensor', 'sendAction'],
#  ['contact', 'sendAction'],
#  ['app', 'colorControl'],
#  ['app', 'colorControl'],
#  ['contact', 'colorControl'],
#  ['contact', 'colorControl'],
#  ['acceleration', 'colorControl'],
#  ['acceleration', 'colorControl'],
#  ['motion ', 'colorControl'],
#  ['motion ', 'colorControl'],
#  ['switch', 'colorControl'],
#  ['switch', 'colorControl'],
#  ['presence', 'colorControl'],
#  ['presence', 'colorControl'],
#  ['smoke', 'colorControl'],
#  ['smoke', 'colorControl'],
#  ['water sensor', 'colorControl'],
#  ['water sensor', 'colorControl'],
#  ['button', 'colorControl'],
#  ['button', 'colorControl'],
#  ['time', 'switch bulb'],
#  ['contact', 'imageCapture'],
#  ['contact', 'sendAction'],
#  ['contact', 'sendAction'],
#  ['contact', 'sendAction'],
#  ['acceleration', 'imageCapture'],
#  ['acceleration', 'sendAction'],
#  ['acceleration', 'sendAction'],
#  ['acceleration', 'sendAction'],
#  ['motion ', 'imageCapture'],
#  ['motion ', 'sendAction'],
#  ['motion ', 'sendAction'],
#  ['motion ', 'sendAction'],
#  ['switch', 'imageCapture'],
#  ['switch', 'sendAction'],
#  ['switch', 'sendAction'],
#  ['switch', 'sendAction'],
#  ['presence', 'imageCapture'],
#  ['presence', 'sendAction'],
#  ['presence', 'sendAction'],
#  ['presence', 'sendAction'],
#  ['switch', 'switch bulb'],
#  ['presence', 'sendAction'],
#  ['presence', 'sendAction'],
#  ['presence', 'sendAction'],
#  ['contact', 'sendAction'],
#  ['contact', 'sendAction'],
#  ['presence', 'momentary'],
#  ['presence', 'sendAction'],
#  ['acceleration', 'momentary'],
#  ['contact', 'momentary'],
#  ['motion ', 'sendAction'],
#  ['motion ', 'sendAction'],
#  ['motion ', 'sendAction'],
#  ['motion ', 'locationMode'],
#  ['motion ', 'switch bulb'],
#  ['time', 'locationMode'],
#  ['time', 'sendAction'],
#  ['time', 'sendAction'],
#  ['time', 'sendAction'],
#  ['time', 'sendAction'],
#  ['time', 'sendAction'],
#  ['time', 'sendAction'],
#  ['motion ', 'sendAction'],
#  ['motion ', 'sendAction'],
#  ['motion ', 'sendAction'],
#  ['relative humidity ', 'sendAction'],
#  ['relative humidity ', 'sendAction'],
#  ['relative humidity ', 'switch vent'],
#  ['relative humidity ', 'switch vent'],
#  ['motion ', 'switch bulb'],
#  ['motion ', 'switch bulb'],
#  ['motion ', 'sendAction'],
#  ['motion ', 'locationMode'],
#  ['motion ', 'alarm'],
#  ['motion ', 'sendAction'],
#  ['motion ', 'sendAction'],
#  ['motion ', 'alarm'],
#  ['contact', 'sendAction'],
#  ['contact', 'locationMode'],
#  ['contact', 'alarm'],
#  ['contact', 'sendAction'],
#  ['contact', 'sendAction'],
#  ['contact', 'alarm'],
#  ['alarm', 'alarm'],
#  ['app', 'alarm'],
#  ['device.jawboneUser', 'sendAction'],
#  ['device.jawboneUser', 'music player'],
#  ['device.jawboneUser', 'music player'],
#  ['device.jawboneUser', 'music player'],
#  ['device.jawboneUser', 'music player'],
#  ['device.jawboneUser', 'colorControl'],
#  ['device.jawboneUser', 'colorControl'],
#  ['device.jawboneUser', 'switch bulb'],
#  ['contact', 'sendAction'],
#  ['contact', 'sendAction'],
#  ['motion ', 'sendAction'],
#  ['motion ', 'sendAction'],
#  ['switch', 'switch level'],
#  ['contact', 'flash lights'],
#  ['acceleration', 'flash lights'],
#  ['motion ', 'flash lights'],
#  ['switch', 'flash lights'],
#  ['presence', 'flash lights'],
#  ['acceleration', 'sendAction'],
#  ['acceleration', 'sendAction'],
#  ['contact', 'thermostat'],
#  ['contact', 'thermostat'],
#  ['contact', 'thermostat'],
#  ['smoke', 'thermostat'],
#  ['smoke', 'sendAction'],
#  ['carbon_monoxide', 'thermostat'],
#  ['carbon_monoxide', 'sendAction'],
#  ['contact', 'switch bulb'],
#  ['contact', 'switch bulb'],
#  ['presence', 'switch bulb'],
#  ['presence', 'switch bulb'],
#  ['contact', 'switch air_conditioner'],
#  ['presence', 'switch bulb'],
#  ['presence', 'switch bulb'],
#  ['contact', 'switch bulb'],
#  ['presence', 'sendAction'],
#  ['presence', 'lock'],
#  ['temperature', 'switch air_conditioner'],
#  ['temperature', 'switch air_conditioner'],
#  ['motion ', 'switch air_conditioner'],
#  ['motion ', 'switch air_conditioner'],
#  ['time', 'sendAction'],
#  ['time', 'sendAction'],
#  ['temperature', 'switch air_conditioner'],
#  ['temperature', 'switch air_conditioner'],
#  ['thermostat', 'switch air_conditioner'],
#  ['thermostat', 'switch air_conditioner'],
#  ['contact', 'switch air_conditioner'],
#  ['contact', 'switch air_conditioner']]

# %%
print("total pair trigger-action of system+physical channels:",len(trigger_action_translated))
# Out:
# total pair trigger-action of system+physical channels: 294

# %%
# obviously add the switch dedicated to its own physical channel
if not "switch air_conditioner" in cap_to_channel["temperature"]:
    cap_to_channel["temperature"].append("switch air_conditioner")
    
if not "switch vent" in cap_to_channel["humidity"]:    
    cap_to_channel["humidity"].append("switch vent")
    
if not "switch bulb" in cap_to_channel["illumination"]:      
    cap_to_channel["illumination"].append("switch bulb")

with open("set_of_capability_related_channels.JSON","w") as outfile:
    json.dump(cap_to_channel, outfile)

cap_to_channel
# Out:
# {'temperature': ['thermostat', 'switch air_conditioner'],
#  'humidity': ['relative humidity ', 'temperature', 'switch vent'],
#  'illumination': ['beacon',
#   'illumination',
#   'flash lights',
#   'switch',
#   'switch level',
#   'switch bulb'],
#  'motion': ['acceleration', 'motion '],
#  'location': ['location', 'presence', 'three axis space'],
#  'smoke': ['carbon_monoxide', 'contact', 'smoke'],
#  'leakage': ['valve', 'water sensor'],
#  'sound': ['music player']}

# %% [markdown]
# ## analysis of the number of trigger-capability and action-capability

# %%
phy_dict_actions_related={"temperature":[], "humidity":[], "illumination":[], "location":[],
                          "motion":[], "smoke":[], "leakage":[], "sound":[]}

phy_dict_trigger_related={"temperature":[], "humidity":[], "illumination":[], "location":[],
                          "motion":[], "smoke":[], "leakage":[], "sound":[]}

sys_dict_actions_related={'alarm':[],'app':[],'button':[],'colorControl':[],'device.PetFeederShield':[], 
        'device.jawboneUser':[],'doorControl':[],'imageCapture':[],'lock':[],'locationMode':[],
        'momentary':[],'powerMeter':[],'sendAction':[],'time':[],'touchSensor':[]}

sys_dict_trigger_related={'alarm':[],'app':[],'button':[],'colorControl':[],'device.PetFeederShield':[], 
        'device.jawboneUser':[],'doorControl':[],'imageCapture':[],'lock':[],'locationMode':[],
        'momentary':[],'powerMeter':[],'sendAction':[],'time':[],'touchSensor':[]}

for pair in trigger_action_translated: # check every trigger-action pair of system+physical channels
        trigger_cap = pair[0]
        action_cap = pair[1]
        # save all trigger capability
        if not trigger_cap in list_system_cap: # if trigger cap is about a physical channel
            for phy_channel in phy_dict_trigger_related.keys(): # for every physical channel
                if trigger_cap in cap_to_channel[phy_channel]: # find if there is that trigger capability
                    phy_dict_trigger_related[phy_channel].append(trigger_cap) # and save the trigger capability
        else:
            sys_dict_trigger_related[trigger_cap].append(trigger_cap) # if trigger cap is about a system channel
            
        # save all action capability
        if not action_cap in list_system_cap:  # if action cap is about a physical channel
            for phy_channel in phy_dict_actions_related.keys(): # for every channel
                if action_cap in cap_to_channel[phy_channel]: # find if there is that action capability
                    phy_dict_actions_related[phy_channel].append(action_cap) # if there is save the trigger capability
        else:
            sys_dict_actions_related[action_cap].append(action_cap) # if action cap is about a system channel

# %%
# physical trigger capabilities analysis 
phy_trigger_related = []
for key in phy_dict_trigger_related.keys():
    phy_trigger_related.append(len(phy_dict_trigger_related[key]))
phy_trigger_related = np.array(phy_trigger_related)
phy_trigger_related
# Out:
# array([ 5, 23, 25, 50, 64, 52, 11,  0])

# %%
# physical action capabilities analysis 
phy_actions_related = []
for key in phy_dict_actions_related.keys():
    phy_actions_related.append(len(phy_dict_actions_related[key]))
phy_actions_related = np.array(phy_actions_related)
phy_actions_related
# Out:
# array([39,  6, 53,  0,  0,  0,  1,  4])

# %%
# system trigger capabilities analysis 
sys_trigger_related = []
for key in sys_dict_trigger_related.keys():
    sys_trigger_related.append(len(sys_dict_trigger_related[key]))
sys_trigger_related = np.array(sys_trigger_related)
sys_trigger_related
# Out:
# array([ 1, 15, 10,  0,  0,  8,  0,  0,  0,  0,  0,  4,  0, 23,  3])

# %%
# system action capabilities analysis 
sys_actions_related = []
for key in sys_dict_actions_related.keys():
    sys_actions_related.append(len(sys_dict_actions_related[key]))
sys_actions_related = np.array(sys_actions_related)
sys_actions_related
# Out:
# array([  8,   0,   0,  26,   1,   0,   2,   5,  10,   9,   3,   0, 127,
#          0,   0])

# %%
import matplotlib.pyplot as plt

phy_labels = ["Temperature","Humidity", "Illumination", "Location", "Motion", "Smoke", "Leakage", "Sound"]
sys_labels = list_system_cap

phy_x_pos = np.arange(len(phy_x))
sys_x_pos = np.arange(len(sys_x))


fig, axs = plt.subplots(2, 1, figsize=(15, 15), sharey=True)
fig.suptitle('Trigger-related Channel analysis')

axs[0].bar(phy_labels, phy_trigger_related, align='center')
axs[0].set_xticklabels( phy_labels, rotation=45 )
axs[0].set_ylabel('Amount of interactions')
axs[0].set_xlabel('Channel type')

axs[1].bar(sys_labels, sys_trigger_related, align='center')
axs[1].set_xticklabels( sys_labels, rotation=45 )
axs[1].set_ylabel('Amount of interactions')
axs[1].set_xlabel('Channel type')

plt.show()
# Out:
# <ipython-input-80-c6194b4250fc>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_xticklabels( phy_labels, rotation=45 )
# <ipython-input-80-c6194b4250fc>:19: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_xticklabels( sys_labels, rotation=45 )

# %%
phy_labels = ["Temperature","Humidity", "Illumination", "Location", "Motion", "Smoke", "Leakage", "Sound"]
sys_labels = list_system_cap

phy_x_pos = np.arange(len(phy_x))
sys_x_pos = np.arange(len(sys_x))


fig, axs = plt.subplots(2, 1, figsize=(15, 15), sharey=True)
fig.suptitle('Action-related Channel analysis')

axs[0].bar(phy_labels, phy_actions_related, align='center')
axs[0].set_xticklabels( phy_labels, rotation=45 )
axs[0].set_ylabel('Amount of interactions')
axs[0].set_xlabel('Channel type')

axs[1].bar(sys_labels, sys_actions_related, align='center')
axs[1].set_xticklabels( sys_labels, rotation=45 )
axs[1].set_ylabel('Amount of interactions')
axs[1].set_xlabel('Channel type')

plt.show()
# Out:
# <ipython-input-81-bc423ba2356b>:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_xticklabels( phy_labels, rotation=45 )
# <ipython-input-81-bc423ba2356b>:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_xticklabels( sys_labels, rotation=45 )
