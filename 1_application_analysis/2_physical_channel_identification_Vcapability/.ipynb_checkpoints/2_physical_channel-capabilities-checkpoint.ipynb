# %% [markdown]
# ## this python script create the correlation between trigger capablity and physical channels

# %%
from gensim.models import Word2Vec, KeyedVectors 
import json   # for read the JSON file
import stanza # Official Stanford NLP Python Library for Many Human Languages
import re 
import numpy as np

# %%
file = open("trigger-action_FINAL.JSON","r") # read all the capability extrapolated from the apps
trigger_action = json.load(file)
print("tot app analysed:",len(trigger_action.keys()))
# Out:
# tot app analysed: 84

# %%
file = open("app-description.JSON","r") # need the desription of the analysed apps
app_description = json.load(file)

# %%
# as wrote in the paper "In the end, we check each cluster’s representative keyword and remove
# non-physical-channel related keywords." (cap 4.2 - p 835) so modify and use cluster_pysical_channels_FINAL
file = open("cluster_pysical_channels_NEW_VERSION.JSON","r") 
dict_physical_channels = json.load(file)
dict_physical_channels
# Out:
# {'temperature': ['air_conditioner',
#   'heater',
#   'sensor',
#   'sensors',
#   'thermostat',
#   'ventilation',
#   'water',
#   'weather',
#   'temperature'],
#  'humidity': ['Weather',
#   'air_conditioner',
#   'moisture',
#   'thermostat',
#   'ventilation',
#   'weather',
#   'humidity'],
#  'illumination': ['LED',
#   'appliances',
#   'brightness',
#   'bulbs',
#   'camera',
#   'cameras',
#   'candle',
#   'colors',
#   'light',
#   'lighting',
#   'switch',
#   'switches',
#   'lights'],
#  'motion': ['Motion', 'action', 'motion'],
#  'location': ['area', 'place', 'location'],
#  'smoke': ['ambient',
#   'fire',
#   'heater',
#   'leaks',
#   'moisture',
#   'carbon_monoxide'],
#  'leakage': ['SMS',
#   'chat',
#   'mail',
#   'mailbox',
#   'message',
#   'notification',
#   'notifications',
#   'phone',
#   'pictures',
#   'text',
#   'messages'],
#  'time': ['amount',
#   'anytime',
#   'day',
#   'days',
#   'hour',
#   'minutes',
#   'period',
#   'place',
#   'times',
#   'week',
#   'time'],
#  'locationMode': ['location', 'mode'],
#  'lock': ['door', 'doors', 'lever', 'push', 'lock']}

# %%
stanza.download('en')       # This downloads the English models for the neural pipeline
nlp = stanza.Pipeline('en') # This sets up a default neural pipeline in English
model = KeyedVectors.load_word2vec_format('/home/volta/Documenti/CCS18_CS/word2vec/GoogleNews-vectors-negative300.bin', binary=True, limit=100000) # load word2vec pre-trained
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.2.2.json:   0%|   …
# 2021-09-29 10:08:54 INFO: Downloading default packages for language: en (English)...
# 2021-09-29 10:08:55 INFO: File exists: /home/volta/stanza_resources/en/default.zip.
# 2021-09-29 10:09:01 INFO: Finished downloading models and saved to /home/volta/stanza_resources.
# 2021-09-29 10:09:01 INFO: Loading these models for language: en (English):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | combined  |
# | pos       | combined  |
# | lemma     | combined  |
# | depparse  | combined  |
# | sentiment | sstplus   |
# | ner       | ontonotes |
# =========================
#
# 2021-09-29 10:09:01 INFO: Use device: cpu
# 2021-09-29 10:09:01 INFO: Loading: tokenize
# 2021-09-29 10:09:01 INFO: Loading: pos
# 2021-09-29 10:09:01 INFO: Loading: lemma
# 2021-09-29 10:09:01 INFO: Loading: depparse
# 2021-09-29 10:09:01 INFO: Loading: sentiment
# 2021-09-29 10:09:02 INFO: Loading: ner
# 2021-09-29 10:09:02 INFO: Done loading processors!

# %%
list_all_capabilities = []
for app in trigger_action.keys():         # for every app analysed
    for trigger_cap in trigger_action[app].keys():      # for every trigger channel of that app
            for action in trigger_action[app][trigger_cap]: # for every action 
                action_cap = action[0]
                if not trigger_cap in list_all_capabilities: # if not duplicate
                    list_all_capabilities.append(trigger_cap)
                if not action_cap in list_all_capabilities:
                    list_all_capabilities.append(action_cap)

list_all_capabilities.sort()
list_all_capabilities
# Out:
# ['capability.accelerationSensor',
#  'capability.alarm',
#  'capability.app',
#  'capability.beacon',
#  'capability.button',
#  'capability.carbonMonoxideDetector',
#  'capability.colorControl',
#  'capability.contactSensor',
#  'capability.doorControl',
#  'capability.illuminanceMeasurement',
#  'capability.imageCapture',
#  'capability.location',
#  'capability.lock',
#  'capability.momentary',
#  'capability.motionSensor',
#  'capability.powerMeter',
#  'capability.presenceSensor',
#  'capability.relativeHumidityMeasurement',
#  'capability.smokeDetector',
#  'capability.switch',
#  'capability.switchLevel',
#  'capability.temperatureMeasurement',
#  'capability.thermostat',
#  'capability.threeAxis',
#  'capability.touchSensor',
#  'capability.valve',
#  'capability.waterSensor',
#  'device.PetFeederShield',
#  'locationMode',
#  'number',
#  'sendAction',
#  'time']

# %%
# function that map the capability to string
def cap2string(capability):
    switcher = {
        'capability.accelerationSensor': "acceleration",
        'capability.alarm': "alarm",
        'capability.app': "app",
        'capability.beacon': "beacon",
        'capability.button': "button",
        'capability.carbonMonoxideDetector': "carbon_monoxide",
        'capability.colorControl': "color",
        'capability.contactSensor': "contact",
        'capability.doorControl': "door",
        'capability.illuminanceMeasurement':"illumination ",
        'capability.imageCapture': "image capture",
        'capability.location':"location",
        'capability.lock':"lock",
        'capability.momentary': "momentary",
        'capability.motionSensor':"motion ",
        'capability.powerMeter':"power",
        'capability.presenceSensor': "presence",
        'capability.relativeHumidityMeasurement': "relative humidity ",
        'capability.smokeDetector': "smoke",
        'capability.switch': "switch",
        'capability.switchLevel': "switch level",
        'capability.temperatureMeasurement':"temperature",
        'capability.thermostat': "thermostat",
        'capability.threeAxis':"three axis",
        'capability.touchSensor':"touch",
        'capability.valve':"valve",
        'capability.waterSensor':"water",
        'device.PetFeederShield':"pet feeder shield",
        'locationMode':"location mode",
        'number': "number",
        'sendAction':"send action",
        'time':"time"
    }
    return switcher.get(capability, f"capabliti not found: {capability}")

# %%
list_string_capabilities = []
for cap in list_all_capabilities:
    list_string_capabilities.append(cap2string(cap))
    
list_string_capabilities
# Out:
# ['acceleration',
#  'alarm',
#  'app',
#  'beacon',
#  'button',
#  'carbon_monoxide',
#  'color',
#  'contact',
#  'door',
#  'illumination ',
#  'image capture',
#  'location',
#  'lock',
#  'momentary',
#  'motion ',
#  'power',
#  'presence',
#  'relative humidity ',
#  'smoke',
#  'switch',
#  'switch level',
#  'temperature',
#  'thermostat',
#  'three axis',
#  'touch',
#  'valve',
#  'water',
#  'pet feeder shield',
#  'location mode',
#  'number',
#  'send action',
#  'time']

# %%
words_pattern = '[a-zA-Z_]+'
cap_to_physical_channel = {"temperature":[], "humidity":[], "illumination":[], "motion":[], "location":[], 
                           "smoke":[], "leakage":[], "time":[], "locationMode":[], "lock":[]}

for cap in list_string_capabilities: # analyse every cap
    keywords = [] # keywords found inside app capability
    keywords = re.findall(words_pattern, cap, flags=re.IGNORECASE) # extrapolate the word from capability
    print(keywords)
    
    clean_keywords = [] # find what words can be really processed by word2vec
    for i in range(len(keywords)):                   # for every keyword exstracted
        try:
            model[keywords[i]]                       # check Word2Vec
            clean_keywords.append(keywords[i])       # if can apply word2vec save it
        except KeyError as err:
            print("handling Error: ", err)           # some words can not be processed by Word2Vec

    print(cap,"-", clean_keywords)        
    
    similarity_list = {} # list made by 
    if len(clean_keywords) == 0: # case there aren't any NN keyword inside that app description (strange)
        print(f"error!!")

    else:
        if len(clean_keywords) == 1: # case there are only 1 keyword inside capability
            for key in dict_physical_channels.keys(): # check for every physical channel
                similarity_temp = 0
                for channel_NN in dict_physical_channels[key]: # for every keyword inside the channel cluster
                    similarity_temp += model.similarity(clean_keywords[0],channel_NN)
                # divide by the number of cluster keywords --> result: the mean of similarity
                similarity_list[key] = (similarity_temp/len(dict_physical_channels[key]))*100

        else: # case there are more than 1 keyword inside tcapability
            for key in dict_physical_channels.keys(): # check for every physical channel
                similarity_partial = 0
                for keyword in clean_keywords: # for every keyword NN extracted from description
                    similarity_temp = 0
                    for channel_NN in dict_physical_channels[key]:  # for every keyword inside the channel cluster
                        #print(keyword,channel_NN,"\t", model.similarity(keyword,channel_NN))
                        similarity_temp += model.similarity(keyword,channel_NN)
                     # divide by the number of cluster keywords --> result: the mean of similarity (given by only 1 NN)
                    similarity_temp = similarity_temp/len(dict_physical_channels[key])
                    similarity_partial += similarity_temp
                #print("this keyword for ",key,"has got a level", similarity_partial/len(clean_keywords))
                similarity_list[key] = (similarity_partial/len(clean_keywords))*100
        
        print(similarity_list)
        # now find the highest physical channel association 
        channel_association = ""
        max_value = 0
        for physical_channel in similarity_list.keys():
            if (similarity_list[physical_channel] > max_value):
                max_value = similarity_list[physical_channel]
                channel_association = physical_channel
                
        print("most similar:", channel_association, max_value, "\n")
        cap_to_physical_channel[channel_association].append(cap)

cap_to_physical_channel
# Out:
# ['acceleration']
# acceleration - ['acceleration']
# {'temperature': 14.402317918009228, 'humidity': 10.788692640406746, 'illumination': 11.011040651311095, 'motion': 18.738453090190887, 'location': 3.843489723900954, 'smoke': 11.546409192184608, 'leakage': 4.690031529488889, 'time': 10.315930453891104, 'locationMode': 13.713190518319607, 'lock': 13.48956348374486}
# most similar: motion 18.738453090190887
#
# ['alarm']
# alarm - ['alarm']
# {'temperature': 23.916613227791256, 'humidity': 20.151226541825704, 'illumination': 19.0124393082582, 'motion': 4.248584799158076, 'location': 8.010678365826607, 'smoke': 22.299601261814438, 'leakage': 14.576887271621011, 'time': 5.714066550585399, 'locationMode': 11.390898749232292, 'lock': 18.920034766197205}
# most similar: temperature 23.916613227791256
#
# ['app']
# app - ['app']
# {'temperature': 10.86615519080725, 'humidity': 10.405267242874418, 'illumination': 9.858510851000364, 'motion': 9.863258711993694, 'location': 13.752645999193192, 'smoke': 8.002922746042412, 'leakage': 22.64838977293535, 'time': 10.667778619311074, 'locationMode': 23.382367193698883, 'lock': 7.16662771999836}
# most similar: locationMode 23.382367193698883
#
# ['beacon']
# beacon - ['beacon']
# {'temperature': 11.874983997808561, 'humidity': 8.8705163449049, 'illumination': 19.669464846643116, 'motion': 1.7026897209386032, 'location': 13.700144986311594, 'smoke': 7.745113410055637, 'leakage': 9.730925896755336, 'time': 2.5572560431266376, 'locationMode': 14.448393508791924, 'lock': 10.332696214318275}
# most similar: illumination 19.669464846643116
#
# ['button']
# button - ['button']
# {'temperature': 18.470320933394962, 'humidity': 14.72005280000823, 'illumination': 20.551312829439457, 'motion': 6.572883700331052, 'location': 5.731289849306146, 'smoke': 9.219066829731066, 'leakage': 20.341659134084527, 'time': 9.844772369516166, 'locationMode': 26.380472630262375, 'lock': 27.28810518980026}
# most similar: lock 27.28810518980026
#
# ['carbon_monoxide']
# carbon_monoxide - ['carbon_monoxide']
# {'temperature': 31.798118352890015, 'humidity': 31.396796660763876, 'illumination': 13.78901545674755, 'motion': 1.9965887690583866, 'location': 8.987294510006905, 'smoke': 44.7825367252032, 'leakage': 10.039287602359598, 'time': 6.751353530721231, 'locationMode': 6.996669992804527, 'lock': 7.457877174019814}
# most similar: smoke 44.7825367252032
#
# ['color']
# color - ['color']
# {'temperature': 13.801273165477646, 'humidity': 14.61088987333434, 'illumination': 27.412475215700955, 'motion': 6.7381078998247785, 'location': 9.681073452035587, 'smoke': 9.707994914303224, 'leakage': 9.394411471757023, 'time': 5.955278859685429, 'locationMode': 16.91184490919113, 'lock': 3.2682619616389275}
# most similar: illumination 27.412475215700955
#
# ['contact']
# contact - ['contact']
# {'temperature': 7.773444780872928, 'humidity': 6.531719743673291, 'illumination': 5.469046074610491, 'motion': 7.468844950199127, 'location': 11.818157757321995, 'smoke': 8.819155403762124, 'leakage': 19.61002485318617, 'time': 4.7318451275879685, 'locationMode': 9.464890381786972, 'lock': 10.756528973579407}
# most similar: leakage 19.61002485318617
#
# ['door']
# door - ['door']
# {'temperature': 13.185724222825634, 'humidity': 11.20960692475949, 'illumination': 9.013057786684769, 'motion': 0.9464734544356664, 'location': 9.522317846616108, 'smoke': 11.954380447665852, 'leakage': 16.897702623497356, 'time': 11.5384425629269, 'locationMode': 10.514091327786446, 'lock': 51.21033012866973}
# most similar: lock 51.21033012866973
#
# ['illumination']
# illumination  - ['illumination']
# {'temperature': 26.06869422727161, 'humidity': 21.406483543770655, 'illumination': 38.84427816821979, 'motion': 7.306933278838794, 'location': 9.23720436791579, 'smoke': 21.322502071658768, 'leakage': 6.535966838286682, 'time': 2.3576736720067193, 'locationMode': 18.199537694454193, 'lock': 1.6141549963504076}
# most similar: illumination 38.84427816821979
#
# ['image', 'capture']
# image capture - ['image', 'capture']
# {'temperature': 6.67714055808675, 'humidity': 4.989405480279986, 'illumination': 13.098083893195367, 'motion': 9.781158963839214, 'location': 12.001813016831875, 'smoke': 5.40971711355572, 'leakage': 11.43338792026043, 'time': 4.039358075665818, 'locationMode': 15.75328465551138, 'lock': 6.236558910459281}
# most similar: locationMode 15.75328465551138
#
# ['location']
# location - ['location']
# {'temperature': 16.3348993493451, 'humidity': 14.419951077018464, 'illumination': 9.055554250685068, 'motion': 5.833206449945768, 'location': 59.65882142384847, 'smoke': 11.37789177397887, 'leakage': 14.585140076550571, 'time': 14.36493064869534, 'locationMode': 54.88940477371216, 'lock': 8.960800133645535}
# most similar: location 59.65882142384847
#
# ['lock']
# lock - ['lock']
# {'temperature': 10.733505255646175, 'humidity': 9.84889077288764, 'illumination': 9.35201165624536, 'motion': 4.575514669219652, 'location': 11.026642844080925, 'smoke': 7.802437990903854, 'leakage': 8.622949587350542, 'time': 8.862581849098206, 'locationMode': 13.839195668697357, 'lock': 47.21677839756012}
# most similar: lock 47.21677839756012
#
# ['momentary']
# momentary - ['momentary']
# {'temperature': 9.317202493548393, 'humidity': 5.545644994292941, 'illumination': 14.816198870539665, 'motion': 10.405807942152023, 'location': 1.6143148764967918, 'smoke': 7.5896175267795725, 'leakage': 4.871608757159927, 'time': 11.398976330052722, 'locationMode': 10.013522394001484, 'lock': 6.961417384445667}
# most similar: illumination 14.816198870539665
#
# ['motion']
# motion  - ['motion']
# {'temperature': 11.45795171873437, 'humidity': 6.13403101451695, 'illumination': 13.125654610876852, 'motion': 61.31342649459839, 'location': 2.179054853816827, 'smoke': 6.35705462967356, 'leakage': 7.609359149567106, 'time': 4.369432182813233, 'locationMode': 16.526607796549797, 'lock': 7.227906882762909}
# most similar: motion 61.31342649459839
#
# ['power']
# power - ['power']
# {'temperature': 14.446889691882664, 'humidity': 11.597188402499471, 'illumination': 16.020417113143665, 'motion': 7.046828729410966, 'location': 6.562451211114724, 'smoke': 11.200815935929615, 'leakage': 4.288867267314345, 'time': 9.62824174626307, 'locationMode': 9.291708748787642, 'lock': 11.941937729716301}
# most similar: illumination 16.020417113143665
#
# ['presence']
# presence - ['presence']
# {'temperature': 1.1260381844800171, 'humidity': 4.69043800964885, 'illumination': 6.28391786191899, 'motion': 6.4244322789212065, 'location': 17.647618800401688, 'smoke': 5.977737593154112, 'leakage': 6.924895044754852, 'time': 3.5035073100351095, 'locationMode': 8.82914699614048, 'lock': 6.840304005891085}
# most similar: location 17.647618800401688
#
# ['relative', 'humidity']
# relative humidity  - ['relative', 'humidity']
# {'temperature': 20.68211038260617, 'humidity': 28.221370028664495, 'illumination': 10.150370061791573, 'motion': 2.2902588942088187, 'location': 12.38649288813273, 'smoke': 19.369759162267048, 'leakage': 4.626055400479923, 'time': 9.658305956558747, 'locationMode': 9.94157218374312, 'lock': 5.2372297178953895}
# most similar: humidity 28.221370028664495
#
# ['smoke']
# smoke - ['smoke']
# {'temperature': 18.25285760892762, 'humidity': 20.92115581035614, 'illumination': 14.32417745773609, 'motion': 6.482925762732823, 'location': 9.705692778031032, 'smoke': 30.387601504723232, 'leakage': 11.120569096370177, 'time': 6.06484672435644, 'locationMode': 1.0573692619800568, 'lock': 12.810958102345465}
# most similar: smoke 30.387601504723232
#
# ['switch']
# switch - ['switch']
# {'temperature': 13.048788615398937, 'humidity': 9.619501233100891, 'illumination': 27.541080117225647, 'motion': 12.033340148627758, 'location': 4.142117422694961, 'smoke': 7.186374580487609, 'leakage': 9.080338342623277, 'time': 5.737636730455878, 'locationMode': 15.632269904017448, 'lock': 21.98973000049591}
# most similar: illumination 27.541080117225647
#
# ['switch', 'level']
# switch level - ['switch', 'level']
# {'temperature': 10.438770928885788, 'humidity': 8.371901936230383, 'illumination': 17.305436429495995, 'motion': 10.379326588008553, 'location': 9.38231407199055, 'smoke': 7.606571144424379, 'leakage': 5.918276438023895, 'time': 12.300111260794273, 'locationMode': 16.087515279650688, 'lock': 16.89978025853634}
# most similar: illumination 17.305436429495995
#
# ['temperature']
# temperature - ['temperature']
# {'temperature': 45.99171015951369, 'humidity': 44.56449789660318, 'illumination': 19.218537211418152, 'motion': 7.301681116223335, 'location': 13.487208386262258, 'smoke': 32.08524758617084, 'leakage': 4.698701118203727, 'time': 10.292984172701836, 'locationMode': 17.848211526870728, 'lock': 6.3550940528512}
# most similar: temperature 45.99171015951369
#
# ['thermostat']
# thermostat - ['thermostat']
# {'temperature': 45.341289871268806, 'humidity': 42.07192999976022, 'illumination': 27.10818252884425, 'motion': 5.5100902294119205, 'location': 0.7684259365002315, 'smoke': 27.602084974447887, 'leakage': 10.80709353766658, 'time': 5.627157852392306, 'locationMode': 15.35276509821415, 'lock': 19.17321801185608}
# most similar: temperature 45.341289871268806
#
# ['three', 'axis']
# three axis - ['three', 'axis']
# {'temperature': 7.017031715561946, 'humidity': 4.644024960829744, 'illumination': 8.598765734439858, 'motion': 8.41986114780108, 'location': 8.032209115723768, 'smoke': 2.72566209314391, 'leakage': 3.7351503862406723, 'time': 11.625044702139514, 'locationMode': 10.496157314628363, 'lock': 9.319486666936427}
# most similar: time 11.625044702139514
#
# ['touch']
# touch - ['touch']
# {'temperature': 9.627321196926966, 'humidity': 10.583726636001042, 'illumination': 15.995747596025467, 'motion': 12.038593242565792, 'location': 11.739627520243328, 'smoke': 7.893592119216919, 'leakage': 18.613477118990637, 'time': 9.835802081347952, 'locationMode': 14.597614109516144, 'lock': 19.03079703450203}
# most similar: lock 19.03079703450203
#
# ['valve']
# valve - ['valve']
# {'temperature': 31.77891986237632, 'humidity': 22.368090307073935, 'illumination': 12.95920339627908, 'motion': 3.6311084404587746, 'location': 4.592155354718367, 'smoke': 25.906493763128918, 'leakage': 4.248210419477387, 'time': 2.5843444936485453, 'locationMode': 10.423966683447361, 'lock': 22.959496825933456}
# most similar: temperature 31.77891986237632
#
# ['water']
# water - ['water']
# {'temperature': 32.665176855193245, 'humidity': 26.25866936785834, 'illumination': 13.169669976028112, 'motion': 5.998598039150238, 'location': 16.875251134236656, 'smoke': 25.835391382376354, 'leakage': 8.176479827273976, 'time': 10.418342798948288, 'locationMode': 8.858033269643784, 'lock': 6.37243039906025}
# most similar: temperature 32.665176855193245
#
# ['pet', 'feeder', 'shield']
# pet feeder shield - ['pet', 'feeder', 'shield']
# {'temperature': 11.117365744171872, 'humidity': 9.356127189294924, 'illumination': 8.777862401732888, 'motion': 4.386258329355366, 'location': 10.624149524503284, 'smoke': 7.278997823919377, 'leakage': 5.752460085292997, 'time': 3.33923721989391, 'locationMode': 7.882325027215605, 'lock': 12.212030465404194}
# most similar: lock 12.212030465404194
#
# ['location', 'mode']
# location mode - ['location', 'mode']
# {'temperature': 14.640750446253353, 'humidity': 11.886519047298602, 'illumination': 12.764584072507345, 'motion': 13.328862128158411, 'location': 34.47571011881034, 'smoke': 9.361624118173495, 'leakage': 14.075654203241522, 'time': 14.010370878333395, 'locationMode': 54.88940477371216, 'lock': 11.585812401026487}
# most similar: locationMode 54.88940477371216
#
# ['number']
# number - ['number']
# {'temperature': 4.186232512195906, 'humidity': 4.954561870545149, 'illumination': 5.017600466425602, 'motion': 4.25289993484815, 'location': 15.554291506608328, 'smoke': 2.368131171291073, 'leakage': 12.703526426445356, 'time': 14.067548047751188, 'locationMode': 9.298316412605345, 'lock': 7.590525150299072}
# most similar: location 15.554291506608328
#
# ['send', 'action']
# send action - ['send', 'action']
# {'temperature': 4.302147605145971, 'humidity': 4.691306448408536, 'illumination': 5.337654199236288, 'motion': 28.140084259212017, 'location': 12.800552695989609, 'smoke': 3.008850283610324, 'leakage': 16.39025809920647, 'time': 10.9144349667159, 'locationMode': 10.126383928582072, 'lock': 9.266257870476693}
# most similar: motion 28.140084259212017
#
# ['time']
# time - ['time']
# {'temperature': 8.904805986417665, 'humidity': 7.971232810190745, 'illumination': 7.978642739069003, 'motion': 9.782553060601156, 'location': 24.665712316830955, 'smoke': 4.233468417078257, 'leakage': 6.858826157721606, 'time': 46.94936004551975, 'locationMode': 18.648989498615265, 'lock': 8.670111894607544}
# most similar: time 46.94936004551975
# {'temperature': ['alarm', 'temperature', 'thermostat', 'valve', 'water'],
#  'humidity': ['relative humidity '],
#  'illumination': ['beacon',
#   'color',
#   'illumination ',
#   'momentary',
#   'power',
#   'switch',
#   'switch level'],
#  'motion': ['acceleration', 'motion ', 'send action'],
#  'location': ['location', 'presence', 'number'],
#  'smoke': ['carbon_monoxide', 'smoke'],
#  'leakage': ['contact'],
#  'time': ['three axis', 'time'],
#  'locationMode': ['app', 'image capture', 'location mode'],
#  'lock': ['button', 'door', 'lock', 'touch', 'pet feeder shield']}

# %%
cap_to_physical_channel
# Out:
# {'temperature': ['alarm', 'temperature', 'thermostat', 'valve', 'water'],
#  'humidity': ['relative humidity '],
#  'illumination': ['beacon',
#   'color',
#   'illumination ',
#   'momentary',
#   'power',
#   'switch',
#   'switch level'],
#  'motion': ['acceleration', 'motion ', 'send action'],
#  'location': ['location', 'presence', 'number'],
#  'smoke': ['carbon_monoxide', 'smoke'],
#  'leakage': ['contact'],
#  'time': ['three axis', 'time'],
#  'locationMode': ['app', 'image capture', 'location mode'],
#  'lock': ['button', 'door', 'lock', 'touch', 'pet feeder shield']}

# %%
with open("set_of_capability_related_physical_channels.JSON","w") as outfile:
    json.dump(cap_to_physical_channel, outfile)

# %% [markdown]
# ## analysis of the number of trigger-capability and action-capability

# %%
dict_actions_related={"temperature":[], "humidity":[], "illumination":[], "location":[],
                          "motion":[], "smoke":[], "leakage":[], "time":[], "locationMode":[], "lock":[]}
dict_trigger_related={"temperature":[], "humidity":[], "illumination":[], "location":[],
                          "motion":[], "smoke":[], "leakage":[], "time":[], "locationMode":[], "lock":[]}
                
for app in trigger_action.keys(): # for every app where I can extrapolate info
    for trigger_cap in trigger_action[app].keys(): # for every app trigger capability
        # now I search all action capabilities
        for actions in trigger_action[app][trigger_cap]: # for every action correlated to that trigger capability
            string_action_capability = cap2string(actions[0]) # save the action capability and convert it to string
            # save the action capability
            for channel in cap_to_physical_channel.keys(): # for every physical channel
                if string_action_capability in cap_to_physical_channel[channel]: # find if there is that action capability
                    dict_actions_related[channel].append(string_action_capability) # if there is save the action capability 
        
        # save all trigger capability
        string_trigger_capability = cap2string(trigger_cap)
        for channel in cap_to_physical_channel.keys(): # for every physical channel
            if string_trigger_capability in cap_to_physical_channel[channel]: # find if there is that action capability
                    dict_trigger_related[channel].append(string_trigger_capability) # if there is save the action capability 
        
dict_trigger_related
# Out:
# {'temperature': ['water',
#   'water',
#   'water',
#   'temperature',
#   'temperature',
#   'thermostat',
#   'temperature',
#   'thermostat',
#   'alarm',
#   'temperature',
#   'temperature',
#   'thermostat'],
#  'humidity': ['relative humidity ', 'relative humidity '],
#  'illumination': ['beacon',
#   'switch',
#   'power',
#   'power',
#   'switch',
#   'switch',
#   'illumination ',
#   'switch',
#   'switch',
#   'switch',
#   'switch'],
#  'location': ['location',
#   'location',
#   'presence',
#   'presence',
#   'presence',
#   'presence',
#   'location',
#   'presence',
#   'location',
#   'location',
#   'presence',
#   'location',
#   'presence',
#   'presence',
#   'presence',
#   'presence',
#   'location',
#   'location',
#   'presence',
#   'presence',
#   'presence',
#   'presence'],
#  'motion': ['motion ',
#   'motion ',
#   'motion ',
#   'motion ',
#   'motion ',
#   'motion ',
#   'acceleration',
#   'acceleration',
#   'motion ',
#   'acceleration',
#   'acceleration',
#   'motion ',
#   'acceleration',
#   'motion ',
#   'motion ',
#   'motion ',
#   'motion ',
#   'motion ',
#   'acceleration',
#   'motion ',
#   'acceleration',
#   'motion '],
#  'smoke': ['smoke', 'carbon_monoxide'],
#  'leakage': ['contact',
#   'contact',
#   'contact',
#   'contact',
#   'contact',
#   'contact',
#   'contact',
#   'contact',
#   'contact',
#   'contact',
#   'contact',
#   'contact',
#   'contact',
#   'contact',
#   'contact',
#   'contact',
#   'contact',
#   'contact',
#   'contact'],
#  'time': ['time',
#   'time',
#   'time',
#   'three axis',
#   'time',
#   'time',
#   'time',
#   'time',
#   'time',
#   'time',
#   'time',
#   'time'],
#  'locationMode': ['app', 'app', 'app', 'app', 'app', 'app', 'app'],
#  'lock': ['button', 'button', 'touch']}

# %%
dict_actions_related
# Out:
# {'temperature': ['valve',
#   'alarm',
#   'alarm',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'alarm',
#   'alarm',
#   'alarm',
#   'alarm',
#   'alarm',
#   'alarm',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat'],
#  'humidity': [],
#  'illumination': ['switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'color',
#   'color',
#   'color',
#   'color',
#   'color',
#   'color',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'momentary',
#   'momentary',
#   'momentary',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch level',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch'],
#  'location': ['number', 'number', 'number', 'number', 'number'],
#  'motion': ['send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action',
#   'send action'],
#  'smoke': [],
#  'leakage': [],
#  'time': [],
#  'locationMode': ['location mode',
#   'location mode',
#   'location mode',
#   'location mode',
#   'location mode',
#   'image capture',
#   'image capture',
#   'image capture',
#   'image capture',
#   'image capture',
#   'location mode',
#   'location mode',
#   'location mode',
#   'location mode'],
#  'lock': ['lock',
#   'lock',
#   'pet feeder shield',
#   'lock',
#   'lock',
#   'lock',
#   'lock',
#   'lock',
#   'lock',
#   'door',
#   'lock',
#   'door',
#   'lock']}

# %%
action_related = []
for key in dict_actions_related.keys():
    action_related.append(len(dict_actions_related[key]))
action_related = np.array(action_related)
action_related
# Out:
# array([ 31,   0,  82,   5, 118,   0,   0,   0,  14,  13])

# %%
trigger_related = []
for key in dict_trigger_related.keys():
    trigger_related.append(len(dict_trigger_related[key]))
trigger_related = np.array(trigger_related)
trigger_related
# Out:
# array([12,  2, 11, 22, 22,  2, 19, 12,  7,  3])

# %%
import matplotlib.pyplot as plt

x = ["Temperature","Humidity", "Illumination", "Location", "Motion", "Smoke", "Leakage", "Time", "LocationMode", "Lock"]
x_pos = np.arange(len(x))
plt.figure(figsize=[15, 5])
plt.bar(x_pos, trigger_related, align='center')
plt.xticks(x_pos, x)
plt.ylabel('Amount of interactions')
plt.xlabel('Channel type')
plt.title('Trigger-related Channel analysis')
plt.show()

# %%
x_pos = np.arange(len(x))
plt.figure(figsize=[15, 5])
plt.bar(x_pos, action_related, align='center')
plt.xticks(x_pos, x)
plt.ylabel('Amount of interactions')
plt.xlabel('Channel type')
plt.title('Action-related Channel analysis')
plt.show()
