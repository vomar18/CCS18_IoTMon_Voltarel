# %% [markdown]
# ## creation of the correlation between trigger capablity and physical channels - tab. 3
#
# **This approach is based on the fact that from every app description is always possible to extrapolate the physical channel which the smartapp is trigger on.**
#
# possible problems:
# 1. what happens if is not possible to extrapolate a physical channel from Samsung smartapp description?
# 2. if a smartapp has too many trigger capabilities, are they all correlated to only one physical channel?
#
# evolution:
# 1. save every pair of trigger-action and every smart app description
# 2. save the cluster of every channel
# 3. extrapolate from the description the physical channel which the app is trigger on, so creation of the correlation between smartapp<-->channel
# 4. save for every smartapp, all the trigger capability to smartapp's channel

# %%
from gensim.models import Word2Vec, KeyedVectors 
import json   # for read the JSON file
import stanza # Official Stanford NLP Python Library for Many Human Languages
import numpy as np

# %%
file = open("../../1_Intra_app_Analysis/trigger-action.JSON","r") # read all the capability extrapolated from the apps
trigger_action = json.load(file)
print("tot app analysed:",len(trigger_action.keys()))
# Out:
# tot app analysed: 86

# %%
file = open("../../1_Intra_app_Analysis/app-description.JSON","r") # need the desription of the analysed apps
app_description = json.load(file)

# %%
# as wrote in the paper "In the end, we check each cluster’s representative keyword and remove
# non-physical-channel related keywords." (cap 4.2 - p 835) so modify and use cluster_pysical_channels_FINAL
file = open("../cluster_channels.JSON","r") 
dict_channels = json.load(file)
dict_channels
# Out:
# {'temperature': ['air_conditioner',
#   'ambient',
#   'brightness',
#   'carbon_monoxide',
#   'heater',
#   'humidity',
#   'moisture',
#   'sensor',
#   'sensors',
#   'temp',
#   'thermostat',
#   'ventilation',
#   'water',
#   'weather',
#   'temperature'],
#  'humidity': ['air_conditioner',
#   'ambient',
#   'brightness',
#   'carbon_monoxide',
#   'moisture',
#   'temperature',
#   'thermostat',
#   'ventilation',
#   'weather',
#   'humidity'],
#  'illumination': ['air_conditioner',
#   'alarm',
#   'appliances',
#   'brightness',
#   'bulbs',
#   'cameras',
#   'candle',
#   'colors',
#   'heater',
#   'light',
#   'lighting',
#   'sirens',
#   'switch',
#   'switches',
#   'thermostat',
#   'lights'],
#  'motion': ['action', 'motion'],
#  'location': ['area', 'hub', 'place', 'location'],
#  'smoke': ['air_conditioner',
#   'ambient',
#   'fire',
#   'heater',
#   'humidity',
#   'leaks',
#   'moisture',
#   'temperature',
#   'thermostat',
#   'ventilation',
#   'carbon_monoxide'],
#  'leakage': ['air_conditioner',
#   'device',
#   'heater',
#   'leaks',
#   'lever',
#   'sensor',
#   'sensors',
#   'switches',
#   'thermostat',
#   'ventilation',
#   'valve'],
#  'time': ['amount',
#   'anytime',
#   'day',
#   'days',
#   'hour',
#   'minutes',
#   'period',
#   'place',
#   'times',
#   'week',
#   'time'],
#  'locationMode': ['location', 'mode'],
#  'lock': ['door', 'doors', 'lever', 'push', 'turn', 'lock']}

# %%
stanza.download('en')       # This downloads the English models for the neural pipeline
nlp = stanza.Pipeline('en') # This sets up a default neural pipeline in English
model = KeyedVectors.load_word2vec_format('../../../../GoogleNews-vectors-negative300.bin', binary=True, limit=100000) # load word2vec pre-trained
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.2.2.json:   0%|   …
# 2021-10-05 12:41:57 INFO: Downloading default packages for language: en (English)...
# 2021-10-05 12:42:00 INFO: File exists: /home/volta/stanza_resources/en/default.zip.
# 2021-10-05 12:42:05 INFO: Finished downloading models and saved to /home/volta/stanza_resources.
# 2021-10-05 12:42:05 INFO: Loading these models for language: en (English):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | combined  |
# | pos       | combined  |
# | lemma     | combined  |
# | depparse  | combined  |
# | sentiment | sstplus   |
# | ner       | ontonotes |
# =========================
#
# 2021-10-05 12:42:05 INFO: Use device: cpu
# 2021-10-05 12:42:05 INFO: Loading: tokenize
# 2021-10-05 12:42:05 INFO: Loading: pos
# 2021-10-05 12:42:06 INFO: Loading: lemma
# 2021-10-05 12:42:06 INFO: Loading: depparse
# 2021-10-05 12:42:07 INFO: Loading: sentiment
# 2021-10-05 12:42:07 INFO: Loading: ner
# 2021-10-05 12:42:08 INFO: Done loading processors!

# %%
# during the analysis of the most important keywords inside a description is better to use only singular pronoun 
# due to the fact of the NNS like lights that are very frequent inside smartapp descriptions 

POS_accepted=["NN"] # part of speech tags accepted ---> deleted: "NNS", "NNP", "NNPS"
app_to_channel = {} # dictionary made of [samsung-app]: "correlated channel".

for app in trigger_action.keys(): # analyse every samsung app
    #app = "energy-alerts"
    keywords = [] # keywords found inside an app description 
    des_analysed = nlp(app_description[app])         # apply Stanford NLP to description
    for sent in des_analysed.sentences:
        for word in sent.words:                      # check each word of the description
            if word.xpos in POS_accepted:
                keyword_found = word.text.lower()    # filter: to all lowercase words
                if len(keyword_found) > 1:           # not accept symbols
                    if not keyword_found in keywords:    # if not already saved, 
                        #print(f"found word:{word.text}   \txpos: {word.xpos}\n")
                        keywords.append(keyword_found)   # add to the list of keywords

    # after finish to check the app description keywords
    clean_keywords = [] # find what words can be really processed by word2vec
    for i in range(len(keywords)):                   # for every keyword exstracted
        try:
            model[keywords[i]]                       # check Word2Vec
            clean_keywords.append(keywords[i])       # if can apply word2vec save it
        except KeyError as err:
            print("handling Error: ", err)           # some words can not be processed by Word2Vec

    print(app,"-", clean_keywords)        
    similarity_matrix = {}

    if len(clean_keywords) == 0: # case there aren't any NN keyword inside that app description (strange)
        print(f"-->app [{app}] non presenta nessun NN")

    else:
        if len(clean_keywords) == 1: # case there are only 1 NN keyword inside that app description
            for key in dict_channels.keys(): # check for every channel
                similarity_temp = 0
                for channel_NN in dict_channels[key]: # for every keyword inside the channel cluster
                    #print(f"check {clean_keywords[0]} and {channel_NN}")
                    similarity_temp += model.similarity(clean_keywords[0],channel_NN)
                # divide by the number of cluster keywords --> result: the mean of similarity
                similarity_matrix[key] = (similarity_temp/len(dict_channels[key]))*100

        else: # case there are more than 1 NN keyword inside that app description
            for key in dict_channels.keys(): # check for every channel
                similarity_partial = 0
                for keyword in clean_keywords: # for every keyword NN extracted from description
                    similarity_temp = 0
                    for channel_NN in dict_channels[key]:  # for every keyword inside the channel cluster
                        #print(keyword,channel_NN,"\t", model.similarity(keyword,channel_NN))
                        similarity_temp += model.similarity(keyword,channel_NN)
                     # divide by the number of cluster keywords --> result: the mean of similarity (given by only 1 NN)
                    similarity_temp = similarity_temp/len(dict_channels[key])
                    similarity_partial += similarity_temp
                #print("this keyword for ",key,"has got a level", similarity_partial/len(clean_keywords))
                similarity_matrix[key] = (similarity_partial/len(clean_keywords))*100
        
        #print(similarity_matrix)
        # now find the highest channel association 
        channel_association = ""
        max_value = 0
        for channel in similarity_matrix.keys():
            if (similarity_matrix[channel] > max_value):
                max_value = similarity_matrix[channel]
                channel_association = channel
                
        print("most similar:", channel_association, max_value)
        app_to_channel[app] = channel_association
# Out:
# beacon-control - ['home', 'phrase', 'door', 'region']
# most similar: lock 17.881229620737336
# big-turn-off - []
# -->app [big-turn-off] non presenta nessun NN
# big-turn-on - []
# -->app [big-turn-on] non presenta nessun NN
# bon-voyage - ['set', 'presence', 'mode', 'change', 'everyone', 'conjunction', 'turn', 'thermostat', 'security']
# most similar: locationMode 15.198862198222843
# brighten-dark-places - ['sensor', 'space']
# most similar: leakage 28.244500217789952
# brighten-my-path - ['motion']
# most similar: motion 65.6542420387268
# button-controller - ['control']
# most similar: lock 17.78656169772148
# camera-power-scheduler - ['power', 'time']
# most similar: time 28.28880089589141
# cameras-on-when-im-away - []
# -->app [cameras-on-when-im-away] non presenta nessun NN
# carpool-notifier - ['carpooling', 'person', 'notification']
# most similar: locationMode 14.494351545969645
# close-the-valve - ['valve', 'moisture', 'sms', 'notification']
# most similar: leakage 20.958356260830026
# curling-iron - ['outlet', 'user', 'period', 'time']
# most similar: time 24.194091756362468
# darken-behind-me - ['period', 'motion']
# most similar: motion 35.08423645980656
# double-tap - ['number', 'switch', 'row']
# most similar: lock 15.936106195052465
# dry-the-wetspot - ['moisture', 'sensor', 'input']
# most similar: temperature 29.79087644153171
# elder-care-daily-routine - ['time', 'cabinet', 'door', 'set', 'schedule']
# most similar: time 19.91645856337114
# elder-care-slip-fall - ['motion', 'bedroom', 'bathroom', 'night', 'occupant', 'period', 'time']
# most similar: time 20.1419772822168
# energy-alerts - ['energy']
# most similar: humidity 19.95879702270031
# energy-saver - ['energy']
# most similar: humidity 19.95879702270031
# feed-my-pet - ['schedule', 'pet', 'food', 'feeder', 'app', 'time', 'life']
# most similar: time 15.56815718778397
# flood-alert - ['push', 'notification', 'text', 'message', 'water']
# most similar: lock 13.529004522909721
# forgiving-security - ['something', 'grace', 'period', 'presence']
# most similar: time 17.118630440232995
# garage-door-monitor - ['garage', 'door', 'text', 'message']
# most similar: lock 20.760738663375378
# garage-door-opener - ['garage', 'door', 'switch']
# most similar: lock 30.500709927744335
# good-night - ['motion', 'time', 'night']
# most similar: motion 29.967832006514072
# greetings-earthling - ['set', 'presence', 'mode', 'change', 'someone', 'home']
# most similar: locationMode 17.655969919481628
# habit-helper - ['something', 'day', 'text', 'message']
# most similar: time 19.68994499131275
# has-barkley-been-fed - ['schedule', 'pet', 'food', 'feeder', 'app', 'time', 'life']
# most similar: time 15.56815718778397
# handling Error:  "Key 'ip' not present"
# hub-ip-notifier - ['hub']
# most similar: location 45.796140283346176
# humidity-alert - ['humidity', 'threshold', 'switch']
# most similar: humidity 22.588987130050857
# it-moved - ['text', 'movement']
# most similar: motion 18.063797056674957
# its-too-cold - ['temperature', 'setting', 'text', 'heater', 'appliance']
# most similar: smoke 24.7993837153031
# handling Error:  "Key 'a/c' not present"
# its-too-hot - ['temperature', 'setting', 'notification', 'unit', 'fan']
# most similar: humidity 17.005825676838867
# keep-me-cozy - ['thermostat', 'response', 'mode', 'change', 'energy', 'money']
# most similar: locationMode 17.072040552739054
# keep-me-cozy-ii - ['temperature', 'sensor', 'space', 'thermostat', 'time']
# most similar: temperature 28.88257770240307
# laundry-monitor - ['message', 'light', 'laundry']
# most similar: illumination 17.893299588225396
# left-it-open - ['door', 'window', 'amount', 'time']
# most similar: time 24.97374572875825
# let-there-be-dark - ['contact', 'sensor']
# most similar: leakage 26.291993624446068
# let-there-be-light - ['multi']
# most similar: motion 8.067143149673939
# light-follows-me - ['motion', 'period', 'time']
# most similar: time 28.608044905757364
# lights-off-when-closed - ['sensor']
# most similar: leakage 44.34692548079924
# light-up-the-night - []
# -->app [light-up-the-night] non presenta nessun NN
# lock-it-at-a-specific-time - ['door', 'time', 'option', 'contact', 'sensor']
# most similar: lock 17.981984131038185
# handling Error:  "Key 'deadbolt' not present"
# lock-it-when-i-leave - ['lever', 'lock', 'presence', 'tag', 'smartphone', 'location']
# most similar: locationMode 20.800286096831165
# mail-arrived - ['text', 'mail', 'mailbox', 'multi', 'door', 'note', 'battery', 'life']
# most similar: lock 13.336770320893265
# handling Error:  "Key 'setpoint' not present"
# make-it-so - ['set', 'thermostat', 'mode', 'change', 'app', 'state']
# most similar: locationMode 19.393042517670743
# medicine-management-contact-sensor - ['app', 'ambient', 'light', 'notification', 'drawer', 'cabinet', 'reminder', 'time', 'day', 'draw', 'message', 'led']
# most similar: time 14.977979139163807
# mini-hue-controller - ['hue']
# most similar: illumination 14.994511276017874
# handling Error:  "Key 'toggling' not present"
# nfc-tag-toggle - ['switch', 'lock', 'garage', 'door', 'tag', 'touch', 'event']
# most similar: lock 24.553591616096952
# notify-me-when - ['anything', 'home']
# most similar: time 15.906451202251695
# notify-me-when-it-opens - ['push', 'message', 'phone', 'sensor']
# most similar: leakage 18.16935208335053
# notify-me-with-hue - ['color', 'brightness', 'hue', 'variety', 'motion', 'contact', 'acceleration', 'moisture', 'presence']
# most similar: humidity 17.226573429102753
# once-a-day - ['time']
# most similar: time 46.94936004551975
# photo-burst-when - ['burst', 'push', 'notification']
# most similar: lock 20.46924135130313
# power-allowance - ['energy', 'time', 'appliance', 'curling', 'iron', 'tv', 'use', 'switch', 'number']
# most similar: illumination 13.145304479177058
# presence-change-push - ['push', 'notification', 'presence', 'tag', 'smartphone', 'location']
# most similar: locationMode 18.863330455496907
# presence-change-text - ['text', 'message', 'presence', 'status']
# most similar: locationMode 14.67329291626811
# handling Error:  "Key 'inclement' not present"
# ready-for-rain - ['weather']
# most similar: humidity 34.829993546009064
# ridiculously-automated-garage-door - ['arrival', 'departure', 'car', 'door', 'motion', 'interior']
# most similar: lock 15.866028843447566
# rise-and-shine - ['someone', 'time', 'morning']
# most similar: time 30.222984933943465
# scheduled-mode-change - ['time', 'day']
# most similar: time 46.37143239378929
# sleepy-time - ['sleep', 'mode', 'house', 'bed', 'morning', 'button', 'up']
# most similar: locationMode 18.871821050665208
# smart-care-daily-routine - ['time', 'cabinet', 'door', 'set', 'schedule']
# most similar: time 19.91645856337114
# smart-care-detect-motion - ['motion', 'bedroom', 'bathroom', 'night', 'occupant', 'period', 'time']
# most similar: time 20.1419772822168
# handling Error:  "Key 'humidifier' not present"
# smart-humidifier - ['humidity', 'sensor']
# most similar: humidity 39.30689334869385
# smart-nightlight - ['motion', 'light', 'time']
# most similar: motion 31.365954130887985
# smart-security - ['glass', 'water', 'middle', 'night']
# most similar: temperature 14.529544401836269
# smart-turn-it-on - ['device', 'time', 'week', 'person']
# most similar: time 27.685813760300253
# step-notifier - ['step', 'tracker', 'device']
# most similar: leakage 18.344358253208075
# sunrise-sunset - ['mode', 'sunrise', 'sunset']
# most similar: locationMode 26.542366668581963
# text-me-when-it-opens - ['text', 'message', 'phone', 'sensor']
# most similar: leakage 17.680670694839634
# text-me-when-theres-motion-and-im-not-here - ['text', 'message', 'motion']
# most similar: motion 30.84231565395991
# the-big-switch - ['collection', 'state', 'switch']
# most similar: illumination 11.728289637540001
# the-flasher - ['set', 'response', 'motion', 'event', 'switch']
# most similar: motion 27.20483779907227
# the-gun-case-moved - ['text', 'gun', 'case']
# most similar: motion 16.24148587385813
# thermostat-auto-off - ['thermostat', 'everything']
# most similar: humidity 27.695272732526067
# thermostats - ['anything', 'home']
# most similar: time 15.906451202251695
# turn-it-on-for-5-minutes - ['switch']
# most similar: illumination 26.527393609285355
# turn-it-on-when-im-here - ['something']
# most similar: lock 19.411427527666092
# turn-it-on-when-it-opens - ['something', 'sensor']
# most similar: leakage 28.603775867007
# turn-on-only-if-i-arrive-after-sunset - ['something', 'sunset', 'anytime']
# most similar: time 20.74950808433421
# undead-early-warning - ['warning']
# most similar: motion 12.371037900447845
# unlock-it-when-i-arrive - ['door', 'location']
# most similar: locationMode 32.7017480507493
# virtual-thermostat - ['space', 'heater', 'window', 'air_conditioner', 'conjunction', 'temperature', 'sensor', 'multi']
# most similar: leakage 24.88937104274307
# when-its-going-to-rain - ['shed', 'grill', 'lawn', 'tomorrow']
# most similar: illumination 13.933413446829945
# whole-house-fan - ['house', 'fan', 'switch', 'temp', 'thermostat']
# most similar: smoke 19.842980006942526

# %%
print(len(app_to_channel))
app_to_channel
# Out:
# 82
# {'beacon-control': 'lock',
#  'bon-voyage': 'locationMode',
#  'brighten-dark-places': 'leakage',
#  'brighten-my-path': 'motion',
#  'button-controller': 'lock',
#  'camera-power-scheduler': 'time',
#  'carpool-notifier': 'locationMode',
#  'close-the-valve': 'leakage',
#  'curling-iron': 'time',
#  'darken-behind-me': 'motion',
#  'double-tap': 'lock',
#  'dry-the-wetspot': 'temperature',
#  'elder-care-daily-routine': 'time',
#  'elder-care-slip-fall': 'time',
#  'energy-alerts': 'humidity',
#  'energy-saver': 'humidity',
#  'feed-my-pet': 'time',
#  'flood-alert': 'lock',
#  'forgiving-security': 'time',
#  'garage-door-monitor': 'lock',
#  'garage-door-opener': 'lock',
#  'good-night': 'motion',
#  'greetings-earthling': 'locationMode',
#  'habit-helper': 'time',
#  'has-barkley-been-fed': 'time',
#  'hub-ip-notifier': 'location',
#  'humidity-alert': 'humidity',
#  'it-moved': 'motion',
#  'its-too-cold': 'smoke',
#  'its-too-hot': 'humidity',
#  'keep-me-cozy': 'locationMode',
#  'keep-me-cozy-ii': 'temperature',
#  'laundry-monitor': 'illumination',
#  'left-it-open': 'time',
#  'let-there-be-dark': 'leakage',
#  'let-there-be-light': 'motion',
#  'light-follows-me': 'time',
#  'lights-off-when-closed': 'leakage',
#  'lock-it-at-a-specific-time': 'lock',
#  'lock-it-when-i-leave': 'locationMode',
#  'mail-arrived': 'lock',
#  'make-it-so': 'locationMode',
#  'medicine-management-contact-sensor': 'time',
#  'mini-hue-controller': 'illumination',
#  'nfc-tag-toggle': 'lock',
#  'notify-me-when': 'time',
#  'notify-me-when-it-opens': 'leakage',
#  'notify-me-with-hue': 'humidity',
#  'once-a-day': 'time',
#  'photo-burst-when': 'lock',
#  'power-allowance': 'illumination',
#  'presence-change-push': 'locationMode',
#  'presence-change-text': 'locationMode',
#  'ready-for-rain': 'humidity',
#  'ridiculously-automated-garage-door': 'lock',
#  'rise-and-shine': 'time',
#  'scheduled-mode-change': 'time',
#  'sleepy-time': 'locationMode',
#  'smart-care-daily-routine': 'time',
#  'smart-care-detect-motion': 'time',
#  'smart-humidifier': 'humidity',
#  'smart-nightlight': 'motion',
#  'smart-security': 'temperature',
#  'smart-turn-it-on': 'time',
#  'step-notifier': 'leakage',
#  'sunrise-sunset': 'locationMode',
#  'text-me-when-it-opens': 'leakage',
#  'text-me-when-theres-motion-and-im-not-here': 'motion',
#  'the-big-switch': 'illumination',
#  'the-flasher': 'motion',
#  'the-gun-case-moved': 'motion',
#  'thermostat-auto-off': 'humidity',
#  'thermostats': 'time',
#  'turn-it-on-for-5-minutes': 'illumination',
#  'turn-it-on-when-im-here': 'lock',
#  'turn-it-on-when-it-opens': 'leakage',
#  'turn-on-only-if-i-arrive-after-sunset': 'time',
#  'undead-early-warning': 'motion',
#  'unlock-it-when-i-arrive': 'locationMode',
#  'virtual-thermostat': 'leakage',
#  'when-its-going-to-rain': 'illumination',
#  'whole-house-fan': 'smoke'}

# %%
# function that map the capability to string
def cap2string(capability):
    switcher = {
        'accelerationSensor': "acceleration",
        'alarm': "alarm",
        'app': "app",
        'beacon': "beacon",
        'button': "button",
        'carbonMonoxideDetector': "carbon_monoxide",
        'colorControl': "color",
        'contactSensor': "contact",
        'doorControl': "door control",
        'hub':"hub",
        'illuminanceMeasurement':"illumination",
        'imageCapture': "image capture",
        'location':"location",
        'momentary': "momentary",
        'motionSensor':"motion ",
        'musicPlayer': "music player",
        'powerMeter':"power",
        'presenceSensor': "presence",
        'relativeHumidityMeasurement': "relative humidity ",
        'smokeDetector': "smoke",
        'switch': "switch",
        'switchLevel': "switch level",
        'temperatureMeasurement':"temperature",
        'thermostat': "thermostat",
        'threeAxis':"three axis",
        'touchSensor':"touch",
        'valve':"valve",
        'waterSensor':"water sensor",
        'device.PetFeederShield':"pet feeder shield",
        'device.jawboneUser':"jawbone user",
        'number': "number",
        
        'lock':"lock",
        'locationMode':"locationMode",
        'sendAction':"sendAction",
        'time':"time"
    }
    return switcher.get(capability, f"capabliti not found: {capability}")

# %%
dict_channels_capability={"temperature":[], "humidity":[], "illumination":[], "location":[],
                          "motion":[], "smoke":[], "leakage":[], "time":[], "locationMode":[], "lock":[]}

# # this are the capability related to the system channel (so not physical channel related capabilities)
# capability_not_accepted = ["app","time", "sendAction", "locationMode", "hub",
#                            "lock", "button","powerMeter","device.jawboneUser", "alarm"]

for app in app_to_channel.keys(): # for every analysed app
    list_of_capabilities = trigger_action[app].keys() # save the trigger capabilities 
    channel_capabilities = []
    for capability in list_of_capabilities:
            channel_capabilities.append(capability) # save all the trigger capabilities
    
    if len(channel_capabilities) <= 2 and len(channel_capabilities) != 0: 
            if not cap2string(capability) in dict_channels_capability[app_to_channel[app]]: # avoid duplicate
                dict_channels_capability[app_to_channel[app]].append(cap2string(capability))
                print(app, "  \tadd ", cap2string(capability))
# Out:
# beacon-control   	add  beacon
# bon-voyage   	add  presence
# brighten-dark-places   	add  contact
# brighten-my-path   	add  motion
# button-controller   	add  button
# camera-power-scheduler   	add  time
# close-the-valve   	add  water sensor
# curling-iron   	add  presence
# double-tap   	add  switch
# dry-the-wetspot   	add  water sensor
# elder-care-slip-fall   	add  motion
# energy-alerts   	add  power
# flood-alert   	add  water sensor
# garage-door-monitor   	add  three axis
# good-night   	add  switch
# hub-ip-notifier   	add  hub
# humidity-alert   	add  relative humidity
# it-moved   	add  acceleration
# its-too-cold   	add  temperature
# its-too-hot   	add  temperature
# laundry-monitor   	add  acceleration
# left-it-open   	add  contact
# let-there-be-light   	add  contact
# lock-it-at-a-specific-time   	add  time
# mail-arrived   	add  acceleration
# make-it-so   	add  app
# mini-hue-controller   	add  button
# nfc-tag-toggle   	add  app
# power-allowance   	add  switch
# ready-for-rain   	add  contact
# sleepy-time   	add  jawbone user
# step-notifier   	add  jawbone user
# sunrise-sunset   	add  location
# thermostats   	add  carbon_monoxide
# turn-it-on-for-5-minutes   	add  contact
# turn-it-on-when-im-here   	add  presence
# virtual-thermostat   	add  motion
# when-its-going-to-rain   	add  time

# %%
dict_channels_capability
# Out:
# {'temperature': ['water sensor'],
#  'humidity': ['power', 'relative humidity ', 'temperature', 'contact'],
#  'illumination': ['acceleration', 'button', 'switch', 'contact', 'time'],
#  'location': ['hub'],
#  'motion': ['motion ', 'switch', 'acceleration', 'contact'],
#  'smoke': ['temperature'],
#  'leakage': ['contact', 'water sensor', 'jawbone user', 'motion '],
#  'time': ['time', 'presence', 'motion ', 'contact', 'carbon_monoxide'],
#  'locationMode': ['presence', 'app', 'jawbone user', 'location'],
#  'lock': ['beacon',
#   'button',
#   'switch',
#   'water sensor',
#   'three axis',
#   'time',
#   'acceleration',
#   'app',
#   'presence']}

# %%
with open("set_of_capability_related_channels.JSON","w") as outfile:
    json.dump(dict_channels_capability, outfile)

# %% [markdown]
# ## analysis of the number of trigger-capability and action-capability

# %%
dict_actions_related={"temperature":[], "humidity":[], "illumination":[], "location":[],
                          "motion":[], "smoke":[], "leakage":[], "time":[], "locationMode":[], "lock":[]}
dict_trigger_related={"temperature":[], "humidity":[], "illumination":[], "location":[],
                          "motion":[], "smoke":[], "leakage":[], "time":[], "locationMode":[], "lock":[]}

for app in trigger_action.keys(): # for every app 
    if app in app_to_channel.keys(): # where I can extrapolate info (some app description couldn't have some NN) 
        channel_correlated = app_to_channel[app] # save the physical trigger channel of that app
        for trigger_cap in trigger_action[app].keys(): # for every trigger channel of that app
           # if not trigger_cap in capability_not_accepted: # if the trigger capability is correlated to physical channel
             dict_trigger_related[channel_correlated].append(trigger_cap) # save it 
                
for app in trigger_action.keys(): # for every app where I can extrapolate info
    for trigger_cap in trigger_action[app].keys(): # for every app trigger trigger capability
        for actions in trigger_action[app][trigger_cap]: # for every action correlated to that trigger capability
            action_capability = actions[0] # save the action capability
            for channel in dict_channels_capability.keys(): # for every physical channel
                if action_capability in dict_channels_capability[channel]: # find if there is that action capability
                    dict_actions_related[channel].append(action_capability) # if there is save the action capability 

                    
dict_actions_related
# Out:
# {'temperature': [],
#  'humidity': [],
#  'illumination': ['switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch'],
#  'location': [],
#  'motion': ['switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch'],
#  'smoke': [],
#  'leakage': [],
#  'time': [],
#  'locationMode': [],
#  'lock': ['switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch']}

# %%
action_related = []
for key in dict_actions_related.keys():
    action_related.append(len(dict_actions_related[key]))
action_related = np.array(action_related)
action_related
# Out:
# array([ 0,  0, 70,  0, 70,  0,  0,  0,  0, 70])

# %%
trigger_related = []
for key in dict_trigger_related.keys():
    trigger_related.append(len(dict_trigger_related[key]))
trigger_related = np.array(trigger_related)
trigger_related
# Out:
# array([ 8, 16,  6,  1, 15,  4, 10, 30, 14, 20])

# %%
import matplotlib.pyplot as plt

x = ["Temperature","Humidity", "Illumination", "Location", "Motion", "Smoke", "Leakage", "time", "locationMode", "lock" ]
x_pos = np.arange(len(x))
plt.figure(figsize=[15, 5])
plt.bar(x_pos, trigger_related, align='center')
plt.xticks(x_pos, x)
plt.ylabel('Amount of interactions')
plt.xlabel('Channel type')
plt.title('Trigger-related Channel analysis')
plt.show()

# %%
x_pos = np.arange(len(x))
plt.figure(figsize=[15, 5])
plt.bar(x_pos, action_related, align='center')
plt.xticks(x_pos, x)
plt.ylabel('Amount of interactions')
plt.xlabel('Channel type')
plt.title('Action-related Channel analysis')
plt.show()
