# %% [markdown]
# ##  interaction chain discovery algorithm

# %%
import json   # for read the JSON file
import numpy as np

# %%
file = open("../1_application_analysis/2_physical_channel_identification/trigger-action_FINAL.JSON","r") # read all the capability extrapolated from the apps
trigger_action = json.load(file)
print("tot app analysed:",len(trigger_action.keys()))
# Out:
# tot app analysed: 84

# %%
# you need the AP_tr,ac all trigger-action behaviour tuples in applications (cap 4.3.2 - p835)
list_trigger_action = []
for app in trigger_action.keys():         # for every app analysed
    for trigger in trigger_action[app].keys():      # for every trigger channel of that app
            for action in trigger_action[app][trigger]: # for every action 
                check = any(element == [trigger, action] for element in list_trigger_action)
                if not check: # if not duplicate
                    list_trigger_action.append([trigger, action]) # save capability (the channel) and action
list_trigger_action.sort()
list_trigger_action
# Out:
# [['capability.accelerationSensor',
#   ['capability.imageCapture', 'imageCapture.take']],
#  ['capability.accelerationSensor', ['capability.momentary', 'momentary.push']],
#  ['capability.accelerationSensor', ['capability.switch', 'switch.on']],
#  ['capability.accelerationSensor', ['number', 'number.times']],
#  ['capability.accelerationSensor',
#   ['sendAction', 'sendNotificationToContacts']],
#  ['capability.accelerationSensor', ['sendAction', 'sendPush']],
#  ['capability.accelerationSensor', ['sendAction', 'sendSms']],
#  ['capability.alarm', ['capability.alarm', 'alarm.off']],
#  ['capability.app', ['capability.alarm', 'alarm.off']],
#  ['capability.app', ['capability.doorControl', 'doorControl.each']],
#  ['capability.app', ['capability.lock', 'lock.each']],
#  ['capability.app', ['capability.switch', 'switch.each']],
#  ['capability.app', ['capability.switch', 'switch.off']],
#  ['capability.app', ['capability.switch', 'switch.on']],
#  ['capability.app', ['capability.thermostat', 'thermostat.each']],
#  ['capability.app', ['capability.thermostat', 'thermostat.poll']],
#  ['capability.app',
#   ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#  ['capability.app',
#   ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#  ['capability.beacon', ['capability.lock', 'lock.lock']],
#  ['capability.beacon', ['capability.lock', 'lock.unlock']],
#  ['capability.beacon', ['capability.switch', 'switch.off']],
#  ['capability.beacon', ['capability.switch', 'switch.on']],
#  ['capability.button', ['capability.colorControl', 'colorControl.off']],
#  ['capability.button', ['capability.colorControl', 'colorControl.on']],
#  ['capability.button', ['capability.colorControl', 'colorControl.setColor']],
#  ['capability.button', ['capability.colorControl', 'colorControl.setLevel']],
#  ['capability.button', ['locationMode', 'locationMode.setLocationMode']],
#  ['capability.button', ['sendAction', 'sendPush']],
#  ['capability.button', ['sendAction', 'sendSms']],
#  ['capability.carbonMonoxideDetector',
#   ['capability.thermostat', 'thermostat.setThermostatMode']],
#  ['capability.carbonMonoxideDetector',
#   ['sendAction', 'sendNotificationToContacts']],
#  ['capability.contactSensor', ['capability.alarm', 'alarm.both']],
#  ['capability.contactSensor', ['capability.alarm', 'alarm.strobe']],
#  ['capability.contactSensor', ['capability.colorControl', 'colorControl.off']],
#  ['capability.contactSensor',
#   ['capability.colorControl', 'colorControl.setHue']],
#  ['capability.contactSensor',
#   ['capability.imageCapture', 'imageCapture.take']],
#  ['capability.contactSensor', ['capability.momentary', 'momentary.push']],
#  ['capability.contactSensor', ['capability.switch', 'switch.currentValue']],
#  ['capability.contactSensor', ['capability.switch', 'switch.off']],
#  ['capability.contactSensor', ['capability.switch', 'switch.on']],
#  ['capability.contactSensor',
#   ['capability.thermostat', 'thermostat.currentValue']],
#  ['capability.contactSensor', ['capability.thermostat', 'thermostat.off']],
#  ['capability.contactSensor',
#   ['capability.thermostat', 'thermostat.setThermostatMode']],
#  ['capability.contactSensor',
#   ['locationMode', 'locationMode.setLocationMode']],
#  ['capability.contactSensor', ['number', 'number.times']],
#  ['capability.contactSensor', ['sendAction', 'sendNotificationToContacts']],
#  ['capability.contactSensor', ['sendAction', 'sendPush']],
#  ['capability.contactSensor', ['sendAction', 'sendSms']],
#  ['capability.illuminanceMeasurement', ['capability.switch', 'switch.off']],
#  ['capability.illuminanceMeasurement', ['capability.switch', 'switch.on']],
#  ['capability.location', ['capability.lock', 'lock.each']],
#  ['capability.location', ['capability.switch', 'switch.each']],
#  ['capability.location', ['capability.switch', 'switch.off']],
#  ['capability.location', ['capability.switch', 'switch.on']],
#  ['capability.location', ['capability.thermostat', 'thermostat.each']],
#  ['capability.location', ['capability.thermostat', 'thermostat.poll']],
#  ['capability.location',
#   ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#  ['capability.location',
#   ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#  ['capability.motionSensor', ['capability.alarm', 'alarm.both']],
#  ['capability.motionSensor', ['capability.alarm', 'alarm.strobe']],
#  ['capability.motionSensor', ['capability.imageCapture', 'imageCapture.take']],
#  ['capability.motionSensor', ['capability.switch', 'switch.off']],
#  ['capability.motionSensor', ['capability.switch', 'switch.on']],
#  ['capability.motionSensor', ['locationMode', 'locationMode.setLocationMode']],
#  ['capability.motionSensor', ['number', 'number.times']],
#  ['capability.motionSensor', ['sendAction', 'sendNotificationToContacts']],
#  ['capability.motionSensor', ['sendAction', 'sendPush']],
#  ['capability.motionSensor', ['sendAction', 'sendSms']],
#  ['capability.powerMeter', ['capability.switch', 'switch.off']],
#  ['capability.powerMeter', ['sendAction', 'sendNotificationToContacts']],
#  ['capability.powerMeter', ['sendAction', 'sendPush']],
#  ['capability.powerMeter', ['sendAction', 'sendSms']],
#  ['capability.presenceSensor',
#   ['capability.imageCapture', 'imageCapture.take']],
#  ['capability.presenceSensor', ['capability.lock', 'lock.lock']],
#  ['capability.presenceSensor', ['capability.lock', 'lock.unlock']],
#  ['capability.presenceSensor', ['capability.momentary', 'momentary.push']],
#  ['capability.presenceSensor', ['capability.switch', 'switch.off']],
#  ['capability.presenceSensor', ['capability.switch', 'switch.on']],
#  ['capability.presenceSensor',
#   ['locationMode', 'locationMode.setLocationMode']],
#  ['capability.presenceSensor', ['number', 'number.times']],
#  ['capability.presenceSensor', ['sendAction', 'sendNotificationToContacts']],
#  ['capability.presenceSensor', ['sendAction', 'sendPush']],
#  ['capability.presenceSensor', ['sendAction', 'sendSms']],
#  ['capability.relativeHumidityMeasurement',
#   ['capability.switch', 'switch.off']],
#  ['capability.relativeHumidityMeasurement',
#   ['capability.switch', 'switch.on']],
#  ['capability.relativeHumidityMeasurement', ['sendAction', 'sendPush']],
#  ['capability.relativeHumidityMeasurement', ['sendAction', 'sendSms']],
#  ['capability.smokeDetector',
#   ['capability.thermostat', 'thermostat.setThermostatMode']],
#  ['capability.smokeDetector', ['sendAction', 'sendNotificationToContacts']],
#  ['capability.switch', ['capability.imageCapture', 'imageCapture.take']],
#  ['capability.switch', ['capability.switch', 'switch.off']],
#  ['capability.switch', ['capability.switch', 'switch.on']],
#  ['capability.switch', ['capability.switchLevel', 'switchLevel.setLevel']],
#  ['capability.switch', ['locationMode', 'locationMode.setLocationMode']],
#  ['capability.switch', ['number', 'number.times']],
#  ['capability.switch', ['sendAction', 'sendNotificationToContacts']],
#  ['capability.switch', ['sendAction', 'sendPush']],
#  ['capability.switch', ['sendAction', 'sendSms']],
#  ['capability.temperatureMeasurement', ['capability.switch', 'switch.off']],
#  ['capability.temperatureMeasurement', ['capability.switch', 'switch.on']],
#  ['capability.temperatureMeasurement',
#   ['capability.thermostat', 'thermostat.poll']],
#  ['capability.temperatureMeasurement',
#   ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#  ['capability.temperatureMeasurement',
#   ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#  ['capability.temperatureMeasurement',
#   ['sendAction', 'sendNotificationToContacts']],
#  ['capability.temperatureMeasurement', ['sendAction', 'sendPush']],
#  ['capability.temperatureMeasurement', ['sendAction', 'sendSms']],
#  ['capability.thermostat', ['capability.switch', 'switch.off']],
#  ['capability.thermostat', ['capability.switch', 'switch.on']],
#  ['capability.thermostat', ['capability.thermostat', 'thermostat.poll']],
#  ['capability.thermostat',
#   ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#  ['capability.thermostat',
#   ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#  ['capability.threeAxis', ['sendAction', 'sendNotificationToContacts']],
#  ['capability.threeAxis', ['sendAction', 'sendPush']],
#  ['capability.threeAxis', ['sendAction', 'sendSms']],
#  ['capability.touchSensor', ['capability.doorControl', 'doorControl.each']],
#  ['capability.touchSensor', ['capability.lock', 'lock.each']],
#  ['capability.touchSensor', ['capability.switch', 'switch.each']],
#  ['capability.waterSensor', ['capability.switch', 'switch.off']],
#  ['capability.waterSensor', ['capability.switch', 'switch.on']],
#  ['capability.waterSensor', ['capability.valve', 'valve.close']],
#  ['capability.waterSensor', ['sendAction', 'sendNotificationToContacts']],
#  ['capability.waterSensor', ['sendAction', 'sendPush']],
#  ['capability.waterSensor', ['sendAction', 'sendSms']],
#  ['time', ['capability.lock', 'lock.lock']],
#  ['time', ['capability.switch', 'switch.off']],
#  ['time', ['capability.switch', 'switch.on']],
#  ['time', ['device.PetFeederShield', 'device.PetFeederShield.feed']],
#  ['time', ['locationMode', 'locationMode.setLocationMode']],
#  ['time', ['sendAction', 'sendNotificationToContacts']],
#  ['time', ['sendAction', 'sendPush']],
#  ['time', ['sendAction', 'sendSms']]]

# %%
file = open("../1_application_analysis/2_physical_channel_identification/set_of_capability_related_physical_channels.JSON","r")
capability_channel = json.load(file)
capability_channel
# Out:
# {'temperature': ['capability.contactSensor',
#   'capability.waterSensor',
#   'capability.temperatureMeasurement',
#   'capability.thermostat',
#   'capability.location',
#   'capability.relativeHumidityMeasurement',
#   'capability.motionSensor'],
#  'humidity': ['capability.relativeHumidityMeasurement',
#   'capability.location',
#   'capability.contactSensor'],
#  'illumination': ['capability.presenceSensor',
#   'capability.contactSensor',
#   'capability.touchSensor',
#   'capability.location'],
#  'location': ['capability.beacon',
#   'capability.motionSensor',
#   'capability.presenceSensor',
#   'capability.contactSensor',
#   'capability.location',
#   'capability.smokeDetector',
#   'capability.carbonMonoxideDetector'],
#  'motion': ['capability.motionSensor', 'capability.location'],
#  'smoke': ['capability.temperatureMeasurement'],
#  'leakage': ['capability.presenceSensor',
#   'capability.waterSensor',
#   'capability.threeAxis',
#   'capability.accelerationSensor',
#   'capability.contactSensor']}

# %%
system_capabilities = [ "capability.app","time", "sendAction", "locationMode", "hub",
                        "capability.switch", "capability.lock", "capability.button",
                        "capability.powerMeter","device.jawboneUser", "capability.alarm"]

# %%
# algorithm 1: algorithm for interaction chain discovery
INTAC = []
for i in list_trigger_action: # for every pair of trigger-action
    for j in list_trigger_action:
        for physical_channel in capability_channel.keys(): # this implies --> k.ch == m.ch
            #print("physical channel:",physical_channel)
            for k in capability_channel[physical_channel]: # for every possible pair of capabilities
                for m in capability_channel[physical_channel]: # correlated to the same physical channel
                    action_cap = i[1][0] # action capability of first trigger-action
                    trigger_cap = j[0]   # trigger capability of second trigger-action
                    if ((action_cap == k) and (trigger_cap == m) and (action_cap != trigger_cap)): 
                        if not [i, physical_channel, j] in INTAC: # not duplicates 
                            print(f"action {action_cap} nel canale {physical_channel} triggera {trigger_cap}")
                            INTAC.append([i, physical_channel, j])
        for system_channel in system_capabilities: # now check the system channels
            if (action_cap == system_channel) and (trigger_cap == system_channel): 
                        if not [i, system_channel, j] in INTAC: # not duplicates 
                            print(f"action {action_cap} nel canale {physical_channel} triggera {trigger_cap}")
                            INTAC.append([i, physical_channel, j])
# Out:
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.alarm nel canale leakage triggera capability.alarm
# action capability.alarm nel canale leakage triggera capability.alarm
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.alarm nel canale leakage triggera capability.alarm
# action capability.alarm nel canale leakage triggera capability.alarm
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# ...
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.contactSensor
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.location
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.motionSensor
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.relativeHumidityMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.temperatureMeasurement
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.thermostat nel canale temperature triggera capability.waterSensor
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch
# action capability.switch nel canale leakage triggera capability.switch

# %%
print(len(INTAC)) # for the paper just 570 (cap 5.2 - p839) prima avevo 2500 .....
# Out:
# 1301

# %%
INTAC
# Out:
# [[['capability.accelerationSensor', ['capability.switch', 'switch.on']],
#   'leakage',
#   ['capability.switch', ['capability.imageCapture', 'imageCapture.take']]],
#  [['capability.accelerationSensor', ['capability.switch', 'switch.on']],
#   'leakage',
#   ['capability.switch', ['capability.switch', 'switch.off']]],
#  [['capability.accelerationSensor', ['capability.switch', 'switch.on']],
#   'leakage',
#   ['capability.switch', ['capability.switch', 'switch.on']]],
#  [['capability.accelerationSensor', ['capability.switch', 'switch.on']],
#   'leakage',
#   ['capability.switch', ['capability.switchLevel', 'switchLevel.setLevel']]],
#  [['capability.accelerationSensor', ['capability.switch', 'switch.on']],
#   'leakage',
#   ['capability.switch', ['locationMode', 'locationMode.setLocationMode']]],
#  [['capability.accelerationSensor', ['capability.switch', 'switch.on']],
#   'leakage',
#   ['capability.switch', ['number', 'number.times']]],
#  [['capability.accelerationSensor', ['capability.switch', 'switch.on']],
#   'leakage',
#   ['capability.switch', ['sendAction', 'sendNotificationToContacts']]],
#  [['capability.accelerationSensor', ['capability.switch', 'switch.on']],
#   'leakage',
#   ['capability.switch', ['sendAction', 'sendPush']]],
#  [['capability.accelerationSensor', ['capability.switch', 'switch.on']],
#   'leakage',
#   ['capability.switch', ['sendAction', 'sendSms']]],
#  [['capability.alarm', ['capability.alarm', 'alarm.off']],
#   'leakage',
#   ['capability.alarm', ['capability.alarm', 'alarm.off']]],
#  [['capability.app', ['capability.alarm', 'alarm.off']],
#   'leakage',
#   ['capability.alarm', ['capability.alarm', 'alarm.off']]],
#  [['capability.app', ['capability.switch', 'switch.each']],
#   'leakage',
#   ['capability.switch', ['capability.imageCapture', 'imageCapture.take']]],
#  [['capability.app', ['capability.switch', 'switch.each']],
#   'leakage',
#   ['capability.switch', ['capability.switch', 'switch.off']]],
#  [['capability.app', ['capability.switch', 'switch.each']],
#   'leakage',
#   ['capability.switch', ['capability.switch', 'switch.on']]],
#  [['capability.app', ['capability.switch', 'switch.each']],
#   'leakage',
#   ['capability.switch', ['capability.switchLevel', 'switchLevel.setLevel']]],
#  [['capability.app', ['capability.switch', 'switch.each']],
#   'leakage',
#   ['capability.switch', ['locationMode', 'locationMode.setLocationMode']]],
#  [['capability.app', ['capability.switch', 'switch.each']],
#   'leakage',
#   ['capability.switch', ['number', 'number.times']]],
#  [['capability.app', ['capability.switch', 'switch.each']],
#   'leakage',
#   ['capability.switch', ['sendAction', 'sendNotificationToContacts']]],
#  [['capability.app', ['capability.switch', 'switch.each']],
#   'leakage',
#   ['capability.switch', ['sendAction', 'sendPush']]],
#  [['capability.app', ['capability.switch', 'switch.each']],
#   'leakage',
#   ['capability.switch', ['sendAction', 'sendSms']]],
#  [['capability.app', ['capability.switch', 'switch.off']],
#   'leakage',
#   ['capability.switch', ['capability.imageCapture', 'imageCapture.take']]],
#  [['capability.app', ['capability.switch', 'switch.off']],
#   'leakage',
#   ['capability.switch', ['capability.switch', 'switch.off']]],
#  [['capability.app', ['capability.switch', 'switch.off']],
#   'leakage',
#   ['capability.switch', ['capability.switch', 'switch.on']]],
#  [['capability.app', ['capability.switch', 'switch.off']],
#   'leakage',
#   ['capability.switch', ['capability.switchLevel', 'switchLevel.setLevel']]],
#  [['capability.app', ['capability.switch', 'switch.off']],
#   'leakage',
#   ['capability.switch', ['locationMode', 'locationMode.setLocationMode']]],
#  [['capability.app', ['capability.switch', 'switch.off']],
#   'leakage',
#   ['capability.switch', ['number', 'number.times']]],
#  [['capability.app', ['capability.switch', 'switch.off']],
#   'leakage',
#   ['capability.switch', ['sendAction', 'sendNotificationToContacts']]],
#  [['capability.app', ['capability.switch', 'switch.off']],
#   'leakage',
#   ['capability.switch', ['sendAction', 'sendPush']]],
#  [['capability.app', ['capability.switch', 'switch.off']],
#   'leakage',
#   ['capability.switch', ['sendAction', 'sendSms']]],
#  [['capability.app', ['capability.switch', 'switch.on']],
#   'leakage',
#   ['capability.switch', ['capability.imageCapture', 'imageCapture.take']]],
#  [['capability.app', ['capability.switch', 'switch.on']],
#   'leakage',
#   ['capability.switch', ['capability.switch', 'switch.off']]],
#  [['capability.app', ['capability.switch', 'switch.on']],
#   'leakage',
#   ['capability.switch', ['capability.switch', 'switch.on']]],
#  [['capability.app', ['capability.switch', 'switch.on']],
#   'leakage',
#   ['capability.switch', ['capability.switchLevel', 'switchLevel.setLevel']]],
#  [['capability.app', ['capability.switch', 'switch.on']],
#   'leakage',
#   ['capability.switch', ['locationMode', 'locationMode.setLocationMode']]],
#  [['capability.app', ['capability.switch', 'switch.on']],
#   'leakage',
#   ['capability.switch', ['number', 'number.times']]],
#  [['capability.app', ['capability.switch', 'switch.on']],
#   'leakage',
#   ['capability.switch', ['sendAction', 'sendNotificationToContacts']]],
#  [['capability.app', ['capability.switch', 'switch.on']],
#   'leakage',
#   ['capability.switch', ['sendAction', 'sendPush']]],
#  [['capability.app', ['capability.switch', 'switch.on']],
#   'leakage',
#   ['capability.switch', ['sendAction', 'sendSms']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.contactSensor', ['capability.alarm', 'alarm.both']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.contactSensor', ['capability.alarm', 'alarm.strobe']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.colorControl', 'colorControl.off']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.colorControl', 'colorControl.setHue']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.imageCapture', 'imageCapture.take']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.contactSensor', ['capability.momentary', 'momentary.push']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.contactSensor', ['capability.switch', 'switch.currentValue']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.contactSensor', ['capability.switch', 'switch.off']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.contactSensor', ['capability.switch', 'switch.on']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.thermostat', 'thermostat.currentValue']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.contactSensor', ['capability.thermostat', 'thermostat.off']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.thermostat', 'thermostat.setThermostatMode']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.contactSensor',
#    ['locationMode', 'locationMode.setLocationMode']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.contactSensor', ['number', 'number.times']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.contactSensor', ['sendAction', 'sendNotificationToContacts']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.contactSensor', ['sendAction', 'sendPush']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.contactSensor', ['sendAction', 'sendSms']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.location', ['capability.lock', 'lock.each']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.location', ['capability.switch', 'switch.each']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.location', ['capability.switch', 'switch.off']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.location', ['capability.switch', 'switch.on']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.location', ['capability.thermostat', 'thermostat.each']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.location', ['capability.thermostat', 'thermostat.poll']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.location',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.location',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.motionSensor', ['capability.alarm', 'alarm.both']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.motionSensor', ['capability.alarm', 'alarm.strobe']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.motionSensor',
#    ['capability.imageCapture', 'imageCapture.take']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.motionSensor', ['capability.switch', 'switch.off']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.motionSensor', ['capability.switch', 'switch.on']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.motionSensor',
#    ['locationMode', 'locationMode.setLocationMode']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.motionSensor', ['number', 'number.times']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.motionSensor', ['sendAction', 'sendNotificationToContacts']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.motionSensor', ['sendAction', 'sendPush']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.motionSensor', ['sendAction', 'sendSms']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.relativeHumidityMeasurement',
#    ['capability.switch', 'switch.off']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.relativeHumidityMeasurement',
#    ['capability.switch', 'switch.on']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.relativeHumidityMeasurement', ['sendAction', 'sendPush']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.relativeHumidityMeasurement', ['sendAction', 'sendSms']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.temperatureMeasurement', ['capability.switch', 'switch.off']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.temperatureMeasurement', ['capability.switch', 'switch.on']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.temperatureMeasurement',
#    ['sendAction', 'sendNotificationToContacts']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.temperatureMeasurement', ['sendAction', 'sendPush']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.temperatureMeasurement', ['sendAction', 'sendSms']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.waterSensor', ['capability.switch', 'switch.off']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.waterSensor', ['capability.switch', 'switch.on']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.waterSensor', ['capability.valve', 'valve.close']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.waterSensor', ['sendAction', 'sendNotificationToContacts']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.waterSensor', ['sendAction', 'sendPush']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.each']],
#   'temperature',
#   ['capability.waterSensor', ['sendAction', 'sendSms']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor', ['capability.alarm', 'alarm.both']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor', ['capability.alarm', 'alarm.strobe']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.colorControl', 'colorControl.off']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.colorControl', 'colorControl.setHue']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.imageCapture', 'imageCapture.take']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor', ['capability.momentary', 'momentary.push']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor', ['capability.switch', 'switch.currentValue']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor', ['capability.switch', 'switch.off']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor', ['capability.switch', 'switch.on']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.thermostat', 'thermostat.currentValue']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor', ['capability.thermostat', 'thermostat.off']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.thermostat', 'thermostat.setThermostatMode']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor',
#    ['locationMode', 'locationMode.setLocationMode']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor', ['number', 'number.times']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor', ['sendAction', 'sendNotificationToContacts']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor', ['sendAction', 'sendPush']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor', ['sendAction', 'sendSms']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.location', ['capability.lock', 'lock.each']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.location', ['capability.switch', 'switch.each']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.location', ['capability.switch', 'switch.off']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.location', ['capability.switch', 'switch.on']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.location', ['capability.thermostat', 'thermostat.each']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.location', ['capability.thermostat', 'thermostat.poll']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.location',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.location',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.motionSensor', ['capability.alarm', 'alarm.both']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.motionSensor', ['capability.alarm', 'alarm.strobe']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.motionSensor',
#    ['capability.imageCapture', 'imageCapture.take']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.motionSensor', ['capability.switch', 'switch.off']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.motionSensor', ['capability.switch', 'switch.on']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.motionSensor',
#    ['locationMode', 'locationMode.setLocationMode']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.motionSensor', ['number', 'number.times']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.motionSensor', ['sendAction', 'sendNotificationToContacts']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.motionSensor', ['sendAction', 'sendPush']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.motionSensor', ['sendAction', 'sendSms']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.relativeHumidityMeasurement',
#    ['capability.switch', 'switch.off']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.relativeHumidityMeasurement',
#    ['capability.switch', 'switch.on']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.relativeHumidityMeasurement', ['sendAction', 'sendPush']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.relativeHumidityMeasurement', ['sendAction', 'sendSms']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.temperatureMeasurement', ['capability.switch', 'switch.off']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.temperatureMeasurement', ['capability.switch', 'switch.on']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.temperatureMeasurement',
#    ['sendAction', 'sendNotificationToContacts']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.temperatureMeasurement', ['sendAction', 'sendPush']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.temperatureMeasurement', ['sendAction', 'sendSms']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.waterSensor', ['capability.switch', 'switch.off']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.waterSensor', ['capability.switch', 'switch.on']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.waterSensor', ['capability.valve', 'valve.close']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.waterSensor', ['sendAction', 'sendNotificationToContacts']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.waterSensor', ['sendAction', 'sendPush']]],
#  [['capability.app', ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.waterSensor', ['sendAction', 'sendSms']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor', ['capability.alarm', 'alarm.both']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor', ['capability.alarm', 'alarm.strobe']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.colorControl', 'colorControl.off']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.colorControl', 'colorControl.setHue']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.imageCapture', 'imageCapture.take']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor', ['capability.momentary', 'momentary.push']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor', ['capability.switch', 'switch.currentValue']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor', ['capability.switch', 'switch.off']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor', ['capability.switch', 'switch.on']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.thermostat', 'thermostat.currentValue']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor', ['capability.thermostat', 'thermostat.off']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.thermostat', 'thermostat.setThermostatMode']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor',
#    ['locationMode', 'locationMode.setLocationMode']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor', ['number', 'number.times']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor', ['sendAction', 'sendNotificationToContacts']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor', ['sendAction', 'sendPush']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor', ['sendAction', 'sendSms']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.location', ['capability.lock', 'lock.each']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.location', ['capability.switch', 'switch.each']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.location', ['capability.switch', 'switch.off']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.location', ['capability.switch', 'switch.on']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.location', ['capability.thermostat', 'thermostat.each']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.location', ['capability.thermostat', 'thermostat.poll']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.location',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.location',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.motionSensor', ['capability.alarm', 'alarm.both']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.motionSensor', ['capability.alarm', 'alarm.strobe']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.motionSensor',
#    ['capability.imageCapture', 'imageCapture.take']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.motionSensor', ['capability.switch', 'switch.off']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.motionSensor', ['capability.switch', 'switch.on']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.motionSensor',
#    ['locationMode', 'locationMode.setLocationMode']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.motionSensor', ['number', 'number.times']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.motionSensor', ['sendAction', 'sendNotificationToContacts']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.motionSensor', ['sendAction', 'sendPush']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.motionSensor', ['sendAction', 'sendSms']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.relativeHumidityMeasurement',
#    ['capability.switch', 'switch.off']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.relativeHumidityMeasurement',
#    ['capability.switch', 'switch.on']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.relativeHumidityMeasurement', ['sendAction', 'sendPush']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.relativeHumidityMeasurement', ['sendAction', 'sendSms']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.temperatureMeasurement', ['capability.switch', 'switch.off']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.temperatureMeasurement', ['capability.switch', 'switch.on']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.temperatureMeasurement',
#    ['sendAction', 'sendNotificationToContacts']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.temperatureMeasurement', ['sendAction', 'sendPush']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.temperatureMeasurement', ['sendAction', 'sendSms']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.waterSensor', ['capability.switch', 'switch.off']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.waterSensor', ['capability.switch', 'switch.on']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.waterSensor', ['capability.valve', 'valve.close']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.waterSensor', ['sendAction', 'sendNotificationToContacts']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.waterSensor', ['sendAction', 'sendPush']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.waterSensor', ['sendAction', 'sendSms']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.contactSensor', ['capability.alarm', 'alarm.both']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.contactSensor', ['capability.alarm', 'alarm.strobe']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.colorControl', 'colorControl.off']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.colorControl', 'colorControl.setHue']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.imageCapture', 'imageCapture.take']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.contactSensor', ['capability.momentary', 'momentary.push']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.contactSensor', ['capability.switch', 'switch.currentValue']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.contactSensor', ['capability.switch', 'switch.off']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.contactSensor', ['capability.switch', 'switch.on']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.thermostat', 'thermostat.currentValue']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.contactSensor', ['capability.thermostat', 'thermostat.off']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.thermostat', 'thermostat.setThermostatMode']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.contactSensor',
#    ['locationMode', 'locationMode.setLocationMode']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.contactSensor', ['number', 'number.times']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.contactSensor', ['sendAction', 'sendNotificationToContacts']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.contactSensor', ['sendAction', 'sendPush']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.contactSensor', ['sendAction', 'sendSms']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.location', ['capability.lock', 'lock.each']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.location', ['capability.switch', 'switch.each']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.location', ['capability.switch', 'switch.off']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.location', ['capability.switch', 'switch.on']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.location', ['capability.thermostat', 'thermostat.each']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.location', ['capability.thermostat', 'thermostat.poll']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.location',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.location',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.motionSensor', ['capability.alarm', 'alarm.both']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.motionSensor', ['capability.alarm', 'alarm.strobe']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.motionSensor',
#    ['capability.imageCapture', 'imageCapture.take']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.motionSensor', ['capability.switch', 'switch.off']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.motionSensor', ['capability.switch', 'switch.on']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.motionSensor',
#    ['locationMode', 'locationMode.setLocationMode']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.motionSensor', ['number', 'number.times']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.motionSensor', ['sendAction', 'sendNotificationToContacts']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.motionSensor', ['sendAction', 'sendPush']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.motionSensor', ['sendAction', 'sendSms']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.relativeHumidityMeasurement',
#    ['capability.switch', 'switch.off']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.relativeHumidityMeasurement',
#    ['capability.switch', 'switch.on']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.relativeHumidityMeasurement', ['sendAction', 'sendPush']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.relativeHumidityMeasurement', ['sendAction', 'sendSms']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.temperatureMeasurement', ['capability.switch', 'switch.off']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.temperatureMeasurement', ['capability.switch', 'switch.on']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.temperatureMeasurement',
#    ['sendAction', 'sendNotificationToContacts']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.temperatureMeasurement', ['sendAction', 'sendPush']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.temperatureMeasurement', ['sendAction', 'sendSms']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.waterSensor', ['capability.switch', 'switch.off']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.waterSensor', ['capability.switch', 'switch.on']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.waterSensor', ['capability.valve', 'valve.close']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.waterSensor', ['sendAction', 'sendNotificationToContacts']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.waterSensor', ['sendAction', 'sendPush']]],
#  [['capability.app',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#   'temperature',
#   ['capability.waterSensor', ['sendAction', 'sendSms']]],
#  [['capability.beacon', ['capability.switch', 'switch.off']],
#   'leakage',
#   ['capability.switch', ['capability.imageCapture', 'imageCapture.take']]],
#  [['capability.beacon', ['capability.switch', 'switch.off']],
#   'leakage',
#   ['capability.switch', ['capability.switch', 'switch.off']]],
#  [['capability.beacon', ['capability.switch', 'switch.off']],
#   'leakage',
#   ['capability.switch', ['capability.switch', 'switch.on']]],
#  [['capability.beacon', ['capability.switch', 'switch.off']],
#   'leakage',
#   ['capability.switch', ['capability.switchLevel', 'switchLevel.setLevel']]],
#  [['capability.beacon', ['capability.switch', 'switch.off']],
#   'leakage',
#   ['capability.switch', ['locationMode', 'locationMode.setLocationMode']]],
#  [['capability.beacon', ['capability.switch', 'switch.off']],
#   'leakage',
#   ['capability.switch', ['number', 'number.times']]],
#  [['capability.beacon', ['capability.switch', 'switch.off']],
#   'leakage',
#   ['capability.switch', ['sendAction', 'sendNotificationToContacts']]],
#  [['capability.beacon', ['capability.switch', 'switch.off']],
#   'leakage',
#   ['capability.switch', ['sendAction', 'sendPush']]],
#  [['capability.beacon', ['capability.switch', 'switch.off']],
#   'leakage',
#   ['capability.switch', ['sendAction', 'sendSms']]],
#  [['capability.beacon', ['capability.switch', 'switch.on']],
#   'leakage',
#   ['capability.switch', ['capability.imageCapture', 'imageCapture.take']]],
#  [['capability.beacon', ['capability.switch', 'switch.on']],
#   'leakage',
#   ['capability.switch', ['capability.switch', 'switch.off']]],
#  [['capability.beacon', ['capability.switch', 'switch.on']],
#   'leakage',
#   ['capability.switch', ['capability.switch', 'switch.on']]],
#  [['capability.beacon', ['capability.switch', 'switch.on']],
#   'leakage',
#   ['capability.switch', ['capability.switchLevel', 'switchLevel.setLevel']]],
#  [['capability.beacon', ['capability.switch', 'switch.on']],
#   'leakage',
#   ['capability.switch', ['locationMode', 'locationMode.setLocationMode']]],
#  [['capability.beacon', ['capability.switch', 'switch.on']],
#   'leakage',
#   ['capability.switch', ['number', 'number.times']]],
#  [['capability.beacon', ['capability.switch', 'switch.on']],
#   'leakage',
#   ['capability.switch', ['sendAction', 'sendNotificationToContacts']]],
#  [['capability.beacon', ['capability.switch', 'switch.on']],
#   'leakage',
#   ['capability.switch', ['sendAction', 'sendPush']]],
#  [['capability.beacon', ['capability.switch', 'switch.on']],
#   'leakage',
#   ['capability.switch', ['sendAction', 'sendSms']]],
#  [['capability.carbonMonoxideDetector',
#    ['capability.thermostat', 'thermostat.setThermostatMode']],
#   'temperature',
#   ['capability.contactSensor', ['capability.alarm', 'alarm.both']]],
#  [['capability.carbonMonoxideDetector',
#    ['capability.thermostat', 'thermostat.setThermostatMode']],
#   'temperature',
#   ['capability.contactSensor', ['capability.alarm', 'alarm.strobe']]],
#  [['capability.carbonMonoxideDetector',
#    ['capability.thermostat', 'thermostat.setThermostatMode']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.colorControl', 'colorControl.off']]],
#  [['capability.carbonMonoxideDetector',
#    ['capability.thermostat', 'thermostat.setThermostatMode']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.colorControl', 'colorControl.setHue']]],
#  [['capability.carbonMonoxideDetector',
#    ['capability.thermostat', 'thermostat.setThermostatMode']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.imageCapture', 'imageCapture.take']]],
#  [['capability.carbonMonoxideDetector',
#    ['capability.thermostat', 'thermostat.setThermostatMode']],
#   'temperature',
#   ['capability.contactSensor', ['capability.momentary', 'momentary.push']]],
#  [['capability.carbonMonoxideDetector',
#    ['capability.thermostat', 'thermostat.setThermostatMode']],
#   'temperature',
#   ['capability.contactSensor', ['capability.switch', 'switch.currentValue']]],
#  [['capability.carbonMonoxideDetector',
#    ['capability.thermostat', 'thermostat.setThermostatMode']],
#   'temperature',
#   ['capability.contactSensor', ['capability.switch', 'switch.off']]],
#  [['capability.carbonMonoxideDetector',
#    ['capability.thermostat', 'thermostat.setThermostatMode']],
#   'temperature',
#   ['capability.contactSensor', ['capability.switch', 'switch.on']]],
#  [['capability.carbonMonoxideDetector',
#    ['capability.thermostat', 'thermostat.setThermostatMode']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.thermostat', 'thermostat.currentValue']]],
#  [['capability.carbonMonoxideDetector',
#    ['capability.thermostat', 'thermostat.setThermostatMode']],
#   'temperature',
#   ['capability.contactSensor', ['capability.thermostat', 'thermostat.off']]],
#  [['capability.carbonMonoxideDetector',
#    ['capability.thermostat', 'thermostat.setThermostatMode']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.thermostat', 'thermostat.setThermostatMode']]],
#  [['capability.carbonMonoxideDetector',
#    ['capability.thermostat', 'thermostat.setThermostatMode']],
#   'temperature',
#   ['capability.contactSensor',
#    ['locationMode', 'locationMode.setLocationMode']]],
#  [['capability.carbonMonoxideDetector',
#    ['capability.thermostat', 'thermostat.setThermostatMode']],
#   'temperature',
#   ['capability.contactSensor', ['number', 'number.times']]],
#  [['capability.carbonMonoxideDetector',
#    ['capability.thermostat', 'thermostat.setThermostatMode']],
#   'temperature',
#   ['capability.contactSensor', ['sendAction', 'sendNotificationToContacts']]],
#  [['capability.carbonMonoxideDetector',
#    ['capability.thermostat', 'thermostat.setThermostatMode']],
#   'temperature',
#   ['capability.contactSensor', ['sendAction', 'sendPush']]],
#  [['capability.carbonMonoxideDetector',
#    ['capability.thermostat', 'thermostat.setThermostatMode']],
#   'temperature',
#   ['capability.contactSensor', ['sendAction', 'sendSms']]],
#  [['capability.carbonMonoxideDetector',
#    ['capability.thermostat', 'thermostat.setThermostatMode']],
#   'temperature',
#   ['capability.location', ['capability.lock', 'lock.each']]],
#  [['capability.carbonMonoxideDetector',
#    ['capability.thermostat', 'thermostat.setThermostatMode']],
#   'temperature',
#   ['capability.location', ['capability.switch', 'switch.each']]],
#  [['capability.carbonMonoxideDetector',
#    ['capability.thermostat', 'thermostat.setThermostatMode']],
#   'temperature',
#   ['capability.location', ['capability.switch', 'switch.off']]],
#  [['capability.carbonMonoxideDetector',
#    ['capability.thermostat', 'thermostat.setThermostatMode']],
#   'temperature',
#   ['capability.location', ['capability.switch', 'switch.on']]],
#  [['capability.carbonMonoxideDetector',
#    ['capability.thermostat', 'thermostat.setThermostatMode']],
#   'temperature',
#   ['capability.location', ['capability.thermostat', 'thermostat.each']]],
#  [['capability.carbonMonoxideDetector',
# ...
#   'leakage',
#   ['capability.switch', ['capability.switch', 'switch.on']]],
#  [['capability.temperatureMeasurement', ['capability.switch', 'switch.on']],
#   'leakage',
#   ['capability.switch', ['capability.switchLevel', 'switchLevel.setLevel']]],
#  [['capability.temperatureMeasurement', ['capability.switch', 'switch.on']],
#   'leakage',
#   ['capability.switch', ['locationMode', 'locationMode.setLocationMode']]],
#  [['capability.temperatureMeasurement', ['capability.switch', 'switch.on']],
#   'leakage',
#   ['capability.switch', ['number', 'number.times']]],
#  [['capability.temperatureMeasurement', ['capability.switch', 'switch.on']],
#   'leakage',
#   ['capability.switch', ['sendAction', 'sendNotificationToContacts']]],
#  [['capability.temperatureMeasurement', ['capability.switch', 'switch.on']],
#   'leakage',
#   ['capability.switch', ['sendAction', 'sendPush']]],
#  [['capability.temperatureMeasurement', ['capability.switch', 'switch.on']],
#   'leakage',
#   ['capability.switch', ['sendAction', 'sendSms']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor', ['capability.alarm', 'alarm.both']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor', ['capability.alarm', 'alarm.strobe']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.colorControl', 'colorControl.off']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.colorControl', 'colorControl.setHue']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.imageCapture', 'imageCapture.take']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor', ['capability.momentary', 'momentary.push']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor', ['capability.switch', 'switch.currentValue']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor', ['capability.switch', 'switch.off']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor', ['capability.switch', 'switch.on']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.thermostat', 'thermostat.currentValue']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor', ['capability.thermostat', 'thermostat.off']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.thermostat', 'thermostat.setThermostatMode']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor',
#    ['locationMode', 'locationMode.setLocationMode']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor', ['number', 'number.times']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor', ['sendAction', 'sendNotificationToContacts']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor', ['sendAction', 'sendPush']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.contactSensor', ['sendAction', 'sendSms']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.location', ['capability.lock', 'lock.each']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.location', ['capability.switch', 'switch.each']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.location', ['capability.switch', 'switch.off']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.location', ['capability.switch', 'switch.on']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.location', ['capability.thermostat', 'thermostat.each']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.location', ['capability.thermostat', 'thermostat.poll']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.location',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.location',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.motionSensor', ['capability.alarm', 'alarm.both']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.motionSensor', ['capability.alarm', 'alarm.strobe']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.motionSensor',
#    ['capability.imageCapture', 'imageCapture.take']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.motionSensor', ['capability.switch', 'switch.off']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.motionSensor', ['capability.switch', 'switch.on']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.motionSensor',
#    ['locationMode', 'locationMode.setLocationMode']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.motionSensor', ['number', 'number.times']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.motionSensor', ['sendAction', 'sendNotificationToContacts']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.motionSensor', ['sendAction', 'sendPush']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.motionSensor', ['sendAction', 'sendSms']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.relativeHumidityMeasurement',
#    ['capability.switch', 'switch.off']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.relativeHumidityMeasurement',
#    ['capability.switch', 'switch.on']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.relativeHumidityMeasurement', ['sendAction', 'sendPush']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.relativeHumidityMeasurement', ['sendAction', 'sendSms']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.temperatureMeasurement', ['capability.switch', 'switch.off']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.temperatureMeasurement', ['capability.switch', 'switch.on']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.temperatureMeasurement',
#    ['sendAction', 'sendNotificationToContacts']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.temperatureMeasurement', ['sendAction', 'sendPush']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.temperatureMeasurement', ['sendAction', 'sendSms']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.waterSensor', ['capability.switch', 'switch.off']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.waterSensor', ['capability.switch', 'switch.on']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.waterSensor', ['capability.valve', 'valve.close']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.waterSensor', ['sendAction', 'sendNotificationToContacts']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.waterSensor', ['sendAction', 'sendPush']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.poll']],
#   'temperature',
#   ['capability.waterSensor', ['sendAction', 'sendSms']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor', ['capability.alarm', 'alarm.both']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor', ['capability.alarm', 'alarm.strobe']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.colorControl', 'colorControl.off']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.colorControl', 'colorControl.setHue']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.imageCapture', 'imageCapture.take']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor', ['capability.momentary', 'momentary.push']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor', ['capability.switch', 'switch.currentValue']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor', ['capability.switch', 'switch.off']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor', ['capability.switch', 'switch.on']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.thermostat', 'thermostat.currentValue']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor', ['capability.thermostat', 'thermostat.off']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor',
#    ['capability.thermostat', 'thermostat.setThermostatMode']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor',
#    ['locationMode', 'locationMode.setLocationMode']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor', ['number', 'number.times']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor', ['sendAction', 'sendNotificationToContacts']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor', ['sendAction', 'sendPush']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.contactSensor', ['sendAction', 'sendSms']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.location', ['capability.lock', 'lock.each']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.location', ['capability.switch', 'switch.each']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.location', ['capability.switch', 'switch.off']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.location', ['capability.switch', 'switch.on']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.location', ['capability.thermostat', 'thermostat.each']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.location', ['capability.thermostat', 'thermostat.poll']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.location',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.location',
#    ['capability.thermostat', 'thermostat.setHeatingSetpoint']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.motionSensor', ['capability.alarm', 'alarm.both']]],
#  [['capability.temperatureMeasurement',
#    ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#   'temperature',
#   ['capability.motionSensor', ['capability.alarm', 'alarm.strobe']]],
#  ...]
