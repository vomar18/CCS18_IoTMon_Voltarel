# %% [markdown]
# ## risk analysis and mitigation
# 1. channel tuple frequency analysis
# 2. channel value assignment
# 3. vector value assignment
# 4. similarity calculation
#     - risk score

# %%
import numpy as np
import json

# %%
# channel tuple frequency analysis
file = open("../1_application_analysis/2_physical_channel_identification/trigger-action_FINAL.JSON","r") # read all the capability extrapolated from the apps
trigger_action = json.load(file)
print("tot app analysed:",len(trigger_action.keys()))
# Out:
# tot app analysed: 84

# %%
#--- attention! now don't remove the duplicates pair trigger-action
list_trigger_action = []
for app in trigger_action.keys():         # for every app analysed
    for trigger in trigger_action[app].keys():      # for every trigger channel
            for action in trigger_action[app][trigger]:
                list_trigger_action.append([trigger, action]) #save capability (the channel) and action
list_trigger_action.sort()
list_trigger_action
# Out:
# [['capability.accelerationSensor',
#   ['capability.imageCapture', 'imageCapture.take']],
#  ['capability.accelerationSensor', ['capability.momentary', 'momentary.push']],
#  ['capability.accelerationSensor', ['capability.switch', 'switch.on']],
#  ['capability.accelerationSensor', ['number', 'number.times']],
#  ['capability.accelerationSensor',
#   ['sendAction', 'sendNotificationToContacts']],
#  ['capability.accelerationSensor',
#   ['sendAction', 'sendNotificationToContacts']],
#  ['capability.accelerationSensor',
#   ['sendAction', 'sendNotificationToContacts']],
#  ['capability.accelerationSensor',
#   ['sendAction', 'sendNotificationToContacts']],
#  ['capability.accelerationSensor',
#   ['sendAction', 'sendNotificationToContacts']],
#  ['capability.accelerationSensor', ['sendAction', 'sendPush']],
#  ['capability.accelerationSensor', ['sendAction', 'sendPush']],
#  ['capability.accelerationSensor', ['sendAction', 'sendPush']],
#  ['capability.accelerationSensor', ['sendAction', 'sendSms']],
#  ['capability.accelerationSensor', ['sendAction', 'sendSms']],
#  ['capability.accelerationSensor', ['sendAction', 'sendSms']],
#  ['capability.accelerationSensor', ['sendAction', 'sendSms']],
#  ['capability.accelerationSensor', ['sendAction', 'sendSms']],
#  ['capability.alarm', ['capability.alarm', 'alarm.off']],
#  ['capability.app', ['capability.alarm', 'alarm.off']],
#  ['capability.app', ['capability.doorControl', 'doorControl.each']],
#  ['capability.app', ['capability.lock', 'lock.each']],
#  ['capability.app', ['capability.lock', 'lock.each']],
#  ['capability.app', ['capability.switch', 'switch.each']],
#  ['capability.app', ['capability.switch', 'switch.each']],
#  ['capability.app', ['capability.switch', 'switch.off']],
#  ['capability.app', ['capability.switch', 'switch.on']],
#  ['capability.app', ['capability.switch', 'switch.on']],
#  ['capability.app', ['capability.thermostat', 'thermostat.each']],
#  ['capability.app', ['capability.thermostat', 'thermostat.poll']],
#  ['capability.app',
#   ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#  ['capability.app',
#   ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#  ['capability.beacon', ['capability.lock', 'lock.lock']],
#  ['capability.beacon', ['capability.lock', 'lock.unlock']],
#  ['capability.beacon', ['capability.switch', 'switch.off']],
#  ['capability.beacon', ['capability.switch', 'switch.off']],
#  ['capability.beacon', ['capability.switch', 'switch.on']],
#  ['capability.beacon', ['capability.switch', 'switch.on']],
#  ['capability.button', ['capability.colorControl', 'colorControl.off']],
#  ['capability.button', ['capability.colorControl', 'colorControl.on']],
#  ['capability.button', ['capability.colorControl', 'colorControl.setColor']],
#  ['capability.button', ['capability.colorControl', 'colorControl.setLevel']],
#  ['capability.button', ['locationMode', 'locationMode.setLocationMode']],
#  ['capability.button', ['sendAction', 'sendPush']],
#  ['capability.button', ['sendAction', 'sendSms']],
#  ['capability.carbonMonoxideDetector',
#   ['capability.thermostat', 'thermostat.setThermostatMode']],
#  ['capability.carbonMonoxideDetector',
#   ['sendAction', 'sendNotificationToContacts']],
#  ['capability.contactSensor', ['capability.alarm', 'alarm.both']],
#  ['capability.contactSensor', ['capability.alarm', 'alarm.both']],
#  ['capability.contactSensor', ['capability.alarm', 'alarm.strobe']],
#  ['capability.contactSensor', ['capability.colorControl', 'colorControl.off']],
#  ['capability.contactSensor',
#   ['capability.colorControl', 'colorControl.setHue']],
#  ['capability.contactSensor',
#   ['capability.imageCapture', 'imageCapture.take']],
#  ['capability.contactSensor', ['capability.momentary', 'momentary.push']],
#  ['capability.contactSensor', ['capability.switch', 'switch.currentValue']],
#  ['capability.contactSensor', ['capability.switch', 'switch.off']],
#  ['capability.contactSensor', ['capability.switch', 'switch.off']],
#  ['capability.contactSensor', ['capability.switch', 'switch.off']],
#  ['capability.contactSensor', ['capability.switch', 'switch.off']],
#  ['capability.contactSensor', ['capability.switch', 'switch.off']],
#  ['capability.contactSensor', ['capability.switch', 'switch.on']],
#  ['capability.contactSensor', ['capability.switch', 'switch.on']],
#  ['capability.contactSensor', ['capability.switch', 'switch.on']],
#  ['capability.contactSensor', ['capability.switch', 'switch.on']],
#  ['capability.contactSensor', ['capability.switch', 'switch.on']],
#  ['capability.contactSensor', ['capability.switch', 'switch.on']],
#  ['capability.contactSensor', ['capability.switch', 'switch.on']],
#  ['capability.contactSensor', ['capability.switch', 'switch.on']],
#  ['capability.contactSensor',
#   ['capability.thermostat', 'thermostat.currentValue']],
#  ['capability.contactSensor', ['capability.thermostat', 'thermostat.off']],
#  ['capability.contactSensor',
#   ['capability.thermostat', 'thermostat.setThermostatMode']],
#  ['capability.contactSensor',
#   ['locationMode', 'locationMode.setLocationMode']],
#  ['capability.contactSensor', ['number', 'number.times']],
#  ['capability.contactSensor', ['sendAction', 'sendNotificationToContacts']],
#  ['capability.contactSensor', ['sendAction', 'sendNotificationToContacts']],
#  ['capability.contactSensor', ['sendAction', 'sendNotificationToContacts']],
#  ['capability.contactSensor', ['sendAction', 'sendNotificationToContacts']],
#  ['capability.contactSensor', ['sendAction', 'sendPush']],
#  ['capability.contactSensor', ['sendAction', 'sendPush']],
#  ['capability.contactSensor', ['sendAction', 'sendPush']],
#  ['capability.contactSensor', ['sendAction', 'sendPush']],
#  ['capability.contactSensor', ['sendAction', 'sendPush']],
#  ['capability.contactSensor', ['sendAction', 'sendPush']],
#  ['capability.contactSensor', ['sendAction', 'sendSms']],
#  ['capability.contactSensor', ['sendAction', 'sendSms']],
#  ['capability.contactSensor', ['sendAction', 'sendSms']],
#  ['capability.contactSensor', ['sendAction', 'sendSms']],
#  ['capability.contactSensor', ['sendAction', 'sendSms']],
#  ['capability.contactSensor', ['sendAction', 'sendSms']],
#  ['capability.illuminanceMeasurement', ['capability.switch', 'switch.off']],
#  ['capability.illuminanceMeasurement', ['capability.switch', 'switch.on']],
#  ['capability.location', ['capability.lock', 'lock.each']],
#  ['capability.location', ['capability.switch', 'switch.each']],
#  ['capability.location', ['capability.switch', 'switch.off']],
#  ['capability.location', ['capability.switch', 'switch.on']],
#  ['capability.location', ['capability.thermostat', 'thermostat.each']],
#  ['capability.location', ['capability.thermostat', 'thermostat.poll']],
#  ['capability.location', ['capability.thermostat', 'thermostat.poll']],
#  ['capability.location',
#   ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#  ['capability.location',
#   ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#  ['capability.location',
#   ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#  ['capability.location',
#   ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#  ['capability.motionSensor', ['capability.alarm', 'alarm.both']],
#  ['capability.motionSensor', ['capability.alarm', 'alarm.both']],
#  ['capability.motionSensor', ['capability.alarm', 'alarm.strobe']],
#  ['capability.motionSensor', ['capability.imageCapture', 'imageCapture.take']],
#  ['capability.motionSensor', ['capability.switch', 'switch.off']],
#  ['capability.motionSensor', ['capability.switch', 'switch.off']],
#  ['capability.motionSensor', ['capability.switch', 'switch.off']],
#  ['capability.motionSensor', ['capability.switch', 'switch.off']],
#  ['capability.motionSensor', ['capability.switch', 'switch.off']],
#  ['capability.motionSensor', ['capability.switch', 'switch.on']],
#  ['capability.motionSensor', ['capability.switch', 'switch.on']],
#  ['capability.motionSensor', ['capability.switch', 'switch.on']],
#  ['capability.motionSensor', ['capability.switch', 'switch.on']],
#  ['capability.motionSensor', ['capability.switch', 'switch.on']],
#  ['capability.motionSensor', ['capability.switch', 'switch.on']],
#  ['capability.motionSensor', ['capability.switch', 'switch.on']],
#  ['capability.motionSensor', ['locationMode', 'locationMode.setLocationMode']],
#  ['capability.motionSensor', ['locationMode', 'locationMode.setLocationMode']],
#  ['capability.motionSensor', ['locationMode', 'locationMode.setLocationMode']],
#  ['capability.motionSensor', ['number', 'number.times']],
#  ['capability.motionSensor', ['sendAction', 'sendNotificationToContacts']],
#  ['capability.motionSensor', ['sendAction', 'sendNotificationToContacts']],
#  ['capability.motionSensor', ['sendAction', 'sendNotificationToContacts']],
#  ['capability.motionSensor', ['sendAction', 'sendNotificationToContacts']],
#  ['capability.motionSensor', ['sendAction', 'sendNotificationToContacts']],
#  ['capability.motionSensor', ['sendAction', 'sendNotificationToContacts']],
#  ['capability.motionSensor', ['sendAction', 'sendNotificationToContacts']],
#  ['capability.motionSensor', ['sendAction', 'sendPush']],
#  ['capability.motionSensor', ['sendAction', 'sendPush']],
#  ['capability.motionSensor', ['sendAction', 'sendPush']],
#  ['capability.motionSensor', ['sendAction', 'sendPush']],
#  ['capability.motionSensor', ['sendAction', 'sendPush']],
#  ['capability.motionSensor', ['sendAction', 'sendPush']],
#  ['capability.motionSensor', ['sendAction', 'sendPush']],
#  ['capability.motionSensor', ['sendAction', 'sendSms']],
#  ['capability.motionSensor', ['sendAction', 'sendSms']],
#  ['capability.motionSensor', ['sendAction', 'sendSms']],
#  ['capability.motionSensor', ['sendAction', 'sendSms']],
#  ['capability.motionSensor', ['sendAction', 'sendSms']],
#  ['capability.motionSensor', ['sendAction', 'sendSms']],
#  ['capability.motionSensor', ['sendAction', 'sendSms']],
#  ['capability.motionSensor', ['sendAction', 'sendSms']],
#  ['capability.powerMeter', ['capability.switch', 'switch.off']],
#  ['capability.powerMeter', ['sendAction', 'sendNotificationToContacts']],
#  ['capability.powerMeter', ['sendAction', 'sendPush']],
#  ['capability.powerMeter', ['sendAction', 'sendSms']],
#  ['capability.presenceSensor',
#   ['capability.imageCapture', 'imageCapture.take']],
#  ['capability.presenceSensor', ['capability.lock', 'lock.lock']],
#  ['capability.presenceSensor', ['capability.lock', 'lock.unlock']],
#  ['capability.presenceSensor', ['capability.lock', 'lock.unlock']],
#  ['capability.presenceSensor', ['capability.momentary', 'momentary.push']],
#  ['capability.presenceSensor', ['capability.switch', 'switch.off']],
#  ['capability.presenceSensor', ['capability.switch', 'switch.off']],
#  ['capability.presenceSensor', ['capability.switch', 'switch.off']],
#  ['capability.presenceSensor', ['capability.switch', 'switch.off']],
#  ['capability.presenceSensor', ['capability.switch', 'switch.on']],
#  ['capability.presenceSensor', ['capability.switch', 'switch.on']],
#  ['capability.presenceSensor', ['capability.switch', 'switch.on']],
#  ['capability.presenceSensor',
#   ['locationMode', 'locationMode.setLocationMode']],
#  ['capability.presenceSensor',
#   ['locationMode', 'locationMode.setLocationMode']],
#  ['capability.presenceSensor', ['number', 'number.times']],
#  ['capability.presenceSensor', ['sendAction', 'sendNotificationToContacts']],
#  ['capability.presenceSensor', ['sendAction', 'sendNotificationToContacts']],
#  ['capability.presenceSensor', ['sendAction', 'sendNotificationToContacts']],
#  ['capability.presenceSensor', ['sendAction', 'sendNotificationToContacts']],
#  ['capability.presenceSensor', ['sendAction', 'sendNotificationToContacts']],
#  ['capability.presenceSensor', ['sendAction', 'sendNotificationToContacts']],
#  ['capability.presenceSensor', ['sendAction', 'sendPush']],
#  ['capability.presenceSensor', ['sendAction', 'sendPush']],
#  ['capability.presenceSensor', ['sendAction', 'sendPush']],
#  ['capability.presenceSensor', ['sendAction', 'sendPush']],
#  ['capability.presenceSensor', ['sendAction', 'sendPush']],
#  ['capability.presenceSensor', ['sendAction', 'sendPush']],
#  ['capability.presenceSensor', ['sendAction', 'sendPush']],
#  ['capability.presenceSensor', ['sendAction', 'sendSms']],
#  ['capability.presenceSensor', ['sendAction', 'sendSms']],
#  ['capability.presenceSensor', ['sendAction', 'sendSms']],
#  ['capability.presenceSensor', ['sendAction', 'sendSms']],
#  ['capability.presenceSensor', ['sendAction', 'sendSms']],
#  ['capability.relativeHumidityMeasurement',
#   ['capability.switch', 'switch.off']],
#  ['capability.relativeHumidityMeasurement',
#   ['capability.switch', 'switch.off']],
#  ['capability.relativeHumidityMeasurement',
#   ['capability.switch', 'switch.on']],
#  ['capability.relativeHumidityMeasurement',
#   ['capability.switch', 'switch.on']],
#  ['capability.relativeHumidityMeasurement', ['sendAction', 'sendPush']],
#  ['capability.relativeHumidityMeasurement', ['sendAction', 'sendPush']],
#  ['capability.relativeHumidityMeasurement', ['sendAction', 'sendSms']],
#  ['capability.relativeHumidityMeasurement', ['sendAction', 'sendSms']],
#  ['capability.smokeDetector',
#   ['capability.thermostat', 'thermostat.setThermostatMode']],
#  ['capability.smokeDetector', ['sendAction', 'sendNotificationToContacts']],
#  ['capability.switch', ['capability.imageCapture', 'imageCapture.take']],
#  ['capability.switch', ['capability.switch', 'switch.off']],
#  ['capability.switch', ['capability.switch', 'switch.off']],
#  ['capability.switch', ['capability.switch', 'switch.off']],
#  ['capability.switch', ['capability.switch', 'switch.on']],
#  ['capability.switch', ['capability.switchLevel', 'switchLevel.setLevel']],
#  ['capability.switch', ['locationMode', 'locationMode.setLocationMode']],
#  ['capability.switch', ['number', 'number.times']],
#  ['capability.switch', ['sendAction', 'sendNotificationToContacts']],
#  ['capability.switch', ['sendAction', 'sendNotificationToContacts']],
#  ['capability.switch', ['sendAction', 'sendPush']],
#  ['capability.switch', ['sendAction', 'sendPush']],
#  ['capability.switch', ['sendAction', 'sendSms']],
#  ['capability.switch', ['sendAction', 'sendSms']],
#  ['capability.temperatureMeasurement', ['capability.switch', 'switch.off']],
#  ['capability.temperatureMeasurement', ['capability.switch', 'switch.off']],
#  ['capability.temperatureMeasurement', ['capability.switch', 'switch.on']],
#  ['capability.temperatureMeasurement', ['capability.switch', 'switch.on']],
#  ['capability.temperatureMeasurement', ['capability.switch', 'switch.on']],
#  ['capability.temperatureMeasurement', ['capability.switch', 'switch.on']],
#  ['capability.temperatureMeasurement',
#   ['capability.thermostat', 'thermostat.poll']],
#  ['capability.temperatureMeasurement',
#   ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#  ['capability.temperatureMeasurement',
#   ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#  ['capability.temperatureMeasurement',
#   ['sendAction', 'sendNotificationToContacts']],
#  ['capability.temperatureMeasurement',
#   ['sendAction', 'sendNotificationToContacts']],
#  ['capability.temperatureMeasurement', ['sendAction', 'sendPush']],
#  ['capability.temperatureMeasurement', ['sendAction', 'sendPush']],
#  ['capability.temperatureMeasurement', ['sendAction', 'sendSms']],
#  ['capability.temperatureMeasurement', ['sendAction', 'sendSms']],
#  ['capability.thermostat', ['capability.switch', 'switch.off']],
#  ['capability.thermostat', ['capability.switch', 'switch.on']],
#  ['capability.thermostat', ['capability.thermostat', 'thermostat.poll']],
#  ['capability.thermostat',
#   ['capability.thermostat', 'thermostat.setCoolingSetpoint']],
#  ['capability.thermostat',
#   ['capability.thermostat', 'thermostat.setHeatingSetpoint']],
#  ['capability.threeAxis', ['sendAction', 'sendNotificationToContacts']],
#  ['capability.threeAxis', ['sendAction', 'sendPush']],
#  ['capability.threeAxis', ['sendAction', 'sendSms']],
#  ['capability.touchSensor', ['capability.doorControl', 'doorControl.each']],
#  ['capability.touchSensor', ['capability.lock', 'lock.each']],
#  ['capability.touchSensor', ['capability.switch', 'switch.each']],
#  ['capability.waterSensor', ['capability.switch', 'switch.off']],
#  ['capability.waterSensor', ['capability.switch', 'switch.on']],
#  ['capability.waterSensor', ['capability.valve', 'valve.close']],
#  ['capability.waterSensor', ['sendAction', 'sendNotificationToContacts']],
#  ['capability.waterSensor', ['sendAction', 'sendPush']],
#  ['capability.waterSensor', ['sendAction', 'sendPush']],
#  ['capability.waterSensor', ['sendAction', 'sendSms']],
#  ['capability.waterSensor', ['sendAction', 'sendSms']],
#  ['time', ['capability.lock', 'lock.lock']],
#  ['time', ['capability.switch', 'switch.off']],
#  ['time', ['capability.switch', 'switch.off']],
#  ['time', ['capability.switch', 'switch.on']],
#  ['time', ['capability.switch', 'switch.on']],
#  ['time', ['device.PetFeederShield', 'device.PetFeederShield.feed']],
#  ['time', ['locationMode', 'locationMode.setLocationMode']],
#  ['time', ['sendAction', 'sendNotificationToContacts']],
#  ['time', ['sendAction', 'sendNotificationToContacts']],
#  ['time', ['sendAction', 'sendNotificationToContacts']],
#  ['time', ['sendAction', 'sendNotificationToContacts']],
#  ['time', ['sendAction', 'sendNotificationToContacts']],
#  ['time', ['sendAction', 'sendNotificationToContacts']],
#  ['time', ['sendAction', 'sendPush']],
#  ['time', ['sendAction', 'sendPush']],
#  ['time', ['sendAction', 'sendPush']],
#  ['time', ['sendAction', 'sendPush']],
#  ['time', ['sendAction', 'sendPush']],
#  ['time', ['sendAction', 'sendSms']],
#  ['time', ['sendAction', 'sendSms']],
#  ['time', ['sendAction', 'sendSms']],
#  ['time', ['sendAction', 'sendSms']],
#  ['time', ['sendAction', 'sendSms']],
#  ['time', ['sendAction', 'sendSms']],
#  ['time', ['sendAction', 'sendSms']]]

# %%
with open("../1_application_analysis/2_physical_channel_identification/set_of_capability_related_physical_channels.JSON","r") as inputfile:
    dict_channels_capabilities = json.load(inputfile)
dict_channels_capabilities
# Out:
# {'temperature': ['capability.contactSensor',
#   'capability.waterSensor',
#   'capability.temperatureMeasurement',
#   'capability.thermostat',
#   'capability.location',
#   'capability.relativeHumidityMeasurement',
#   'capability.motionSensor'],
#  'humidity': ['capability.relativeHumidityMeasurement',
#   'capability.location',
#   'capability.contactSensor'],
#  'illumination': ['capability.presenceSensor',
#   'capability.contactSensor',
#   'capability.touchSensor',
#   'capability.location'],
#  'location': ['capability.beacon',
#   'capability.motionSensor',
#   'capability.presenceSensor',
#   'capability.contactSensor',
#   'capability.location',
#   'capability.smokeDetector',
#   'capability.carbonMonoxideDetector'],
#  'motion': ['capability.motionSensor',
#   'capability.location',
#   'capability.presenceSensor',
#   'capability.accelerationSensor',
#   'capability.contactSensor'],
#  'smoke': ['capability.temperatureMeasurement',
#   'capability.thermostat',
#   'capability.contactSensor'],
#  'leakage': ['capability.presenceSensor',
#   'capability.waterSensor',
#   'capability.threeAxis',
#   'capability.accelerationSensor',
#   'capability.contactSensor',
#   'capability.motionSensor']}

# %%
system_capabilities = [ "capability.app","time", "sendAction", "locationMode", "hub",
                        "capability.switch", "capability.lock", "capability.button",
                        "capability.powerMeter","device.jawboneUser", "capability.alarm"]

# %%
# find all the channel tuple 
channel_tuple = []
for trig_act in list_trigger_action: # take every pair trigger-action
    trigger_cap = trig_act[0]
    action_cap = trig_act[1][0]
    if (trigger_cap in system_capabilities) and (action_cap in system_capabilities):
        channel_tuple.append([trigger_cap, action_cap])
    elif not(trigger_cap in system_capabilities) and (action_cap in system_capabilities):
        for tri_channel in dict_channels_capabilities.keys():
            if trigger_cap in dict_channels_capabilities[tri_channel]:
                channel_tuple.append([tri_channel, action_cap])
    elif trigger_cap in system_capabilities and not(action_cap in system_capabilities):
        for act_channel in dict_channels_capabilities.keys():
            if action_cap in dict_channels_capabilities[act_channel]:
                channel_tuple.append([trigger_cap, act_channel])
    else:
        for tri_channel in dict_channels_capabilities.keys():
            if trigger_cap in dict_channels_capabilities[tri_channel]:
                for cap_channel in dict_channels_capabilities.keys():
                    if action_cap in dict_channels_capabilities[cap_channel]:
                        channel_tuple.append([tri_channel, cap_channel])
print(len(channel_tuple))
channel_tuple.sort()
channel_tuple
# Out:
# 836
# [['capability.alarm', 'capability.alarm'],
#  ['capability.app', 'capability.alarm'],
#  ['capability.app', 'capability.lock'],
#  ['capability.app', 'capability.lock'],
#  ['capability.app', 'capability.switch'],
#  ['capability.app', 'capability.switch'],
#  ['capability.app', 'capability.switch'],
#  ['capability.app', 'capability.switch'],
#  ['capability.app', 'capability.switch'],
#  ['capability.app', 'smoke'],
#  ['capability.app', 'smoke'],
#  ['capability.app', 'smoke'],
#  ['capability.app', 'smoke'],
#  ['capability.app', 'temperature'],
#  ['capability.app', 'temperature'],
#  ['capability.app', 'temperature'],
#  ['capability.app', 'temperature'],
#  ['capability.button', 'locationMode'],
#  ['capability.button', 'sendAction'],
#  ['capability.button', 'sendAction'],
#  ['capability.powerMeter', 'capability.switch'],
#  ['capability.powerMeter', 'sendAction'],
#  ['capability.powerMeter', 'sendAction'],
#  ['capability.powerMeter', 'sendAction'],
#  ['capability.switch', 'capability.switch'],
#  ['capability.switch', 'capability.switch'],
#  ['capability.switch', 'capability.switch'],
#  ['capability.switch', 'capability.switch'],
#  ['capability.switch', 'locationMode'],
#  ['capability.switch', 'sendAction'],
#  ['capability.switch', 'sendAction'],
#  ['capability.switch', 'sendAction'],
#  ['capability.switch', 'sendAction'],
#  ['capability.switch', 'sendAction'],
#  ['capability.switch', 'sendAction'],
#  ['humidity', 'capability.alarm'],
#  ['humidity', 'capability.alarm'],
#  ['humidity', 'capability.alarm'],
#  ['humidity', 'capability.lock'],
#  ['humidity', 'capability.switch'],
#  ['humidity', 'capability.switch'],
#  ['humidity', 'capability.switch'],
#  ['humidity', 'capability.switch'],
#  ['humidity', 'capability.switch'],
#  ['humidity', 'capability.switch'],
#  ['humidity', 'capability.switch'],
#  ['humidity', 'capability.switch'],
#  ['humidity', 'capability.switch'],
#  ['humidity', 'capability.switch'],
#  ['humidity', 'capability.switch'],
#  ['humidity', 'capability.switch'],
#  ['humidity', 'capability.switch'],
#  ['humidity', 'capability.switch'],
#  ['humidity', 'capability.switch'],
#  ['humidity', 'capability.switch'],
#  ['humidity', 'capability.switch'],
#  ['humidity', 'capability.switch'],
#  ['humidity', 'capability.switch'],
#  ['humidity', 'capability.switch'],
#  ['humidity', 'capability.switch'],
#  ['humidity', 'locationMode'],
#  ['humidity', 'sendAction'],
#  ['humidity', 'sendAction'],
#  ['humidity', 'sendAction'],
#  ['humidity', 'sendAction'],
#  ['humidity', 'sendAction'],
#  ['humidity', 'sendAction'],
#  ['humidity', 'sendAction'],
#  ['humidity', 'sendAction'],
#  ['humidity', 'sendAction'],
#  ['humidity', 'sendAction'],
#  ['humidity', 'sendAction'],
#  ['humidity', 'sendAction'],
#  ['humidity', 'sendAction'],
#  ['humidity', 'sendAction'],
#  ['humidity', 'sendAction'],
#  ['humidity', 'sendAction'],
#  ['humidity', 'sendAction'],
#  ['humidity', 'sendAction'],
#  ['humidity', 'sendAction'],
#  ['humidity', 'sendAction'],
#  ['humidity', 'smoke'],
#  ['humidity', 'smoke'],
#  ['humidity', 'smoke'],
#  ['humidity', 'smoke'],
#  ['humidity', 'smoke'],
#  ['humidity', 'smoke'],
#  ['humidity', 'smoke'],
#  ['humidity', 'smoke'],
#  ['humidity', 'smoke'],
#  ['humidity', 'smoke'],
#  ['humidity', 'temperature'],
#  ['humidity', 'temperature'],
#  ['humidity', 'temperature'],
#  ['humidity', 'temperature'],
#  ['humidity', 'temperature'],
#  ['humidity', 'temperature'],
#  ['humidity', 'temperature'],
#  ['humidity', 'temperature'],
#  ['humidity', 'temperature'],
#  ['humidity', 'temperature'],
#  ['illumination', 'capability.alarm'],
#  ['illumination', 'capability.alarm'],
#  ['illumination', 'capability.alarm'],
#  ['illumination', 'capability.lock'],
#  ['illumination', 'capability.lock'],
#  ['illumination', 'capability.lock'],
#  ['illumination', 'capability.lock'],
#  ['illumination', 'capability.lock'],
#  ['illumination', 'capability.switch'],
#  ['illumination', 'capability.switch'],
#  ['illumination', 'capability.switch'],
#  ['illumination', 'capability.switch'],
#  ['illumination', 'capability.switch'],
#  ['illumination', 'capability.switch'],
#  ['illumination', 'capability.switch'],
#  ['illumination', 'capability.switch'],
#  ['illumination', 'capability.switch'],
#  ['illumination', 'capability.switch'],
#  ['illumination', 'capability.switch'],
#  ['illumination', 'capability.switch'],
#  ['illumination', 'capability.switch'],
#  ['illumination', 'capability.switch'],
#  ['illumination', 'capability.switch'],
#  ['illumination', 'capability.switch'],
#  ['illumination', 'capability.switch'],
#  ['illumination', 'capability.switch'],
#  ['illumination', 'capability.switch'],
#  ['illumination', 'capability.switch'],
#  ['illumination', 'capability.switch'],
#  ['illumination', 'capability.switch'],
#  ['illumination', 'capability.switch'],
#  ['illumination', 'capability.switch'],
#  ['illumination', 'capability.switch'],
#  ['illumination', 'locationMode'],
#  ['illumination', 'locationMode'],
#  ['illumination', 'locationMode'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'sendAction'],
#  ['illumination', 'smoke'],
#  ['illumination', 'smoke'],
#  ['illumination', 'smoke'],
#  ['illumination', 'smoke'],
#  ['illumination', 'smoke'],
#  ['illumination', 'smoke'],
#  ['illumination', 'smoke'],
#  ['illumination', 'smoke'],
#  ['illumination', 'smoke'],
#  ['illumination', 'smoke'],
#  ['illumination', 'temperature'],
#  ['illumination', 'temperature'],
#  ['illumination', 'temperature'],
#  ['illumination', 'temperature'],
#  ['illumination', 'temperature'],
#  ['illumination', 'temperature'],
#  ['illumination', 'temperature'],
#  ['illumination', 'temperature'],
#  ['illumination', 'temperature'],
#  ['illumination', 'temperature'],
#  ['leakage', 'capability.alarm'],
#  ['leakage', 'capability.alarm'],
#  ['leakage', 'capability.alarm'],
#  ['leakage', 'capability.alarm'],
#  ['leakage', 'capability.alarm'],
#  ['leakage', 'capability.alarm'],
#  ['leakage', 'capability.lock'],
#  ['leakage', 'capability.lock'],
#  ['leakage', 'capability.lock'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'capability.switch'],
#  ['leakage', 'locationMode'],
#  ['leakage', 'locationMode'],
#  ['leakage', 'locationMode'],
#  ['leakage', 'locationMode'],
#  ['leakage', 'locationMode'],
#  ['leakage', 'locationMode'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'sendAction'],
#  ['leakage', 'smoke'],
#  ['leakage', 'smoke'],
#  ['leakage', 'smoke'],
#  ['leakage', 'temperature'],
#  ['leakage', 'temperature'],
#  ['leakage', 'temperature'],
#  ['location', 'capability.alarm'],
#  ['location', 'capability.alarm'],
#  ['location', 'capability.alarm'],
#  ['location', 'capability.alarm'],
#  ['location', 'capability.alarm'],
#  ['location', 'capability.alarm'],
#  ['location', 'capability.lock'],
#  ['location', 'capability.lock'],
#  ['location', 'capability.lock'],
#  ['location', 'capability.lock'],
#  ['location', 'capability.lock'],
#  ['location', 'capability.lock'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'capability.switch'],
#  ['location', 'locationMode'],
#  ['location', 'locationMode'],
#  ['location', 'locationMode'],
#  ['location', 'locationMode'],
#  ['location', 'locationMode'],
#  ['location', 'locationMode'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'sendAction'],
#  ['location', 'smoke'],
#  ['location', 'smoke'],
#  ['location', 'smoke'],
#  ['location', 'smoke'],
#  ['location', 'smoke'],
#  ['location', 'smoke'],
#  ['location', 'smoke'],
#  ['location', 'smoke'],
#  ['location', 'smoke'],
#  ['location', 'smoke'],
#  ['location', 'smoke'],
#  ['location', 'smoke'],
#  ['location', 'temperature'],
#  ['location', 'temperature'],
#  ['location', 'temperature'],
#  ['location', 'temperature'],
#  ['location', 'temperature'],
#  ['location', 'temperature'],
#  ['location', 'temperature'],
#  ['location', 'temperature'],
#  ['location', 'temperature'],
#  ['location', 'temperature'],
#  ['location', 'temperature'],
#  ['location', 'temperature'],
#  ['motion', 'capability.alarm'],
#  ['motion', 'capability.alarm'],
#  ['motion', 'capability.alarm'],
#  ['motion', 'capability.alarm'],
#  ['motion', 'capability.alarm'],
#  ['motion', 'capability.alarm'],
#  ['motion', 'capability.lock'],
#  ['motion', 'capability.lock'],
#  ['motion', 'capability.lock'],
#  ['motion', 'capability.lock'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'capability.switch'],
#  ['motion', 'locationMode'],
#  ['motion', 'locationMode'],
#  ['motion', 'locationMode'],
#  ['motion', 'locationMode'],
#  ['motion', 'locationMode'],
#  ['motion', 'locationMode'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'sendAction'],
#  ['motion', 'smoke'],
#  ['motion', 'smoke'],
#  ['motion', 'smoke'],
#  ['motion', 'smoke'],
#  ['motion', 'smoke'],
#  ['motion', 'smoke'],
#  ['motion', 'smoke'],
#  ['motion', 'smoke'],
#  ['motion', 'smoke'],
#  ['motion', 'smoke'],
#  ['motion', 'temperature'],
#  ['motion', 'temperature'],
#  ['motion', 'temperature'],
#  ['motion', 'temperature'],
#  ['motion', 'temperature'],
#  ['motion', 'temperature'],
#  ['motion', 'temperature'],
#  ['motion', 'temperature'],
#  ['motion', 'temperature'],
#  ['motion', 'temperature'],
#  ['smoke', 'capability.alarm'],
#  ['smoke', 'capability.alarm'],
#  ['smoke', 'capability.alarm'],
#  ['smoke', 'capability.switch'],
#  ['smoke', 'capability.switch'],
#  ['smoke', 'capability.switch'],
#  ['smoke', 'capability.switch'],
#  ['smoke', 'capability.switch'],
#  ['smoke', 'capability.switch'],
#  ['smoke', 'capability.switch'],
#  ['smoke', 'capability.switch'],
#  ['smoke', 'capability.switch'],
#  ['smoke', 'capability.switch'],
#  ['smoke', 'capability.switch'],
#  ['smoke', 'capability.switch'],
#  ['smoke', 'capability.switch'],
#  ['smoke', 'capability.switch'],
#  ['smoke', 'capability.switch'],
#  ['smoke', 'capability.switch'],
#  ['smoke', 'capability.switch'],
#  ['smoke', 'capability.switch'],
#  ['smoke', 'capability.switch'],
#  ['smoke', 'capability.switch'],
#  ['smoke', 'capability.switch'],
#  ['smoke', 'capability.switch'],
#  ['smoke', 'locationMode'],
#  ['smoke', 'sendAction'],
#  ['smoke', 'sendAction'],
#  ['smoke', 'sendAction'],
#  ['smoke', 'sendAction'],
#  ['smoke', 'sendAction'],
#  ['smoke', 'sendAction'],
#  ['smoke', 'sendAction'],
#  ['smoke', 'sendAction'],
#  ['smoke', 'sendAction'],
#  ['smoke', 'sendAction'],
#  ['smoke', 'sendAction'],
#  ['smoke', 'sendAction'],
#  ['smoke', 'sendAction'],
#  ['smoke', 'sendAction'],
#  ['smoke', 'sendAction'],
#  ['smoke', 'sendAction'],
#  ['smoke', 'sendAction'],
#  ['smoke', 'sendAction'],
#  ['smoke', 'sendAction'],
#  ['smoke', 'sendAction'],
#  ['smoke', 'sendAction'],
#  ['smoke', 'sendAction'],
#  ['smoke', 'smoke'],
#  ['smoke', 'smoke'],
#  ['smoke', 'smoke'],
#  ['smoke', 'smoke'],
#  ['smoke', 'smoke'],
#  ['smoke', 'smoke'],
#  ['smoke', 'smoke'],
#  ['smoke', 'smoke'],
#  ['smoke', 'smoke'],
#  ['smoke', 'temperature'],
#  ['smoke', 'temperature'],
#  ['smoke', 'temperature'],
#  ['smoke', 'temperature'],
#  ['smoke', 'temperature'],
#  ['smoke', 'temperature'],
#  ['smoke', 'temperature'],
#  ['smoke', 'temperature'],
#  ['smoke', 'temperature'],
#  ['temperature', 'capability.alarm'],
#  ['temperature', 'capability.alarm'],
#  ['temperature', 'capability.alarm'],
#  ['temperature', 'capability.alarm'],
#  ['temperature', 'capability.alarm'],
#  ['temperature', 'capability.alarm'],
#  ['temperature', 'capability.lock'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'capability.switch'],
#  ['temperature', 'locationMode'],
#  ['temperature', 'locationMode'],
#  ['temperature', 'locationMode'],
#  ['temperature', 'locationMode'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'sendAction'],
#  ['temperature', 'smoke'],
#  ['temperature', 'smoke'],
#  ['temperature', 'smoke'],
#  ['temperature', 'smoke'],
#  ['temperature', 'smoke'],
#  ['temperature', 'smoke'],
#  ['temperature', 'smoke'],
#  ['temperature', 'smoke'],
#  ['temperature', 'smoke'],
#  ['temperature', 'smoke'],
#  ['temperature', 'smoke'],
#  ['temperature', 'smoke'],
#  ['temperature', 'smoke'],
#  ['temperature', 'smoke'],
#  ['temperature', 'smoke'],
#  ['temperature', 'smoke'],
#  ['temperature', 'temperature'],
#  ['temperature', 'temperature'],
#  ['temperature', 'temperature'],
#  ['temperature', 'temperature'],
#  ['temperature', 'temperature'],
#  ['temperature', 'temperature'],
#  ['temperature', 'temperature'],
#  ['temperature', 'temperature'],
#  ['temperature', 'temperature'],
#  ['temperature', 'temperature'],
#  ['temperature', 'temperature'],
#  ['temperature', 'temperature'],
#  ['temperature', 'temperature'],
#  ['temperature', 'temperature'],
#  ['temperature', 'temperature'],
#  ['temperature', 'temperature'],
#  ['time', 'capability.lock'],
#  ['time', 'capability.switch'],
#  ['time', 'capability.switch'],
#  ['time', 'capability.switch'],
#  ['time', 'capability.switch'],
#  ['time', 'locationMode'],
#  ['time', 'sendAction'],
#  ['time', 'sendAction'],
#  ['time', 'sendAction'],
#  ['time', 'sendAction'],
#  ['time', 'sendAction'],
#  ['time', 'sendAction'],
#  ['time', 'sendAction'],
#  ['time', 'sendAction'],
#  ['time', 'sendAction'],
#  ['time', 'sendAction'],
#  ['time', 'sendAction'],
#  ['time', 'sendAction'],
#  ['time', 'sendAction'],
#  ['time', 'sendAction'],
#  ['time', 'sendAction'],
#  ['time', 'sendAction'],
#  ['time', 'sendAction'],
#  ['time', 'sendAction']]

# %%
def freq(pair):
    return pair[1]

result = []
tuple_found = []
for i in channel_tuple:
    if not i in tuple_found:
        frequency = channel_tuple.count(i)
        tuple_found.append(i)
        result.append([i, frequency])

result.sort(reverse=True, key=freq)
result
# Out:
# [[['leakage', 'sendAction'], 77],
#  [['motion', 'sendAction'], 69],
#  [['location', 'sendAction'], 58],
#  [['temperature', 'sendAction'], 53],
#  [['temperature', 'capability.switch'], 43],
#  [['location', 'capability.switch'], 40],
#  [['motion', 'capability.switch'], 37],
#  [['leakage', 'capability.switch'], 36],
#  [['illumination', 'sendAction'], 34],
#  [['illumination', 'capability.switch'], 25],
#  [['smoke', 'capability.switch'], 22],
#  [['smoke', 'sendAction'], 22],
#  [['humidity', 'capability.switch'], 21],
#  [['humidity', 'sendAction'], 20],
#  [['time', 'sendAction'], 18],
#  [['temperature', 'smoke'], 16],
#  [['temperature', 'temperature'], 16],
#  [['location', 'smoke'], 12],
#  [['location', 'temperature'], 12],
#  [['humidity', 'smoke'], 10],
#  [['humidity', 'temperature'], 10],
#  [['illumination', 'smoke'], 10],
#  [['illumination', 'temperature'], 10],
#  [['motion', 'smoke'], 10],
#  [['motion', 'temperature'], 10],
#  [['smoke', 'smoke'], 9],
#  [['smoke', 'temperature'], 9],
#  [['capability.switch', 'sendAction'], 6],
#  [['leakage', 'capability.alarm'], 6],
#  [['leakage', 'locationMode'], 6],
#  [['location', 'capability.alarm'], 6],
#  [['location', 'capability.lock'], 6],
#  [['location', 'locationMode'], 6],
#  [['motion', 'capability.alarm'], 6],
#  [['motion', 'locationMode'], 6],
#  [['temperature', 'capability.alarm'], 6],
#  [['capability.app', 'capability.switch'], 5],
#  [['illumination', 'capability.lock'], 5],
#  [['capability.app', 'smoke'], 4],
#  [['capability.app', 'temperature'], 4],
#  [['capability.switch', 'capability.switch'], 4],
#  [['motion', 'capability.lock'], 4],
#  [['temperature', 'locationMode'], 4],
#  [['time', 'capability.switch'], 4],
#  [['capability.powerMeter', 'sendAction'], 3],
#  [['humidity', 'capability.alarm'], 3],
#  [['illumination', 'capability.alarm'], 3],
#  [['illumination', 'locationMode'], 3],
#  [['leakage', 'capability.lock'], 3],
#  [['leakage', 'smoke'], 3],
#  [['leakage', 'temperature'], 3],
#  [['smoke', 'capability.alarm'], 3],
#  [['capability.app', 'capability.lock'], 2],
#  [['capability.button', 'sendAction'], 2],
#  [['capability.alarm', 'capability.alarm'], 1],
#  [['capability.app', 'capability.alarm'], 1],
#  [['capability.button', 'locationMode'], 1],
#  [['capability.powerMeter', 'capability.switch'], 1],
#  [['capability.switch', 'locationMode'], 1],
#  [['humidity', 'capability.lock'], 1],
#  [['humidity', 'locationMode'], 1],
#  [['smoke', 'locationMode'], 1],
#  [['temperature', 'capability.lock'], 1],
#  [['time', 'capability.lock'], 1],
#  [['time', 'locationMode'], 1]]

# %%
# value assignment to physical channel
channel_analysed = []
channel_values = []
k = 15
delta = 15

for i in range(len(result)):
    channel = result[i][0][0] # fist channel of the pair
    if not channel in system_capabilities:
        if not channel in channel_analysed:
            channel_analysed.append(channel)
            channel_values.append(k)
            k += delta
    channel = result[i][0][1] # second channel of the pair
    if not channel in system_capabilities:
        if not channel in channel_analysed:
            channel_analysed.append(channel)
            channel_values.append(k)
            k += delta
        
print(channel_analysed)
print(channel_values)
# Out:
# ['leakage', 'motion', 'location', 'temperature', 'illumination', 'smoke', 'humidity']
# [15, 30, 45, 60, 75, 90, 105]

# %%
# value assignment to system channel
system_channel = []
for app in trigger_action.keys():
    triggers = trigger_action[app].keys()
    for cap_trigger in triggers:
        if cap_trigger in system_capabilities:
            system_value = 0
            for action in trigger_action[app][cap_trigger]:
                if action[0] in channel_analysed:
                    system_value += channel_values[channel_analysed.index(action[0])]
            system_channel.append([cap_trigger, system_value])
                    
system_channel
# Out:
# [['capability.app', 0],
#  ['capability.app', 0],
#  ['capability.button', 0],
#  ['time', 0],
#  ['capability.switch', 0],
#  ['time', 0],
#  ['capability.powerMeter', 0],
#  ['capability.powerMeter', 0],
#  ['time', 0],
#  ['capability.app', 0],
#  ['capability.switch', 0],
#  ['capability.switch', 0],
#  ['time', 0],
#  ['time', 0],
#  ['hub', 0],
#  ['capability.app', 0],
#  ['time', 0],
#  ['capability.app', 0],
#  ['time', 0],
#  ['capability.button', 0],
#  ['capability.app', 0],
#  ['time', 0],
#  ['capability.switch', 0],
#  ['capability.switch', 0],
#  ['time', 0],
#  ['device.jawboneUser', 0],
#  ['time', 0],
#  ['capability.alarm', 0],
#  ['capability.app', 0],
#  ['capability.switch', 0],
#  ['capability.switch', 0],
#  ['time', 0]]

# %%
# vector value assignment
set_of_vectors = []
pair_vector = [0, 0, 0, 0, 0, 0, 0]
for pair in channel_tuple:
    if (pair[0] in channel_analysed) and (pair[1] in channel_analysed):
        interaction = pair
        trigger_value = -1 * channel_values[channel_analysed.index(pair[0])]
        pair_vector[channel_analysed.index(pair[0])] = trigger_value
        action_value = channel_values[channel_analysed.index(pair[1])]
        pair_vector[channel_analysed.index(pair[1])] = action_value
        if not pair_vector in set_of_vectors:
            set_of_vectors.append(pair_vector)
        pair_vector = [0, 0, 0, 0, 0, 0, 0]

set_of_vectors
# Out:
# [[0, 0, 0, 0, 0, 90, -105],
#  [0, 0, 0, 60, 0, 0, -105],
#  [0, 0, 0, 0, -75, 90, 0],
#  [0, 0, 0, 60, -75, 0, 0],
#  [-15, 0, 0, 0, 0, 90, 0],
#  [-15, 0, 0, 60, 0, 0, 0],
#  [0, 0, -45, 0, 0, 90, 0],
#  [0, 0, -45, 60, 0, 0, 0],
#  [0, -30, 0, 0, 0, 90, 0],
#  [0, -30, 0, 60, 0, 0, 0],
#  [0, 0, 0, 0, 0, 90, 0],
#  [0, 0, 0, 60, 0, -90, 0],
#  [0, 0, 0, -60, 0, 90, 0],
#  [0, 0, 0, 60, 0, 0, 0]]

# %%
# similarity calculation
from sklearn.cluster import KMeans

np_set_of_vectors = np.array(set_of_vectors)
cluster = np_set_of_vectors.shape[1]
max_iter = 500

sk_kmeans = KMeans(n_clusters=cluster, max_iter=max_iter).fit(np_set_of_vectors)
sk_labels = sk_kmeans.labels_
sk_centroids = sk_kmeans.cluster_centers_
print(sk_labels)
# Out:
# [2 4 5 6 0 1 0 1 0 1 0 3 0 1]

# %%
# risk evaluation --> risk score
