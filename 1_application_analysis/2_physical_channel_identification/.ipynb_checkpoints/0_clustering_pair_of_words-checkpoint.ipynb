# %% [markdown]
# # ## second clustering approach: pair of keywords
# since that I use a new app dataset (that is the union of the Official Samsung SmartThings: https://github.com/vomar18/SmartThingsPublic and the nsslabcuus: https://github.com/nsslabcuus/IoTMon)
# 1. check every single app description in order to identify:"The entity keyword with the highest aggregated value is considered as a representative keyword for the cluster"
# 2. create the distance and then the similarity matrix
# 3. save the pair of word with the highest aggregation value (over than 90%??)
# 4. save the result inside: "analysis_NEW/physical_channel_2.JSON"

# %%
# !!attention!! use python 3.6 for manage the packet stanza that is 
# the Official Stanford NLP Python Library for Many Human Languages

from gensim.models import Word2Vec, KeyedVectors 
from sklearn.cluster import KMeans
from scipy import spatial
import json   # for read the JSON file
import stanza # Official Stanford NLP Python Library for Many Human Languages
import re     # for preprocessing the descriptions (necessary for using the word2vec)
import numpy as np

# %%
#read only descriptions and save them
descriptions = {} #dictionary with descriptions
with open("app-description.JSON", "r") as read_file: # load the JSON file with app descriptions
    descriptions = json.load(read_file)

# %%
print("total app description found: "+ str(len(descriptions)))
# Out:
# total app description found: 140

# %%
stanza.download('en')       # This downloads the English models for the neural pipeline
nlp = stanza.Pipeline('en') # This sets up a default neural pipeline in English
model = KeyedVectors.load_word2vec_format('/home/volta/Documenti/CCS18_CS/word2vec/GoogleNews-vectors-negative300.bin', binary=True, limit=100000) # load word2vec pre-trained
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.2.2.json:   0%|   …
# 2021-09-22 17:43:31 INFO: Downloading default packages for language: en (English)...
# 2021-09-22 17:43:32 INFO: File exists: /home/volta/stanza_resources/en/default.zip.
# 2021-09-22 17:43:37 INFO: Finished downloading models and saved to /home/volta/stanza_resources.
# 2021-09-22 17:43:37 INFO: Loading these models for language: en (English):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | combined  |
# | pos       | combined  |
# | lemma     | combined  |
# | depparse  | combined  |
# | sentiment | sstplus   |
# | ner       | ontonotes |
# =========================
#
# 2021-09-22 17:43:37 INFO: Use device: cpu
# 2021-09-22 17:43:37 INFO: Loading: tokenize
# 2021-09-22 17:43:37 INFO: Loading: pos
# 2021-09-22 17:43:37 INFO: Loading: lemma
# 2021-09-22 17:43:37 INFO: Loading: depparse
# 2021-09-22 17:43:37 INFO: Loading: sentiment
# 2021-09-22 17:43:38 INFO: Loading: ner
# 2021-09-22 17:43:38 INFO: Done loading processors!

# %%
set_of_keywords = []
POS_accepted=["NN", "NNS"] # part of speech tags accepted ---> deleted: "NNP", "NNPS"
percentage_lv = 25

for app in descriptions.keys():
    keywords = []       # keywords found
    keyword_vector = {} # dictionary keyword -> vector rappresentation
    print("analysing app description: ",app)
    des_analysed = nlp(descriptions[app]) # apply Stanford NLP to description
    for sent in des_analysed.sentences:
        for word in sent.words: # check each word of the description
            if word.xpos in POS_accepted:
                keywords_found = word.text.lower() # filter: to all lowercase words
                if not keywords_found in keywords: # if not already save that word
                    #print(f"word:{word.text}")
                    keywords.append(keywords_found) # add to the list of keywords
    
    for i in range(len(keywords)):
            try:
                word = str(keywords[i])
                if len(word) > 1:
                    keyword_vector[word] = model[word] # using Word2Vec
                else:
                    print("word not processed: ",word)
            except KeyError as err:
                print("handling Error: ", err) # some words can not be processed by Word2Vec
    
    keywords = list(keyword_vector.keys())
    
    if len(keywords) == 0:
        print("no one keyword found")
    
    elif len(keywords) == 1:
        print("tot_keywords:1 -", keywords[0])
        if not keywords[0] in set_of_keywords:
            set_of_keywords.append(keywords[0])
    
    elif len(keywords) == 2:
        print("tot_keywords:2 -", keywords)
        if not keywords[0] in set_of_keywords:
            set_of_keywords.append(keywords[0])
        if not keywords[1] in set_of_keywords:
            set_of_keywords.append(keywords[1])
    else:
        

        similarity_matrix = np.ones((len(keyword_vector.keys()), len(keyword_vector.keys())))
        tot_keyword_found = len(keywords)
        print("tot_keywords:",tot_keyword_found,"-", keywords)
        for key_x in range(tot_keyword_found):
            for key_y in range(key_x, tot_keyword_found):
                if key_x != key_y:
                    #print("check",keywords[key_x], " and ", keywords[key_y])
                    # -------------------------------  model.similarity() is equal to 1 - cosine.distance() --------
                    similarity_matrix[key_x][key_y] = (model.similarity(keywords[key_x], keywords[key_y]))*100
                    if similarity_matrix[key_x][key_y] >= percentage_lv:
                        if not keywords[key_x] in set_of_keywords:
                            print("add", keywords[key_x])
                            set_of_keywords.append(keywords[key_x])
                        if not keywords[key_y] in set_of_keywords:
                            print("add", keywords[key_y])
                            set_of_keywords.append(keywords[key_y])

np.set_printoptions(precision=2)
print(len(set_of_keywords))
set_of_keywords.sort()
set_of_keywords
# Out:
# analysing app description:  alfred-workflow
# /home/volta/.local/lib/python3.6/site-packages/torch/nn/functional.py:652: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool1d(input, kernel_size, stride, padding, dilation, ceil_mode)
# tot_keywords:2 - ['things', 'graph']
# analysing app description:  beacon-control
# tot_keywords: 5 - ['home', 'phrase', 'lights', 'door', 'region']
# add home
# add door
# analysing app description:  big-turn-off
# tot_keywords:1 - lights
# analysing app description:  big-turn-on
# tot_keywords:1 - lights
# analysing app description:  bon-voyage
# tot_keywords: 14 - ['set', 'presence', 'tags', 'smartphones', 'mode', 'change', 'everyone', 'conjunction', 'turn', 'lights', 'appliances', 'thermostat', 'security', 'apps']
# add smartphones
# add appliances
# add apps
# add change
# add turn
# add thermostat
# analysing app description:  bose-soundtouch-control
# word not processed:  ®
# tot_keywords: 4 - ['sound', 'actions', 'place', 'home']
# add place
# analysing app description:  brighten-dark-places
# tot_keywords: 3 - ['lights', 'sensor', 'space']
# analysing app description:  brighten-my-path
# tot_keywords:2 - ['lights', 'motion']
# analysing app description:  button-controller
# tot_keywords: 3 - ['control', 'devices', 'buttons']
# analysing app description:  camera-power-scheduler
# tot_keywords:2 - ['power', 'time']
# analysing app description:  cameras-on-when-im-away
# tot_keywords:1 - cameras
# analysing app description:  carpool-notifier
# tot_keywords: 6 - ['notifications', 'carpooling', 'buddies', 'person', 'minutes', 'notification']
# add notifications
# add notification
# analysing app description:  close-the-valve
# tot_keywords: 4 - ['valve', 'moisture', 'sms', 'notification']
# analysing app description:  color-coordinator
# tot_keywords: 3 - ['lights', 'light', 'settings']
# add light
# analysing app description:  curling-iron
# tot_keywords: 4 - ['outlet', 'user', 'period', 'time']
# add period
# analysing app description:  darken-behind-me
# tot_keywords: 3 - ['lights', 'period', 'motion']
# analysing app description:  device-tile-controller
# tot_keywords: 6 - ['controller', 'devices', 'location', 'order', 'device', 'tiles']
# add controller
# add devices
# add device
# add location
# analysing app description:  double-tap
# tot_keywords: 4 - ['number', 'switches', 'switch', 'row']
# add switches
# add switch
# analysing app description:  dry-the-wetspot
# tot_keywords: 3 - ['moisture', 'sensor', 'input']
# add moisture
# add sensor
# analysing app description:  ecobee-connect
# tot_keywords:1 - thermostat
# analysing app description:  elder-care-daily-routine
# tot_keywords: 6 - ['ones', 'time', 'cabinet', 'door', 'set', 'schedule']
# add schedule
# analysing app description:  elder-care-slip-fall
# tot_keywords: 9 - ['monitors', 'motion', 'sensors', 'bedroom', 'bathroom', 'night', 'occupant', 'period', 'time']
# add monitors
# add sensors
# add bedroom
# add bathroom
# add occupant
# add night
# analysing app description:  energy-alerts
# tot_keywords:1 - energy
# analysing app description:  energy-saver
# tot_keywords:2 - ['things', 'energy']
# analysing app description:  every-element
# tot_keywords: 3 - ['element', 'demonstration', 'app']
# analysing app description:  feed-my-pet
# tot_keywords: 7 - ['schedule', 'pet', 'food', 'feeder', 'app', 'time', 'life']
# add pet
# add food
# add life
# analysing app description:  flood-alert
# tot_keywords: 5 - ['push', 'notification', 'text', 'message', 'water']
# add message
# add text
# analysing app description:  forgiving-security
# tot_keywords: 6 - ['something', 'grace', 'period', 'presence', 'sensors', 'seconds']
# add seconds
# analysing app description:  foscam-connect
# tot_keywords:2 - ['pictures', 'camera']
# analysing app description:  garage-door-monitor
# tot_keywords: 4 - ['garage', 'door', 'text', 'message']
# add garage
# analysing app description:  garage-door-opener
# tot_keywords: 3 - ['garage', 'door', 'switch']
# analysing app description:  gentle-wake-up
# tot_keywords:1 - lights
# analysing app description:  gideon-smart-home
# handling Error:  "Key 'smartthings' not present"
# tot_keywords:2 - ['devices', 'app']
# analysing app description:  gidjit-hub
# tot_keywords: 7 - ['endpoint', 'user', 'devices', 'routines', 'users', 'actions', 'environment']
# add endpoint
# add user
# add users
# analysing app description:  good-night
# tot_keywords: 4 - ['changes', 'motion', 'time', 'night']
# analysing app description:  greetings-earthling
# tot_keywords: 7 - ['set', 'presence', 'detectors', 'mode', 'change', 'someone', 'home']
# analysing app description:  habit-helper
# tot_keywords: 5 - ['something', 'day', 'text', 'message', 'habits']
# add something
# analysing app description:  has-barkley-been-fed
# tot_keywords: 7 - ['schedule', 'pet', 'food', 'feeder', 'app', 'time', 'life']
# analysing app description:  hello-home-phrase-director
# tot_keywords: 10 - ['set', 'presence', 'sensors', 'phrases', 'home', 'status', 'change', 'sun', 'state', 'occupancy']
# add presence
# add status
# analysing app description:  hub-ip-notifier
# handling Error:  "Key 'ip' not present"
# tot_keywords:2 - ['changes', 'hub']
# analysing app description:  hue-connect
# tot_keywords: 3 - ['lights', 'area', 'app']
# analysing app description:  hue-mood-lighting
# tot_keywords: 6 - ['colors', 'brightness', 'level', 'hue', 'lights', 'mood']
# add colors
# add brightness
# add hue
# add mood
# analysing app description:  humidity-alert
# tot_keywords: 3 - ['humidity', 'threshold', 'switch']
# analysing app description:  ifttt
# tot_keywords:1 - internet
# analysing app description:  it-moved
# tot_keywords:2 - ['text', 'movement']
# analysing app description:  its-too-cold
# tot_keywords: 5 - ['temperature', 'setting', 'text', 'heater', 'appliance']
# add temperature
# add heater
# add appliance
# analysing app description:  its-too-hot
# handling Error:  "Key 'a/c' not present"
# tot_keywords: 5 - ['temperature', 'setting', 'notification', 'unit', 'fan']
# analysing app description:  jawbone-button-notifier
# tot_keywords: 4 - ['notifications', 'messages', 'jawbone', 'button']
# add messages
# add button
# analysing app description:  jenkins-notifier
# tot_keywords:2 - ['devices', 'state']
# analysing app description:  keep-me-cozy
# tot_keywords: 7 - ['thermostat', 'settings', 'response', 'mode', 'change', 'energy', 'money']
# add settings
# add mode
# analysing app description:  keep-me-cozy-ii
# tot_keywords: 5 - ['temperature', 'sensor', 'space', 'thermostat', 'time']
# add space
# analysing app description:  laundry-monitor
# tot_keywords: 3 - ['message', 'light', 'laundry']
# analysing app description:  left-it-open
# tot_keywords: 4 - ['door', 'window', 'amount', 'time']
# add window
# add amount
# analysing app description:  let-there-be-dark
# tot_keywords: 3 - ['lights', 'contact', 'sensor']
# analysing app description:  let-there-be-light
# tot_keywords:2 - ['lights', 'multi']
# analysing app description:  life360-connect
# tot_keywords:2 - ['service', 'manager']
# analysing app description:  light-follows-me
# tot_keywords: 4 - ['lights', 'motion', 'period', 'time']
# analysing app description:  lighting-director
# handling Error:  "Key 'illuminance' not present"
# tot_keywords: 7 - ['sets', 'scenarios', 'lights', 'motion', 'door', 'contacts', 'levels']
# analysing app description:  lights-off-when-closed
# tot_keywords:2 - ['lights', 'sensor']
# analysing app description:  light-up-the-night
# tot_keywords:1 - lights
# analysing app description:  lock-it-at-a-specific-time
# tot_keywords: 5 - ['door', 'time', 'option', 'contact', 'sensor']
# analysing app description:  lock-it-when-i-leave
# handling Error:  "Key 'deadbolt' not present"
# tot_keywords: 6 - ['lever', 'lock', 'presence', 'tag', 'smartphone', 'location']
# add lever
# add lock
# analysing app description:  logitech-harmony-connect
# tot_keywords:2 - ['harmony', 'account']
# analysing app description:  mail-arrived
# tot_keywords: 9 - ['text', 'mail', 'mailbox', 'multi', 'door', 'note', 'battery', 'life', 'climates']
# add mail
# add mailbox
# add battery
# analysing app description:  make-it-so
# handling Error:  "Key 'setpoints' not present"
# handling Error:  "Key 'setpoint' not present"
# tot_keywords: 9 - ['states', 'set', 'switches', 'thermostat', 'mode', 'change', 'app', 'devices', 'state']
# add states
# analysing app description:  medicine-management-contact-sensor
# tot_keywords: 16 - ['devices', 'capabilities', 'app', 'ambient', 'light', 'notification', 'drawer', 'cabinet', 'meds', 'reminder', 'time', 'day', 'draw', 'minutes', 'message', 'led']
# add capabilities
# add drawer
# add cabinet
# add reminder
# add day
# add minutes
# analysing app description:  medicine-reminder
# tot_keywords: 8 - ['reminder', 'medicine', 'cabinet', 'drawer', 'time', 'notification', 'text', 'message']
# analysing app description:  mini-hue-controller
# tot_keywords:2 - ['hue', 'bulbs']
# analysing app description:  mood-cube
# tot_keywords:2 - ['lighting', 'cube']
# analysing app description:  nfc-tag-toggle
# handling Error:  "Key 'toggling' not present"
# tot_keywords: 7 - ['switch', 'lock', 'garage', 'door', 'tag', 'touch', 'event']
# analysing app description:  notify-me-when
# tot_keywords: 3 - ['notifications', 'anything', 'home']
# analysing app description:  notify-me-when-it-opens
# tot_keywords: 4 - ['push', 'message', 'phone', 'sensor']
# add phone
# analysing app description:  notify-me-with-hue
# tot_keywords: 12 - ['color', 'brightness', 'hue', 'bulbs', 'variety', 'motion', 'contact', 'acceleration', 'moisture', 'presence', 'sensors', 'switches']
# add color
# add contact
# analysing app description:  once-a-day
# tot_keywords:2 - ['switches', 'time']
# analysing app description:  opent2t-smartapp-test
# handling Error:  "Key 'smartthings' not present"
# tot_keywords: 4 - ['test', 'app', 'end', 'scenarios']
# analysing app description:  photo-burst-when
# tot_keywords: 4 - ['burst', 'photos', 'push', 'notification']
# add burst
# add push
# analysing app description:  power-allowance
# handling Error:  "Key 'curling_iron' not present"
# tot_keywords: 8 - ['energy', 'time', 'appliance', 'tv', 'use', 'switch', 'number', 'minutes']
# add use
# analysing app description:  presence-change-push
# tot_keywords: 6 - ['push', 'notification', 'presence', 'tag', 'smartphone', 'location']
# analysing app description:  presence-change-text
# tot_keywords: 4 - ['text', 'message', 'presence', 'status']
# analysing app description:  ready-for-rain
# handling Error:  "Key 'inclement' not present"
# tot_keywords: 3 - ['doors', 'windows', 'weather']
# add doors
# add windows
# analysing app description:  ridiculously-automated-garage-door
# word not processed:  n
# tot_keywords: 8 - ['monitors', 'arrival', 'departure', 'car', 'door', 'minutes', 'motion', 'interior']
# add arrival
# add departure
# add car
# analysing app description:  rise-and-shine
# tot_keywords: 4 - ['changes', 'someone', 'time', 'morning']
# add morning
# analysing app description:  scheduled-mode-change
# tot_keywords: 3 - ['changes', 'time', 'day']
# analysing app description:  severe-weather-alert
# tot_keywords: 4 - ['push', 'notification', 'weather', 'area']
# analysing app description:  shabbat-and-holiday-modes
# handling Error:  "Key 'havdalah' not present"
# handling Error:  "Key 'api' not present"
# handling Error:  "Key 'shabbat' not present"
# handling Error:  "Key 'chag' not present"
# tot_keywords: 7 - ['mode', 'candle', 'lighting', 'days', 'time', 'times', 'modes']
# add modes
# add candle
# add days
# add times
# analysing app description:  simple-sync-trigger
# tot_keywords: 5 - ['control', 'activities', 'actions', 'place', 'home']
# add activities
# add actions
# analysing app description:  single-button-controller
# tot_keywords: 3 - ['panic', 'button', 'events']
# analysing app description:  sleepy-time
# tot_keywords: 9 - ['sleep', 'mode', 'events', 'phrases', 'house', 'bed', 'morning', 'button', 'up']
# add sleep
# add bed
# add house
# analysing app description:  smart-alarm
# tot_keywords: 12 - ['alarm', 'panel', 'security', 'zones', 'sirens', 'light', 'switches', 'notification', 'text', 'message', 'location', 'mode']
# add alarm
# add sirens
# add zones
# analysing app description:  smartblock-chat-sender
# tot_keywords: 3 - ['chat', 'messages', 'mod']
# add chat
# analysing app description:  smart-care-daily-routine
# tot_keywords: 6 - ['ones', 'time', 'cabinet', 'door', 'set', 'schedule']
# analysing app description:  smart-care-detect-motion
# tot_keywords: 9 - ['monitors', 'motion', 'sensors', 'bedroom', 'bathroom', 'night', 'occupant', 'period', 'time']
# analysing app description:  smart-home-monitor
# tot_keywords: 5 - ['home', 'intrusion', 'fire', 'carbon_monoxide', 'leaks']
# add intrusion
# add leaks
# add fire
# add carbon_monoxide
# analysing app description:  smart-home-ventilation
# tot_keywords: 5 - ['schedule', 'scenarios', 'home', 'ventilation', 'switches']
# analysing app description:  smart-humidifier
# handling Error:  "Key 'humidifier' not present"
# tot_keywords:2 - ['humidity', 'sensor']
# analysing app description:  smart-humidity-Vent
# tot_keywords: 4 - ['humidity', 'level', 'vent', 'fans']
# analysing app description:  smart-nightlight
# tot_keywords: 4 - ['lights', 'motion', 'light', 'time']
# analysing app description:  smart-security
# tot_keywords: 5 - ['intruders', 'glass', 'water', 'middle', 'night']
# analysing app description:  smart-turn-it-on
# tot_keywords: 5 - ['device', 'time', 'days', 'week', 'person']
# add week
# analysing app description:  smartweather-station-controller
# tot_keywords: 5 - ['updates', 'weather', 'tile', 'devices', 'hour']
# analysing app description:  sonos-music-modes
# tot_keywords: 3 - ['song', 'station', 'mode']
# analysing app description:  sonos-remote-control
# tot_keywords:1 - system
# analysing app description:  speaker-control
# tot_keywords: 4 - ['speaker', 'actions', 'place', 'home']
# analysing app description:  speaker-mood-music
# tot_keywords:2 - ['song', 'station']
# analysing app description:  speaker-notify-with-sound
# tot_keywords: 6 - ['sound', 'message', 'speaker', 'mode', 'changes', 'events']
# add events
# analysing app description:  speaker-weather-forecast
# tot_keywords: 6 - ['weather', 'report', 'speaker', 'mode', 'changes', 'events']
# add weather
# analysing app description:  sprayer-controller-2
# handling Error:  "Key 'sprayers' not present"
# tot_keywords: 6 - ['control', 'period', 'time', 'number', 'times', 'hour']
# add hour
# analysing app description:  spruce-scheduler
# tot_keywords: 5 - ['setup', 'schedules', 'spruce', 'irrigation', 'controller']
# analysing app description:  step-notifier
# tot_keywords: 5 - ['step', 'tracker', 'device', 'goals', 'actions']
# analysing app description:  sunrise-sunset
# tot_keywords: 7 - ['changes', 'mode', 'controls', 'lights', 'sunrise', 'sunset', 'times']
# add sunrise
# add sunset
# analysing app description:  switch-activates-home-phrase-or-mode
# tot_keywords: 6 - ['home', 'phrase', 'mode', 'switch', 'state', 'use']
# analysing app description:  switch-changes-mode
# tot_keywords: 4 - ['mode', 'switch', 'state', 'use']
# analysing app description:  talking-alarm-clock
# tot_keywords: 4 - ['waking', 'schedules', 'speaker', 'alarm']
# add waking
# analysing app description:  tesla-connect
# tot_keywords:1 - car
# analysing app description:  text-me-when-it-opens
# tot_keywords: 4 - ['text', 'message', 'phone', 'sensor']
# analysing app description:  text-me-when-theres-motion-and-im-not-here
# tot_keywords: 3 - ['text', 'message', 'motion']
# analysing app description:  the-big-switch
# tot_keywords: 4 - ['collection', 'lights', 'state', 'switch']
# analysing app description:  the-flasher
# tot_keywords: 6 - ['set', 'lights', 'response', 'motion', 'event', 'switch']
# analysing app description:  the-gun-case-moved
# tot_keywords: 3 - ['text', 'gun', 'case']
# analysing app description:  thermostat-auto-off
# tot_keywords: 4 - ['thermostat', 'windows', 'doors', 'everything']
# analysing app description:  thermostats
# tot_keywords: 3 - ['notifications', 'anything', 'home']
# analysing app description:  turn-it-on-for-5-minutes
# tot_keywords:2 - ['switch', 'minutes']
# analysing app description:  turn-it-on-when-im-here
# tot_keywords:1 - something
# analysing app description:  turn-it-on-when-it-opens
# tot_keywords:2 - ['something', 'sensor']
# analysing app description:  turn-on-only-if-i-arrive-after-sunset
# tot_keywords: 3 - ['something', 'sunset', 'anytime']
# add anytime
# analysing app description:  ubi
# handling Error:  "Key 'ubi' not present"
# handling Error:  "Key 'smartthings' not present"
# tot_keywords:2 - ['device', 'account']
# analysing app description:  undead-early-warning
# tot_keywords:1 - warning
# analysing app description:  unlock-it-when-i-arrive
# tot_keywords:2 - ['door', 'location']
# analysing app description:  virtual-device-creator
# tot_keywords:1 - devices
# analysing app description:  virtual-thermostat
# tot_keywords: 8 - ['space', 'heater', 'window', 'air_conditioner', 'conjunction', 'temperature', 'sensor', 'multi']
# add air_conditioner
# analysing app description:  wattvision-manager
# tot_keywords: 4 - ['house', 'energy', 'use', 'account']
# analysing app description:  weatherbug-home
# tot_keywords:1 - weather
# analysing app description:  weather-underground-pws-connect
# tot_keywords:1 - sensor
# analysing app description:  wemo-connect
# handling Error:  "Key 'wemo' not present"
# tot_keywords: 3 - ['switch', 'motion', 'sensor']
# analysing app description:  when-its-going-to-rain
# tot_keywords: 7 - ['shed', 'windows', 'grill', 'dogs', 'lawn', 'plants', 'tomorrow']
# add lawn
# add grill
# analysing app description:  whole-house-fan
# word not processed:  x
# tot_keywords: 5 - ['house', 'fan', 'switch', 'temp', 'thermostat']
# add temp
# analysing app description:  withings
# tot_keywords:1 - scale
# analysing app description:  withings-manager
# no one keyword found
# analysing app description:  working-from-home
# tot_keywords: 5 - ['time', 'day', 'person', 'home', 'action']
# add person
# analysing app description:  yoics-connect
# handling Error:  "Key 'yoics' not present"
# tot_keywords:1 - devices
# 139
# ['account',
#  'actions',
#  'activities',
#  'air_conditioner',
#  'alarm',
#  'amount',
#  'anytime',
#  'app',
#  'appliance',
#  'appliances',
#  'apps',
#  'arrival',
#  'bathroom',
#  'battery',
#  'bed',
#  'bedroom',
#  'brightness',
#  'bulbs',
#  'burst',
#  'button',
#  'cabinet',
#  'camera',
#  'cameras',
#  'candle',
#  'capabilities',
#  'car',
#  'carbon_monoxide',
#  'change',
#  'changes',
#  'chat',
#  'color',
#  'colors',
#  'contact',
#  'controller',
#  'cube',
#  'day',
#  'days',
#  'departure',
#  'device',
#  'devices',
#  'door',
#  'doors',
#  'drawer',
#  'endpoint',
#  'energy',
#  'events',
#  'fire',
#  'food',
#  'garage',
#  'graph',
#  'grill',
#  'harmony',
#  'heater',
#  'home',
#  'hour',
#  'house',
#  'hub',
#  'hue',
#  'humidity',
#  'internet',
#  'intrusion',
#  'lawn',
#  'leaks',
#  'lever',
#  'life',
#  'light',
#  'lighting',
#  'lights',
#  'location',
#  'lock',
#  'mail',
#  'mailbox',
#  'manager',
#  'message',
#  'messages',
#  'minutes',
#  'mode',
#  'modes',
#  'moisture',
#  'monitors',
#  'mood',
#  'morning',
#  'motion',
#  'movement',
#  'multi',
#  'night',
#  'notification',
#  'notifications',
#  'occupant',
#  'period',
#  'person',
#  'pet',
#  'phone',
#  'pictures',
#  'place',
#  'power',
#  'presence',
#  'push',
#  'reminder',
#  'scale',
#  'schedule',
#  'seconds',
#  'sensor',
#  'sensors',
#  'service',
#  'settings',
#  'sirens',
#  'sleep',
#  'smartphones',
#  'something',
#  'song',
#  'space',
#  'state',
#  'states',
#  'station',
#  'status',
#  'sunrise',
#  'sunset',
#  'switch',
#  'switches',
#  'system',
#  'temp',
#  'temperature',
#  'text',
#  'thermostat',
#  'things',
#  'time',
#  'times',
#  'turn',
#  'use',
#  'user',
#  'users',
#  'waking',
#  'warning',
#  'weather',
#  'week',
#  'window',
#  'windows',
#  'zones']

# %%
print(len(set_of_keywords))
set_of_keywords
# Out:
# 139
# ['account',
#  'actions',
#  'activities',
#  'air_conditioner',
#  'alarm',
#  'amount',
#  'anytime',
#  'app',
#  'appliance',
#  'appliances',
#  'apps',
#  'arrival',
#  'bathroom',
#  'battery',
#  'bed',
#  'bedroom',
#  'brightness',
#  'bulbs',
#  'burst',
#  'button',
#  'cabinet',
#  'camera',
#  'cameras',
#  'candle',
#  'capabilities',
#  'car',
#  'carbon_monoxide',
#  'change',
#  'changes',
#  'chat',
#  'color',
#  'colors',
#  'contact',
#  'controller',
#  'cube',
#  'day',
#  'days',
#  'departure',
#  'device',
#  'devices',
#  'door',
#  'doors',
#  'drawer',
#  'endpoint',
#  'energy',
#  'events',
#  'fire',
#  'food',
#  'garage',
#  'graph',
#  'grill',
#  'harmony',
#  'heater',
#  'home',
#  'hour',
#  'house',
#  'hub',
#  'hue',
#  'humidity',
#  'internet',
#  'intrusion',
#  'lawn',
#  'leaks',
#  'lever',
#  'life',
#  'light',
#  'lighting',
#  'lights',
#  'location',
#  'lock',
#  'mail',
#  'mailbox',
#  'manager',
#  'message',
#  'messages',
#  'minutes',
#  'mode',
#  'modes',
#  'moisture',
#  'monitors',
#  'mood',
#  'morning',
#  'motion',
#  'movement',
#  'multi',
#  'night',
#  'notification',
#  'notifications',
#  'occupant',
#  'period',
#  'person',
#  'pet',
#  'phone',
#  'pictures',
#  'place',
#  'power',
#  'presence',
#  'push',
#  'reminder',
#  'scale',
#  'schedule',
#  'seconds',
#  'sensor',
#  'sensors',
#  'service',
#  'settings',
#  'sirens',
#  'sleep',
#  'smartphones',
#  'something',
#  'song',
#  'space',
#  'state',
#  'states',
#  'station',
#  'status',
#  'sunrise',
#  'sunset',
#  'switch',
#  'switches',
#  'system',
#  'temp',
#  'temperature',
#  'text',
#  'thermostat',
#  'things',
#  'time',
#  'times',
#  'turn',
#  'use',
#  'user',
#  'users',
#  'waking',
#  'warning',
#  'weather',
#  'week',
#  'window',
#  'windows',
#  'zones']

# %%
tot_keywords = len(set_of_keywords)
channels_matrix = np.zeros((tot_keywords ,tot_keywords ))
for key_x in range(tot_keywords):
    for key_y in range(tot_keywords):
        #print("check",keywords[key_x], " and ", keywords[key_y])
        channels_matrix[key_x][key_y] = model.similarity(set_of_keywords[key_x], set_of_keywords[key_y])

channels_matrix = channels_matrix * 100        
np.set_printoptions(precision=2)
print(channels_matrix)
# Out:
# [[100.    23.09  12.98 ...  12.22   3.37   5.56]
#  [ 23.09 100.    39.79 ...   4.16   7.54   8.74]
#  [ 12.98  39.79 100.   ...  -0.2    3.93  18.49]
#  ...
#  [ 12.22   4.16  -0.2  ... 100.    72.61   3.31]
#  [  3.37   7.54   3.93 ...  72.61 100.    11.16]
#  [  5.56   8.74  18.49 ...   3.31  11.16 100.  ]]

# %%
tot_keywords = len(set_of_keywords)
channel_level = 25
physical_channel = {}
for i in range(tot_keywords):
    physical_channel[set_of_keywords[i]]=[]

for key_x in range(tot_keywords):
    for key_y in range(tot_keywords):
        if (key_y != key_x) and (channels_matrix[key_x][key_y]>=channel_level):
            physical_channel[set_of_keywords[key_x]].append(set_of_keywords[key_y])
            
physical_channel
# Out:
# {'account': ['amount'],
#  'actions': ['activities', 'changes', 'events', 'things'],
#  'activities': ['actions', 'events', 'movement'],
#  'air_conditioner': ['alarm',
#   'appliance',
#   'appliances',
#   'bathroom',
#   'battery',
#   'bed',
#   'bedroom',
#   'brightness',
#   'bulbs',
#   'candle',
#   'car',
#   'carbon_monoxide',
#   'door',
#   'doors',
#   'energy',
#   'garage',
#   'grill',
#   'heater',
#   'home',
#   'house',
#   'humidity',
#   'lawn',
#   'lighting',
#   'lights',
#   'mailbox',
#   'moisture',
#   'occupant',
#   'phone',
#   'sensor',
#   'sirens',
#   'sleep',
#   'temp',
#   'temperature',
#   'thermostat',
#   'weather',
#   'window',
#   'windows'],
#  'alarm': ['air_conditioner',
#   'bathroom',
#   'bedroom',
#   'carbon_monoxide',
#   'fire',
#   'garage',
#   'heater',
#   'lights',
#   'monitors',
#   'notification',
#   'notifications',
#   'sensors',
#   'sirens',
#   'thermostat',
#   'waking',
#   'warning'],
#  'amount': ['account', 'period', 'scale', 'time'],
#  'anytime': ['chat', 'notifications', 'person', 'phone', 'something', 'time'],
#  'app': ['apps',
#   'button',
#   'cube',
#   'device',
#   'devices',
#   'graph',
#   'internet',
#   'modes',
#   'notifications',
#   'phone',
#   'sensor',
#   'smartphones',
#   'text',
#   'user',
#   'users'],
#  'appliance': ['air_conditioner',
#   'appliances',
#   'bathroom',
#   'battery',
#   'bulbs',
#   'device',
#   'devices',
#   'endpoint',
#   'garage',
#   'grill',
#   'heater',
#   'lighting',
#   'sensor',
#   'switches',
#   'thermostat',
#   'user',
#   'users'],
#  'appliances': ['air_conditioner',
#   'appliance',
#   'bathroom',
#   'bedroom',
#   'bulbs',
#   'cabinet',
#   'devices',
#   'energy',
#   'garage',
#   'grill',
#   'heater',
#   'home',
#   'house',
#   'lighting',
#   'lights',
#   'sensors',
#   'smartphones',
#   'switches',
#   'thermostat',
#   'windows'],
#  'apps': ['app',
#   'capabilities',
#   'cube',
#   'device',
#   'devices',
#   'endpoint',
#   'graph',
#   'internet',
#   'modes',
#   'notifications',
#   'settings',
#   'smartphones',
#   'things',
#   'user',
#   'users'],
#  'arrival': ['burst', 'departure', 'presence', 'status', 'sunrise'],
#  'bathroom': ['air_conditioner',
#   'alarm',
#   'appliance',
#   'appliances',
#   'bed',
#   'bedroom',
#   'camera',
#   'car',
#   'carbon_monoxide',
#   'door',
#   'doors',
#   'drawer',
#   'garage',
#   'heater',
#   'home',
#   'house',
#   'lawn',
#   'lighting',
#   'mailbox',
#   'sleep',
#   'thermostat',
#   'waking',
#   'window',
#   'windows'],
#  'battery': ['air_conditioner',
#   'appliance',
#   'brightness',
#   'bulbs',
#   'camera',
#   'device',
#   'devices',
#   'heater',
#   'life',
#   'phone',
#   'power',
#   'sensor',
#   'thermostat'],
#  'bed': ['air_conditioner',
#   'bathroom',
#   'bedroom',
#   'car',
#   'door',
#   'drawer',
#   'garage',
#   'heater',
#   'home',
#   'house',
#   'lawn',
#   'morning',
#   'night',
#   'sleep',
#   'waking',
#   'window'],
#  'bedroom': ['air_conditioner',
#   'alarm',
#   'appliances',
#   'bathroom',
#   'bed',
#   'car',
#   'door',
#   'drawer',
#   'garage',
#   'heater',
#   'home',
#   'house',
#   'lawn',
#   'mailbox',
#   'occupant',
#   'sleep',
#   'thermostat',
#   'waking',
#   'window',
#   'windows'],
#  'brightness': ['air_conditioner',
#   'battery',
#   'bulbs',
#   'camera',
#   'carbon_monoxide',
#   'color',
#   'colors',
#   'heater',
#   'hue',
#   'humidity',
#   'light',
#   'lighting',
#   'lights',
#   'mode',
#   'modes',
#   'moisture',
#   'sensor',
#   'sensors',
#   'settings',
#   'sleep',
#   'temperature',
#   'thermostat',
#   'windows'],
#  'bulbs': ['air_conditioner',
#   'appliance',
#   'appliances',
#   'battery',
#   'brightness',
#   'candle',
#   'colors',
#   'devices',
#   'heater',
#   'lawn',
#   'light',
#   'lighting',
#   'lights',
#   'switches',
#   'thermostat'],
#  'burst': ['arrival', 'fire', 'minutes', 'push', 'seconds', 'turn'],
#  'button': ['app',
#   'camera',
#   'color',
#   'controller',
#   'cube',
#   'device',
#   'door',
#   'drawer',
#   'lever',
#   'mode',
#   'modes',
#   'notifications',
#   'sensor',
#   'settings',
#   'switch',
#   'switches',
#   'text',
#   'thermostat',
#   'window'],
#  'cabinet': ['appliances', 'drawer'],
#  'camera': ['bathroom',
#   'battery',
#   'brightness',
#   'button',
#   'cameras',
#   'controller',
#   'device',
#   'light',
#   'lighting',
#   'lights',
#   'motion',
#   'phone',
#   'pictures',
#   'sensor',
#   'sensors',
#   'smartphones'],
#  'cameras': ['camera',
#   'devices',
#   'light',
#   'lighting',
#   'lights',
#   'monitors',
#   'pictures',
#   'sensor',
#   'sensors',
#   'sirens',
#   'smartphones'],
#  'candle': ['air_conditioner',
#   'bulbs',
#   'drawer',
#   'fire',
#   'grill',
#   'heater',
#   'house',
#   'light',
#   'lighting',
#   'lights',
#   'sunrise',
#   'window'],
#  'capabilities': ['apps',
#   'device',
#   'devices',
#   'modes',
#   'presence',
#   'scale',
#   'sensor',
#   'sensors',
#   'service',
#   'settings',
#   'smartphones',
#   'system',
#   'use',
#   'users'],
#  'car': ['air_conditioner',
#   'bathroom',
#   'bed',
#   'bedroom',
#   'device',
#   'door',
#   'garage',
#   'heater',
#   'home',
#   'house',
#   'mailbox',
#   'occupant',
#   'phone',
#   'sirens',
#   'station',
#   'window',
#   'windows'],
#  'carbon_monoxide': ['air_conditioner',
#   'alarm',
#   'bathroom',
#   'brightness',
#   'fire',
#   'garage',
#   'heater',
#   'humidity',
#   'leaks',
#   'moisture',
#   'occupant',
#   'sirens',
#   'temperature',
#   'thermostat'],
#  'change': ['changes',
#   'departure',
#   'movement',
#   'push',
#   'something',
#   'switch',
#   'things',
#   'turn'],
#  'changes': ['actions', 'change', 'departure', 'events', 'switch', 'things'],
#  'chat': ['anytime', 'contact', 'internet', 'messages', 'phone', 'pictures'],
#  'color': ['brightness',
#   'button',
#   'colors',
#   'hue',
#   'light',
#   'lighting',
#   'pictures',
#   'settings',
#   'text'],
#  'colors': ['brightness',
#   'bulbs',
#   'color',
#   'hue',
#   'light',
#   'lighting',
#   'lights',
#   'modes',
#   'mood',
#   'pictures',
#   'settings'],
#  'contact': ['chat', 'notification', 'phone', 'presence'],
#  'controller': ['button',
#   'camera',
#   'device',
#   'devices',
#   'hub',
#   'lever',
#   'mode',
#   'modes',
#   'monitors',
#   'sensor',
#   'sensors',
#   'switches'],
#  'cube': ['app', 'apps', 'button', 'drawer', 'graph', 'space'],
#  'day': ['days',
#   'hour',
#   'minutes',
#   'morning',
#   'night',
#   'period',
#   'person',
#   'place',
#   'schedule',
#   'sunrise',
#   'sunset',
#   'time',
#   'times',
#   'waking',
#   'week'],
#  'days': ['day',
#   'hour',
#   'minutes',
#   'morning',
#   'night',
#   'period',
#   'seconds',
#   'sunrise',
#   'time',
#   'times',
#   'waking',
#   'week'],
#  'departure': ['arrival', 'change', 'changes', 'switch'],
#  'device': ['app',
#   'appliance',
#   'apps',
#   'battery',
#   'button',
#   'camera',
#   'capabilities',
#   'car',
#   'controller',
#   'devices',
#   'endpoint',
#   'location',
#   'monitors',
#   'phone',
#   'sensor',
#   'sensors',
#   'smartphones',
#   'system',
#   'user',
#   'users'],
#  'devices': ['app',
#   'appliance',
#   'appliances',
#   'apps',
#   'battery',
#   'bulbs',
#   'cameras',
#   'capabilities',
#   'controller',
#   'device',
#   'endpoint',
#   'modes',
#   'monitors',
#   'notifications',
#   'phone',
#   'sensor',
#   'sensors',
#   'settings',
#   'smartphones',
#   'switches',
#   'system',
#   'use',
#   'user',
#   'users'],
#  'door': ['air_conditioner',
#   'bathroom',
#   'bed',
#   'bedroom',
#   'button',
#   'car',
#   'doors',
#   'drawer',
#   'garage',
#   'home',
#   'house',
#   'lever',
#   'lock',
#   'mailbox',
#   'occupant',
#   'window',
#   'windows'],
#  'doors': ['air_conditioner',
#   'bathroom',
#   'door',
#   'drawer',
#   'garage',
#   'house',
#   'lever',
#   'lock',
#   'mailbox',
#   'window',
#   'windows'],
#  'drawer': ['bathroom',
#   'bed',
#   'bedroom',
#   'button',
#   'cabinet',
#   'candle',
#   'cube',
#   'door',
#   'doors',
#   'garage',
#   'grill',
#   'heater',
#   'lever',
#   'lock',
#   'mailbox',
#   'window'],
#  'endpoint': ['appliance',
#   'apps',
#   'device',
#   'devices',
#   'sensor',
#   'settings',
#   'switches',
#   'user',
#   'users'],
#  'energy': ['air_conditioner',
#   'appliances',
#   'food',
#   'lighting',
#   'power',
#   'space',
#   'thermostat'],
#  'events': ['actions',
#   'activities',
#   'changes',
#   'place',
#   'things',
#   'times',
#   'weather'],
#  'fire': ['alarm',
#   'burst',
#   'candle',
#   'carbon_monoxide',
#   'garage',
#   'grill',
#   'heater',
#   'house',
#   'humidity',
#   'sirens'],
#  'food': ['energy', 'pet'],
#  'garage': ['air_conditioner',
#   'alarm',
#   'appliance',
#   'appliances',
#   'bathroom',
#   'bed',
#   'bedroom',
#   'car',
#   'carbon_monoxide',
#   'door',
#   'doors',
#   'drawer',
#   'fire',
#   'grill',
#   'heater',
#   'home',
#   'house',
#   'lawn',
#   'lights',
#   'mailbox',
#   'occupant',
#   'space',
#   'station',
#   'thermostat',
#   'window',
#   'windows'],
#  'graph': ['app', 'apps', 'cube', 'text'],
#  'grill': ['air_conditioner',
#   'appliance',
#   'appliances',
#   'candle',
#   'drawer',
#   'fire',
#   'garage',
#   'heater',
#   'house',
#   'lawn',
#   'lights',
#   'thermostat',
#   'window'],
#  'harmony': ['song'],
#  'heater': ['air_conditioner',
#   'alarm',
#   'appliance',
#   'appliances',
#   'bathroom',
#   'battery',
#   'bed',
#   'bedroom',
#   'brightness',
#   'bulbs',
#   'candle',
#   'car',
#   'carbon_monoxide',
#   'drawer',
#   'fire',
#   'garage',
#   'grill',
#   'house',
#   'humidity',
#   'leaks',
#   'lighting',
#   'lights',
#   'moisture',
#   'occupant',
#   'sensor',
#   'sensors',
#   'sleep',
#   'station',
#   'temp',
#   'temperature',
#   'thermostat',
#   'window',
#   'windows'],
#  'home': ['air_conditioner',
#   'appliances',
#   'bathroom',
#   'bed',
#   'bedroom',
#   'car',
#   'door',
#   'garage',
#   'house',
#   'lawn',
#   'mailbox',
#   'night',
#   'place',
#   'sleep',
#   'time'],
#  'hour': ['day',
#   'days',
#   'minutes',
#   'morning',
#   'night',
#   'seconds',
#   'station',
#   'sunrise',
#   'sunset',
#   'time',
#   'times',
#   'week'],
#  'house': ['air_conditioner',
#   'appliances',
#   'bathroom',
#   'bed',
#   'bedroom',
#   'candle',
#   'car',
#   'door',
#   'doors',
#   'fire',
#   'garage',
#   'grill',
#   'heater',
#   'home',
#   'lawn',
#   'mailbox',
#   'occupant',
#   'station',
#   'window',
#   'windows'],
#  'hub': ['controller', 'location'],
#  'hue': ['brightness', 'color', 'colors', 'light', 'mood'],
#  'humidity': ['air_conditioner',
#   'brightness',
#   'carbon_monoxide',
#   'fire',
#   'heater',
#   'lighting',
#   'moisture',
#   'temperature',
#   'thermostat',
#   'weather'],
#  'internet': ['app',
#   'apps',
#   'chat',
#   'phone',
#   'smartphones',
#   'text',
#   'user',
#   'users'],
#  'intrusion': ['leaks'],
#  'lawn': ['air_conditioner',
#   'bathroom',
#   'bed',
#   'bedroom',
#   'bulbs',
#   'garage',
#   'grill',
#   'home',
#   'house',
#   'lighting',
#   'lights',
#   'mailbox',
#   'pet',
#   'window',
#   'windows'],
#  'leaks': ['carbon_monoxide', 'heater', 'intrusion'],
#  'lever': ['button',
#   'controller',
#   'door',
#   'doors',
#   'drawer',
#   'lock',
#   'mode',
#   'occupant',
#   'push',
#   'switch',
#   'switches',
#   'thermostat',
#   'window'],
#  'life': ['battery', 'sleep', 'something', 'things', 'time'],
#  'light': ['brightness',
#   'bulbs',
#   'camera',
#   'cameras',
#   'candle',
#   'color',
#   'colors',
#   'hue',
#   'lighting',
#   'lights'],
#  'lighting': ['air_conditioner',
#   'appliance',
#   'appliances',
#   'bathroom',
#   'brightness',
#   'bulbs',
#   'camera',
#   'cameras',
#   'candle',
#   'color',
#   'colors',
#   'energy',
#   'heater',
#   'humidity',
#   'lawn',
#   'light',
#   'lights',
#   'mood',
#   'sensor',
#   'sensors',
#   'settings',
#   'sirens',
#   'switches',
#   'thermostat'],
#  'lights': ['air_conditioner',
#   'alarm',
#   'appliances',
#   'brightness',
#   'bulbs',
#   'camera',
#   'cameras',
#   'candle',
#   'colors',
#   'garage',
#   'grill',
#   'heater',
#   'lawn',
#   'light',
#   'lighting',
#   'sensors',
#   'sirens',
#   'sunrise',
#   'sunset',
#   'switch',
#   'switches',
#   'thermostat',
#   'turn',
#   'window',
#   'windows'],
#  'location': ['device',
#   'hub',
#   'place',
#   'presence',
#   'settings',
#   'space',
#   'station',
#   'weather'],
#  'lock': ['door',
#   'doors',
#   'drawer',
#   'lever',
#   'push',
#   'switch',
#   'turn',
#   'window'],
#  'mail': ['mailbox',
#   'message',
#   'messages',
#   'notification',
#   'notifications',
#   'phone',
#   'service'],
#  'mailbox': ['air_conditioner',
#   'bathroom',
#   'bedroom',
#   'car',
#   'door',
#   'doors',
#   'drawer',
#   'garage',
#   'home',
#   'house',
#   'lawn',
#   'mail',
#   'message',
#   'messages',
#   'notification',
#   'notifications',
#   'phone',
#   'window',
#   'windows'],
#  'manager': [],
#  'message': ['mail',
#   'mailbox',
#   'messages',
#   'notification',
#   'notifications',
#   'phone',
#   'reminder',
#   'something',
#   'text',
#   'warning'],
#  'messages': ['chat',
#   'mail',
#   'mailbox',
#   'message',
#   'notification',
#   'notifications',
#   'phone',
#   'pictures',
#   'text',
#   'users',
#   'warning'],
#  'minutes': ['burst',
#   'day',
#   'days',
#   'hour',
#   'morning',
#   'night',
#   'period',
#   'seconds',
#   'sunrise',
#   'time',
#   'times',
#   'week'],
#  'mode': ['brightness',
#   'button',
#   'controller',
#   'lever',
#   'modes',
#   'mood',
#   'settings',
#   'switches',
#   'system',
#   'zones'],
#  'modes': ['app',
#   'apps',
#   'brightness',
#   'button',
#   'capabilities',
#   'colors',
#   'controller',
#   'devices',
#   'mode',
#   'sensor',
#   'sensors',
#   'settings',
#   'switches',
#   'times',
#   'zones'],
#  'moisture': ['air_conditioner',
#   'brightness',
#   'carbon_monoxide',
#   'heater',
#   'humidity',
#   'sensor',
#   'sensors',
#   'temperature',
#   'weather'],
#  'monitors': ['alarm',
#   'cameras',
#   'controller',
#   'device',
#   'devices',
#   'sensor',
#   'sensors',
#   'system'],
#  'mood': ['colors', 'hue', 'lighting', 'mode', 'things', 'weather'],
#  'morning': ['bed',
#   'day',
#   'days',
#   'hour',
#   'minutes',
#   'night',
#   'sunrise',
#   'time',
#   'waking',
#   'week'],
#  'motion': ['camera', 'sensor'],
#  'movement': ['activities', 'change', 'push'],
#  'multi': [],
#  'night': ['bed',
#   'day',
#   'days',
#   'home',
#   'hour',
#   'minutes',
#   'morning',
#   'sleep',
#   'sunrise',
#   'time',
#   'waking',
#   'week'],
#  'notification': ['alarm',
#   'contact',
#   'mail',
#   'mailbox',
#   'message',
#   'messages',
#   'notifications',
#   'service',
#   'sirens',
#   'warning'],
#  'notifications': ['alarm',
#   'anytime',
#   'app',
#   'apps',
#   'button',
#   'devices',
#   'mail',
#   'mailbox',
#   'message',
#   'messages',
#   'notification',
#   'settings',
#   'sirens',
#   'text',
#   'user',
#   'users',
#   'warning'],
#  'occupant': ['air_conditioner',
#   'bedroom',
#   'car',
#   'carbon_monoxide',
#   'door',
#   'garage',
#   'heater',
#   'house',
#   'lever',
#   'person',
#   'window'],
#  'period': ['amount', 'day', 'days', 'minutes', 'seconds', 'time', 'times'],
#  'person': ['anytime', 'day', 'occupant', 'something', 'user'],
#  'pet': ['food', 'lawn'],
#  'phone': ['air_conditioner',
#   'anytime',
#   'app',
#   'battery',
#   'camera',
#   'car',
#   'chat',
#   'contact',
#   'device',
#   'devices',
#   'internet',
#   'mail',
#   'mailbox',
#   'message',
#   'messages',
#   'service',
#   'smartphones',
#   'text'],
#  'pictures': ['camera',
#   'cameras',
#   'chat',
#   'color',
#   'colors',
#   'messages',
#   'text'],
#  'place': ['day', 'events', 'home', 'location', 'things', 'time'],
#  'power': ['battery', 'energy'],
#  'presence': ['arrival', 'capabilities', 'contact', 'location', 'status'],
#  'push': ['burst', 'change', 'lever', 'lock', 'movement', 'switch', 'turn'],
#  'reminder': ['message', 'warning'],
#  'scale': ['amount', 'capabilities'],
#  'schedule': ['day', 'time', 'weather'],
#  'seconds': ['burst', 'days', 'hour', 'minutes', 'period', 'time', 'times'],
#  'sensor': ['air_conditioner',
#   'app',
#   'appliance',
#   'battery',
#   'brightness',
#   'button',
#   'camera',
#   'cameras',
#   'capabilities',
#   'controller',
#   'device',
#   'devices',
#   'endpoint',
#   'heater',
#   'lighting',
#   'modes',
#   'moisture',
#   'monitors',
#   'motion',
#   'sensors',
#   'switches',
#   'system',
#   'temperature',
#   'thermostat',
#   'user'],
#  'sensors': ['alarm',
#   'appliances',
#   'brightness',
#   'camera',
#   'cameras',
#   'capabilities',
#   'controller',
#   'device',
#   'devices',
#   'heater',
#   'lighting',
#   'lights',
#   'modes',
#   'moisture',
#   'monitors',
#   'sensor',
#   'smartphones',
#   'switches',
#   'system',
#   'temperature',
#   'thermostat'],
#  'service': ['capabilities',
#   'mail',
#   'notification',
#   'phone',
#   'system',
#   'users'],
#  'settings': ['apps',
#   'brightness',
#   'button',
#   'capabilities',
#   'color',
#   'colors',
#   'devices',
#   'endpoint',
#   'lighting',
#   'location',
#   'mode',
#   'modes',
#   'notifications',
#   'switches',
#   'system',
#   'thermostat',
#   'use',
#   'user',
#   'users',
#   'windows'],
#  'sirens': ['air_conditioner',
#   'alarm',
#   'cameras',
#   'car',
#   'carbon_monoxide',
#   'fire',
#   'lighting',
#   'lights',
#   'notification',
#   'notifications',
#   'sunrise',
#   'warning',
#   'windows'],
#  'sleep': ['air_conditioner',
#   'bathroom',
#   'bed',
#   'bedroom',
#   'brightness',
#   'heater',
#   'home',
#   'life',
#   'night',
#   'sunrise',
#   'temperature',
#   'thermostat',
#   'waking'],
#  'smartphones': ['app',
#   'appliances',
#   'apps',
#   'camera',
#   'cameras',
#   'capabilities',
#   'device',
#   'devices',
#   'internet',
#   'phone',
#   'sensors',
#   'user',
#   'users'],
#  'something': ['anytime',
#   'change',
#   'life',
#   'message',
#   'person',
#   'things',
#   'time',
#   'turn',
#   'waking'],
#  'song': ['harmony'],
#  'space': ['cube', 'energy', 'garage', 'location', 'time'],
#  'state': ['states', 'system'],
#  'states': ['state'],
#  'station': ['car', 'garage', 'heater', 'hour', 'house', 'location'],
#  'status': ['arrival', 'presence'],
#  'sunrise': ['arrival',
#   'candle',
#   'day',
#   'days',
#   'hour',
#   'lights',
#   'minutes',
#   'morning',
#   'night',
#   'sirens',
#   'sleep',
#   'sunset',
#   'waking'],
#  'sunset': ['day', 'hour', 'lights', 'sunrise'],
#  'switch': ['button',
#   'change',
#   'changes',
#   'departure',
#   'lever',
#   'lights',
#   'lock',
#   'push',
#   'switches',
#   'thermostat',
#   'turn',
#   'use'],
#  'switches': ['appliance',
#   'appliances',
#   'bulbs',
#   'button',
#   'controller',
#   'devices',
#   'endpoint',
#   'lever',
#   'lighting',
#   'lights',
#   'mode',
#   'modes',
#   'sensor',
#   'sensors',
#   'settings',
#   'switch',
#   'thermostat'],
#  'system': ['capabilities',
#   'device',
#   'devices',
#   'mode',
#   'monitors',
#   'sensor',
#   'sensors',
#   'service',
#   'settings',
#   'state'],
#  'temp': ['air_conditioner', 'heater', 'temperature', 'thermostat'],
#  'temperature': ['air_conditioner',
#   'brightness',
#   'carbon_monoxide',
#   'heater',
#   'humidity',
#   'moisture',
#   'sensor',
#   'sensors',
#   'sleep',
#   'temp',
#   'thermostat',
#   'weather'],
#  'text': ['app',
#   'button',
#   'color',
#   'graph',
#   'internet',
#   'message',
#   'messages',
#   'notifications',
#   'phone',
#   'pictures',
#   'user'],
#  'thermostat': ['air_conditioner',
#   'alarm',
#   'appliance',
#   'appliances',
#   'bathroom',
#   'battery',
#   'bedroom',
#   'brightness',
#   'bulbs',
#   'button',
#   'carbon_monoxide',
#   'energy',
#   'garage',
#   'grill',
#   'heater',
#   'humidity',
#   'lever',
#   'lighting',
#   'lights',
#   'sensor',
#   'sensors',
#   'settings',
#   'sleep',
#   'switch',
#   'switches',
#   'temp',
#   'temperature',
#   'windows'],
#  'things': ['actions',
#   'apps',
#   'change',
#   'changes',
#   'events',
#   'life',
#   'mood',
#   'place',
#   'something',
#   'time',
#   'times',
#   'turn'],
#  'time': ['amount',
#   'anytime',
#   'day',
#   'days',
#   'home',
#   'hour',
#   'life',
#   'minutes',
#   'morning',
#   'night',
#   'period',
#   'place',
#   'schedule',
#   'seconds',
#   'something',
#   'space',
#   'things',
#   'times',
#   'waking',
#   'week'],
#  'times': ['day',
#   'days',
#   'events',
#   'hour',
#   'minutes',
#   'modes',
#   'period',
#   'seconds',
#   'things',
#   'time'],
#  'turn': ['burst',
#   'change',
#   'lights',
#   'lock',
#   'push',
#   'something',
#   'switch',
#   'things'],
#  'use': ['capabilities', 'devices', 'settings', 'switch', 'user', 'users'],
#  'user': ['app',
#   'appliance',
#   'apps',
#   'device',
#   'devices',
#   'endpoint',
#   'internet',
#   'notifications',
#   'person',
#   'sensor',
#   'settings',
#   'smartphones',
#   'text',
#   'use',
#   'users'],
#  'users': ['app',
#   'appliance',
#   'apps',
#   'capabilities',
#   'device',
#   'devices',
#   'endpoint',
#   'internet',
#   'messages',
#   'notifications',
#   'service',
#   'settings',
#   'smartphones',
#   'use',
#   'user'],
#  'waking': ['alarm',
#   'bathroom',
#   'bed',
#   'bedroom',
#   'day',
#   'days',
#   'morning',
#   'night',
#   'sleep',
#   'something',
#   'sunrise',
#   'time'],
#  'warning': ['alarm',
#   'message',
#   'messages',
#   'notification',
#   'notifications',
#   'reminder',
#   'sirens'],
#  'weather': ['air_conditioner',
#   'events',
#   'humidity',
#   'location',
#   'moisture',
#   'mood',
#   'schedule',
#   'temperature'],
#  'week': ['day', 'days', 'hour', 'minutes', 'morning', 'night', 'time'],
#  'window': ['air_conditioner',
#   'bathroom',
#   'bed',
#   'bedroom',
#   'button',
#   'candle',
#   'car',
#   'door',
#   'doors',
#   'drawer',
#   'garage',
#   'grill',
#   'heater',
#   'house',
#   'lawn',
#   'lever',
#   'lights',
#   'lock',
#   'mailbox',
#   'occupant',
#   'windows'],
#  'windows': ['air_conditioner',
#   'appliances',
#   'bathroom',
#   'bedroom',
#   'brightness',
#   'car',
#   'door',
#   'doors',
#   'garage',
#   'heater',
#   'house',
#   'lawn',
#   'lights',
#   'mailbox',
#   'settings',
#   'sirens',
#   'thermostat',
#   'window'],
#  'zones': ['mode', 'modes']}

# %%
dict_physical_channel = {}
temp = physical_channel["temperature"]
temp.append("temperature")
dict_physical_channel["temperature"] = temp
temp = physical_channel["humidity"]
temp.append("humidity")
dict_physical_channel["humidity"]= temp
temp =physical_channel["light"]
temp.append("light")
dict_physical_channel["illumination"]=temp
temp = physical_channel["motion"]
temp.append("motion")
dict_physical_channel["motion"]=temp
temp = physical_channel["location"]
temp.append("location")
dict_physical_channel["location"]=temp
temp = physical_channel["carbon_monoxide"]
temp.append("carbon_monoxide")
dict_physical_channel["smoke"]=temp
temp=physical_channel["messages"]
temp.append("messages")
dict_physical_channel["leakage"]=temp
dict_physical_channel
# Out:
# {'temperature': ['air_conditioner',
#   'brightness',
#   'carbon_monoxide',
#   'heater',
#   'humidity',
#   'moisture',
#   'sensor',
#   'sensors',
#   'sleep',
#   'temp',
#   'thermostat',
#   'weather',
#   'temperature'],
#  'humidity': ['air_conditioner',
#   'brightness',
#   'carbon_monoxide',
#   'fire',
#   'heater',
#   'lighting',
#   'moisture',
#   'temperature',
#   'thermostat',
#   'weather',
#   'humidity'],
#  'illumination': ['brightness',
#   'bulbs',
#   'camera',
#   'cameras',
#   'candle',
#   'color',
#   'colors',
#   'hue',
#   'lighting',
#   'lights',
#   'light'],
#  'motion': ['camera', 'sensor', 'motion'],
#  'location': ['device',
#   'hub',
#   'place',
#   'presence',
#   'settings',
#   'space',
#   'station',
#   'weather',
#   'location'],
#  'smoke': ['air_conditioner',
#   'alarm',
#   'bathroom',
#   'brightness',
#   'fire',
#   'garage',
#   'heater',
#   'humidity',
#   'leaks',
#   'moisture',
#   'occupant',
#   'sirens',
#   'temperature',
#   'thermostat',
#   'carbon_monoxide'],
#  'leakage': ['chat',
#   'mail',
#   'mailbox',
#   'message',
#   'notification',
#   'notifications',
#   'phone',
#   'pictures',
#   'text',
#   'users',
#   'warning',
#   'messages']}

# %%
with open("cluster_pysical_channels.JSON", "w") as write_file: # load the JSON file with app descriptions
    write_file.write("{\n")
    for key in dict_physical_channel.keys():
        write_file.write(f"\"{key}\":\"{dict_physical_channel[key]}\",\n")
    write_file.write("}")
