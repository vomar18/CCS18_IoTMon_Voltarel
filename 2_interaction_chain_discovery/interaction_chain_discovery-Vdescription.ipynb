# %% [markdown]
# ##  interaction chain discovery algorithm - description version
#
# this algorithm is based on the table 3 associated to the smartapp description

# %%
import json   # for read the JSON file
import numpy as np

# %%
file = open("../1_application_analysis/1_Intra_app_Analysis/trigger-action.JSON","r") # read all the capability extrapolated from the apps
trigger_action = json.load(file)
print("tot app analysed:",len(trigger_action.keys()))
# Out:
# tot app analysed: 86

# %%
# you need the AP_tr,ac all trigger-action behaviour tuples in applications (cap 4.3.2 - p835)
list_trigger_action = []
for app in trigger_action.keys():         # for every app analysed
    for trigger in trigger_action[app].keys():      # for every trigger channel of that app
            for action in trigger_action[app][trigger]: # for every action 
                check = any(element == [trigger, action] for element in list_trigger_action)
                if not check: # if not duplicate
                    list_trigger_action.append([trigger, action]) # save capability (the channel) and action
list_trigger_action.sort()
list_trigger_action
# Out:
# [['accelerationSensor', ['colorControl', 'colorControl.each']],
#  ['accelerationSensor', ['colorControl', 'colorControl.setColor']],
#  ['accelerationSensor', ['imageCapture', 'imageCapture.take']],
#  ['accelerationSensor', ['momentary', 'momentary.push']],
#  ['accelerationSensor', ['number', 'number.times']],
#  ['accelerationSensor', ['sendAction', 'sendNotificationToContacts']],
#  ['accelerationSensor', ['sendAction', 'sendPush']],
#  ['accelerationSensor', ['sendAction', 'sendSms']],
#  ['accelerationSensor', ['switch', 'switch.on']],
#  ['alarm', ['alarm', 'alarm.off']],
#  ['app', ['alarm', 'alarm.off']],
#  ['app', ['colorControl', 'colorControl.each']],
#  ['app', ['colorControl', 'colorControl.setColor']],
#  ['app', ['doorControl', 'doorControl.each']],
#  ['app', ['lock', 'lock.each']],
#  ['app', ['switch', 'switch.each']],
#  ['app', ['switch', 'switch.off']],
#  ['app', ['switch', 'switch.on']],
#  ['app', ['thermostat', 'thermostat.each']],
#  ['app', ['thermostat', 'thermostat.poll']],
#  ['app', ['thermostat', 'thermostat.setCoolingSetpoint']],
#  ['app', ['thermostat', 'thermostat.setHeatingSetpoint']],
#  ['beacon', ['lock', 'lock.lock']],
#  ['beacon', ['lock', 'lock.unlock']],
#  ['beacon', ['switch', 'switch.off']],
#  ['beacon', ['switch', 'switch.on']],
#  ['button', ['colorControl', 'colorControl.each']],
#  ['button', ['colorControl', 'colorControl.off']],
#  ['button', ['colorControl', 'colorControl.on']],
#  ['button', ['colorControl', 'colorControl.setColor']],
#  ['button', ['colorControl', 'colorControl.setLevel']],
#  ['button', ['locationMode', 'locationMode.setLocationMode']],
#  ['button', ['sendAction', 'sendNotificationToContacts']],
#  ['button', ['sendAction', 'sendPush']],
#  ['button', ['sendAction', 'sendSms']],
#  ['carbonMonoxideDetector', ['sendAction', 'sendNotificationToContacts']],
#  ['carbonMonoxideDetector', ['thermostat', 'thermostat.setThermostatMode']],
#  ['contactSensor', ['alarm', 'alarm.both']],
#  ['contactSensor', ['alarm', 'alarm.strobe']],
#  ['contactSensor', ['colorControl', 'colorControl.each']],
#  ['contactSensor', ['colorControl', 'colorControl.off']],
#  ['contactSensor', ['colorControl', 'colorControl.setColor']],
#  ['contactSensor', ['colorControl', 'colorControl.setHue']],
#  ['contactSensor', ['imageCapture', 'imageCapture.take']],
#  ['contactSensor', ['locationMode', 'locationMode.setLocationMode']],
#  ['contactSensor', ['momentary', 'momentary.push']],
#  ['contactSensor', ['number', 'number.times']],
#  ['contactSensor', ['sendAction', 'sendNotificationToContacts']],
#  ['contactSensor', ['sendAction', 'sendPush']],
#  ['contactSensor', ['sendAction', 'sendSms']],
#  ['contactSensor', ['switch', 'switch.currentValue']],
#  ['contactSensor', ['switch', 'switch.off']],
#  ['contactSensor', ['switch', 'switch.on']],
#  ['contactSensor', ['thermostat', 'thermostat.currentValue']],
#  ['contactSensor', ['thermostat', 'thermostat.off']],
#  ['contactSensor', ['thermostat', 'thermostat.setThermostatMode']],
#  ['device.jawboneUser', ['colorControl', 'colorControl.each']],
#  ['device.jawboneUser', ['colorControl', 'colorControl.setColor']],
#  ['device.jawboneUser', ['musicPlayer', 'musicPlayer.on']],
#  ['device.jawboneUser', ['musicPlayer', 'musicPlayer.playTrack']],
#  ['device.jawboneUser', ['musicPlayer', 'musicPlayer.playTrackAndResume']],
#  ['device.jawboneUser', ['musicPlayer', 'musicPlayer.playTrackAtVolume']],
#  ['device.jawboneUser', ['sendAction', 'sendNotificationToContacts']],
#  ['device.jawboneUser', ['switch', 'switch.each']],
#  ['illuminanceMeasurement', ['switch', 'switch.off']],
#  ['illuminanceMeasurement', ['switch', 'switch.on']],
#  ['location', ['lock', 'lock.each']],
#  ['location', ['switch', 'switch.each']],
#  ['location', ['switch', 'switch.off']],
#  ['location', ['switch', 'switch.on']],
#  ['location', ['thermostat', 'thermostat.each']],
#  ['location', ['thermostat', 'thermostat.poll']],
#  ['location', ['thermostat', 'thermostat.setCoolingSetpoint']],
#  ['location', ['thermostat', 'thermostat.setHeatingSetpoint']],
#  ['motionSensor', ['alarm', 'alarm.both']],
#  ['motionSensor', ['alarm', 'alarm.strobe']],
#  ['motionSensor', ['colorControl', 'colorControl.each']],
#  ['motionSensor', ['colorControl', 'colorControl.setColor']],
#  ['motionSensor', ['imageCapture', 'imageCapture.take']],
#  ['motionSensor', ['locationMode', 'locationMode.setLocationMode']],
#  ['motionSensor', ['number', 'number.times']],
#  ['motionSensor', ['sendAction', 'sendNotificationToContacts']],
#  ['motionSensor', ['sendAction', 'sendPush']],
#  ['motionSensor', ['sendAction', 'sendSms']],
#  ['motionSensor', ['switch', 'switch.off']],
#  ['motionSensor', ['switch', 'switch.on']],
#  ['powerMeter', ['sendAction', 'sendNotificationToContacts']],
#  ['powerMeter', ['sendAction', 'sendPush']],
#  ['powerMeter', ['sendAction', 'sendSms']],
#  ['powerMeter', ['switch', 'switch.off']],
#  ['presenceSensor', ['colorControl', 'colorControl.each']],
#  ['presenceSensor', ['colorControl', 'colorControl.setColor']],
#  ['presenceSensor', ['imageCapture', 'imageCapture.take']],
#  ['presenceSensor', ['locationMode', 'locationMode.setLocationMode']],
#  ['presenceSensor', ['lock', 'lock.lock']],
#  ['presenceSensor', ['lock', 'lock.unlock']],
#  ['presenceSensor', ['momentary', 'momentary.push']],
#  ['presenceSensor', ['number', 'number.times']],
#  ['presenceSensor', ['sendAction', 'sendNotificationToContacts']],
#  ['presenceSensor', ['sendAction', 'sendPush']],
#  ['presenceSensor', ['sendAction', 'sendSms']],
#  ['presenceSensor', ['switch', 'switch.off']],
#  ['presenceSensor', ['switch', 'switch.on']],
#  ['relativeHumidityMeasurement', ['sendAction', 'sendPush']],
#  ['relativeHumidityMeasurement', ['sendAction', 'sendSms']],
#  ['relativeHumidityMeasurement', ['switch', 'switch.off']],
#  ['relativeHumidityMeasurement', ['switch', 'switch.on']],
#  ['smokeDetector', ['colorControl', 'colorControl.each']],
#  ['smokeDetector', ['colorControl', 'colorControl.setColor']],
#  ['smokeDetector', ['sendAction', 'sendNotificationToContacts']],
#  ['smokeDetector', ['thermostat', 'thermostat.setThermostatMode']],
#  ['switch', ['colorControl', 'colorControl.each']],
#  ['switch', ['colorControl', 'colorControl.setColor']],
#  ['switch', ['imageCapture', 'imageCapture.take']],
#  ['switch', ['locationMode', 'locationMode.setLocationMode']],
#  ['switch', ['number', 'number.times']],
#  ['switch', ['sendAction', 'sendNotificationToContacts']],
#  ['switch', ['sendAction', 'sendPush']],
#  ['switch', ['sendAction', 'sendSms']],
#  ['switch', ['switch', 'switch.off']],
#  ['switch', ['switch', 'switch.on']],
#  ['switch', ['switchLevel', 'switchLevel.setLevel']],
#  ['temperatureMeasurement', ['sendAction', 'sendNotificationToContacts']],
#  ['temperatureMeasurement', ['sendAction', 'sendPush']],
#  ['temperatureMeasurement', ['sendAction', 'sendSms']],
#  ['temperatureMeasurement', ['switch', 'switch.off']],
#  ['temperatureMeasurement', ['switch', 'switch.on']],
#  ['temperatureMeasurement', ['thermostat', 'thermostat.poll']],
#  ['temperatureMeasurement', ['thermostat', 'thermostat.setCoolingSetpoint']],
#  ['temperatureMeasurement', ['thermostat', 'thermostat.setHeatingSetpoint']],
#  ['thermostat', ['switch', 'switch.off']],
#  ['thermostat', ['switch', 'switch.on']],
#  ['thermostat', ['thermostat', 'thermostat.poll']],
#  ['thermostat', ['thermostat', 'thermostat.setCoolingSetpoint']],
#  ['thermostat', ['thermostat', 'thermostat.setHeatingSetpoint']],
#  ['threeAxis', ['sendAction', 'sendNotificationToContacts']],
#  ['threeAxis', ['sendAction', 'sendPush']],
#  ['threeAxis', ['sendAction', 'sendSms']],
#  ['time', ['device.PetFeederShield', 'device.PetFeederShield.feed']],
#  ['time', ['locationMode', 'locationMode.setLocationMode']],
#  ['time', ['lock', 'lock.lock']],
#  ['time', ['sendAction', 'sendNotificationToContacts']],
#  ['time', ['sendAction', 'sendPush']],
#  ['time', ['sendAction', 'sendSms']],
#  ['time', ['switch', 'switch.off']],
#  ['time', ['switch', 'switch.on']],
#  ['touchSensor', ['doorControl', 'doorControl.each']],
#  ['touchSensor', ['lock', 'lock.each']],
#  ['touchSensor', ['switch', 'switch.each']],
#  ['waterSensor', ['colorControl', 'colorControl.each']],
#  ['waterSensor', ['colorControl', 'colorControl.setColor']],
#  ['waterSensor', ['sendAction', 'sendNotificationToContacts']],
#  ['waterSensor', ['sendAction', 'sendPush']],
#  ['waterSensor', ['sendAction', 'sendSms']],
#  ['waterSensor', ['switch', 'switch.off']],
#  ['waterSensor', ['switch', 'switch.on']],
#  ['waterSensor', ['valve', 'valve.close']]]

# %%
# function that map the capability to string
def cap2string(capability):
    switcher = {
        'accelerationSensor': "acceleration",
        'alarm': "alarm",
        'app': "app",
        'beacon': "beacon",
        'button': "button",
        'carbonMonoxideDetector': "carbon_monoxide",
        'colorControl': "color",
        'contactSensor': "contact",
        'doorControl': "door control",
        'illuminanceMeasurement':"illumination",
        'imageCapture': "image capture",
        'location':"location",
        'momentary': "momentary",
        'motionSensor':"motion ",
        'musicPlayer': "music player",
        'powerMeter':"power",
        'presenceSensor': "presence",
        'relativeHumidityMeasurement': "relative humidity ",
        'smokeDetector': "smoke",
        'switch': "switch",
        'switchLevel': "switch level",
        'temperatureMeasurement':"temperature",
        'thermostat': "thermostat",
        'threeAxis':"three axis",
        'touchSensor':"touch",
        'valve':"valve",
        'waterSensor':"water sensor",
        'device.PetFeederShield':"pet feeder shield",
        'device.jawboneUser':"jawbone user",
        'number': "number",
        
        'lock':"lock",
        'locationMode':"locationMode",
        'sendAction':"sendAction",
        'time':"time"
    }
    return switcher.get(capability, f"capabliti not found: {capability}")

# %%
file = open("../1_application_analysis/2_physical_channel_identification/0_relay_on_description/set_of_capability_related_channels.JSON","r")
capability_channel = json.load(file)
capability_channel
# Out:
# {'temperature': ['water sensor'],
#  'humidity': ['power', 'relative humidity ', 'temperature', 'contact'],
#  'illumination': ['acceleration', 'button', 'switch', 'contact', 'time'],
#  'location': ['hub'],
#  'motion': ['motion ', 'switch', 'acceleration', 'contact'],
#  'smoke': ['temperature'],
#  'leakage': ['contact', 'water sensor', 'jawbone user', 'motion '],
#  'time': ['time', 'presence', 'motion ', 'contact', 'carbon_monoxide'],
#  'locationMode': ['presence', 'app', 'jawbone user', 'location'],
#  'lock': ['beacon',
#   'button',
#   'switch',
#   'water sensor',
#   'three axis',
#   'time',
#   'acceleration',
#   'app',
#   'presence']}

# %%
# algorithm 1: algorithm for interaction chain discovery
INTAC = []
for i in list_trigger_action: # for every pair of trigger-action
    for j in list_trigger_action:
        for channel in capability_channel.keys(): # this implies --> k.ch == m.ch
            #print("physical channel:",physical_channel)
            for k in capability_channel[channel]:     # for every possible pair of capabilities
                for m in capability_channel[channel]: # correlated to the same physical channel
                    action_cap = cap2string(i[1][0]) # action capability of first trigger-action
                    trigger_cap = cap2string(j[0])   # trigger capability of second trigger-action
                    if ((action_cap == k) and (trigger_cap == m)):
                        first_app = [i[0], i[1][0]]  # use only trigger-action
                        second_app = [j[0], j[1][0]] # use only trigger-action
                        if not [first_app, channel, second_app] in INTAC: # not duplicates 
                            print(f"action {action_cap} nel canale {channel}\ttriggera {trigger_cap}")
                            INTAC.append([first_app, channel, second_app])
                            
                            
# this part was correlated to the system channels ...
#         for system_channel in system_capabilities: # now check the system channels
#             if (action_cap == system_channel) and (trigger_cap == system_channel): 
#                         if not [i, system_channel, j] in INTAC: # not duplicates 
#                             print(f"action {action_cap} nel canale {physical_channel} triggera {trigger_cap}")
#                             INTAC.append([i, physical_channel, j])
# Out:
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera beacon
# action switch nel canale lock triggera beacon
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale lock triggera three axis
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera beacon
# action switch nel canale lock triggera beacon
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale lock triggera three axis
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera beacon
# action switch nel canale lock triggera beacon
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale lock triggera three axis
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera beacon
# action switch nel canale lock triggera beacon
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale lock triggera three axis
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera beacon
# action switch nel canale lock triggera beacon
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale lock triggera three axis
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera beacon
# action switch nel canale lock triggera beacon
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale lock triggera three axis
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera beacon
# action switch nel canale lock triggera beacon
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale lock triggera three axis
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera beacon
# action switch nel canale lock triggera beacon
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale lock triggera three axis
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera beacon
# action switch nel canale lock triggera beacon
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale lock triggera three axis
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera beacon
# action switch nel canale lock triggera beacon
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# ...
# action switch nel canale lock triggera three axis
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera beacon
# action switch nel canale lock triggera beacon
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale lock triggera three axis
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera beacon
# action switch nel canale lock triggera beacon
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale lock triggera three axis
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale illumination triggera acceleration
# action switch nel canale motion triggera acceleration
# action switch nel canale lock triggera acceleration
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera app
# action switch nel canale lock triggera beacon
# action switch nel canale lock triggera beacon
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera button
# action switch nel canale lock triggera button
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale illumination triggera contact
# action switch nel canale motion triggera contact
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale motion triggera motion
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale lock triggera presence
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale illumination triggera switch
# action switch nel canale motion triggera switch
# action switch nel canale lock triggera switch
# action switch nel canale lock triggera three axis
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale illumination triggera time
# action switch nel canale lock triggera time
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor
# action switch nel canale lock triggera water sensor

# %%
print(len(INTAC)) # for the paper just 570 (cap 5.2 - p839) prima avevo 2500 .....
# Out:
# 1717

# %%
# take second element for sort
def takeSecond(elem):
    return elem[1]

INTAC.sort(key=takeSecond)
INTAC
# Out:
# [[['accelerationSensor', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'colorControl']],
#  [['accelerationSensor', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'imageCapture']],
#  [['accelerationSensor', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'momentary']],
#  [['accelerationSensor', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'number']],
#  [['accelerationSensor', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'sendAction']],
#  [['accelerationSensor', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'switch']],
#  [['accelerationSensor', 'switch'],
#   'illumination',
#   ['button', 'colorControl']],
#  [['accelerationSensor', 'switch'],
#   'illumination',
#   ['button', 'locationMode']],
#  [['accelerationSensor', 'switch'], 'illumination', ['button', 'sendAction']],
#  [['accelerationSensor', 'switch'],
#   'illumination',
#   ['contactSensor', 'alarm']],
#  [['accelerationSensor', 'switch'],
#   'illumination',
#   ['contactSensor', 'colorControl']],
#  [['accelerationSensor', 'switch'],
#   'illumination',
#   ['contactSensor', 'imageCapture']],
#  [['accelerationSensor', 'switch'],
#   'illumination',
#   ['contactSensor', 'locationMode']],
#  [['accelerationSensor', 'switch'],
#   'illumination',
#   ['contactSensor', 'momentary']],
#  [['accelerationSensor', 'switch'],
#   'illumination',
#   ['contactSensor', 'number']],
#  [['accelerationSensor', 'switch'],
#   'illumination',
#   ['contactSensor', 'sendAction']],
#  [['accelerationSensor', 'switch'],
#   'illumination',
#   ['contactSensor', 'switch']],
#  [['accelerationSensor', 'switch'],
#   'illumination',
#   ['contactSensor', 'thermostat']],
#  [['accelerationSensor', 'switch'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['accelerationSensor', 'switch'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['accelerationSensor', 'switch'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['accelerationSensor', 'switch'], 'illumination', ['switch', 'number']],
#  [['accelerationSensor', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['accelerationSensor', 'switch'], 'illumination', ['switch', 'switch']],
#  [['accelerationSensor', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['accelerationSensor', 'switch'],
#   'illumination',
#   ['time', 'device.PetFeederShield']],
#  [['accelerationSensor', 'switch'], 'illumination', ['time', 'locationMode']],
#  [['accelerationSensor', 'switch'], 'illumination', ['time', 'lock']],
#  [['accelerationSensor', 'switch'], 'illumination', ['time', 'sendAction']],
#  [['accelerationSensor', 'switch'], 'illumination', ['time', 'switch']],
#  [['app', 'switch'], 'illumination', ['accelerationSensor', 'colorControl']],
#  [['app', 'switch'], 'illumination', ['accelerationSensor', 'imageCapture']],
#  [['app', 'switch'], 'illumination', ['accelerationSensor', 'momentary']],
#  [['app', 'switch'], 'illumination', ['accelerationSensor', 'number']],
#  [['app', 'switch'], 'illumination', ['accelerationSensor', 'sendAction']],
#  [['app', 'switch'], 'illumination', ['accelerationSensor', 'switch']],
#  [['app', 'switch'], 'illumination', ['button', 'colorControl']],
#  [['app', 'switch'], 'illumination', ['button', 'locationMode']],
#  [['app', 'switch'], 'illumination', ['button', 'sendAction']],
#  [['app', 'switch'], 'illumination', ['contactSensor', 'alarm']],
#  [['app', 'switch'], 'illumination', ['contactSensor', 'colorControl']],
#  [['app', 'switch'], 'illumination', ['contactSensor', 'imageCapture']],
#  [['app', 'switch'], 'illumination', ['contactSensor', 'locationMode']],
#  [['app', 'switch'], 'illumination', ['contactSensor', 'momentary']],
#  [['app', 'switch'], 'illumination', ['contactSensor', 'number']],
#  [['app', 'switch'], 'illumination', ['contactSensor', 'sendAction']],
#  [['app', 'switch'], 'illumination', ['contactSensor', 'switch']],
#  [['app', 'switch'], 'illumination', ['contactSensor', 'thermostat']],
#  [['app', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['app', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['app', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['app', 'switch'], 'illumination', ['switch', 'number']],
#  [['app', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['app', 'switch'], 'illumination', ['switch', 'switch']],
#  [['app', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['app', 'switch'], 'illumination', ['time', 'device.PetFeederShield']],
#  [['app', 'switch'], 'illumination', ['time', 'locationMode']],
#  [['app', 'switch'], 'illumination', ['time', 'lock']],
#  [['app', 'switch'], 'illumination', ['time', 'sendAction']],
#  [['app', 'switch'], 'illumination', ['time', 'switch']],
#  [['beacon', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'colorControl']],
#  [['beacon', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'imageCapture']],
#  [['beacon', 'switch'], 'illumination', ['accelerationSensor', 'momentary']],
#  [['beacon', 'switch'], 'illumination', ['accelerationSensor', 'number']],
#  [['beacon', 'switch'], 'illumination', ['accelerationSensor', 'sendAction']],
#  [['beacon', 'switch'], 'illumination', ['accelerationSensor', 'switch']],
#  [['beacon', 'switch'], 'illumination', ['button', 'colorControl']],
#  [['beacon', 'switch'], 'illumination', ['button', 'locationMode']],
#  [['beacon', 'switch'], 'illumination', ['button', 'sendAction']],
#  [['beacon', 'switch'], 'illumination', ['contactSensor', 'alarm']],
#  [['beacon', 'switch'], 'illumination', ['contactSensor', 'colorControl']],
#  [['beacon', 'switch'], 'illumination', ['contactSensor', 'imageCapture']],
#  [['beacon', 'switch'], 'illumination', ['contactSensor', 'locationMode']],
#  [['beacon', 'switch'], 'illumination', ['contactSensor', 'momentary']],
#  [['beacon', 'switch'], 'illumination', ['contactSensor', 'number']],
#  [['beacon', 'switch'], 'illumination', ['contactSensor', 'sendAction']],
#  [['beacon', 'switch'], 'illumination', ['contactSensor', 'switch']],
#  [['beacon', 'switch'], 'illumination', ['contactSensor', 'thermostat']],
#  [['beacon', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['beacon', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['beacon', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['beacon', 'switch'], 'illumination', ['switch', 'number']],
#  [['beacon', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['beacon', 'switch'], 'illumination', ['switch', 'switch']],
#  [['beacon', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['beacon', 'switch'], 'illumination', ['time', 'device.PetFeederShield']],
#  [['beacon', 'switch'], 'illumination', ['time', 'locationMode']],
#  [['beacon', 'switch'], 'illumination', ['time', 'lock']],
#  [['beacon', 'switch'], 'illumination', ['time', 'sendAction']],
#  [['beacon', 'switch'], 'illumination', ['time', 'switch']],
#  [['contactSensor', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'colorControl']],
#  [['contactSensor', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'imageCapture']],
#  [['contactSensor', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'momentary']],
#  [['contactSensor', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'number']],
#  [['contactSensor', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'sendAction']],
#  [['contactSensor', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'switch']],
#  [['contactSensor', 'switch'], 'illumination', ['button', 'colorControl']],
#  [['contactSensor', 'switch'], 'illumination', ['button', 'locationMode']],
#  [['contactSensor', 'switch'], 'illumination', ['button', 'sendAction']],
#  [['contactSensor', 'switch'], 'illumination', ['contactSensor', 'alarm']],
#  [['contactSensor', 'switch'],
#   'illumination',
#   ['contactSensor', 'colorControl']],
#  [['contactSensor', 'switch'],
#   'illumination',
#   ['contactSensor', 'imageCapture']],
#  [['contactSensor', 'switch'],
#   'illumination',
#   ['contactSensor', 'locationMode']],
#  [['contactSensor', 'switch'], 'illumination', ['contactSensor', 'momentary']],
#  [['contactSensor', 'switch'], 'illumination', ['contactSensor', 'number']],
#  [['contactSensor', 'switch'],
#   'illumination',
#   ['contactSensor', 'sendAction']],
#  [['contactSensor', 'switch'], 'illumination', ['contactSensor', 'switch']],
#  [['contactSensor', 'switch'],
#   'illumination',
#   ['contactSensor', 'thermostat']],
#  [['contactSensor', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['contactSensor', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['contactSensor', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['contactSensor', 'switch'], 'illumination', ['switch', 'number']],
#  [['contactSensor', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['contactSensor', 'switch'], 'illumination', ['switch', 'switch']],
#  [['contactSensor', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['contactSensor', 'switch'],
#   'illumination',
#   ['time', 'device.PetFeederShield']],
#  [['contactSensor', 'switch'], 'illumination', ['time', 'locationMode']],
#  [['contactSensor', 'switch'], 'illumination', ['time', 'lock']],
#  [['contactSensor', 'switch'], 'illumination', ['time', 'sendAction']],
#  [['contactSensor', 'switch'], 'illumination', ['time', 'switch']],
#  [['device.jawboneUser', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'colorControl']],
#  [['device.jawboneUser', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'imageCapture']],
#  [['device.jawboneUser', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'momentary']],
#  [['device.jawboneUser', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'number']],
#  [['device.jawboneUser', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'sendAction']],
#  [['device.jawboneUser', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'switch']],
#  [['device.jawboneUser', 'switch'],
#   'illumination',
#   ['button', 'colorControl']],
#  [['device.jawboneUser', 'switch'],
#   'illumination',
#   ['button', 'locationMode']],
#  [['device.jawboneUser', 'switch'], 'illumination', ['button', 'sendAction']],
#  [['device.jawboneUser', 'switch'],
#   'illumination',
#   ['contactSensor', 'alarm']],
#  [['device.jawboneUser', 'switch'],
#   'illumination',
#   ['contactSensor', 'colorControl']],
#  [['device.jawboneUser', 'switch'],
#   'illumination',
#   ['contactSensor', 'imageCapture']],
#  [['device.jawboneUser', 'switch'],
#   'illumination',
#   ['contactSensor', 'locationMode']],
#  [['device.jawboneUser', 'switch'],
#   'illumination',
#   ['contactSensor', 'momentary']],
#  [['device.jawboneUser', 'switch'],
#   'illumination',
#   ['contactSensor', 'number']],
#  [['device.jawboneUser', 'switch'],
#   'illumination',
#   ['contactSensor', 'sendAction']],
#  [['device.jawboneUser', 'switch'],
#   'illumination',
#   ['contactSensor', 'switch']],
#  [['device.jawboneUser', 'switch'],
#   'illumination',
#   ['contactSensor', 'thermostat']],
#  [['device.jawboneUser', 'switch'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['device.jawboneUser', 'switch'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['device.jawboneUser', 'switch'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['device.jawboneUser', 'switch'], 'illumination', ['switch', 'number']],
#  [['device.jawboneUser', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['device.jawboneUser', 'switch'], 'illumination', ['switch', 'switch']],
#  [['device.jawboneUser', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['device.jawboneUser', 'switch'],
#   'illumination',
#   ['time', 'device.PetFeederShield']],
#  [['device.jawboneUser', 'switch'], 'illumination', ['time', 'locationMode']],
#  [['device.jawboneUser', 'switch'], 'illumination', ['time', 'lock']],
#  [['device.jawboneUser', 'switch'], 'illumination', ['time', 'sendAction']],
#  [['device.jawboneUser', 'switch'], 'illumination', ['time', 'switch']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'colorControl']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'imageCapture']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'momentary']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'number']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'sendAction']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'switch']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['button', 'colorControl']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['button', 'locationMode']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['button', 'sendAction']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['contactSensor', 'alarm']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['contactSensor', 'colorControl']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['contactSensor', 'imageCapture']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['contactSensor', 'locationMode']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['contactSensor', 'momentary']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['contactSensor', 'number']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['contactSensor', 'sendAction']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['contactSensor', 'switch']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['contactSensor', 'thermostat']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['illuminanceMeasurement', 'switch'], 'illumination', ['switch', 'number']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'sendAction']],
#  [['illuminanceMeasurement', 'switch'], 'illumination', ['switch', 'switch']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'switchLevel']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['time', 'device.PetFeederShield']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['time', 'locationMode']],
#  [['illuminanceMeasurement', 'switch'], 'illumination', ['time', 'lock']],
#  [['illuminanceMeasurement', 'switch'],
#   'illumination',
#   ['time', 'sendAction']],
#  [['illuminanceMeasurement', 'switch'], 'illumination', ['time', 'switch']],
#  [['location', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'colorControl']],
#  [['location', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'imageCapture']],
#  [['location', 'switch'], 'illumination', ['accelerationSensor', 'momentary']],
#  [['location', 'switch'], 'illumination', ['accelerationSensor', 'number']],
#  [['location', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'sendAction']],
#  [['location', 'switch'], 'illumination', ['accelerationSensor', 'switch']],
#  [['location', 'switch'], 'illumination', ['button', 'colorControl']],
#  [['location', 'switch'], 'illumination', ['button', 'locationMode']],
#  [['location', 'switch'], 'illumination', ['button', 'sendAction']],
#  [['location', 'switch'], 'illumination', ['contactSensor', 'alarm']],
#  [['location', 'switch'], 'illumination', ['contactSensor', 'colorControl']],
#  [['location', 'switch'], 'illumination', ['contactSensor', 'imageCapture']],
#  [['location', 'switch'], 'illumination', ['contactSensor', 'locationMode']],
#  [['location', 'switch'], 'illumination', ['contactSensor', 'momentary']],
#  [['location', 'switch'], 'illumination', ['contactSensor', 'number']],
#  [['location', 'switch'], 'illumination', ['contactSensor', 'sendAction']],
#  [['location', 'switch'], 'illumination', ['contactSensor', 'switch']],
#  [['location', 'switch'], 'illumination', ['contactSensor', 'thermostat']],
#  [['location', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['location', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['location', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['location', 'switch'], 'illumination', ['switch', 'number']],
#  [['location', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['location', 'switch'], 'illumination', ['switch', 'switch']],
#  [['location', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['location', 'switch'], 'illumination', ['time', 'device.PetFeederShield']],
#  [['location', 'switch'], 'illumination', ['time', 'locationMode']],
#  [['location', 'switch'], 'illumination', ['time', 'lock']],
#  [['location', 'switch'], 'illumination', ['time', 'sendAction']],
#  [['location', 'switch'], 'illumination', ['time', 'switch']],
#  [['motionSensor', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'colorControl']],
#  [['motionSensor', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'imageCapture']],
#  [['motionSensor', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'momentary']],
#  [['motionSensor', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'number']],
#  [['motionSensor', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'sendAction']],
#  [['motionSensor', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'switch']],
#  [['motionSensor', 'switch'], 'illumination', ['button', 'colorControl']],
#  [['motionSensor', 'switch'], 'illumination', ['button', 'locationMode']],
#  [['motionSensor', 'switch'], 'illumination', ['button', 'sendAction']],
#  [['motionSensor', 'switch'], 'illumination', ['contactSensor', 'alarm']],
#  [['motionSensor', 'switch'],
#   'illumination',
#   ['contactSensor', 'colorControl']],
#  [['motionSensor', 'switch'],
#   'illumination',
#   ['contactSensor', 'imageCapture']],
#  [['motionSensor', 'switch'],
#   'illumination',
#   ['contactSensor', 'locationMode']],
#  [['motionSensor', 'switch'], 'illumination', ['contactSensor', 'momentary']],
#  [['motionSensor', 'switch'], 'illumination', ['contactSensor', 'number']],
#  [['motionSensor', 'switch'], 'illumination', ['contactSensor', 'sendAction']],
#  [['motionSensor', 'switch'], 'illumination', ['contactSensor', 'switch']],
#  [['motionSensor', 'switch'], 'illumination', ['contactSensor', 'thermostat']],
#  [['motionSensor', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['motionSensor', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['motionSensor', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['motionSensor', 'switch'], 'illumination', ['switch', 'number']],
#  [['motionSensor', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['motionSensor', 'switch'], 'illumination', ['switch', 'switch']],
#  [['motionSensor', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['motionSensor', 'switch'],
#   'illumination',
#   ['time', 'device.PetFeederShield']],
#  [['motionSensor', 'switch'], 'illumination', ['time', 'locationMode']],
#  [['motionSensor', 'switch'], 'illumination', ['time', 'lock']],
#  [['motionSensor', 'switch'], 'illumination', ['time', 'sendAction']],
#  [['motionSensor', 'switch'], 'illumination', ['time', 'switch']],
#  [['powerMeter', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'colorControl']],
#  [['powerMeter', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'imageCapture']],
#  [['powerMeter', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'momentary']],
#  [['powerMeter', 'switch'], 'illumination', ['accelerationSensor', 'number']],
#  [['powerMeter', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'sendAction']],
#  [['powerMeter', 'switch'], 'illumination', ['accelerationSensor', 'switch']],
#  [['powerMeter', 'switch'], 'illumination', ['button', 'colorControl']],
#  [['powerMeter', 'switch'], 'illumination', ['button', 'locationMode']],
#  [['powerMeter', 'switch'], 'illumination', ['button', 'sendAction']],
#  [['powerMeter', 'switch'], 'illumination', ['contactSensor', 'alarm']],
#  [['powerMeter', 'switch'], 'illumination', ['contactSensor', 'colorControl']],
#  [['powerMeter', 'switch'], 'illumination', ['contactSensor', 'imageCapture']],
#  [['powerMeter', 'switch'], 'illumination', ['contactSensor', 'locationMode']],
#  [['powerMeter', 'switch'], 'illumination', ['contactSensor', 'momentary']],
#  [['powerMeter', 'switch'], 'illumination', ['contactSensor', 'number']],
#  [['powerMeter', 'switch'], 'illumination', ['contactSensor', 'sendAction']],
#  [['powerMeter', 'switch'], 'illumination', ['contactSensor', 'switch']],
#  [['powerMeter', 'switch'], 'illumination', ['contactSensor', 'thermostat']],
#  [['powerMeter', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['powerMeter', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['powerMeter', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['powerMeter', 'switch'], 'illumination', ['switch', 'number']],
#  [['powerMeter', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['powerMeter', 'switch'], 'illumination', ['switch', 'switch']],
#  [['powerMeter', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['powerMeter', 'switch'],
#   'illumination',
#   ['time', 'device.PetFeederShield']],
#  [['powerMeter', 'switch'], 'illumination', ['time', 'locationMode']],
#  [['powerMeter', 'switch'], 'illumination', ['time', 'lock']],
#  [['powerMeter', 'switch'], 'illumination', ['time', 'sendAction']],
#  [['powerMeter', 'switch'], 'illumination', ['time', 'switch']],
#  [['presenceSensor', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'colorControl']],
#  [['presenceSensor', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'imageCapture']],
#  [['presenceSensor', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'momentary']],
#  [['presenceSensor', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'number']],
#  [['presenceSensor', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'sendAction']],
#  [['presenceSensor', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'switch']],
#  [['presenceSensor', 'switch'], 'illumination', ['button', 'colorControl']],
#  [['presenceSensor', 'switch'], 'illumination', ['button', 'locationMode']],
#  [['presenceSensor', 'switch'], 'illumination', ['button', 'sendAction']],
#  [['presenceSensor', 'switch'], 'illumination', ['contactSensor', 'alarm']],
#  [['presenceSensor', 'switch'],
#   'illumination',
#   ['contactSensor', 'colorControl']],
#  [['presenceSensor', 'switch'],
#   'illumination',
#   ['contactSensor', 'imageCapture']],
#  [['presenceSensor', 'switch'],
#   'illumination',
#   ['contactSensor', 'locationMode']],
#  [['presenceSensor', 'switch'],
#   'illumination',
#   ['contactSensor', 'momentary']],
#  [['presenceSensor', 'switch'], 'illumination', ['contactSensor', 'number']],
#  [['presenceSensor', 'switch'],
#   'illumination',
#   ['contactSensor', 'sendAction']],
#  [['presenceSensor', 'switch'], 'illumination', ['contactSensor', 'switch']],
#  [['presenceSensor', 'switch'],
#   'illumination',
#   ['contactSensor', 'thermostat']],
#  [['presenceSensor', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['presenceSensor', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['presenceSensor', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['presenceSensor', 'switch'], 'illumination', ['switch', 'number']],
#  [['presenceSensor', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['presenceSensor', 'switch'], 'illumination', ['switch', 'switch']],
#  [['presenceSensor', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['presenceSensor', 'switch'],
#   'illumination',
#   ['time', 'device.PetFeederShield']],
#  [['presenceSensor', 'switch'], 'illumination', ['time', 'locationMode']],
#  [['presenceSensor', 'switch'], 'illumination', ['time', 'lock']],
#  [['presenceSensor', 'switch'], 'illumination', ['time', 'sendAction']],
#  [['presenceSensor', 'switch'], 'illumination', ['time', 'switch']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'colorControl']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'imageCapture']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'momentary']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'number']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'sendAction']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'switch']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['button', 'colorControl']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['button', 'locationMode']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['button', 'sendAction']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['contactSensor', 'alarm']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['contactSensor', 'colorControl']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['contactSensor', 'imageCapture']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['contactSensor', 'locationMode']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['contactSensor', 'momentary']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['contactSensor', 'number']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['contactSensor', 'sendAction']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['contactSensor', 'switch']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['contactSensor', 'thermostat']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'number']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'sendAction']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'switch']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'switchLevel']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['time', 'device.PetFeederShield']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['time', 'locationMode']],
#  [['relativeHumidityMeasurement', 'switch'], 'illumination', ['time', 'lock']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['time', 'sendAction']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'illumination',
#   ['time', 'switch']],
#  [['switch', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'colorControl']],
#  [['switch', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'imageCapture']],
#  [['switch', 'switch'], 'illumination', ['accelerationSensor', 'momentary']],
#  [['switch', 'switch'], 'illumination', ['accelerationSensor', 'number']],
#  [['switch', 'switch'], 'illumination', ['accelerationSensor', 'sendAction']],
#  [['switch', 'switch'], 'illumination', ['accelerationSensor', 'switch']],
#  [['switch', 'switch'], 'illumination', ['button', 'colorControl']],
#  [['switch', 'switch'], 'illumination', ['button', 'locationMode']],
#  [['switch', 'switch'], 'illumination', ['button', 'sendAction']],
#  [['switch', 'switch'], 'illumination', ['contactSensor', 'alarm']],
#  [['switch', 'switch'], 'illumination', ['contactSensor', 'colorControl']],
#  [['switch', 'switch'], 'illumination', ['contactSensor', 'imageCapture']],
#  [['switch', 'switch'], 'illumination', ['contactSensor', 'locationMode']],
#  [['switch', 'switch'], 'illumination', ['contactSensor', 'momentary']],
#  [['switch', 'switch'], 'illumination', ['contactSensor', 'number']],
#  [['switch', 'switch'], 'illumination', ['contactSensor', 'sendAction']],
#  [['switch', 'switch'], 'illumination', ['contactSensor', 'switch']],
#  [['switch', 'switch'], 'illumination', ['contactSensor', 'thermostat']],
#  [['switch', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['switch', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['switch', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['switch', 'switch'], 'illumination', ['switch', 'number']],
#  [['switch', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['switch', 'switch'], 'illumination', ['switch', 'switch']],
#  [['switch', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['switch', 'switch'], 'illumination', ['time', 'device.PetFeederShield']],
#  [['switch', 'switch'], 'illumination', ['time', 'locationMode']],
#  [['switch', 'switch'], 'illumination', ['time', 'lock']],
#  [['switch', 'switch'], 'illumination', ['time', 'sendAction']],
#  [['switch', 'switch'], 'illumination', ['time', 'switch']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'colorControl']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'imageCapture']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'momentary']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'number']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'sendAction']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'switch']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['button', 'colorControl']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['button', 'locationMode']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['button', 'sendAction']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['contactSensor', 'alarm']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['contactSensor', 'colorControl']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['contactSensor', 'imageCapture']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['contactSensor', 'locationMode']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['contactSensor', 'momentary']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['contactSensor', 'number']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['contactSensor', 'sendAction']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['contactSensor', 'switch']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['contactSensor', 'thermostat']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'colorControl']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'imageCapture']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'locationMode']],
#  [['temperatureMeasurement', 'switch'], 'illumination', ['switch', 'number']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'sendAction']],
#  [['temperatureMeasurement', 'switch'], 'illumination', ['switch', 'switch']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['switch', 'switchLevel']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['time', 'device.PetFeederShield']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['time', 'locationMode']],
#  [['temperatureMeasurement', 'switch'], 'illumination', ['time', 'lock']],
#  [['temperatureMeasurement', 'switch'],
#   'illumination',
#   ['time', 'sendAction']],
#  [['temperatureMeasurement', 'switch'], 'illumination', ['time', 'switch']],
#  [['thermostat', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'colorControl']],
#  [['thermostat', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'imageCapture']],
#  [['thermostat', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'momentary']],
#  [['thermostat', 'switch'], 'illumination', ['accelerationSensor', 'number']],
#  [['thermostat', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'sendAction']],
#  [['thermostat', 'switch'], 'illumination', ['accelerationSensor', 'switch']],
#  [['thermostat', 'switch'], 'illumination', ['button', 'colorControl']],
#  [['thermostat', 'switch'], 'illumination', ['button', 'locationMode']],
#  [['thermostat', 'switch'], 'illumination', ['button', 'sendAction']],
#  [['thermostat', 'switch'], 'illumination', ['contactSensor', 'alarm']],
#  [['thermostat', 'switch'], 'illumination', ['contactSensor', 'colorControl']],
#  [['thermostat', 'switch'], 'illumination', ['contactSensor', 'imageCapture']],
#  [['thermostat', 'switch'], 'illumination', ['contactSensor', 'locationMode']],
#  [['thermostat', 'switch'], 'illumination', ['contactSensor', 'momentary']],
#  [['thermostat', 'switch'], 'illumination', ['contactSensor', 'number']],
#  [['thermostat', 'switch'], 'illumination', ['contactSensor', 'sendAction']],
#  [['thermostat', 'switch'], 'illumination', ['contactSensor', 'switch']],
#  [['thermostat', 'switch'], 'illumination', ['contactSensor', 'thermostat']],
#  [['thermostat', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['thermostat', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['thermostat', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['thermostat', 'switch'], 'illumination', ['switch', 'number']],
#  [['thermostat', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['thermostat', 'switch'], 'illumination', ['switch', 'switch']],
#  [['thermostat', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['thermostat', 'switch'],
#   'illumination',
#   ['time', 'device.PetFeederShield']],
#  [['thermostat', 'switch'], 'illumination', ['time', 'locationMode']],
#  [['thermostat', 'switch'], 'illumination', ['time', 'lock']],
#  [['thermostat', 'switch'], 'illumination', ['time', 'sendAction']],
#  [['thermostat', 'switch'], 'illumination', ['time', 'switch']],
#  [['time', 'switch'], 'illumination', ['accelerationSensor', 'colorControl']],
#  [['time', 'switch'], 'illumination', ['accelerationSensor', 'imageCapture']],
#  [['time', 'switch'], 'illumination', ['accelerationSensor', 'momentary']],
#  [['time', 'switch'], 'illumination', ['accelerationSensor', 'number']],
#  [['time', 'switch'], 'illumination', ['accelerationSensor', 'sendAction']],
#  [['time', 'switch'], 'illumination', ['accelerationSensor', 'switch']],
#  [['time', 'switch'], 'illumination', ['button', 'colorControl']],
#  [['time', 'switch'], 'illumination', ['button', 'locationMode']],
#  [['time', 'switch'], 'illumination', ['button', 'sendAction']],
#  [['time', 'switch'], 'illumination', ['contactSensor', 'alarm']],
#  [['time', 'switch'], 'illumination', ['contactSensor', 'colorControl']],
#  [['time', 'switch'], 'illumination', ['contactSensor', 'imageCapture']],
#  [['time', 'switch'], 'illumination', ['contactSensor', 'locationMode']],
#  [['time', 'switch'], 'illumination', ['contactSensor', 'momentary']],
#  [['time', 'switch'], 'illumination', ['contactSensor', 'number']],
#  [['time', 'switch'], 'illumination', ['contactSensor', 'sendAction']],
#  [['time', 'switch'], 'illumination', ['contactSensor', 'switch']],
#  [['time', 'switch'], 'illumination', ['contactSensor', 'thermostat']],
#  [['time', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['time', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['time', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['time', 'switch'], 'illumination', ['switch', 'number']],
#  [['time', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['time', 'switch'], 'illumination', ['switch', 'switch']],
#  [['time', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['time', 'switch'], 'illumination', ['time', 'device.PetFeederShield']],
#  [['time', 'switch'], 'illumination', ['time', 'locationMode']],
#  [['time', 'switch'], 'illumination', ['time', 'lock']],
#  [['time', 'switch'], 'illumination', ['time', 'sendAction']],
#  [['time', 'switch'], 'illumination', ['time', 'switch']],
#  [['touchSensor', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'colorControl']],
#  [['touchSensor', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'imageCapture']],
#  [['touchSensor', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'momentary']],
#  [['touchSensor', 'switch'], 'illumination', ['accelerationSensor', 'number']],
#  [['touchSensor', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'sendAction']],
#  [['touchSensor', 'switch'], 'illumination', ['accelerationSensor', 'switch']],
#  [['touchSensor', 'switch'], 'illumination', ['button', 'colorControl']],
#  [['touchSensor', 'switch'], 'illumination', ['button', 'locationMode']],
#  [['touchSensor', 'switch'], 'illumination', ['button', 'sendAction']],
#  [['touchSensor', 'switch'], 'illumination', ['contactSensor', 'alarm']],
#  [['touchSensor', 'switch'],
#   'illumination',
#   ['contactSensor', 'colorControl']],
#  [['touchSensor', 'switch'],
#   'illumination',
#   ['contactSensor', 'imageCapture']],
#  [['touchSensor', 'switch'],
#   'illumination',
#   ['contactSensor', 'locationMode']],
#  [['touchSensor', 'switch'], 'illumination', ['contactSensor', 'momentary']],
#  [['touchSensor', 'switch'], 'illumination', ['contactSensor', 'number']],
#  [['touchSensor', 'switch'], 'illumination', ['contactSensor', 'sendAction']],
#  [['touchSensor', 'switch'], 'illumination', ['contactSensor', 'switch']],
#  [['touchSensor', 'switch'], 'illumination', ['contactSensor', 'thermostat']],
#  [['touchSensor', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['touchSensor', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['touchSensor', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['touchSensor', 'switch'], 'illumination', ['switch', 'number']],
#  [['touchSensor', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['touchSensor', 'switch'], 'illumination', ['switch', 'switch']],
#  [['touchSensor', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['touchSensor', 'switch'],
#   'illumination',
#   ['time', 'device.PetFeederShield']],
#  [['touchSensor', 'switch'], 'illumination', ['time', 'locationMode']],
#  [['touchSensor', 'switch'], 'illumination', ['time', 'lock']],
#  [['touchSensor', 'switch'], 'illumination', ['time', 'sendAction']],
#  [['touchSensor', 'switch'], 'illumination', ['time', 'switch']],
#  [['waterSensor', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'colorControl']],
#  [['waterSensor', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'imageCapture']],
#  [['waterSensor', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'momentary']],
#  [['waterSensor', 'switch'], 'illumination', ['accelerationSensor', 'number']],
#  [['waterSensor', 'switch'],
#   'illumination',
#   ['accelerationSensor', 'sendAction']],
#  [['waterSensor', 'switch'], 'illumination', ['accelerationSensor', 'switch']],
#  [['waterSensor', 'switch'], 'illumination', ['button', 'colorControl']],
#  [['waterSensor', 'switch'], 'illumination', ['button', 'locationMode']],
#  [['waterSensor', 'switch'], 'illumination', ['button', 'sendAction']],
#  [['waterSensor', 'switch'], 'illumination', ['contactSensor', 'alarm']],
#  [['waterSensor', 'switch'],
#   'illumination',
#   ['contactSensor', 'colorControl']],
#  [['waterSensor', 'switch'],
#   'illumination',
#   ['contactSensor', 'imageCapture']],
#  [['waterSensor', 'switch'],
#   'illumination',
#   ['contactSensor', 'locationMode']],
#  [['waterSensor', 'switch'], 'illumination', ['contactSensor', 'momentary']],
#  [['waterSensor', 'switch'], 'illumination', ['contactSensor', 'number']],
#  [['waterSensor', 'switch'], 'illumination', ['contactSensor', 'sendAction']],
#  [['waterSensor', 'switch'], 'illumination', ['contactSensor', 'switch']],
#  [['waterSensor', 'switch'], 'illumination', ['contactSensor', 'thermostat']],
#  [['waterSensor', 'switch'], 'illumination', ['switch', 'colorControl']],
#  [['waterSensor', 'switch'], 'illumination', ['switch', 'imageCapture']],
#  [['waterSensor', 'switch'], 'illumination', ['switch', 'locationMode']],
#  [['waterSensor', 'switch'], 'illumination', ['switch', 'number']],
#  [['waterSensor', 'switch'], 'illumination', ['switch', 'sendAction']],
#  [['waterSensor', 'switch'], 'illumination', ['switch', 'switch']],
#  [['waterSensor', 'switch'], 'illumination', ['switch', 'switchLevel']],
#  [['waterSensor', 'switch'],
#   'illumination',
#   ['time', 'device.PetFeederShield']],
#  [['waterSensor', 'switch'], 'illumination', ['time', 'locationMode']],
#  [['waterSensor', 'switch'], 'illumination', ['time', 'lock']],
#  [['waterSensor', 'switch'], 'illumination', ['time', 'sendAction']],
#  [['waterSensor', 'switch'], 'illumination', ['time', 'switch']],
#  [['accelerationSensor', 'switch'],
#   'lock',
#   ['accelerationSensor', 'colorControl']],
#  [['accelerationSensor', 'switch'],
#   'lock',
#   ['accelerationSensor', 'imageCapture']],
#  [['accelerationSensor', 'switch'],
#   'lock',
#   ['accelerationSensor', 'momentary']],
#  [['accelerationSensor', 'switch'], 'lock', ['accelerationSensor', 'number']],
#  [['accelerationSensor', 'switch'],
#   'lock',
#   ['accelerationSensor', 'sendAction']],
#  [['accelerationSensor', 'switch'], 'lock', ['accelerationSensor', 'switch']],
#  [['accelerationSensor', 'switch'], 'lock', ['app', 'alarm']],
#  [['accelerationSensor', 'switch'], 'lock', ['app', 'colorControl']],
#  [['accelerationSensor', 'switch'], 'lock', ['app', 'doorControl']],
#  [['accelerationSensor', 'switch'], 'lock', ['app', 'lock']],
#  [['accelerationSensor', 'switch'], 'lock', ['app', 'switch']],
#  [['accelerationSensor', 'switch'], 'lock', ['app', 'thermostat']],
#  [['accelerationSensor', 'switch'], 'lock', ['beacon', 'lock']],
#  [['accelerationSensor', 'switch'], 'lock', ['beacon', 'switch']],
#  [['accelerationSensor', 'switch'], 'lock', ['button', 'colorControl']],
#  [['accelerationSensor', 'switch'], 'lock', ['button', 'locationMode']],
#  [['accelerationSensor', 'switch'], 'lock', ['button', 'sendAction']],
#  [['accelerationSensor', 'switch'],
#   'lock',
#   ['presenceSensor', 'colorControl']],
#  [['accelerationSensor', 'switch'],
#   'lock',
#   ['presenceSensor', 'imageCapture']],
#  [['accelerationSensor', 'switch'],
#   'lock',
#   ['presenceSensor', 'locationMode']],
#  [['accelerationSensor', 'switch'], 'lock', ['presenceSensor', 'lock']],
#  [['accelerationSensor', 'switch'], 'lock', ['presenceSensor', 'momentary']],
#  [['accelerationSensor', 'switch'], 'lock', ['presenceSensor', 'number']],
#  [['accelerationSensor', 'switch'], 'lock', ['presenceSensor', 'sendAction']],
#  [['accelerationSensor', 'switch'], 'lock', ['presenceSensor', 'switch']],
#  [['accelerationSensor', 'switch'], 'lock', ['switch', 'colorControl']],
#  [['accelerationSensor', 'switch'], 'lock', ['switch', 'imageCapture']],
#  [['accelerationSensor', 'switch'], 'lock', ['switch', 'locationMode']],
#  [['accelerationSensor', 'switch'], 'lock', ['switch', 'number']],
#  [['accelerationSensor', 'switch'], 'lock', ['switch', 'sendAction']],
#  [['accelerationSensor', 'switch'], 'lock', ['switch', 'switch']],
#  [['accelerationSensor', 'switch'], 'lock', ['switch', 'switchLevel']],
#  [['accelerationSensor', 'switch'], 'lock', ['threeAxis', 'sendAction']],
#  [['accelerationSensor', 'switch'],
#   'lock',
#   ['time', 'device.PetFeederShield']],
#  [['accelerationSensor', 'switch'], 'lock', ['time', 'locationMode']],
#  [['accelerationSensor', 'switch'], 'lock', ['time', 'lock']],
#  [['accelerationSensor', 'switch'], 'lock', ['time', 'sendAction']],
#  [['accelerationSensor', 'switch'], 'lock', ['time', 'switch']],
#  [['accelerationSensor', 'switch'], 'lock', ['waterSensor', 'colorControl']],
#  [['accelerationSensor', 'switch'], 'lock', ['waterSensor', 'sendAction']],
#  [['accelerationSensor', 'switch'], 'lock', ['waterSensor', 'switch']],
#  [['accelerationSensor', 'switch'], 'lock', ['waterSensor', 'valve']],
#  [['app', 'switch'], 'lock', ['accelerationSensor', 'colorControl']],
#  [['app', 'switch'], 'lock', ['accelerationSensor', 'imageCapture']],
#  [['app', 'switch'], 'lock', ['accelerationSensor', 'momentary']],
#  [['app', 'switch'], 'lock', ['accelerationSensor', 'number']],
#  [['app', 'switch'], 'lock', ['accelerationSensor', 'sendAction']],
#  [['app', 'switch'], 'lock', ['accelerationSensor', 'switch']],
#  [['app', 'switch'], 'lock', ['app', 'alarm']],
#  [['app', 'switch'], 'lock', ['app', 'colorControl']],
#  [['app', 'switch'], 'lock', ['app', 'doorControl']],
#  [['app', 'switch'], 'lock', ['app', 'lock']],
#  [['app', 'switch'], 'lock', ['app', 'switch']],
#  [['app', 'switch'], 'lock', ['app', 'thermostat']],
#  [['app', 'switch'], 'lock', ['beacon', 'lock']],
#  [['app', 'switch'], 'lock', ['beacon', 'switch']],
#  [['app', 'switch'], 'lock', ['button', 'colorControl']],
#  [['app', 'switch'], 'lock', ['button', 'locationMode']],
#  [['app', 'switch'], 'lock', ['button', 'sendAction']],
#  [['app', 'switch'], 'lock', ['presenceSensor', 'colorControl']],
#  [['app', 'switch'], 'lock', ['presenceSensor', 'imageCapture']],
#  [['app', 'switch'], 'lock', ['presenceSensor', 'locationMode']],
#  [['app', 'switch'], 'lock', ['presenceSensor', 'lock']],
#  [['app', 'switch'], 'lock', ['presenceSensor', 'momentary']],
#  [['app', 'switch'], 'lock', ['presenceSensor', 'number']],
#  [['app', 'switch'], 'lock', ['presenceSensor', 'sendAction']],
#  [['app', 'switch'], 'lock', ['presenceSensor', 'switch']],
#  [['app', 'switch'], 'lock', ['switch', 'colorControl']],
#  [['app', 'switch'], 'lock', ['switch', 'imageCapture']],
#  [['app', 'switch'], 'lock', ['switch', 'locationMode']],
#  [['app', 'switch'], 'lock', ['switch', 'number']],
#  [['app', 'switch'], 'lock', ['switch', 'sendAction']],
#  [['app', 'switch'], 'lock', ['switch', 'switch']],
#  [['app', 'switch'], 'lock', ['switch', 'switchLevel']],
#  [['app', 'switch'], 'lock', ['threeAxis', 'sendAction']],
#  [['app', 'switch'], 'lock', ['time', 'device.PetFeederShield']],
#  [['app', 'switch'], 'lock', ['time', 'locationMode']],
#  [['app', 'switch'], 'lock', ['time', 'lock']],
#  [['app', 'switch'], 'lock', ['time', 'sendAction']],
#  [['app', 'switch'], 'lock', ['time', 'switch']],
#  [['app', 'switch'], 'lock', ['waterSensor', 'colorControl']],
#  [['app', 'switch'], 'lock', ['waterSensor', 'sendAction']],
#  [['app', 'switch'], 'lock', ['waterSensor', 'switch']],
#  [['app', 'switch'], 'lock', ['waterSensor', 'valve']],
#  [['beacon', 'switch'], 'lock', ['accelerationSensor', 'colorControl']],
#  [['beacon', 'switch'], 'lock', ['accelerationSensor', 'imageCapture']],
#  [['beacon', 'switch'], 'lock', ['accelerationSensor', 'momentary']],
#  [['beacon', 'switch'], 'lock', ['accelerationSensor', 'number']],
#  [['beacon', 'switch'], 'lock', ['accelerationSensor', 'sendAction']],
#  [['beacon', 'switch'], 'lock', ['accelerationSensor', 'switch']],
#  [['beacon', 'switch'], 'lock', ['app', 'alarm']],
#  [['beacon', 'switch'], 'lock', ['app', 'colorControl']],
#  [['beacon', 'switch'], 'lock', ['app', 'doorControl']],
#  [['beacon', 'switch'], 'lock', ['app', 'lock']],
#  [['beacon', 'switch'], 'lock', ['app', 'switch']],
#  [['beacon', 'switch'], 'lock', ['app', 'thermostat']],
#  [['beacon', 'switch'], 'lock', ['beacon', 'lock']],
#  [['beacon', 'switch'], 'lock', ['beacon', 'switch']],
#  [['beacon', 'switch'], 'lock', ['button', 'colorControl']],
#  [['beacon', 'switch'], 'lock', ['button', 'locationMode']],
#  [['beacon', 'switch'], 'lock', ['button', 'sendAction']],
#  [['beacon', 'switch'], 'lock', ['presenceSensor', 'colorControl']],
#  [['beacon', 'switch'], 'lock', ['presenceSensor', 'imageCapture']],
#  [['beacon', 'switch'], 'lock', ['presenceSensor', 'locationMode']],
#  [['beacon', 'switch'], 'lock', ['presenceSensor', 'lock']],
#  [['beacon', 'switch'], 'lock', ['presenceSensor', 'momentary']],
#  [['beacon', 'switch'], 'lock', ['presenceSensor', 'number']],
#  [['beacon', 'switch'], 'lock', ['presenceSensor', 'sendAction']],
#  [['beacon', 'switch'], 'lock', ['presenceSensor', 'switch']],
#  [['beacon', 'switch'], 'lock', ['switch', 'colorControl']],
#  [['beacon', 'switch'], 'lock', ['switch', 'imageCapture']],
#  [['beacon', 'switch'], 'lock', ['switch', 'locationMode']],
#  [['beacon', 'switch'], 'lock', ['switch', 'number']],
#  [['beacon', 'switch'], 'lock', ['switch', 'sendAction']],
#  [['beacon', 'switch'], 'lock', ['switch', 'switch']],
#  [['beacon', 'switch'], 'lock', ['switch', 'switchLevel']],
#  [['beacon', 'switch'], 'lock', ['threeAxis', 'sendAction']],
# ...
#  [['location', 'switch'], 'lock', ['app', 'colorControl']],
#  [['location', 'switch'], 'lock', ['app', 'doorControl']],
#  [['location', 'switch'], 'lock', ['app', 'lock']],
#  [['location', 'switch'], 'lock', ['app', 'switch']],
#  [['location', 'switch'], 'lock', ['app', 'thermostat']],
#  [['location', 'switch'], 'lock', ['beacon', 'lock']],
#  [['location', 'switch'], 'lock', ['beacon', 'switch']],
#  [['location', 'switch'], 'lock', ['button', 'colorControl']],
#  [['location', 'switch'], 'lock', ['button', 'locationMode']],
#  [['location', 'switch'], 'lock', ['button', 'sendAction']],
#  [['location', 'switch'], 'lock', ['presenceSensor', 'colorControl']],
#  [['location', 'switch'], 'lock', ['presenceSensor', 'imageCapture']],
#  [['location', 'switch'], 'lock', ['presenceSensor', 'locationMode']],
#  [['location', 'switch'], 'lock', ['presenceSensor', 'lock']],
#  [['location', 'switch'], 'lock', ['presenceSensor', 'momentary']],
#  [['location', 'switch'], 'lock', ['presenceSensor', 'number']],
#  [['location', 'switch'], 'lock', ['presenceSensor', 'sendAction']],
#  [['location', 'switch'], 'lock', ['presenceSensor', 'switch']],
#  [['location', 'switch'], 'lock', ['switch', 'colorControl']],
#  [['location', 'switch'], 'lock', ['switch', 'imageCapture']],
#  [['location', 'switch'], 'lock', ['switch', 'locationMode']],
#  [['location', 'switch'], 'lock', ['switch', 'number']],
#  [['location', 'switch'], 'lock', ['switch', 'sendAction']],
#  [['location', 'switch'], 'lock', ['switch', 'switch']],
#  [['location', 'switch'], 'lock', ['switch', 'switchLevel']],
#  [['location', 'switch'], 'lock', ['threeAxis', 'sendAction']],
#  [['location', 'switch'], 'lock', ['time', 'device.PetFeederShield']],
#  [['location', 'switch'], 'lock', ['time', 'locationMode']],
#  [['location', 'switch'], 'lock', ['time', 'lock']],
#  [['location', 'switch'], 'lock', ['time', 'sendAction']],
#  [['location', 'switch'], 'lock', ['time', 'switch']],
#  [['location', 'switch'], 'lock', ['waterSensor', 'colorControl']],
#  [['location', 'switch'], 'lock', ['waterSensor', 'sendAction']],
#  [['location', 'switch'], 'lock', ['waterSensor', 'switch']],
#  [['location', 'switch'], 'lock', ['waterSensor', 'valve']],
#  [['motionSensor', 'switch'], 'lock', ['accelerationSensor', 'colorControl']],
#  [['motionSensor', 'switch'], 'lock', ['accelerationSensor', 'imageCapture']],
#  [['motionSensor', 'switch'], 'lock', ['accelerationSensor', 'momentary']],
#  [['motionSensor', 'switch'], 'lock', ['accelerationSensor', 'number']],
#  [['motionSensor', 'switch'], 'lock', ['accelerationSensor', 'sendAction']],
#  [['motionSensor', 'switch'], 'lock', ['accelerationSensor', 'switch']],
#  [['motionSensor', 'switch'], 'lock', ['app', 'alarm']],
#  [['motionSensor', 'switch'], 'lock', ['app', 'colorControl']],
#  [['motionSensor', 'switch'], 'lock', ['app', 'doorControl']],
#  [['motionSensor', 'switch'], 'lock', ['app', 'lock']],
#  [['motionSensor', 'switch'], 'lock', ['app', 'switch']],
#  [['motionSensor', 'switch'], 'lock', ['app', 'thermostat']],
#  [['motionSensor', 'switch'], 'lock', ['beacon', 'lock']],
#  [['motionSensor', 'switch'], 'lock', ['beacon', 'switch']],
#  [['motionSensor', 'switch'], 'lock', ['button', 'colorControl']],
#  [['motionSensor', 'switch'], 'lock', ['button', 'locationMode']],
#  [['motionSensor', 'switch'], 'lock', ['button', 'sendAction']],
#  [['motionSensor', 'switch'], 'lock', ['presenceSensor', 'colorControl']],
#  [['motionSensor', 'switch'], 'lock', ['presenceSensor', 'imageCapture']],
#  [['motionSensor', 'switch'], 'lock', ['presenceSensor', 'locationMode']],
#  [['motionSensor', 'switch'], 'lock', ['presenceSensor', 'lock']],
#  [['motionSensor', 'switch'], 'lock', ['presenceSensor', 'momentary']],
#  [['motionSensor', 'switch'], 'lock', ['presenceSensor', 'number']],
#  [['motionSensor', 'switch'], 'lock', ['presenceSensor', 'sendAction']],
#  [['motionSensor', 'switch'], 'lock', ['presenceSensor', 'switch']],
#  [['motionSensor', 'switch'], 'lock', ['switch', 'colorControl']],
#  [['motionSensor', 'switch'], 'lock', ['switch', 'imageCapture']],
#  [['motionSensor', 'switch'], 'lock', ['switch', 'locationMode']],
#  [['motionSensor', 'switch'], 'lock', ['switch', 'number']],
#  [['motionSensor', 'switch'], 'lock', ['switch', 'sendAction']],
#  [['motionSensor', 'switch'], 'lock', ['switch', 'switch']],
#  [['motionSensor', 'switch'], 'lock', ['switch', 'switchLevel']],
#  [['motionSensor', 'switch'], 'lock', ['threeAxis', 'sendAction']],
#  [['motionSensor', 'switch'], 'lock', ['time', 'device.PetFeederShield']],
#  [['motionSensor', 'switch'], 'lock', ['time', 'locationMode']],
#  [['motionSensor', 'switch'], 'lock', ['time', 'lock']],
#  [['motionSensor', 'switch'], 'lock', ['time', 'sendAction']],
#  [['motionSensor', 'switch'], 'lock', ['time', 'switch']],
#  [['motionSensor', 'switch'], 'lock', ['waterSensor', 'colorControl']],
#  [['motionSensor', 'switch'], 'lock', ['waterSensor', 'sendAction']],
#  [['motionSensor', 'switch'], 'lock', ['waterSensor', 'switch']],
#  [['motionSensor', 'switch'], 'lock', ['waterSensor', 'valve']],
#  [['powerMeter', 'switch'], 'lock', ['accelerationSensor', 'colorControl']],
#  [['powerMeter', 'switch'], 'lock', ['accelerationSensor', 'imageCapture']],
#  [['powerMeter', 'switch'], 'lock', ['accelerationSensor', 'momentary']],
#  [['powerMeter', 'switch'], 'lock', ['accelerationSensor', 'number']],
#  [['powerMeter', 'switch'], 'lock', ['accelerationSensor', 'sendAction']],
#  [['powerMeter', 'switch'], 'lock', ['accelerationSensor', 'switch']],
#  [['powerMeter', 'switch'], 'lock', ['app', 'alarm']],
#  [['powerMeter', 'switch'], 'lock', ['app', 'colorControl']],
#  [['powerMeter', 'switch'], 'lock', ['app', 'doorControl']],
#  [['powerMeter', 'switch'], 'lock', ['app', 'lock']],
#  [['powerMeter', 'switch'], 'lock', ['app', 'switch']],
#  [['powerMeter', 'switch'], 'lock', ['app', 'thermostat']],
#  [['powerMeter', 'switch'], 'lock', ['beacon', 'lock']],
#  [['powerMeter', 'switch'], 'lock', ['beacon', 'switch']],
#  [['powerMeter', 'switch'], 'lock', ['button', 'colorControl']],
#  [['powerMeter', 'switch'], 'lock', ['button', 'locationMode']],
#  [['powerMeter', 'switch'], 'lock', ['button', 'sendAction']],
#  [['powerMeter', 'switch'], 'lock', ['presenceSensor', 'colorControl']],
#  [['powerMeter', 'switch'], 'lock', ['presenceSensor', 'imageCapture']],
#  [['powerMeter', 'switch'], 'lock', ['presenceSensor', 'locationMode']],
#  [['powerMeter', 'switch'], 'lock', ['presenceSensor', 'lock']],
#  [['powerMeter', 'switch'], 'lock', ['presenceSensor', 'momentary']],
#  [['powerMeter', 'switch'], 'lock', ['presenceSensor', 'number']],
#  [['powerMeter', 'switch'], 'lock', ['presenceSensor', 'sendAction']],
#  [['powerMeter', 'switch'], 'lock', ['presenceSensor', 'switch']],
#  [['powerMeter', 'switch'], 'lock', ['switch', 'colorControl']],
#  [['powerMeter', 'switch'], 'lock', ['switch', 'imageCapture']],
#  [['powerMeter', 'switch'], 'lock', ['switch', 'locationMode']],
#  [['powerMeter', 'switch'], 'lock', ['switch', 'number']],
#  [['powerMeter', 'switch'], 'lock', ['switch', 'sendAction']],
#  [['powerMeter', 'switch'], 'lock', ['switch', 'switch']],
#  [['powerMeter', 'switch'], 'lock', ['switch', 'switchLevel']],
#  [['powerMeter', 'switch'], 'lock', ['threeAxis', 'sendAction']],
#  [['powerMeter', 'switch'], 'lock', ['time', 'device.PetFeederShield']],
#  [['powerMeter', 'switch'], 'lock', ['time', 'locationMode']],
#  [['powerMeter', 'switch'], 'lock', ['time', 'lock']],
#  [['powerMeter', 'switch'], 'lock', ['time', 'sendAction']],
#  [['powerMeter', 'switch'], 'lock', ['time', 'switch']],
#  [['powerMeter', 'switch'], 'lock', ['waterSensor', 'colorControl']],
#  [['powerMeter', 'switch'], 'lock', ['waterSensor', 'sendAction']],
#  [['powerMeter', 'switch'], 'lock', ['waterSensor', 'switch']],
#  [['powerMeter', 'switch'], 'lock', ['waterSensor', 'valve']],
#  [['presenceSensor', 'switch'],
#   'lock',
#   ['accelerationSensor', 'colorControl']],
#  [['presenceSensor', 'switch'],
#   'lock',
#   ['accelerationSensor', 'imageCapture']],
#  [['presenceSensor', 'switch'], 'lock', ['accelerationSensor', 'momentary']],
#  [['presenceSensor', 'switch'], 'lock', ['accelerationSensor', 'number']],
#  [['presenceSensor', 'switch'], 'lock', ['accelerationSensor', 'sendAction']],
#  [['presenceSensor', 'switch'], 'lock', ['accelerationSensor', 'switch']],
#  [['presenceSensor', 'switch'], 'lock', ['app', 'alarm']],
#  [['presenceSensor', 'switch'], 'lock', ['app', 'colorControl']],
#  [['presenceSensor', 'switch'], 'lock', ['app', 'doorControl']],
#  [['presenceSensor', 'switch'], 'lock', ['app', 'lock']],
#  [['presenceSensor', 'switch'], 'lock', ['app', 'switch']],
#  [['presenceSensor', 'switch'], 'lock', ['app', 'thermostat']],
#  [['presenceSensor', 'switch'], 'lock', ['beacon', 'lock']],
#  [['presenceSensor', 'switch'], 'lock', ['beacon', 'switch']],
#  [['presenceSensor', 'switch'], 'lock', ['button', 'colorControl']],
#  [['presenceSensor', 'switch'], 'lock', ['button', 'locationMode']],
#  [['presenceSensor', 'switch'], 'lock', ['button', 'sendAction']],
#  [['presenceSensor', 'switch'], 'lock', ['presenceSensor', 'colorControl']],
#  [['presenceSensor', 'switch'], 'lock', ['presenceSensor', 'imageCapture']],
#  [['presenceSensor', 'switch'], 'lock', ['presenceSensor', 'locationMode']],
#  [['presenceSensor', 'switch'], 'lock', ['presenceSensor', 'lock']],
#  [['presenceSensor', 'switch'], 'lock', ['presenceSensor', 'momentary']],
#  [['presenceSensor', 'switch'], 'lock', ['presenceSensor', 'number']],
#  [['presenceSensor', 'switch'], 'lock', ['presenceSensor', 'sendAction']],
#  [['presenceSensor', 'switch'], 'lock', ['presenceSensor', 'switch']],
#  [['presenceSensor', 'switch'], 'lock', ['switch', 'colorControl']],
#  [['presenceSensor', 'switch'], 'lock', ['switch', 'imageCapture']],
#  [['presenceSensor', 'switch'], 'lock', ['switch', 'locationMode']],
#  [['presenceSensor', 'switch'], 'lock', ['switch', 'number']],
#  [['presenceSensor', 'switch'], 'lock', ['switch', 'sendAction']],
#  [['presenceSensor', 'switch'], 'lock', ['switch', 'switch']],
#  [['presenceSensor', 'switch'], 'lock', ['switch', 'switchLevel']],
#  [['presenceSensor', 'switch'], 'lock', ['threeAxis', 'sendAction']],
#  [['presenceSensor', 'switch'], 'lock', ['time', 'device.PetFeederShield']],
#  [['presenceSensor', 'switch'], 'lock', ['time', 'locationMode']],
#  [['presenceSensor', 'switch'], 'lock', ['time', 'lock']],
#  [['presenceSensor', 'switch'], 'lock', ['time', 'sendAction']],
#  [['presenceSensor', 'switch'], 'lock', ['time', 'switch']],
#  [['presenceSensor', 'switch'], 'lock', ['waterSensor', 'colorControl']],
#  [['presenceSensor', 'switch'], 'lock', ['waterSensor', 'sendAction']],
#  [['presenceSensor', 'switch'], 'lock', ['waterSensor', 'switch']],
#  [['presenceSensor', 'switch'], 'lock', ['waterSensor', 'valve']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'lock',
#   ['accelerationSensor', 'colorControl']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'lock',
#   ['accelerationSensor', 'imageCapture']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'lock',
#   ['accelerationSensor', 'momentary']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'lock',
#   ['accelerationSensor', 'number']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'lock',
#   ['accelerationSensor', 'sendAction']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'lock',
#   ['accelerationSensor', 'switch']],
#  [['relativeHumidityMeasurement', 'switch'], 'lock', ['app', 'alarm']],
#  [['relativeHumidityMeasurement', 'switch'], 'lock', ['app', 'colorControl']],
#  [['relativeHumidityMeasurement', 'switch'], 'lock', ['app', 'doorControl']],
#  [['relativeHumidityMeasurement', 'switch'], 'lock', ['app', 'lock']],
#  [['relativeHumidityMeasurement', 'switch'], 'lock', ['app', 'switch']],
#  [['relativeHumidityMeasurement', 'switch'], 'lock', ['app', 'thermostat']],
#  [['relativeHumidityMeasurement', 'switch'], 'lock', ['beacon', 'lock']],
#  [['relativeHumidityMeasurement', 'switch'], 'lock', ['beacon', 'switch']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'lock',
#   ['button', 'colorControl']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'lock',
#   ['button', 'locationMode']],
#  [['relativeHumidityMeasurement', 'switch'], 'lock', ['button', 'sendAction']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'lock',
#   ['presenceSensor', 'colorControl']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'lock',
#   ['presenceSensor', 'imageCapture']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'lock',
#   ['presenceSensor', 'locationMode']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'lock',
#   ['presenceSensor', 'lock']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'lock',
#   ['presenceSensor', 'momentary']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'lock',
#   ['presenceSensor', 'number']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'lock',
#   ['presenceSensor', 'sendAction']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'lock',
#   ['presenceSensor', 'switch']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'lock',
#   ['switch', 'colorControl']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'lock',
#   ['switch', 'imageCapture']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'lock',
#   ['switch', 'locationMode']],
#  [['relativeHumidityMeasurement', 'switch'], 'lock', ['switch', 'number']],
#  [['relativeHumidityMeasurement', 'switch'], 'lock', ['switch', 'sendAction']],
#  [['relativeHumidityMeasurement', 'switch'], 'lock', ['switch', 'switch']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'lock',
#   ['switch', 'switchLevel']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'lock',
#   ['threeAxis', 'sendAction']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'lock',
#   ['time', 'device.PetFeederShield']],
#  [['relativeHumidityMeasurement', 'switch'], 'lock', ['time', 'locationMode']],
#  [['relativeHumidityMeasurement', 'switch'], 'lock', ['time', 'lock']],
#  [['relativeHumidityMeasurement', 'switch'], 'lock', ['time', 'sendAction']],
#  [['relativeHumidityMeasurement', 'switch'], 'lock', ['time', 'switch']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'lock',
#   ['waterSensor', 'colorControl']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'lock',
#   ['waterSensor', 'sendAction']],
#  [['relativeHumidityMeasurement', 'switch'],
#   'lock',
#   ['waterSensor', 'switch']],
#  [['relativeHumidityMeasurement', 'switch'], 'lock', ['waterSensor', 'valve']],
#  [['switch', 'switch'], 'lock', ['accelerationSensor', 'colorControl']],
#  [['switch', 'switch'], 'lock', ['accelerationSensor', 'imageCapture']],
#  [['switch', 'switch'], 'lock', ['accelerationSensor', 'momentary']],
#  [['switch', 'switch'], 'lock', ['accelerationSensor', 'number']],
#  [['switch', 'switch'], 'lock', ['accelerationSensor', 'sendAction']],
#  [['switch', 'switch'], 'lock', ['accelerationSensor', 'switch']],
#  [['switch', 'switch'], 'lock', ['app', 'alarm']],
#  [['switch', 'switch'], 'lock', ['app', 'colorControl']],
#  [['switch', 'switch'], 'lock', ['app', 'doorControl']],
#  [['switch', 'switch'], 'lock', ['app', 'lock']],
#  [['switch', 'switch'], 'lock', ['app', 'switch']],
#  [['switch', 'switch'], 'lock', ['app', 'thermostat']],
#  [['switch', 'switch'], 'lock', ['beacon', 'lock']],
#  [['switch', 'switch'], 'lock', ['beacon', 'switch']],
#  [['switch', 'switch'], 'lock', ['button', 'colorControl']],
#  [['switch', 'switch'], 'lock', ['button', 'locationMode']],
#  [['switch', 'switch'], 'lock', ['button', 'sendAction']],
#  [['switch', 'switch'], 'lock', ['presenceSensor', 'colorControl']],
#  [['switch', 'switch'], 'lock', ['presenceSensor', 'imageCapture']],
#  [['switch', 'switch'], 'lock', ['presenceSensor', 'locationMode']],
#  [['switch', 'switch'], 'lock', ['presenceSensor', 'lock']],
#  [['switch', 'switch'], 'lock', ['presenceSensor', 'momentary']],
#  [['switch', 'switch'], 'lock', ['presenceSensor', 'number']],
#  [['switch', 'switch'], 'lock', ['presenceSensor', 'sendAction']],
#  [['switch', 'switch'], 'lock', ['presenceSensor', 'switch']],
#  [['switch', 'switch'], 'lock', ['switch', 'colorControl']],
#  [['switch', 'switch'], 'lock', ['switch', 'imageCapture']],
#  [['switch', 'switch'], 'lock', ['switch', 'locationMode']],
#  ...]

# %%
for triple in INTAC:
    first_app = triple[0]
    channel = triple[1]
    second_app = triple[2]
    print(f"tri_1:{first_app[0]}, act_1:{first_app[1]} \t-- {channel} -- tri_2:{second_app[0]}, act:{second_app[1]}")
# Out:
# tri_1:accelerationSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:colorControl
# tri_1:accelerationSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:imageCapture
# tri_1:accelerationSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:momentary
# tri_1:accelerationSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:number
# tri_1:accelerationSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:sendAction
# tri_1:accelerationSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:switch
# tri_1:accelerationSensor, act_1:switch 	-- illumination -- tri_2:button, act:colorControl
# tri_1:accelerationSensor, act_1:switch 	-- illumination -- tri_2:button, act:locationMode
# tri_1:accelerationSensor, act_1:switch 	-- illumination -- tri_2:button, act:sendAction
# tri_1:accelerationSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:alarm
# tri_1:accelerationSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:colorControl
# tri_1:accelerationSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:imageCapture
# tri_1:accelerationSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:locationMode
# tri_1:accelerationSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:momentary
# tri_1:accelerationSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:number
# tri_1:accelerationSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:sendAction
# tri_1:accelerationSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:switch
# tri_1:accelerationSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:thermostat
# tri_1:accelerationSensor, act_1:switch 	-- illumination -- tri_2:switch, act:colorControl
# tri_1:accelerationSensor, act_1:switch 	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:accelerationSensor, act_1:switch 	-- illumination -- tri_2:switch, act:locationMode
# tri_1:accelerationSensor, act_1:switch 	-- illumination -- tri_2:switch, act:number
# tri_1:accelerationSensor, act_1:switch 	-- illumination -- tri_2:switch, act:sendAction
# tri_1:accelerationSensor, act_1:switch 	-- illumination -- tri_2:switch, act:switch
# tri_1:accelerationSensor, act_1:switch 	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:accelerationSensor, act_1:switch 	-- illumination -- tri_2:time, act:device.PetFeederShield
# tri_1:accelerationSensor, act_1:switch 	-- illumination -- tri_2:time, act:locationMode
# tri_1:accelerationSensor, act_1:switch 	-- illumination -- tri_2:time, act:lock
# tri_1:accelerationSensor, act_1:switch 	-- illumination -- tri_2:time, act:sendAction
# tri_1:accelerationSensor, act_1:switch 	-- illumination -- tri_2:time, act:switch
# tri_1:app, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:colorControl
# tri_1:app, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:imageCapture
# tri_1:app, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:momentary
# tri_1:app, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:number
# tri_1:app, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:sendAction
# tri_1:app, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:switch
# tri_1:app, act_1:switch 	-- illumination -- tri_2:button, act:colorControl
# tri_1:app, act_1:switch 	-- illumination -- tri_2:button, act:locationMode
# tri_1:app, act_1:switch 	-- illumination -- tri_2:button, act:sendAction
# tri_1:app, act_1:switch 	-- illumination -- tri_2:contactSensor, act:alarm
# tri_1:app, act_1:switch 	-- illumination -- tri_2:contactSensor, act:colorControl
# tri_1:app, act_1:switch 	-- illumination -- tri_2:contactSensor, act:imageCapture
# tri_1:app, act_1:switch 	-- illumination -- tri_2:contactSensor, act:locationMode
# tri_1:app, act_1:switch 	-- illumination -- tri_2:contactSensor, act:momentary
# tri_1:app, act_1:switch 	-- illumination -- tri_2:contactSensor, act:number
# tri_1:app, act_1:switch 	-- illumination -- tri_2:contactSensor, act:sendAction
# tri_1:app, act_1:switch 	-- illumination -- tri_2:contactSensor, act:switch
# tri_1:app, act_1:switch 	-- illumination -- tri_2:contactSensor, act:thermostat
# tri_1:app, act_1:switch 	-- illumination -- tri_2:switch, act:colorControl
# tri_1:app, act_1:switch 	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:app, act_1:switch 	-- illumination -- tri_2:switch, act:locationMode
# tri_1:app, act_1:switch 	-- illumination -- tri_2:switch, act:number
# tri_1:app, act_1:switch 	-- illumination -- tri_2:switch, act:sendAction
# tri_1:app, act_1:switch 	-- illumination -- tri_2:switch, act:switch
# tri_1:app, act_1:switch 	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:app, act_1:switch 	-- illumination -- tri_2:time, act:device.PetFeederShield
# tri_1:app, act_1:switch 	-- illumination -- tri_2:time, act:locationMode
# tri_1:app, act_1:switch 	-- illumination -- tri_2:time, act:lock
# tri_1:app, act_1:switch 	-- illumination -- tri_2:time, act:sendAction
# tri_1:app, act_1:switch 	-- illumination -- tri_2:time, act:switch
# tri_1:beacon, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:colorControl
# tri_1:beacon, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:imageCapture
# tri_1:beacon, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:momentary
# tri_1:beacon, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:number
# tri_1:beacon, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:sendAction
# tri_1:beacon, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:switch
# tri_1:beacon, act_1:switch 	-- illumination -- tri_2:button, act:colorControl
# tri_1:beacon, act_1:switch 	-- illumination -- tri_2:button, act:locationMode
# tri_1:beacon, act_1:switch 	-- illumination -- tri_2:button, act:sendAction
# tri_1:beacon, act_1:switch 	-- illumination -- tri_2:contactSensor, act:alarm
# tri_1:beacon, act_1:switch 	-- illumination -- tri_2:contactSensor, act:colorControl
# tri_1:beacon, act_1:switch 	-- illumination -- tri_2:contactSensor, act:imageCapture
# tri_1:beacon, act_1:switch 	-- illumination -- tri_2:contactSensor, act:locationMode
# tri_1:beacon, act_1:switch 	-- illumination -- tri_2:contactSensor, act:momentary
# tri_1:beacon, act_1:switch 	-- illumination -- tri_2:contactSensor, act:number
# tri_1:beacon, act_1:switch 	-- illumination -- tri_2:contactSensor, act:sendAction
# tri_1:beacon, act_1:switch 	-- illumination -- tri_2:contactSensor, act:switch
# tri_1:beacon, act_1:switch 	-- illumination -- tri_2:contactSensor, act:thermostat
# tri_1:beacon, act_1:switch 	-- illumination -- tri_2:switch, act:colorControl
# tri_1:beacon, act_1:switch 	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:beacon, act_1:switch 	-- illumination -- tri_2:switch, act:locationMode
# tri_1:beacon, act_1:switch 	-- illumination -- tri_2:switch, act:number
# tri_1:beacon, act_1:switch 	-- illumination -- tri_2:switch, act:sendAction
# tri_1:beacon, act_1:switch 	-- illumination -- tri_2:switch, act:switch
# tri_1:beacon, act_1:switch 	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:beacon, act_1:switch 	-- illumination -- tri_2:time, act:device.PetFeederShield
# tri_1:beacon, act_1:switch 	-- illumination -- tri_2:time, act:locationMode
# tri_1:beacon, act_1:switch 	-- illumination -- tri_2:time, act:lock
# tri_1:beacon, act_1:switch 	-- illumination -- tri_2:time, act:sendAction
# tri_1:beacon, act_1:switch 	-- illumination -- tri_2:time, act:switch
# tri_1:contactSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:colorControl
# tri_1:contactSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:imageCapture
# tri_1:contactSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:momentary
# tri_1:contactSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:number
# tri_1:contactSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:sendAction
# tri_1:contactSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:switch
# tri_1:contactSensor, act_1:switch 	-- illumination -- tri_2:button, act:colorControl
# tri_1:contactSensor, act_1:switch 	-- illumination -- tri_2:button, act:locationMode
# tri_1:contactSensor, act_1:switch 	-- illumination -- tri_2:button, act:sendAction
# tri_1:contactSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:alarm
# tri_1:contactSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:colorControl
# tri_1:contactSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:imageCapture
# tri_1:contactSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:locationMode
# tri_1:contactSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:momentary
# tri_1:contactSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:number
# tri_1:contactSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:sendAction
# tri_1:contactSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:switch
# tri_1:contactSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:thermostat
# tri_1:contactSensor, act_1:switch 	-- illumination -- tri_2:switch, act:colorControl
# tri_1:contactSensor, act_1:switch 	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:contactSensor, act_1:switch 	-- illumination -- tri_2:switch, act:locationMode
# tri_1:contactSensor, act_1:switch 	-- illumination -- tri_2:switch, act:number
# tri_1:contactSensor, act_1:switch 	-- illumination -- tri_2:switch, act:sendAction
# tri_1:contactSensor, act_1:switch 	-- illumination -- tri_2:switch, act:switch
# tri_1:contactSensor, act_1:switch 	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:contactSensor, act_1:switch 	-- illumination -- tri_2:time, act:device.PetFeederShield
# tri_1:contactSensor, act_1:switch 	-- illumination -- tri_2:time, act:locationMode
# tri_1:contactSensor, act_1:switch 	-- illumination -- tri_2:time, act:lock
# tri_1:contactSensor, act_1:switch 	-- illumination -- tri_2:time, act:sendAction
# tri_1:contactSensor, act_1:switch 	-- illumination -- tri_2:time, act:switch
# tri_1:device.jawboneUser, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:colorControl
# tri_1:device.jawboneUser, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:imageCapture
# tri_1:device.jawboneUser, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:momentary
# tri_1:device.jawboneUser, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:number
# tri_1:device.jawboneUser, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:sendAction
# tri_1:device.jawboneUser, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:switch
# tri_1:device.jawboneUser, act_1:switch 	-- illumination -- tri_2:button, act:colorControl
# tri_1:device.jawboneUser, act_1:switch 	-- illumination -- tri_2:button, act:locationMode
# tri_1:device.jawboneUser, act_1:switch 	-- illumination -- tri_2:button, act:sendAction
# tri_1:device.jawboneUser, act_1:switch 	-- illumination -- tri_2:contactSensor, act:alarm
# tri_1:device.jawboneUser, act_1:switch 	-- illumination -- tri_2:contactSensor, act:colorControl
# tri_1:device.jawboneUser, act_1:switch 	-- illumination -- tri_2:contactSensor, act:imageCapture
# tri_1:device.jawboneUser, act_1:switch 	-- illumination -- tri_2:contactSensor, act:locationMode
# tri_1:device.jawboneUser, act_1:switch 	-- illumination -- tri_2:contactSensor, act:momentary
# tri_1:device.jawboneUser, act_1:switch 	-- illumination -- tri_2:contactSensor, act:number
# tri_1:device.jawboneUser, act_1:switch 	-- illumination -- tri_2:contactSensor, act:sendAction
# tri_1:device.jawboneUser, act_1:switch 	-- illumination -- tri_2:contactSensor, act:switch
# tri_1:device.jawboneUser, act_1:switch 	-- illumination -- tri_2:contactSensor, act:thermostat
# tri_1:device.jawboneUser, act_1:switch 	-- illumination -- tri_2:switch, act:colorControl
# tri_1:device.jawboneUser, act_1:switch 	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:device.jawboneUser, act_1:switch 	-- illumination -- tri_2:switch, act:locationMode
# tri_1:device.jawboneUser, act_1:switch 	-- illumination -- tri_2:switch, act:number
# tri_1:device.jawboneUser, act_1:switch 	-- illumination -- tri_2:switch, act:sendAction
# tri_1:device.jawboneUser, act_1:switch 	-- illumination -- tri_2:switch, act:switch
# tri_1:device.jawboneUser, act_1:switch 	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:device.jawboneUser, act_1:switch 	-- illumination -- tri_2:time, act:device.PetFeederShield
# tri_1:device.jawboneUser, act_1:switch 	-- illumination -- tri_2:time, act:locationMode
# tri_1:device.jawboneUser, act_1:switch 	-- illumination -- tri_2:time, act:lock
# tri_1:device.jawboneUser, act_1:switch 	-- illumination -- tri_2:time, act:sendAction
# tri_1:device.jawboneUser, act_1:switch 	-- illumination -- tri_2:time, act:switch
# tri_1:illuminanceMeasurement, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:colorControl
# tri_1:illuminanceMeasurement, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:imageCapture
# tri_1:illuminanceMeasurement, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:momentary
# tri_1:illuminanceMeasurement, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:number
# tri_1:illuminanceMeasurement, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:sendAction
# tri_1:illuminanceMeasurement, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:switch
# tri_1:illuminanceMeasurement, act_1:switch 	-- illumination -- tri_2:button, act:colorControl
# tri_1:illuminanceMeasurement, act_1:switch 	-- illumination -- tri_2:button, act:locationMode
# tri_1:illuminanceMeasurement, act_1:switch 	-- illumination -- tri_2:button, act:sendAction
# tri_1:illuminanceMeasurement, act_1:switch 	-- illumination -- tri_2:contactSensor, act:alarm
# tri_1:illuminanceMeasurement, act_1:switch 	-- illumination -- tri_2:contactSensor, act:colorControl
# tri_1:illuminanceMeasurement, act_1:switch 	-- illumination -- tri_2:contactSensor, act:imageCapture
# tri_1:illuminanceMeasurement, act_1:switch 	-- illumination -- tri_2:contactSensor, act:locationMode
# tri_1:illuminanceMeasurement, act_1:switch 	-- illumination -- tri_2:contactSensor, act:momentary
# tri_1:illuminanceMeasurement, act_1:switch 	-- illumination -- tri_2:contactSensor, act:number
# tri_1:illuminanceMeasurement, act_1:switch 	-- illumination -- tri_2:contactSensor, act:sendAction
# tri_1:illuminanceMeasurement, act_1:switch 	-- illumination -- tri_2:contactSensor, act:switch
# tri_1:illuminanceMeasurement, act_1:switch 	-- illumination -- tri_2:contactSensor, act:thermostat
# tri_1:illuminanceMeasurement, act_1:switch 	-- illumination -- tri_2:switch, act:colorControl
# tri_1:illuminanceMeasurement, act_1:switch 	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:illuminanceMeasurement, act_1:switch 	-- illumination -- tri_2:switch, act:locationMode
# tri_1:illuminanceMeasurement, act_1:switch 	-- illumination -- tri_2:switch, act:number
# tri_1:illuminanceMeasurement, act_1:switch 	-- illumination -- tri_2:switch, act:sendAction
# tri_1:illuminanceMeasurement, act_1:switch 	-- illumination -- tri_2:switch, act:switch
# tri_1:illuminanceMeasurement, act_1:switch 	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:illuminanceMeasurement, act_1:switch 	-- illumination -- tri_2:time, act:device.PetFeederShield
# tri_1:illuminanceMeasurement, act_1:switch 	-- illumination -- tri_2:time, act:locationMode
# tri_1:illuminanceMeasurement, act_1:switch 	-- illumination -- tri_2:time, act:lock
# tri_1:illuminanceMeasurement, act_1:switch 	-- illumination -- tri_2:time, act:sendAction
# tri_1:illuminanceMeasurement, act_1:switch 	-- illumination -- tri_2:time, act:switch
# tri_1:location, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:colorControl
# tri_1:location, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:imageCapture
# tri_1:location, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:momentary
# tri_1:location, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:number
# tri_1:location, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:sendAction
# tri_1:location, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:switch
# tri_1:location, act_1:switch 	-- illumination -- tri_2:button, act:colorControl
# tri_1:location, act_1:switch 	-- illumination -- tri_2:button, act:locationMode
# tri_1:location, act_1:switch 	-- illumination -- tri_2:button, act:sendAction
# tri_1:location, act_1:switch 	-- illumination -- tri_2:contactSensor, act:alarm
# tri_1:location, act_1:switch 	-- illumination -- tri_2:contactSensor, act:colorControl
# tri_1:location, act_1:switch 	-- illumination -- tri_2:contactSensor, act:imageCapture
# tri_1:location, act_1:switch 	-- illumination -- tri_2:contactSensor, act:locationMode
# tri_1:location, act_1:switch 	-- illumination -- tri_2:contactSensor, act:momentary
# tri_1:location, act_1:switch 	-- illumination -- tri_2:contactSensor, act:number
# tri_1:location, act_1:switch 	-- illumination -- tri_2:contactSensor, act:sendAction
# tri_1:location, act_1:switch 	-- illumination -- tri_2:contactSensor, act:switch
# tri_1:location, act_1:switch 	-- illumination -- tri_2:contactSensor, act:thermostat
# tri_1:location, act_1:switch 	-- illumination -- tri_2:switch, act:colorControl
# tri_1:location, act_1:switch 	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:location, act_1:switch 	-- illumination -- tri_2:switch, act:locationMode
# tri_1:location, act_1:switch 	-- illumination -- tri_2:switch, act:number
# tri_1:location, act_1:switch 	-- illumination -- tri_2:switch, act:sendAction
# tri_1:location, act_1:switch 	-- illumination -- tri_2:switch, act:switch
# tri_1:location, act_1:switch 	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:location, act_1:switch 	-- illumination -- tri_2:time, act:device.PetFeederShield
# tri_1:location, act_1:switch 	-- illumination -- tri_2:time, act:locationMode
# tri_1:location, act_1:switch 	-- illumination -- tri_2:time, act:lock
# tri_1:location, act_1:switch 	-- illumination -- tri_2:time, act:sendAction
# tri_1:location, act_1:switch 	-- illumination -- tri_2:time, act:switch
# tri_1:motionSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:colorControl
# tri_1:motionSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:imageCapture
# tri_1:motionSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:momentary
# tri_1:motionSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:number
# tri_1:motionSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:sendAction
# tri_1:motionSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:switch
# tri_1:motionSensor, act_1:switch 	-- illumination -- tri_2:button, act:colorControl
# tri_1:motionSensor, act_1:switch 	-- illumination -- tri_2:button, act:locationMode
# tri_1:motionSensor, act_1:switch 	-- illumination -- tri_2:button, act:sendAction
# tri_1:motionSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:alarm
# tri_1:motionSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:colorControl
# tri_1:motionSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:imageCapture
# tri_1:motionSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:locationMode
# tri_1:motionSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:momentary
# tri_1:motionSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:number
# tri_1:motionSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:sendAction
# tri_1:motionSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:switch
# tri_1:motionSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:thermostat
# tri_1:motionSensor, act_1:switch 	-- illumination -- tri_2:switch, act:colorControl
# tri_1:motionSensor, act_1:switch 	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:motionSensor, act_1:switch 	-- illumination -- tri_2:switch, act:locationMode
# tri_1:motionSensor, act_1:switch 	-- illumination -- tri_2:switch, act:number
# tri_1:motionSensor, act_1:switch 	-- illumination -- tri_2:switch, act:sendAction
# tri_1:motionSensor, act_1:switch 	-- illumination -- tri_2:switch, act:switch
# tri_1:motionSensor, act_1:switch 	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:motionSensor, act_1:switch 	-- illumination -- tri_2:time, act:device.PetFeederShield
# tri_1:motionSensor, act_1:switch 	-- illumination -- tri_2:time, act:locationMode
# tri_1:motionSensor, act_1:switch 	-- illumination -- tri_2:time, act:lock
# tri_1:motionSensor, act_1:switch 	-- illumination -- tri_2:time, act:sendAction
# tri_1:motionSensor, act_1:switch 	-- illumination -- tri_2:time, act:switch
# tri_1:powerMeter, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:colorControl
# tri_1:powerMeter, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:imageCapture
# tri_1:powerMeter, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:momentary
# tri_1:powerMeter, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:number
# tri_1:powerMeter, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:sendAction
# tri_1:powerMeter, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:switch
# tri_1:powerMeter, act_1:switch 	-- illumination -- tri_2:button, act:colorControl
# tri_1:powerMeter, act_1:switch 	-- illumination -- tri_2:button, act:locationMode
# tri_1:powerMeter, act_1:switch 	-- illumination -- tri_2:button, act:sendAction
# tri_1:powerMeter, act_1:switch 	-- illumination -- tri_2:contactSensor, act:alarm
# tri_1:powerMeter, act_1:switch 	-- illumination -- tri_2:contactSensor, act:colorControl
# tri_1:powerMeter, act_1:switch 	-- illumination -- tri_2:contactSensor, act:imageCapture
# tri_1:powerMeter, act_1:switch 	-- illumination -- tri_2:contactSensor, act:locationMode
# tri_1:powerMeter, act_1:switch 	-- illumination -- tri_2:contactSensor, act:momentary
# tri_1:powerMeter, act_1:switch 	-- illumination -- tri_2:contactSensor, act:number
# tri_1:powerMeter, act_1:switch 	-- illumination -- tri_2:contactSensor, act:sendAction
# tri_1:powerMeter, act_1:switch 	-- illumination -- tri_2:contactSensor, act:switch
# tri_1:powerMeter, act_1:switch 	-- illumination -- tri_2:contactSensor, act:thermostat
# tri_1:powerMeter, act_1:switch 	-- illumination -- tri_2:switch, act:colorControl
# tri_1:powerMeter, act_1:switch 	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:powerMeter, act_1:switch 	-- illumination -- tri_2:switch, act:locationMode
# tri_1:powerMeter, act_1:switch 	-- illumination -- tri_2:switch, act:number
# tri_1:powerMeter, act_1:switch 	-- illumination -- tri_2:switch, act:sendAction
# tri_1:powerMeter, act_1:switch 	-- illumination -- tri_2:switch, act:switch
# tri_1:powerMeter, act_1:switch 	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:powerMeter, act_1:switch 	-- illumination -- tri_2:time, act:device.PetFeederShield
# tri_1:powerMeter, act_1:switch 	-- illumination -- tri_2:time, act:locationMode
# tri_1:powerMeter, act_1:switch 	-- illumination -- tri_2:time, act:lock
# tri_1:powerMeter, act_1:switch 	-- illumination -- tri_2:time, act:sendAction
# tri_1:powerMeter, act_1:switch 	-- illumination -- tri_2:time, act:switch
# tri_1:presenceSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:colorControl
# tri_1:presenceSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:imageCapture
# tri_1:presenceSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:momentary
# tri_1:presenceSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:number
# tri_1:presenceSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:sendAction
# tri_1:presenceSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:switch
# tri_1:presenceSensor, act_1:switch 	-- illumination -- tri_2:button, act:colorControl
# tri_1:presenceSensor, act_1:switch 	-- illumination -- tri_2:button, act:locationMode
# tri_1:presenceSensor, act_1:switch 	-- illumination -- tri_2:button, act:sendAction
# tri_1:presenceSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:alarm
# tri_1:presenceSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:colorControl
# tri_1:presenceSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:imageCapture
# tri_1:presenceSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:locationMode
# tri_1:presenceSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:momentary
# tri_1:presenceSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:number
# tri_1:presenceSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:sendAction
# tri_1:presenceSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:switch
# tri_1:presenceSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:thermostat
# tri_1:presenceSensor, act_1:switch 	-- illumination -- tri_2:switch, act:colorControl
# tri_1:presenceSensor, act_1:switch 	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:presenceSensor, act_1:switch 	-- illumination -- tri_2:switch, act:locationMode
# tri_1:presenceSensor, act_1:switch 	-- illumination -- tri_2:switch, act:number
# tri_1:presenceSensor, act_1:switch 	-- illumination -- tri_2:switch, act:sendAction
# tri_1:presenceSensor, act_1:switch 	-- illumination -- tri_2:switch, act:switch
# tri_1:presenceSensor, act_1:switch 	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:presenceSensor, act_1:switch 	-- illumination -- tri_2:time, act:device.PetFeederShield
# tri_1:presenceSensor, act_1:switch 	-- illumination -- tri_2:time, act:locationMode
# tri_1:presenceSensor, act_1:switch 	-- illumination -- tri_2:time, act:lock
# tri_1:presenceSensor, act_1:switch 	-- illumination -- tri_2:time, act:sendAction
# tri_1:presenceSensor, act_1:switch 	-- illumination -- tri_2:time, act:switch
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:colorControl
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:imageCapture
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:momentary
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:number
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:sendAction
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:switch
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- illumination -- tri_2:button, act:colorControl
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- illumination -- tri_2:button, act:locationMode
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- illumination -- tri_2:button, act:sendAction
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- illumination -- tri_2:contactSensor, act:alarm
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- illumination -- tri_2:contactSensor, act:colorControl
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- illumination -- tri_2:contactSensor, act:imageCapture
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- illumination -- tri_2:contactSensor, act:locationMode
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- illumination -- tri_2:contactSensor, act:momentary
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- illumination -- tri_2:contactSensor, act:number
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- illumination -- tri_2:contactSensor, act:sendAction
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- illumination -- tri_2:contactSensor, act:switch
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- illumination -- tri_2:contactSensor, act:thermostat
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- illumination -- tri_2:switch, act:colorControl
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- illumination -- tri_2:switch, act:locationMode
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- illumination -- tri_2:switch, act:number
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- illumination -- tri_2:switch, act:sendAction
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- illumination -- tri_2:switch, act:switch
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- illumination -- tri_2:time, act:device.PetFeederShield
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- illumination -- tri_2:time, act:locationMode
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- illumination -- tri_2:time, act:lock
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- illumination -- tri_2:time, act:sendAction
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- illumination -- tri_2:time, act:switch
# tri_1:switch, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:colorControl
# tri_1:switch, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:imageCapture
# tri_1:switch, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:momentary
# tri_1:switch, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:number
# tri_1:switch, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:sendAction
# tri_1:switch, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:switch
# tri_1:switch, act_1:switch 	-- illumination -- tri_2:button, act:colorControl
# tri_1:switch, act_1:switch 	-- illumination -- tri_2:button, act:locationMode
# tri_1:switch, act_1:switch 	-- illumination -- tri_2:button, act:sendAction
# tri_1:switch, act_1:switch 	-- illumination -- tri_2:contactSensor, act:alarm
# tri_1:switch, act_1:switch 	-- illumination -- tri_2:contactSensor, act:colorControl
# tri_1:switch, act_1:switch 	-- illumination -- tri_2:contactSensor, act:imageCapture
# tri_1:switch, act_1:switch 	-- illumination -- tri_2:contactSensor, act:locationMode
# tri_1:switch, act_1:switch 	-- illumination -- tri_2:contactSensor, act:momentary
# tri_1:switch, act_1:switch 	-- illumination -- tri_2:contactSensor, act:number
# tri_1:switch, act_1:switch 	-- illumination -- tri_2:contactSensor, act:sendAction
# tri_1:switch, act_1:switch 	-- illumination -- tri_2:contactSensor, act:switch
# tri_1:switch, act_1:switch 	-- illumination -- tri_2:contactSensor, act:thermostat
# tri_1:switch, act_1:switch 	-- illumination -- tri_2:switch, act:colorControl
# tri_1:switch, act_1:switch 	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:switch, act_1:switch 	-- illumination -- tri_2:switch, act:locationMode
# tri_1:switch, act_1:switch 	-- illumination -- tri_2:switch, act:number
# tri_1:switch, act_1:switch 	-- illumination -- tri_2:switch, act:sendAction
# tri_1:switch, act_1:switch 	-- illumination -- tri_2:switch, act:switch
# tri_1:switch, act_1:switch 	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:switch, act_1:switch 	-- illumination -- tri_2:time, act:device.PetFeederShield
# tri_1:switch, act_1:switch 	-- illumination -- tri_2:time, act:locationMode
# tri_1:switch, act_1:switch 	-- illumination -- tri_2:time, act:lock
# tri_1:switch, act_1:switch 	-- illumination -- tri_2:time, act:sendAction
# tri_1:switch, act_1:switch 	-- illumination -- tri_2:time, act:switch
# tri_1:temperatureMeasurement, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:colorControl
# tri_1:temperatureMeasurement, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:imageCapture
# tri_1:temperatureMeasurement, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:momentary
# tri_1:temperatureMeasurement, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:number
# tri_1:temperatureMeasurement, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:sendAction
# tri_1:temperatureMeasurement, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:switch
# tri_1:temperatureMeasurement, act_1:switch 	-- illumination -- tri_2:button, act:colorControl
# tri_1:temperatureMeasurement, act_1:switch 	-- illumination -- tri_2:button, act:locationMode
# tri_1:temperatureMeasurement, act_1:switch 	-- illumination -- tri_2:button, act:sendAction
# tri_1:temperatureMeasurement, act_1:switch 	-- illumination -- tri_2:contactSensor, act:alarm
# tri_1:temperatureMeasurement, act_1:switch 	-- illumination -- tri_2:contactSensor, act:colorControl
# tri_1:temperatureMeasurement, act_1:switch 	-- illumination -- tri_2:contactSensor, act:imageCapture
# tri_1:temperatureMeasurement, act_1:switch 	-- illumination -- tri_2:contactSensor, act:locationMode
# tri_1:temperatureMeasurement, act_1:switch 	-- illumination -- tri_2:contactSensor, act:momentary
# tri_1:temperatureMeasurement, act_1:switch 	-- illumination -- tri_2:contactSensor, act:number
# tri_1:temperatureMeasurement, act_1:switch 	-- illumination -- tri_2:contactSensor, act:sendAction
# tri_1:temperatureMeasurement, act_1:switch 	-- illumination -- tri_2:contactSensor, act:switch
# tri_1:temperatureMeasurement, act_1:switch 	-- illumination -- tri_2:contactSensor, act:thermostat
# tri_1:temperatureMeasurement, act_1:switch 	-- illumination -- tri_2:switch, act:colorControl
# tri_1:temperatureMeasurement, act_1:switch 	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:temperatureMeasurement, act_1:switch 	-- illumination -- tri_2:switch, act:locationMode
# tri_1:temperatureMeasurement, act_1:switch 	-- illumination -- tri_2:switch, act:number
# tri_1:temperatureMeasurement, act_1:switch 	-- illumination -- tri_2:switch, act:sendAction
# tri_1:temperatureMeasurement, act_1:switch 	-- illumination -- tri_2:switch, act:switch
# tri_1:temperatureMeasurement, act_1:switch 	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:temperatureMeasurement, act_1:switch 	-- illumination -- tri_2:time, act:device.PetFeederShield
# tri_1:temperatureMeasurement, act_1:switch 	-- illumination -- tri_2:time, act:locationMode
# tri_1:temperatureMeasurement, act_1:switch 	-- illumination -- tri_2:time, act:lock
# tri_1:temperatureMeasurement, act_1:switch 	-- illumination -- tri_2:time, act:sendAction
# tri_1:temperatureMeasurement, act_1:switch 	-- illumination -- tri_2:time, act:switch
# tri_1:thermostat, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:colorControl
# tri_1:thermostat, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:imageCapture
# tri_1:thermostat, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:momentary
# tri_1:thermostat, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:number
# tri_1:thermostat, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:sendAction
# tri_1:thermostat, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:switch
# tri_1:thermostat, act_1:switch 	-- illumination -- tri_2:button, act:colorControl
# tri_1:thermostat, act_1:switch 	-- illumination -- tri_2:button, act:locationMode
# tri_1:thermostat, act_1:switch 	-- illumination -- tri_2:button, act:sendAction
# tri_1:thermostat, act_1:switch 	-- illumination -- tri_2:contactSensor, act:alarm
# tri_1:thermostat, act_1:switch 	-- illumination -- tri_2:contactSensor, act:colorControl
# tri_1:thermostat, act_1:switch 	-- illumination -- tri_2:contactSensor, act:imageCapture
# tri_1:thermostat, act_1:switch 	-- illumination -- tri_2:contactSensor, act:locationMode
# tri_1:thermostat, act_1:switch 	-- illumination -- tri_2:contactSensor, act:momentary
# tri_1:thermostat, act_1:switch 	-- illumination -- tri_2:contactSensor, act:number
# tri_1:thermostat, act_1:switch 	-- illumination -- tri_2:contactSensor, act:sendAction
# tri_1:thermostat, act_1:switch 	-- illumination -- tri_2:contactSensor, act:switch
# tri_1:thermostat, act_1:switch 	-- illumination -- tri_2:contactSensor, act:thermostat
# tri_1:thermostat, act_1:switch 	-- illumination -- tri_2:switch, act:colorControl
# tri_1:thermostat, act_1:switch 	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:thermostat, act_1:switch 	-- illumination -- tri_2:switch, act:locationMode
# tri_1:thermostat, act_1:switch 	-- illumination -- tri_2:switch, act:number
# tri_1:thermostat, act_1:switch 	-- illumination -- tri_2:switch, act:sendAction
# tri_1:thermostat, act_1:switch 	-- illumination -- tri_2:switch, act:switch
# tri_1:thermostat, act_1:switch 	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:thermostat, act_1:switch 	-- illumination -- tri_2:time, act:device.PetFeederShield
# tri_1:thermostat, act_1:switch 	-- illumination -- tri_2:time, act:locationMode
# tri_1:thermostat, act_1:switch 	-- illumination -- tri_2:time, act:lock
# tri_1:thermostat, act_1:switch 	-- illumination -- tri_2:time, act:sendAction
# tri_1:thermostat, act_1:switch 	-- illumination -- tri_2:time, act:switch
# tri_1:time, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:colorControl
# tri_1:time, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:imageCapture
# tri_1:time, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:momentary
# tri_1:time, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:number
# tri_1:time, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:sendAction
# tri_1:time, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:switch
# tri_1:time, act_1:switch 	-- illumination -- tri_2:button, act:colorControl
# tri_1:time, act_1:switch 	-- illumination -- tri_2:button, act:locationMode
# tri_1:time, act_1:switch 	-- illumination -- tri_2:button, act:sendAction
# tri_1:time, act_1:switch 	-- illumination -- tri_2:contactSensor, act:alarm
# tri_1:time, act_1:switch 	-- illumination -- tri_2:contactSensor, act:colorControl
# tri_1:time, act_1:switch 	-- illumination -- tri_2:contactSensor, act:imageCapture
# tri_1:time, act_1:switch 	-- illumination -- tri_2:contactSensor, act:locationMode
# tri_1:time, act_1:switch 	-- illumination -- tri_2:contactSensor, act:momentary
# tri_1:time, act_1:switch 	-- illumination -- tri_2:contactSensor, act:number
# tri_1:time, act_1:switch 	-- illumination -- tri_2:contactSensor, act:sendAction
# tri_1:time, act_1:switch 	-- illumination -- tri_2:contactSensor, act:switch
# tri_1:time, act_1:switch 	-- illumination -- tri_2:contactSensor, act:thermostat
# tri_1:time, act_1:switch 	-- illumination -- tri_2:switch, act:colorControl
# tri_1:time, act_1:switch 	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:time, act_1:switch 	-- illumination -- tri_2:switch, act:locationMode
# tri_1:time, act_1:switch 	-- illumination -- tri_2:switch, act:number
# tri_1:time, act_1:switch 	-- illumination -- tri_2:switch, act:sendAction
# tri_1:time, act_1:switch 	-- illumination -- tri_2:switch, act:switch
# tri_1:time, act_1:switch 	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:time, act_1:switch 	-- illumination -- tri_2:time, act:device.PetFeederShield
# tri_1:time, act_1:switch 	-- illumination -- tri_2:time, act:locationMode
# tri_1:time, act_1:switch 	-- illumination -- tri_2:time, act:lock
# tri_1:time, act_1:switch 	-- illumination -- tri_2:time, act:sendAction
# tri_1:time, act_1:switch 	-- illumination -- tri_2:time, act:switch
# tri_1:touchSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:colorControl
# tri_1:touchSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:imageCapture
# tri_1:touchSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:momentary
# tri_1:touchSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:number
# tri_1:touchSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:sendAction
# tri_1:touchSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:switch
# tri_1:touchSensor, act_1:switch 	-- illumination -- tri_2:button, act:colorControl
# tri_1:touchSensor, act_1:switch 	-- illumination -- tri_2:button, act:locationMode
# tri_1:touchSensor, act_1:switch 	-- illumination -- tri_2:button, act:sendAction
# tri_1:touchSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:alarm
# tri_1:touchSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:colorControl
# tri_1:touchSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:imageCapture
# tri_1:touchSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:locationMode
# tri_1:touchSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:momentary
# tri_1:touchSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:number
# tri_1:touchSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:sendAction
# tri_1:touchSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:switch
# tri_1:touchSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:thermostat
# tri_1:touchSensor, act_1:switch 	-- illumination -- tri_2:switch, act:colorControl
# tri_1:touchSensor, act_1:switch 	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:touchSensor, act_1:switch 	-- illumination -- tri_2:switch, act:locationMode
# tri_1:touchSensor, act_1:switch 	-- illumination -- tri_2:switch, act:number
# tri_1:touchSensor, act_1:switch 	-- illumination -- tri_2:switch, act:sendAction
# tri_1:touchSensor, act_1:switch 	-- illumination -- tri_2:switch, act:switch
# tri_1:touchSensor, act_1:switch 	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:touchSensor, act_1:switch 	-- illumination -- tri_2:time, act:device.PetFeederShield
# tri_1:touchSensor, act_1:switch 	-- illumination -- tri_2:time, act:locationMode
# tri_1:touchSensor, act_1:switch 	-- illumination -- tri_2:time, act:lock
# tri_1:touchSensor, act_1:switch 	-- illumination -- tri_2:time, act:sendAction
# tri_1:touchSensor, act_1:switch 	-- illumination -- tri_2:time, act:switch
# tri_1:waterSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:colorControl
# tri_1:waterSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:imageCapture
# tri_1:waterSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:momentary
# tri_1:waterSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:number
# tri_1:waterSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:sendAction
# tri_1:waterSensor, act_1:switch 	-- illumination -- tri_2:accelerationSensor, act:switch
# tri_1:waterSensor, act_1:switch 	-- illumination -- tri_2:button, act:colorControl
# tri_1:waterSensor, act_1:switch 	-- illumination -- tri_2:button, act:locationMode
# tri_1:waterSensor, act_1:switch 	-- illumination -- tri_2:button, act:sendAction
# tri_1:waterSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:alarm
# tri_1:waterSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:colorControl
# tri_1:waterSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:imageCapture
# tri_1:waterSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:locationMode
# tri_1:waterSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:momentary
# tri_1:waterSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:number
# tri_1:waterSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:sendAction
# tri_1:waterSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:switch
# tri_1:waterSensor, act_1:switch 	-- illumination -- tri_2:contactSensor, act:thermostat
# tri_1:waterSensor, act_1:switch 	-- illumination -- tri_2:switch, act:colorControl
# tri_1:waterSensor, act_1:switch 	-- illumination -- tri_2:switch, act:imageCapture
# tri_1:waterSensor, act_1:switch 	-- illumination -- tri_2:switch, act:locationMode
# tri_1:waterSensor, act_1:switch 	-- illumination -- tri_2:switch, act:number
# tri_1:waterSensor, act_1:switch 	-- illumination -- tri_2:switch, act:sendAction
# tri_1:waterSensor, act_1:switch 	-- illumination -- tri_2:switch, act:switch
# tri_1:waterSensor, act_1:switch 	-- illumination -- tri_2:switch, act:switchLevel
# tri_1:waterSensor, act_1:switch 	-- illumination -- tri_2:time, act:device.PetFeederShield
# tri_1:waterSensor, act_1:switch 	-- illumination -- tri_2:time, act:locationMode
# tri_1:waterSensor, act_1:switch 	-- illumination -- tri_2:time, act:lock
# tri_1:waterSensor, act_1:switch 	-- illumination -- tri_2:time, act:sendAction
# tri_1:waterSensor, act_1:switch 	-- illumination -- tri_2:time, act:switch
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:accelerationSensor, act:colorControl
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:accelerationSensor, act:imageCapture
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:accelerationSensor, act:momentary
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:accelerationSensor, act:number
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:accelerationSensor, act:sendAction
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:accelerationSensor, act:switch
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:app, act:alarm
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:app, act:colorControl
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:app, act:doorControl
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:app, act:lock
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:app, act:switch
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:app, act:thermostat
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:beacon, act:lock
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:beacon, act:switch
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:button, act:colorControl
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:button, act:locationMode
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:button, act:sendAction
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:presenceSensor, act:colorControl
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:presenceSensor, act:imageCapture
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:presenceSensor, act:locationMode
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:presenceSensor, act:lock
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:presenceSensor, act:momentary
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:presenceSensor, act:number
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:presenceSensor, act:sendAction
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:presenceSensor, act:switch
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:switch, act:colorControl
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:switch, act:imageCapture
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:switch, act:locationMode
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:switch, act:number
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:switch, act:sendAction
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:switch, act:switch
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:switch, act:switchLevel
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:threeAxis, act:sendAction
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:time, act:device.PetFeederShield
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:time, act:locationMode
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:time, act:lock
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:time, act:sendAction
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:time, act:switch
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:waterSensor, act:colorControl
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:waterSensor, act:sendAction
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:waterSensor, act:switch
# tri_1:accelerationSensor, act_1:switch 	-- lock -- tri_2:waterSensor, act:valve
# tri_1:app, act_1:switch 	-- lock -- tri_2:accelerationSensor, act:colorControl
# tri_1:app, act_1:switch 	-- lock -- tri_2:accelerationSensor, act:imageCapture
# tri_1:app, act_1:switch 	-- lock -- tri_2:accelerationSensor, act:momentary
# tri_1:app, act_1:switch 	-- lock -- tri_2:accelerationSensor, act:number
# ...
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- motion -- tri_2:contactSensor, act:imageCapture
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- motion -- tri_2:contactSensor, act:locationMode
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- motion -- tri_2:contactSensor, act:momentary
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- motion -- tri_2:contactSensor, act:number
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- motion -- tri_2:contactSensor, act:sendAction
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- motion -- tri_2:contactSensor, act:switch
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- motion -- tri_2:contactSensor, act:thermostat
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- motion -- tri_2:motionSensor, act:alarm
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- motion -- tri_2:motionSensor, act:colorControl
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- motion -- tri_2:motionSensor, act:imageCapture
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- motion -- tri_2:motionSensor, act:locationMode
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- motion -- tri_2:motionSensor, act:number
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- motion -- tri_2:motionSensor, act:sendAction
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- motion -- tri_2:motionSensor, act:switch
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- motion -- tri_2:switch, act:colorControl
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- motion -- tri_2:switch, act:imageCapture
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- motion -- tri_2:switch, act:locationMode
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- motion -- tri_2:switch, act:number
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- motion -- tri_2:switch, act:sendAction
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- motion -- tri_2:switch, act:switch
# tri_1:relativeHumidityMeasurement, act_1:switch 	-- motion -- tri_2:switch, act:switchLevel
# tri_1:switch, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:colorControl
# tri_1:switch, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:imageCapture
# tri_1:switch, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:momentary
# tri_1:switch, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:number
# tri_1:switch, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:sendAction
# tri_1:switch, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:switch
# tri_1:switch, act_1:switch 	-- motion -- tri_2:contactSensor, act:alarm
# tri_1:switch, act_1:switch 	-- motion -- tri_2:contactSensor, act:colorControl
# tri_1:switch, act_1:switch 	-- motion -- tri_2:contactSensor, act:imageCapture
# tri_1:switch, act_1:switch 	-- motion -- tri_2:contactSensor, act:locationMode
# tri_1:switch, act_1:switch 	-- motion -- tri_2:contactSensor, act:momentary
# tri_1:switch, act_1:switch 	-- motion -- tri_2:contactSensor, act:number
# tri_1:switch, act_1:switch 	-- motion -- tri_2:contactSensor, act:sendAction
# tri_1:switch, act_1:switch 	-- motion -- tri_2:contactSensor, act:switch
# tri_1:switch, act_1:switch 	-- motion -- tri_2:contactSensor, act:thermostat
# tri_1:switch, act_1:switch 	-- motion -- tri_2:motionSensor, act:alarm
# tri_1:switch, act_1:switch 	-- motion -- tri_2:motionSensor, act:colorControl
# tri_1:switch, act_1:switch 	-- motion -- tri_2:motionSensor, act:imageCapture
# tri_1:switch, act_1:switch 	-- motion -- tri_2:motionSensor, act:locationMode
# tri_1:switch, act_1:switch 	-- motion -- tri_2:motionSensor, act:number
# tri_1:switch, act_1:switch 	-- motion -- tri_2:motionSensor, act:sendAction
# tri_1:switch, act_1:switch 	-- motion -- tri_2:motionSensor, act:switch
# tri_1:switch, act_1:switch 	-- motion -- tri_2:switch, act:colorControl
# tri_1:switch, act_1:switch 	-- motion -- tri_2:switch, act:imageCapture
# tri_1:switch, act_1:switch 	-- motion -- tri_2:switch, act:locationMode
# tri_1:switch, act_1:switch 	-- motion -- tri_2:switch, act:number
# tri_1:switch, act_1:switch 	-- motion -- tri_2:switch, act:sendAction
# tri_1:switch, act_1:switch 	-- motion -- tri_2:switch, act:switch
# tri_1:switch, act_1:switch 	-- motion -- tri_2:switch, act:switchLevel
# tri_1:temperatureMeasurement, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:colorControl
# tri_1:temperatureMeasurement, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:imageCapture
# tri_1:temperatureMeasurement, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:momentary
# tri_1:temperatureMeasurement, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:number
# tri_1:temperatureMeasurement, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:sendAction
# tri_1:temperatureMeasurement, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:switch
# tri_1:temperatureMeasurement, act_1:switch 	-- motion -- tri_2:contactSensor, act:alarm
# tri_1:temperatureMeasurement, act_1:switch 	-- motion -- tri_2:contactSensor, act:colorControl
# tri_1:temperatureMeasurement, act_1:switch 	-- motion -- tri_2:contactSensor, act:imageCapture
# tri_1:temperatureMeasurement, act_1:switch 	-- motion -- tri_2:contactSensor, act:locationMode
# tri_1:temperatureMeasurement, act_1:switch 	-- motion -- tri_2:contactSensor, act:momentary
# tri_1:temperatureMeasurement, act_1:switch 	-- motion -- tri_2:contactSensor, act:number
# tri_1:temperatureMeasurement, act_1:switch 	-- motion -- tri_2:contactSensor, act:sendAction
# tri_1:temperatureMeasurement, act_1:switch 	-- motion -- tri_2:contactSensor, act:switch
# tri_1:temperatureMeasurement, act_1:switch 	-- motion -- tri_2:contactSensor, act:thermostat
# tri_1:temperatureMeasurement, act_1:switch 	-- motion -- tri_2:motionSensor, act:alarm
# tri_1:temperatureMeasurement, act_1:switch 	-- motion -- tri_2:motionSensor, act:colorControl
# tri_1:temperatureMeasurement, act_1:switch 	-- motion -- tri_2:motionSensor, act:imageCapture
# tri_1:temperatureMeasurement, act_1:switch 	-- motion -- tri_2:motionSensor, act:locationMode
# tri_1:temperatureMeasurement, act_1:switch 	-- motion -- tri_2:motionSensor, act:number
# tri_1:temperatureMeasurement, act_1:switch 	-- motion -- tri_2:motionSensor, act:sendAction
# tri_1:temperatureMeasurement, act_1:switch 	-- motion -- tri_2:motionSensor, act:switch
# tri_1:temperatureMeasurement, act_1:switch 	-- motion -- tri_2:switch, act:colorControl
# tri_1:temperatureMeasurement, act_1:switch 	-- motion -- tri_2:switch, act:imageCapture
# tri_1:temperatureMeasurement, act_1:switch 	-- motion -- tri_2:switch, act:locationMode
# tri_1:temperatureMeasurement, act_1:switch 	-- motion -- tri_2:switch, act:number
# tri_1:temperatureMeasurement, act_1:switch 	-- motion -- tri_2:switch, act:sendAction
# tri_1:temperatureMeasurement, act_1:switch 	-- motion -- tri_2:switch, act:switch
# tri_1:temperatureMeasurement, act_1:switch 	-- motion -- tri_2:switch, act:switchLevel
# tri_1:thermostat, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:colorControl
# tri_1:thermostat, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:imageCapture
# tri_1:thermostat, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:momentary
# tri_1:thermostat, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:number
# tri_1:thermostat, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:sendAction
# tri_1:thermostat, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:switch
# tri_1:thermostat, act_1:switch 	-- motion -- tri_2:contactSensor, act:alarm
# tri_1:thermostat, act_1:switch 	-- motion -- tri_2:contactSensor, act:colorControl
# tri_1:thermostat, act_1:switch 	-- motion -- tri_2:contactSensor, act:imageCapture
# tri_1:thermostat, act_1:switch 	-- motion -- tri_2:contactSensor, act:locationMode
# tri_1:thermostat, act_1:switch 	-- motion -- tri_2:contactSensor, act:momentary
# tri_1:thermostat, act_1:switch 	-- motion -- tri_2:contactSensor, act:number
# tri_1:thermostat, act_1:switch 	-- motion -- tri_2:contactSensor, act:sendAction
# tri_1:thermostat, act_1:switch 	-- motion -- tri_2:contactSensor, act:switch
# tri_1:thermostat, act_1:switch 	-- motion -- tri_2:contactSensor, act:thermostat
# tri_1:thermostat, act_1:switch 	-- motion -- tri_2:motionSensor, act:alarm
# tri_1:thermostat, act_1:switch 	-- motion -- tri_2:motionSensor, act:colorControl
# tri_1:thermostat, act_1:switch 	-- motion -- tri_2:motionSensor, act:imageCapture
# tri_1:thermostat, act_1:switch 	-- motion -- tri_2:motionSensor, act:locationMode
# tri_1:thermostat, act_1:switch 	-- motion -- tri_2:motionSensor, act:number
# tri_1:thermostat, act_1:switch 	-- motion -- tri_2:motionSensor, act:sendAction
# tri_1:thermostat, act_1:switch 	-- motion -- tri_2:motionSensor, act:switch
# tri_1:thermostat, act_1:switch 	-- motion -- tri_2:switch, act:colorControl
# tri_1:thermostat, act_1:switch 	-- motion -- tri_2:switch, act:imageCapture
# tri_1:thermostat, act_1:switch 	-- motion -- tri_2:switch, act:locationMode
# tri_1:thermostat, act_1:switch 	-- motion -- tri_2:switch, act:number
# tri_1:thermostat, act_1:switch 	-- motion -- tri_2:switch, act:sendAction
# tri_1:thermostat, act_1:switch 	-- motion -- tri_2:switch, act:switch
# tri_1:thermostat, act_1:switch 	-- motion -- tri_2:switch, act:switchLevel
# tri_1:time, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:colorControl
# tri_1:time, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:imageCapture
# tri_1:time, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:momentary
# tri_1:time, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:number
# tri_1:time, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:sendAction
# tri_1:time, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:switch
# tri_1:time, act_1:switch 	-- motion -- tri_2:contactSensor, act:alarm
# tri_1:time, act_1:switch 	-- motion -- tri_2:contactSensor, act:colorControl
# tri_1:time, act_1:switch 	-- motion -- tri_2:contactSensor, act:imageCapture
# tri_1:time, act_1:switch 	-- motion -- tri_2:contactSensor, act:locationMode
# tri_1:time, act_1:switch 	-- motion -- tri_2:contactSensor, act:momentary
# tri_1:time, act_1:switch 	-- motion -- tri_2:contactSensor, act:number
# tri_1:time, act_1:switch 	-- motion -- tri_2:contactSensor, act:sendAction
# tri_1:time, act_1:switch 	-- motion -- tri_2:contactSensor, act:switch
# tri_1:time, act_1:switch 	-- motion -- tri_2:contactSensor, act:thermostat
# tri_1:time, act_1:switch 	-- motion -- tri_2:motionSensor, act:alarm
# tri_1:time, act_1:switch 	-- motion -- tri_2:motionSensor, act:colorControl
# tri_1:time, act_1:switch 	-- motion -- tri_2:motionSensor, act:imageCapture
# tri_1:time, act_1:switch 	-- motion -- tri_2:motionSensor, act:locationMode
# tri_1:time, act_1:switch 	-- motion -- tri_2:motionSensor, act:number
# tri_1:time, act_1:switch 	-- motion -- tri_2:motionSensor, act:sendAction
# tri_1:time, act_1:switch 	-- motion -- tri_2:motionSensor, act:switch
# tri_1:time, act_1:switch 	-- motion -- tri_2:switch, act:colorControl
# tri_1:time, act_1:switch 	-- motion -- tri_2:switch, act:imageCapture
# tri_1:time, act_1:switch 	-- motion -- tri_2:switch, act:locationMode
# tri_1:time, act_1:switch 	-- motion -- tri_2:switch, act:number
# tri_1:time, act_1:switch 	-- motion -- tri_2:switch, act:sendAction
# tri_1:time, act_1:switch 	-- motion -- tri_2:switch, act:switch
# tri_1:time, act_1:switch 	-- motion -- tri_2:switch, act:switchLevel
# tri_1:touchSensor, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:colorControl
# tri_1:touchSensor, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:imageCapture
# tri_1:touchSensor, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:momentary
# tri_1:touchSensor, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:number
# tri_1:touchSensor, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:sendAction
# tri_1:touchSensor, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:switch
# tri_1:touchSensor, act_1:switch 	-- motion -- tri_2:contactSensor, act:alarm
# tri_1:touchSensor, act_1:switch 	-- motion -- tri_2:contactSensor, act:colorControl
# tri_1:touchSensor, act_1:switch 	-- motion -- tri_2:contactSensor, act:imageCapture
# tri_1:touchSensor, act_1:switch 	-- motion -- tri_2:contactSensor, act:locationMode
# tri_1:touchSensor, act_1:switch 	-- motion -- tri_2:contactSensor, act:momentary
# tri_1:touchSensor, act_1:switch 	-- motion -- tri_2:contactSensor, act:number
# tri_1:touchSensor, act_1:switch 	-- motion -- tri_2:contactSensor, act:sendAction
# tri_1:touchSensor, act_1:switch 	-- motion -- tri_2:contactSensor, act:switch
# tri_1:touchSensor, act_1:switch 	-- motion -- tri_2:contactSensor, act:thermostat
# tri_1:touchSensor, act_1:switch 	-- motion -- tri_2:motionSensor, act:alarm
# tri_1:touchSensor, act_1:switch 	-- motion -- tri_2:motionSensor, act:colorControl
# tri_1:touchSensor, act_1:switch 	-- motion -- tri_2:motionSensor, act:imageCapture
# tri_1:touchSensor, act_1:switch 	-- motion -- tri_2:motionSensor, act:locationMode
# tri_1:touchSensor, act_1:switch 	-- motion -- tri_2:motionSensor, act:number
# tri_1:touchSensor, act_1:switch 	-- motion -- tri_2:motionSensor, act:sendAction
# tri_1:touchSensor, act_1:switch 	-- motion -- tri_2:motionSensor, act:switch
# tri_1:touchSensor, act_1:switch 	-- motion -- tri_2:switch, act:colorControl
# tri_1:touchSensor, act_1:switch 	-- motion -- tri_2:switch, act:imageCapture
# tri_1:touchSensor, act_1:switch 	-- motion -- tri_2:switch, act:locationMode
# tri_1:touchSensor, act_1:switch 	-- motion -- tri_2:switch, act:number
# tri_1:touchSensor, act_1:switch 	-- motion -- tri_2:switch, act:sendAction
# tri_1:touchSensor, act_1:switch 	-- motion -- tri_2:switch, act:switch
# tri_1:touchSensor, act_1:switch 	-- motion -- tri_2:switch, act:switchLevel
# tri_1:waterSensor, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:colorControl
# tri_1:waterSensor, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:imageCapture
# tri_1:waterSensor, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:momentary
# tri_1:waterSensor, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:number
# tri_1:waterSensor, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:sendAction
# tri_1:waterSensor, act_1:switch 	-- motion -- tri_2:accelerationSensor, act:switch
# tri_1:waterSensor, act_1:switch 	-- motion -- tri_2:contactSensor, act:alarm
# tri_1:waterSensor, act_1:switch 	-- motion -- tri_2:contactSensor, act:colorControl
# tri_1:waterSensor, act_1:switch 	-- motion -- tri_2:contactSensor, act:imageCapture
# tri_1:waterSensor, act_1:switch 	-- motion -- tri_2:contactSensor, act:locationMode
# tri_1:waterSensor, act_1:switch 	-- motion -- tri_2:contactSensor, act:momentary
# tri_1:waterSensor, act_1:switch 	-- motion -- tri_2:contactSensor, act:number
# tri_1:waterSensor, act_1:switch 	-- motion -- tri_2:contactSensor, act:sendAction
# tri_1:waterSensor, act_1:switch 	-- motion -- tri_2:contactSensor, act:switch
# tri_1:waterSensor, act_1:switch 	-- motion -- tri_2:contactSensor, act:thermostat
# tri_1:waterSensor, act_1:switch 	-- motion -- tri_2:motionSensor, act:alarm
# tri_1:waterSensor, act_1:switch 	-- motion -- tri_2:motionSensor, act:colorControl
# tri_1:waterSensor, act_1:switch 	-- motion -- tri_2:motionSensor, act:imageCapture
# tri_1:waterSensor, act_1:switch 	-- motion -- tri_2:motionSensor, act:locationMode
# tri_1:waterSensor, act_1:switch 	-- motion -- tri_2:motionSensor, act:number
# tri_1:waterSensor, act_1:switch 	-- motion -- tri_2:motionSensor, act:sendAction
# tri_1:waterSensor, act_1:switch 	-- motion -- tri_2:motionSensor, act:switch
# tri_1:waterSensor, act_1:switch 	-- motion -- tri_2:switch, act:colorControl
# tri_1:waterSensor, act_1:switch 	-- motion -- tri_2:switch, act:imageCapture
# tri_1:waterSensor, act_1:switch 	-- motion -- tri_2:switch, act:locationMode
# tri_1:waterSensor, act_1:switch 	-- motion -- tri_2:switch, act:number
# tri_1:waterSensor, act_1:switch 	-- motion -- tri_2:switch, act:sendAction
# tri_1:waterSensor, act_1:switch 	-- motion -- tri_2:switch, act:switch
# tri_1:waterSensor, act_1:switch 	-- motion -- tri_2:switch, act:switchLevel
