# %% [markdown]
# ## this python script create the correlation between trigger capablity and physical channels

# %%
from gensim.models import Word2Vec, KeyedVectors 
import json   # for read the JSON file
import stanza # Official Stanford NLP Python Library for Many Human Languages
import re 
import numpy as np

# %%
file = open("../1_Intra_app_Analysis/trigger-action.JSON","r") # read all the capability extrapolated from the apps
trigger_action = json.load(file)
print("tot app analysed:",len(trigger_action.keys()))
# Out:
# tot app analysed: 86

# %%
file = open("../1_Intra_app_Analysis/app-description.JSON","r") # need the desription of the analysed apps
app_description = json.load(file)

# %%
# as wrote in the paper "In the end, we check each cluster’s representative keyword and remove
# non-physical-channel related keywords." (cap 4.2 - p 835) so modify and use cluster_pysical_channels_FINAL
file = open("cluster_pysical_channels_FINAL.JSON","r") 
dict_physical_channels = json.load(file)
dict_physical_channels
# Out:
# {'temperature': ['air_conditioner',
#   'ambient',
#   'heater',
#   'sensor',
#   'sensors',
#   'temp',
#   'thermostat',
#   'ventilation',
#   'temperature'],
#  'humidity': ['ambient',
#   'moisture',
#   'temperature',
#   'thermostat',
#   'ventilation',
#   'weather',
#   'humidity'],
#  'illumination': ['appliances',
#   'brightness',
#   'bulbs',
#   'cameras',
#   'candle',
#   'colors',
#   'heater',
#   'light',
#   'lighting',
#   'sirens',
#   'switch',
#   'switches',
#   'lights'],
#  'motion': ['action', 'motion'],
#  'location': ['area', 'hub', 'place', 'location'],
#  'smoke': ['ambient',
#   'fire',
#   'heater',
#   'leaks',
#   'temperature',
#   'thermostat',
#   'ventilation',
#   'carbon_monoxide'],
#  'leakage': ['device',
#   'heater',
#   'leaks',
#   'lever',
#   'sensor',
#   'sensors',
#   'switches',
#   'thermostat',
#   'ventilation',
#   'valve'],
#  'time': ['amount',
#   'anytime',
#   'day',
#   'days',
#   'hour',
#   'minutes',
#   'period',
#   'place',
#   'times',
#   'week',
#   'time'],
#  'locationMode': ['location', 'mode'],
#  'lock': ['door', 'doors', 'lever', 'push', 'turn', 'lock']}

# %%
stanza.download('en')       # This downloads the English models for the neural pipeline
nlp = stanza.Pipeline('en') # This sets up a default neural pipeline in English
model = KeyedVectors.load_word2vec_format('../../../GoogleNews-vectors-negative300.bin', binary=True, limit=100000) # load word2vec pre-trained
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.2.2.json:   0%|   …
# 2021-10-04 16:19:50 INFO: Downloading default packages for language: en (English)...
# 2021-10-04 16:19:53 INFO: File exists: /home/volta/stanza_resources/en/default.zip.
# 2021-10-04 16:19:58 INFO: Finished downloading models and saved to /home/volta/stanza_resources.
# 2021-10-04 16:19:58 INFO: Loading these models for language: en (English):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | combined  |
# | pos       | combined  |
# | lemma     | combined  |
# | depparse  | combined  |
# | sentiment | sstplus   |
# | ner       | ontonotes |
# =========================
#
# 2021-10-04 16:19:58 INFO: Use device: cpu
# 2021-10-04 16:19:58 INFO: Loading: tokenize
# 2021-10-04 16:19:58 INFO: Loading: pos
# 2021-10-04 16:19:59 INFO: Loading: lemma
# 2021-10-04 16:19:59 INFO: Loading: depparse
# 2021-10-04 16:20:00 INFO: Loading: sentiment
# 2021-10-04 16:20:00 INFO: Loading: ner
# 2021-10-04 16:20:02 INFO: Done loading processors!

# %%
list_all_capabilities = []
for app in trigger_action.keys():         # for every app analysed
    for trigger_cap in trigger_action[app].keys():      # for every trigger channel of that app
            for action in trigger_action[app][trigger_cap]: # for every action 
                action_cap = action[0]
                if not trigger_cap in list_all_capabilities: # if not duplicate
                    list_all_capabilities.append(trigger_cap)
                if not action_cap in list_all_capabilities:
                    list_all_capabilities.append(action_cap)

list_all_capabilities.sort()
list_all_capabilities
# Out:
# ['accelerationSensor',
#  'alarm',
#  'app',
#  'beacon',
#  'button',
#  'carbonMonoxideDetector',
#  'colorControl',
#  'contactSensor',
#  'device.PetFeederShield',
#  'device.jawboneUser',
#  'doorControl',
#  'illuminanceMeasurement',
#  'imageCapture',
#  'location',
#  'locationMode',
#  'lock',
#  'momentary',
#  'motionSensor',
#  'musicPlayer',
#  'number',
#  'powerMeter',
#  'presenceSensor',
#  'relativeHumidityMeasurement',
#  'sendAction',
#  'smokeDetector',
#  'switch',
#  'switchLevel',
#  'temperatureMeasurement',
#  'thermostat',
#  'threeAxis',
#  'time',
#  'touchSensor',
#  'valve',
#  'waterSensor']

# %%
# function that map the capability to string
def cap2string(capability):
    switcher = {
        'accelerationSensor': "acceleration",
        'alarm': "alarm",
        'app': "app",
        'beacon': "beacon",
        'button': "button",
        'carbonMonoxideDetector': "carbon_monoxide",
        'colorControl': "color",
        'contactSensor': "contact",
        'doorControl': "door control",
        'illuminanceMeasurement':"illumination",
        'imageCapture': "image capture",
        'location':"location",
        'momentary': "momentary",
        'motionSensor':"motion ",
        'musicPlayer': "music player",
        'powerMeter':"power",
        'presenceSensor': "presence",
        'relativeHumidityMeasurement': "relative humidity ",
        'smokeDetector': "smoke",
        'switch': "switch",
        'switchLevel': "switch level",
        'temperatureMeasurement':"temperature",
        'thermostat': "thermostat",
        'threeAxis':"three axis",
        'touchSensor':"touch",
        'valve':"valve",
        'waterSensor':"water sensor",
        'device.PetFeederShield':"pet feeder shield",
        'device.jawboneUser':"jawbone user",
        'number': "number",
        
        'lock':"lock",
        'locationMode':"locationMode",
        'sendAction':"sendAction",
        'time':"time"
    }
    return switcher.get(capability, f"capabliti not found: {capability}")

# %%
list_string_capabilities = []
for cap in list_all_capabilities:
    list_string_capabilities.append(cap2string(cap))
    
list_string_capabilities
# Out:
# ['acceleration',
#  'alarm',
#  'app',
#  'beacon',
#  'button',
#  'carbon_monoxide',
#  'color',
#  'contact',
#  'pet feeder shield',
#  'jawbone user',
#  'door control',
#  'illumination',
#  'image capture',
#  'location',
#  'locationMode',
#  'lock',
#  'momentary',
#  'motion ',
#  'music player',
#  'number',
#  'power',
#  'presence',
#  'relative humidity ',
#  'sendAction',
#  'smoke',
#  'switch',
#  'switch level',
#  'temperature',
#  'thermostat',
#  'three axis',
#  'time',
#  'touch',
#  'valve',
#  'water sensor']

# %%
# now correlate every trigger/action capability to its own channel
words_pattern = '[a-zA-Z_]+'
cap_to_physical_channel = {"temperature":[], "humidity":[], "illumination":[], "motion":[], "location":[], 
                           "smoke":[], "leakage":[], "time":[], "locationMode":[], "lock":[]}

for cap in list_string_capabilities: # analyse every cappability (a capability could have more word inside)
    keywords = [] # keywords found inside app capability
    keywords = re.findall(words_pattern, cap, flags=re.IGNORECASE) # extrapolate the words from the capability
    print(keywords)
    
    if "time" in keywords:
        cap_to_physical_channel["time"].append("time")
        
    elif "locationMode" in keywords:
        cap_to_physical_channel["locationMode"].append("locationMode")
        
    elif "lock" in keywords:
        cap_to_physical_channel["lock"].append("lock")
        
    else:
        
        clean_keywords = [] # find what words can be really processed by word2vec
        for i in range(len(keywords)):                   # for every keyword exstracted
            try:
                model[keywords[i]]                       # check Word2Vec
                clean_keywords.append(keywords[i])       # if can apply word2vec save it
            except KeyError as err:
                print("handling Error: ", err)           # some words can not be processed by Word2Vec

        print(cap,"-", clean_keywords)        

        similarity_list = {} # list made by 
        if len(clean_keywords) == 0: # case there aren't any NN keyword inside that app description (strange)
            print(f"!!error!!")

        else:
            if len(clean_keywords) == 1: # case there are only 1 keyword inside capability
                for key in dict_physical_channels.keys(): # check for every physical channel
                    similarity_temp = 0
                    for channel_NN in dict_physical_channels[key]: # for every keyword inside the channel cluster
                        similarity_temp += model.similarity(clean_keywords[0],channel_NN)
                    # divide by the number of cluster keywords --> result: the mean of similarity
                    similarity_list[key] = (similarity_temp/len(dict_physical_channels[key]))*100

            else: # case there are more than 1 keyword inside tcapability
                for key in dict_physical_channels.keys(): # check for every physical channel
                    similarity_partial = 0
                    for keyword in clean_keywords: # for every keyword NN extracted from description
                        similarity_temp = 0
                        for channel_NN in dict_physical_channels[key]:  # for every keyword inside the channel cluster
                            #print(keyword,channel_NN,"\t", model.similarity(keyword,channel_NN))
                            similarity_temp += model.similarity(keyword,channel_NN)
                         # divide by the number of cluster keywords --> result: the mean of similarity (given by only 1 NN)
                        similarity_temp = similarity_temp/len(dict_physical_channels[key])
                        similarity_partial += similarity_temp
                    #print("this keyword for ",key,"has got a level", similarity_partial/len(clean_keywords))
                    similarity_list[key] = (similarity_partial/len(clean_keywords))*100

            print(similarity_list)
            # now find the highest physical channel association 
            channel_association = ""
            max_value = 0
            for physical_channel in similarity_list.keys():
                if (similarity_list[physical_channel] > max_value):
                    max_value = similarity_list[physical_channel]
                    channel_association = physical_channel

            print("most similar:", channel_association, max_value, "\n")
            cap_to_physical_channel[channel_association].append(cap)

cap_to_physical_channel
# Out:
# ['acceleration']
# acceleration - ['acceleration']
# {'temperature': 15.70754283004337, 'humidity': 12.749960379941122, 'illumination': 10.737502356418052, 'motion': 20.86850106716156, 'location': 3.6133636720478535, 'smoke': 11.787985498085618, 'leakage': 18.211312741041183, 'time': 10.315930453891104, 'locationMode': 13.713190518319607, 'lock': 14.81396631958584}
# most similar: motion 20.86850106716156
#
# ['alarm']
# alarm - ['alarm']
# {'temperature': 23.725714741481674, 'humidity': 18.93985771707126, 'illumination': 22.08550635438699, 'motion': 6.232286244630814, 'location': 7.038984447717667, 'smoke': 26.57714392989874, 'leakage': 23.767891973257065, 'time': 5.714066550585399, 'locationMode': 11.390898749232292, 'lock': 16.503637780745827}
# most similar: smoke 26.57714392989874
#
# ['app']
# app - ['app']
# {'temperature': 11.912914701840943, 'humidity': 9.154791444806117, 'illumination': 7.8958931522300615, 'motion': 3.794695157557726, 'location': 12.686729431152344, 'smoke': 6.540941452840343, 'leakage': 15.044327080249786, 'time': 10.667778619311074, 'locationMode': 23.382367193698883, 'lock': 6.486765419443448}
# most similar: locationMode 23.382367193698883
#
# ['beacon']
# beacon - ['beacon']
# {'temperature': 10.032693457065358, 'humidity': 8.966685884765216, 'illumination': 19.514000229537487, 'motion': 1.4528763946145773, 'location': 18.3031152933836, 'smoke': 9.097940009087324, 'leakage': 13.134421296417715, 'time': 2.5572560431266376, 'locationMode': 14.448393508791924, 'lock': 11.102581582963467}
# most similar: illumination 19.514000229537487
#
# ['button']
# button - ['button']
# {'temperature': 19.84432049923473, 'humidity': 15.209851094654628, 'illumination': 18.999299578941788, 'motion': 7.418578490614891, 'location': 6.610615004319698, 'smoke': 13.903458253480494, 'leakage': 25.69998078048229, 'time': 9.844772369516166, 'locationMode': 26.380472630262375, 'lock': 25.337154666582745}
# most similar: locationMode 26.380472630262375
#
# ['carbon_monoxide']
# carbon_monoxide - ['carbon_monoxide']
# {'temperature': 32.10171427991655, 'humidity': 34.205702798707144, 'illumination': 17.566304818655436, 'motion': 2.0187013782560825, 'location': 4.60541183128953, 'smoke': 44.8433268815279, 'leakage': 24.632012583315372, 'time': 6.751353530721231, 'locationMode': 6.996669992804527, 'lock': 5.4968275129795074}
# most similar: smoke 44.8433268815279
#
# ['color']
# color - ['color']
# {'temperature': 14.252720235122574, 'humidity': 17.651129088231496, 'illumination': 24.03036768619831, 'motion': 8.416065573692322, 'location': 6.697256444022059, 'smoke': 10.474345297552645, 'leakage': 9.702148335054517, 'time': 5.955278859685429, 'locationMode': 16.91184490919113, 'lock': 4.478995470951}
# most similar: illumination 24.03036768619831
#
# ['contact']
# contact - ['contact']
# {'temperature': 7.063706701026401, 'humidity': 6.805157881795562, 'illumination': 6.18118135115275, 'motion': 9.540395438671112, 'location': 9.781561326235533, 'smoke': 9.02009839846869, 'leakage': 8.519770633429289, 'time': 4.7318451275879685, 'locationMode': 9.464890381786972, 'lock': 10.765504091978073}
# most similar: lock 10.765504091978073
#
# ['pet', 'feeder', 'shield']
# pet feeder shield - ['pet', 'feeder', 'shield']
# {'temperature': 9.036603169860664, 'humidity': 8.25665960132721, 'illumination': 8.656376510864504, 'motion': 5.849858249227205, 'location': 11.049783932200324, 'smoke': 7.988124682500104, 'leakage': 11.088952683106374, 'time': 3.33923721989391, 'locationMode': 7.882325027215605, 'lock': 11.646824568096132}
# most similar: lock 11.646824568096132
#
# ['jawbone', 'user']
# jawbone user - ['jawbone', 'user']
# {'temperature': 11.219340769781008, 'humidity': 8.348567604220339, 'illumination': 5.0719905805845675, 'motion': 3.172877267934382, 'location': 7.740316726267338, 'smoke': 6.878717947984114, 'leakage': 13.987255226820707, 'time': 3.8564029297876083, 'locationMode': 10.835594031959772, 'lock': 6.168170366436243}
# most similar: leakage 13.987255226820707
#
# ['door', 'control']
# door control - ['door', 'control']
# {'temperature': 12.512304726988077, 'humidity': 10.117706004530191, 'illumination': 9.706251677842095, 'motion': 6.894458690658212, 'location': 9.373103058896959, 'smoke': 11.977355869021267, 'leakage': 15.54678738117218, 'time': 9.827778702178462, 'locationMode': 11.586866900324821, 'lock': 31.008866243064404}
# most similar: lock 31.008866243064404
#
# ['illumination']
# illumination - ['illumination']
# {'temperature': 27.296942306889427, 'humidity': 27.25540889160974, 'illumination': 35.42103635577055, 'motion': 10.320490226149559, 'location': 7.204497326165438, 'smoke': 23.54616643860936, 'leakage': 22.31152795255184, 'time': 2.3576736720067193, 'locationMode': 18.199537694454193, 'lock': 3.0715077882632613}
# most similar: illumination 35.42103635577055
#
# ['image', 'capture']
# image capture - ['image', 'capture']
# {'temperature': 6.819047239453842, 'humidity': 5.614517955109477, 'illumination': 9.964663157454478, 'motion': 10.130544938147068, 'location': 10.80556996166706, 'smoke': 4.805679913260974, 'leakage': 8.13531359191984, 'time': 4.039358075665818, 'locationMode': 15.75328465551138, 'lock': 7.499134773388505}
# most similar: locationMode 15.75328465551138
#
# ['location']
# location - ['location']
# {'temperature': 14.813812656535042, 'humidity': 15.458477288484573, 'illumination': 8.981854310975624, 'motion': 7.57470540702343, 'location': 53.93345132470131, 'smoke': 12.50542625784874, 'leakage': 12.997910305857657, 'time': 14.36493064869534, 'locationMode': 54.88940477371216, 'lock': 8.556625091781218}
# most similar: locationMode 54.88940477371216
#
# ['locationMode']
# ['lock']
# ['momentary']
# momentary - ['momentary']
# {'temperature': 10.0258673230807, 'humidity': 7.408315954463822, 'illumination': 14.147354977635237, 'motion': 11.905237659811974, 'location': 0.7951559033244848, 'smoke': 8.26832412276417, 'leakage': 13.220478110015394, 'time': 11.398976330052722, 'locationMode': 10.013522394001484, 'lock': 8.421709543714922}
# most similar: illumination 14.147354977635237
#
# ['motion']
# motion  - ['motion']
# {'temperature': 11.804073510898485, 'humidity': 8.344903508467334, 'illumination': 11.821971618785309, 'motion': 65.6542420387268, 'location': 1.4803698402829468, 'smoke': 7.871510158292949, 'leakage': 14.322251453995705, 'time': 4.369432182813233, 'locationMode': 16.526607796549797, 'lock': 7.912684231996536}
# most similar: motion 65.6542420387268
#
# ['music', 'player']
# music player - ['music', 'player']
# {'temperature': 5.733776863457428, 'humidity': 6.232657834854243, 'illumination': 8.194376691244543, 'motion': 8.520890027284622, 'location': 9.018041426315904, 'smoke': 5.243899193010293, 'leakage': 4.370768639491871, 'time': 7.100089800290086, 'locationMode': 8.299126103520393, 'lock': 4.068792813147107}
# most similar: location 9.018041426315904
#
# ['number']
# number - ['number']
# {'temperature': 3.6931645539071827, 'humidity': 6.411118632448572, 'illumination': 3.882662565089189, 'motion': 4.91683054715395, 'location': 12.536590732634068, 'smoke': 4.99077879358083, 'leakage': 3.2524148700758815, 'time': 14.067548047751188, 'locationMode': 9.298316412605345, 'lock': 8.04963658253352}
# most similar: time 14.067548047751188
#
# ['power']
# power - ['power']
# {'temperature': 13.255986819664637, 'humidity': 11.899712256022863, 'illumination': 16.754162927659657, 'motion': 10.828366875648499, 'location': 7.49221327714622, 'smoke': 12.728940602391958, 'leakage': 12.828291431069374, 'time': 9.62824174626307, 'locationMode': 9.291708748787642, 'lock': 12.483482497433823}
# most similar: illumination 16.754162927659657
#
# ['presence']
# presence - ['presence']
# {'temperature': 2.822093691146519, 'humidity': 6.771732121706009, 'illumination': 5.583257840659757, 'motion': 8.988641016185284, 'location': 19.022600166499615, 'smoke': 4.292852850630879, 'leakage': 1.0001251194626093, 'time': 3.5035073100351095, 'locationMode': 8.82914699614048, 'lock': 6.703310102845232}
# most similar: location 19.022600166499615
#
# ['relative', 'humidity']
# relative humidity  - ['relative', 'humidity']
# {'temperature': 20.00609419127512, 'humidity': 30.948637533999445, 'illumination': 10.892696495060452, 'motion': 1.578325778245926, 'location': 10.366901918314397, 'smoke': 20.059085918182973, 'leakage': 12.239560290472582, 'time': 9.658305956558747, 'locationMode': 9.94157218374312, 'lock': 4.658990406702893}
# most similar: humidity 30.948637533999445
#
# ['sendAction']
# handling Error:  "Key 'sendAction' not present"
# sendAction - []
# !!error!!
# ['smoke']
# smoke - ['smoke']
# {'temperature': 17.206701636314392, 'humidity': 21.463980312858308, 'illumination': 17.111792415380478, 'motion': 6.924749910831451, 'location': 7.389275578316301, 'smoke': 28.311998210847378, 'leakage': 14.276960790157316, 'time': 6.06484672435644, 'locationMode': 1.0573692619800568, 'lock': 11.792985536158085}
# most similar: smoke 28.311998210847378
#
# ['switch']
# switch - ['switch']
# {'temperature': 13.41797612193558, 'humidity': 9.122311403708798, 'illumination': 27.95158292238529, 'motion': 16.613131761550903, 'location': 6.171486095990986, 'smoke': 11.476985749322921, 'leakage': 21.279598474502563, 'time': 5.737636730455878, 'locationMode': 15.632269904017448, 'lock': 25.15283276637395}
# most similar: illumination 27.95158292238529
#
# ['switch', 'level']
# switch level - ['switch', 'level']
# {'temperature': 11.60382290577723, 'humidity': 11.122211639303714, 'illumination': 17.068225868905966, 'motion': 14.761917758733034, 'location': 9.596193832112476, 'smoke': 11.13394308486022, 'leakage': 14.624420534819366, 'time': 12.300111260794273, 'locationMode': 16.087515279650688, 'lock': 18.281646631658077}
# most similar: lock 18.281646631658077
#
# ['temperature']
# temperature - ['temperature']
# {'temperature': 46.67270216676924, 'humidity': 54.74881827831268, 'illumination': 20.24020684453157, 'motion': 8.94216075539589, 'location': 12.009405717253685, 'smoke': 42.166913114488125, 'leakage': 29.034086167812344, 'time': 10.292984172701836, 'locationMode': 17.848211526870728, 'lock': 6.884511715422074}
# most similar: humidity 54.74881827831268
#
# ['thermostat']
# thermostat - ['thermostat']
# {'temperature': 46.93136165539424, 'humidity': 42.99933399472918, 'illumination': 29.157866824131744, 'motion': 5.126686301082373, 'location': 1.260065846145153, 'smoke': 41.65754392743111, 'leakage': 37.7130526304245, 'time': 5.627157852392306, 'locationMode': 15.35276509821415, 'lock': 19.43939526875814}
# most similar: temperature 46.93136165539424
#
# ['three', 'axis']
# three axis - ['three', 'axis']
# {'temperature': 6.547233260547122, 'humidity': 4.734012408048979, 'illumination': 8.041618954247006, 'motion': 10.571863315999508, 'location': 8.565348386764526, 'smoke': 4.320049192756414, 'leakage': 8.308135274564847, 'time': 11.625044702139514, 'locationMode': 10.496157314628363, 'lock': 9.977786283707246}
# most similar: time 11.625044702139514
#
# ['time']
# ['touch']
# touch - ['touch']
# {'temperature': 10.386196109983656, 'humidity': 11.797624081373215, 'illumination': 14.376247760195, 'motion': 11.300327256321907, 'location': 12.100362777709961, 'smoke': 8.058438543230295, 'leakage': 11.609852872788906, 'time': 9.835802081347952, 'locationMode': 14.597614109516144, 'lock': 19.48333022495111}
# most similar: lock 19.48333022495111
#
# ['valve']
# valve - ['valve']
# {'temperature': 31.537974377473194, 'humidity': 23.227060266903468, 'illumination': 14.73101330204652, 'motion': 4.644567146897316, 'location': 6.687101302668452, 'smoke': 29.342244192957878, 'leakage': 43.10829609632492, 'time': 2.5843444936485453, 'locationMode': 10.423966683447361, 'lock': 20.447061086694397}
# most similar: leakage 43.10829609632492
#
# ['water', 'sensor']
# water sensor - ['water', 'sensor']
# {'temperature': 33.59959895412127, 'humidity': 28.79381829074451, 'illumination': 19.423854085974966, 'motion': 11.835236102342606, 'location': 12.632809270871803, 'smoke': 25.838176254183054, 'leakage': 32.11501318961382, 'time': 6.5369780725714834, 'locationMode': 16.432925313711166, 'lock': 8.446930473049482}
# most similar: temperature 33.59959895412127
# {'temperature': ['thermostat', 'water sensor'],
#  'humidity': ['relative humidity ', 'temperature'],
#  'illumination': ['beacon',
#   'color',
#   'illumination',
#   'momentary',
#   'power',
#   'switch'],
#  'motion': ['acceleration', 'motion '],
#  'location': ['music player', 'presence'],
#  'smoke': ['alarm', 'carbon_monoxide', 'smoke'],
#  'leakage': ['jawbone user', 'valve'],
#  'time': ['number', 'three axis', 'time'],
#  'locationMode': ['app',
#   'button',
#   'image capture',
#   'location',
#   'locationMode'],
#  'lock': ['contact',
#   'pet feeder shield',
#   'door control',
#   'lock',
#   'switch level',
#   'touch']}

# %%
cap_to_physical_channel
# Out:
# {'temperature': ['thermostat', 'water sensor'],
#  'humidity': ['relative humidity ', 'temperature'],
#  'illumination': ['beacon',
#   'color',
#   'illumination',
#   'momentary',
#   'power',
#   'switch'],
#  'motion': ['acceleration', 'motion '],
#  'location': ['music player', 'presence'],
#  'smoke': ['alarm', 'carbon_monoxide', 'smoke'],
#  'leakage': ['jawbone user', 'valve'],
#  'time': ['number', 'three axis', 'time'],
#  'locationMode': ['app',
#   'button',
#   'image capture',
#   'location',
#   'locationMode'],
#  'lock': ['contact',
#   'pet feeder shield',
#   'door control',
#   'lock',
#   'switch level',
#   'touch']}

# %%
with open("set_of_capability_related_physical_channels.JSON","w") as outfile:
    json.dump(cap_to_physical_channel, outfile)

# %% [markdown]
# ## analysis of the number of trigger-capability and action-capability

# %%
dict_actions_related={"temperature":[], "humidity":[], "illumination":[], "location":[],
                          "motion":[], "smoke":[], "leakage":[], "time":[], "locationMode":[], "lock":[]}
dict_trigger_related={"temperature":[], "humidity":[], "illumination":[], "location":[],
                          "motion":[], "smoke":[], "leakage":[], "time":[], "locationMode":[], "lock":[]}
                
for app in trigger_action.keys(): # for every app where I can extrapolate info
    for trigger_cap in trigger_action[app].keys(): # for every app trigger capability
        # now I search all action capabilities
        for actions in trigger_action[app][trigger_cap]: # for every action correlated to that trigger capability
            string_action_capability = cap2string(actions[0]) # save the action capability and convert it to string
            # save the action capability
            for channel in cap_to_physical_channel.keys(): # for every physical channel
                if string_action_capability in cap_to_physical_channel[channel]: # find if there is that action capability
                    dict_actions_related[channel].append(string_action_capability) # if there is save the action capability 
        
        # save all trigger capability
        string_trigger_capability = cap2string(trigger_cap)
        for channel in cap_to_physical_channel.keys(): # for every physical channel
            if string_trigger_capability in cap_to_physical_channel[channel]: # find if there is that action capability
                    dict_trigger_related[channel].append(string_trigger_capability) # if there is save the action capability 
        
dict_trigger_related
# Out:
# {'temperature': ['water sensor',
#   'water sensor',
#   'water sensor',
#   'thermostat',
#   'thermostat',
#   'water sensor',
#   'water sensor',
#   'thermostat'],
#  'humidity': ['relative humidity ',
#   'temperature',
#   'temperature',
#   'temperature',
#   'relative humidity ',
#   'temperature',
#   'temperature'],
#  'illumination': ['beacon',
#   'switch',
#   'power',
#   'power',
#   'switch',
#   'switch',
#   'illumination',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch'],
#  'location': ['presence',
#   'presence',
#   'presence',
#   'presence',
#   'presence',
#   'presence',
#   'presence',
#   'presence',
#   'presence',
#   'presence',
#   'presence',
#   'presence',
#   'presence',
#   'presence',
#   'presence',
#   'presence'],
#  'motion': ['motion ',
#   'motion ',
#   'motion ',
#   'motion ',
#   'motion ',
#   'motion ',
#   'acceleration',
#   'acceleration',
#   'motion ',
#   'acceleration',
#   'acceleration',
#   'motion ',
#   'acceleration',
#   'motion ',
#   'acceleration',
#   'motion ',
#   'acceleration',
#   'motion ',
#   'motion ',
#   'motion ',
#   'motion ',
#   'motion ',
#   'acceleration',
#   'motion ',
#   'acceleration',
#   'motion '],
#  'smoke': ['smoke', 'smoke', 'alarm', 'smoke', 'carbon_monoxide'],
#  'leakage': ['jawbone user', 'jawbone user'],
#  'time': ['time',
#   'time',
#   'time',
#   'three axis',
#   'time',
#   'time',
#   'time',
#   'time',
#   'time',
#   'time',
#   'time',
#   'time'],
#  'locationMode': ['location',
#   'app',
#   'location',
#   'app',
#   'button',
#   'app',
#   'location',
#   'app',
#   'location',
#   'location',
#   'app',
#   'button',
#   'app',
#   'button',
#   'app',
#   'button',
#   'app',
#   'location'],
#  'lock': ['contact',
#   'contact',
#   'contact',
#   'contact',
#   'contact',
#   'contact',
#   'contact',
#   'touch',
#   'contact',
#   'contact',
#   'contact',
#   'contact',
#   'contact',
#   'contact',
#   'contact',
#   'contact',
#   'contact',
#   'contact',
#   'contact',
#   'contact',
#   'contact',
#   'contact']}

# %%
dict_actions_related
# Out:
# {'temperature': ['thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat',
#   'thermostat'],
#  'humidity': [],
#  'illumination': ['switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'color',
#   'color',
#   'color',
#   'color',
#   'color',
#   'color',
#   'switch',
#   'switch',
#   'color',
#   'color',
#   'color',
#   'color',
#   'color',
#   'color',
#   'color',
#   'color',
#   'color',
#   'color',
#   'color',
#   'color',
#   'color',
#   'color',
#   'color',
#   'color',
#   'color',
#   'color',
#   'switch',
#   'switch',
#   'momentary',
#   'momentary',
#   'momentary',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'color',
#   'color',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch',
#   'switch'],
#  'location': ['music player', 'music player', 'music player', 'music player'],
#  'motion': [],
#  'smoke': ['alarm',
#   'alarm',
#   'alarm',
#   'alarm',
#   'alarm',
#   'alarm',
#   'alarm',
#   'alarm'],
#  'leakage': ['valve'],
#  'time': ['number', 'number', 'number', 'number', 'number'],
#  'locationMode': ['locationMode',
#   'locationMode',
#   'locationMode',
#   'locationMode',
#   'locationMode',
#   'image capture',
#   'image capture',
#   'image capture',
#   'image capture',
#   'image capture',
#   'locationMode',
#   'locationMode',
#   'locationMode',
#   'locationMode'],
#  'lock': ['lock',
#   'lock',
#   'pet feeder shield',
#   'lock',
#   'lock',
#   'lock',
#   'lock',
#   'lock',
#   'lock',
#   'door control',
#   'lock',
#   'door control',
#   'switch level',
#   'lock']}

# %%
action_related = []
for key in dict_actions_related.keys():
    action_related.append(len(dict_actions_related[key]))
action_related = np.array(action_related)
action_related
# Out:
# array([22,  0, 99,  4,  0,  8,  1,  5, 14, 14])

# %%
trigger_related = []
for key in dict_trigger_related.keys():
    trigger_related.append(len(dict_trigger_related[key]))
trigger_related = np.array(trigger_related)
trigger_related
# Out:
# array([ 8,  7, 13, 16, 26,  5,  2, 12, 18, 22])

# %%
import matplotlib.pyplot as plt

x = ["Temperature","Humidity", "Illumination", "Location", "Motion", "Smoke", "Leakage", "Time", "LocationMode", "Lock"]
x_pos = np.arange(len(x))
plt.figure(figsize=[15, 5])
plt.bar(x_pos, trigger_related, align='center')
plt.xticks(x_pos, x)
plt.ylabel('Amount of interactions')
plt.xlabel('Channel type')
plt.title('Trigger-related Channel analysis')
plt.show()

# %%
x_pos = np.arange(len(x))
plt.figure(figsize=[15, 5])
plt.bar(x_pos, action_related, align='center')
plt.xticks(x_pos, x)
plt.ylabel('Amount of interactions')
plt.xlabel('Channel type')
plt.title('Action-related Channel analysis')
plt.show()
